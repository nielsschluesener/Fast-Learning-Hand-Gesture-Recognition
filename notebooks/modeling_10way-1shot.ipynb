# %% [markdown]
# #Environment configuration

# %% [markdown]
# Install packages.

# %%
#Don't run this code unless you really want to install the packages.
#!pip install alive-progress -q
#!pip install optuna -q
# Out:
#      |████████████████████████████████| 80 kB 4.7 MB/s
#      |████████████████████████████████| 207 kB 17.4 MB/s
#   Building wheel for grapheme (setup.py) ... done
#      |████████████████████████████████| 308 kB 5.4 MB/s
#      |████████████████████████████████| 81 kB 5.4 MB/s
#      |████████████████████████████████| 209 kB 58.1 MB/s
#      |████████████████████████████████| 78 kB 6.8 MB/s
#      |████████████████████████████████| 112 kB 48.7 MB/s
#      |████████████████████████████████| 146 kB 56.8 MB/s
#      |████████████████████████████████| 49 kB 5.0 MB/s
#   Building wheel for pyperclip (setup.py) ... done

# %% [markdown]
# Import packages.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR

import optuna
from optuna.trial import TrialState

import numpy as np
import os
import math
import argparse
import random
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import itertools
import shutil

from google.colab import drive
from alive_progress import alive_bar
from tabulate import tabulate
import time

# %% [markdown]
# Mount and config GDrive & paths.

# %%
drive.mount('/content/drive')
gdrive = '/content/drive/My Drive/ml_projects/STRHANGE/'

keypoints_path = gdrive + '/data/JESTER/extracted/'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Experiment configuration

# %%
N_WAY = 10
K_SHOT = 1

# %% [markdown]
# # Set up functions and classes

# %% [markdown]
# This section contains all functions and classes that are important for the remainder of this notebook. An explanation of the functions and their parameters & outputs can be found in the function headers.

# %% [markdown]
# #### Model training

# %%
def run_training(task_param, input_param, model_param, training_param):
  """
  Training Function - performs a single model training for a set of parameters
  Args:
    task_param (dict): task-related parameters
    input_param (dict): input-related parameters
    model_param (dict): model-related parameters
    training_param (dict): training-related paramaters
  Returns:
    logging (pd.dataframe): dataframe with user configurated logging information on the training-history
  """

  ### PARAMETER UNPACKING AND INITIALIZATION ###
  print('Initializing training...\n')

  #task-parameters
  SUPPORT_NUM_PER_CLASS = task_param['support_num_per_class'] 
  QUERY_NUM_PER_CLASS = task_param['query_num_per_class']  
  NUM_CLASSES = task_param['num_classes']  

  #input-parameters
  SEQUENCE_LENGTH = input_param['sequence_length']
  FEATURE_LENGTH = input_param['feature_length'] 

  #model-parameters
  NUM_LSTM_LAYER_ENCODER = model_param['num_lstm_layer_encoder']
  NUM_UNITS_LSTM_ENCODER = model_param['num_units_lstm_encoder']
  NUM_LSTM_LAYER_RELATIONNET = model_param['num_lstm_layer_relationnet']
  NUM_UNITS_LSTM_RELATIONNET = model_param['num_units_lstm_relationnet']
  NUM_UNITS_FC_RELU = model_param['num_units_fc_relu']

  #training-parameters
  LEARNING_RATE = training_param['learning_rate']
  LEARNING_RATE_SCHEDULE_RATE = training_param['learning_rate_schedule_rate']
  NUM_TRAIN_EPISODES = training_param['num_train_episodes']
  UPDATE_AND_EVAL_RATE = training_param['update_and_eval_rate']
  NUM_EVAL_EPISODES = training_param['num_eval_episodes']
  SAVE_PATH = training_param['save_path']
  SAVE_LOGGING = training_param['save_logging']
  SAVE_ALL = training_param['save_all']
  SAVE_BEST = training_param['save_best']
  TUNING_RUN = training_param['tuning_run']
  trial = training_param['trial']

  if NUM_TRAIN_EPISODES % UPDATE_AND_EVAL_RATE != 0:
    raise ValueError(f'Invalid Parameters: UPDATE_AND_EVAL_RATE must be a multiple of NUM_TRAIN_EPISODES.')

  print('  Parameters accepted and set.')

  ### MODEL INITIALIZATION ###
  feature_encoder = LSTMEncoder(FEATURE_LENGTH, NUM_UNITS_LSTM_ENCODER, NUM_LSTM_LAYER_ENCODER).to(device)
  print('  Feature encoder intialized, initial weights set.')
  relation_network = RelationNetwork(NUM_UNITS_LSTM_ENCODER*2, NUM_UNITS_LSTM_RELATIONNET, NUM_UNITS_FC_RELU, NUM_LSTM_LAYER_RELATIONNET).to(device) 
  print('  Relation network intialized, initial weights set.')

  feature_encoder_optim = torch.optim.Adam(feature_encoder.parameters(),lr=LEARNING_RATE)
  feature_encoder_scheduler = StepLR(feature_encoder_optim,step_size=LEARNING_RATE_SCHEDULE_RATE,gamma=0.5) 

  relation_network_optim = torch.optim.Adam(relation_network.parameters(),lr=LEARNING_RATE)
  relation_network_scheduler = StepLR(relation_network_optim,step_size=LEARNING_RATE_SCHEDULE_RATE,gamma=0.5) 

  mse = nn.MSELoss().to(device)

  print('  Optimizer & Learning Rate Scheduler initalized.')

  ### SET UP LOGGING ###

  # Create logging dir for current run
  logging = []
  if SAVE_LOGGING == True or SAVE_ALL == True or SAVE_BEST == True:

    if not os.path.exists(SAVE_PATH):
      os.makedirs(SAVE_PATH)

    run = 0
    run_list = os.listdir(SAVE_PATH)

    for i in range(len(run_list)):
      try:
        run_list[i] = int(run_list[i].split('_')[1])
      except:
        next

    run_list = [num for num in run_list if isinstance(num, (int,float))]

    if run_list:
      run = int(max(run_list)) + 1
    log_dir = os.path.join(SAVE_PATH, 'run_' + str(run))

    if not os.path.exists(log_dir):
      os.makedirs(log_dir)

    #Log params to logging dir
    with open(log_dir + '/task_param.pkl', 'wb') as f:
      pickle.dump(task_param, f)

    with open(log_dir + '/input_param.pkl', 'wb') as f:
      pickle.dump(input_param, f)      

    with open(log_dir + '/model_param.pkl', 'wb') as f:
      pickle.dump(model_param, f)

    with open(log_dir + '/training_param.pkl', 'wb') as f:
      pickle.dump(training_param, f)
  
  print(f'  Created logging folder: {log_dir}')

  print('\nTraining initalized. \n\n')

  print('Start training...\n')

  ### TRAINING ###

  #loop over number of episodes
  for episode in range(int(NUM_TRAIN_EPISODES/UPDATE_AND_EVAL_RATE)):

    print(f'Episode: {episode*UPDATE_AND_EVAL_RATE}/{NUM_TRAIN_EPISODES} to {(episode + 1) * UPDATE_AND_EVAL_RATE}/{NUM_TRAIN_EPISODES}')

    step_train_accuracy = 0
    step_train_loss = 0

    with alive_bar(UPDATE_AND_EVAL_RATE, title=f'  Training...', force_tty = True) as bar:
      for i in range(UPDATE_AND_EVAL_RATE):
        # Generate task and get data
        query_x, query_y, support_x, support_y = gen_task(n_way = NUM_CLASSES, n_support = SUPPORT_NUM_PER_CLASS, n_query = QUERY_NUM_PER_CLASS, data_x = X, data_y = y, split = 'train')
        query_x, query_y, support_x, support_y = query_x.to(device), query_y.to(device), support_x.to(device), support_y.to(device)
          
        # Predict
        relations, query_y_one_hot = predict(feature_encoder, relation_network, support_x, query_x, query_y, NUM_CLASSES, SUPPORT_NUM_PER_CLASS, QUERY_NUM_PER_CLASS, SEQUENCE_LENGTH, NUM_UNITS_LSTM_ENCODER)

        # Calculate loss         
        loss = mse(relations,query_y_one_hot)
        step_train_loss += loss.item()

        # Calculate accuracy 
        _,predict_labels = torch.max(relations.data,1)
        rewards = [1 if predict_labels[j]==query_y[j] else 0 for j in range(NUM_CLASSES*QUERY_NUM_PER_CLASS)]
        accuracy = np.sum(rewards)/1.0/NUM_CLASSES/QUERY_NUM_PER_CLASS
        step_train_accuracy += accuracy

        #backpropagation - adjust the model's parameter
        feature_encoder.zero_grad()
        relation_network.zero_grad()

        loss.backward()

        torch.nn.utils.clip_grad_norm_(feature_encoder.parameters(),0.5)
        torch.nn.utils.clip_grad_norm_(relation_network.parameters(),0.5)

        feature_encoder_optim.step()
        relation_network_optim.step()

        #update status bar
        bar()

    # print loss and acc for episode
    step_train_loss = step_train_loss/UPDATE_AND_EVAL_RATE
    step_train_accuracy = step_train_accuracy/UPDATE_AND_EVAL_RATE

    print(f'    Loss: {step_train_loss:.5f}')
    print(f'    Accuracy: {step_train_accuracy:.5f}')

    # start validation
    with torch.no_grad():

      step_eval_loss = 0
      step_eval_accuracy = 0
      best_eval_accuracy = 0

      for i in range(NUM_EVAL_EPISODES):

        # Generate task and get data
        query_x, query_y, support_x, support_y = gen_task(n_way = NUM_CLASSES, n_support = SUPPORT_NUM_PER_CLASS, n_query = QUERY_NUM_PER_CLASS, data_x = X, data_y = y, split = 'eval')
        query_x, query_y, support_x, support_y = query_x.to(device), query_y.to(device), support_x.to(device), support_y.to(device)

        # Predict
        relations, query_y_one_hot = predict(feature_encoder, relation_network, support_x, query_x, query_y, NUM_CLASSES, SUPPORT_NUM_PER_CLASS, QUERY_NUM_PER_CLASS, SEQUENCE_LENGTH, NUM_UNITS_LSTM_ENCODER)

        # Calculate loss             
        loss = mse(relations,query_y_one_hot)
        step_eval_loss += loss.item()

        # Calculate rewards for accuracy 
        _,predict_labels = torch.max(relations.data,1)
        rewards = [1 if predict_labels[j]==query_y[j] else 0 for j in range(NUM_CLASSES*QUERY_NUM_PER_CLASS)]
        step_eval_accuracy += np.sum(rewards)

      # Calculate and print loss / acc for validation-run
      step_eval_loss = step_eval_loss / NUM_EVAL_EPISODES
      step_eval_accuracy = step_eval_accuracy/1.0/NUM_CLASSES/QUERY_NUM_PER_CLASS/NUM_EVAL_EPISODES

      logging.append([step_train_loss, step_train_accuracy, step_eval_loss, step_eval_accuracy])

      print(f'  Validation with {NUM_EVAL_EPISODES} Evaluation-Episodes. Accuracy: {step_eval_accuracy:.5f}, Loss: {step_eval_loss:.5f}\n' )

      # Report results to optuna-tuning
      if TUNING_RUN == True:
        trial.report(step_eval_loss, episode * UPDATE_AND_EVAL_RATE)

        # Prune trial and save logging if loss-decrease is not promising
        if trial.should_prune():
          if SAVE_LOGGING == True:
            logging = pd.DataFrame(logging, columns=['train_loss', 'train_accuracy', 'eval_loss', 'eval_accuracy'])
            logging.eval_loss.iloc[0] = logging.train_loss.iloc[0]
            logging.eval_accuracy.iloc[0] = logging.train_accuracy.iloc[0]
            logging.to_pickle(log_dir + '/logging.pkl')
          raise optuna.exceptions.TrialPruned()

      # Save network 
      if (SAVE_BEST == True or SAVE_ALL == True) and not os.path.exists(os.path.join(log_dir, 'models')):
        os.makedirs(os.path.join(log_dir, 'models'))

      if SAVE_BEST == True and step_eval_accuracy > best_eval_accuracy:
        torch.save(feature_encoder.state_dict(),str(log_dir + '/models/feature_encoder_best.pkl'))
        torch.save(relation_network.state_dict(),str(log_dir + '/models/relation_network_best.pkl'))

      if SAVE_ALL == True:
        torch.save(feature_encoder.state_dict(),str(log_dir + '/models/feature_encoder_e' + str(episode*UPDATE_AND_EVAL_RATE) + '.pkl'))
        torch.save(relation_network.state_dict(),str(log_dir + '/models/relation_network_e' + str(episode*UPDATE_AND_EVAL_RATE) + '.pkl'))

  # Save logging
  if SAVE_LOGGING == True:
    logging = pd.DataFrame(logging, columns=['train_loss', 'train_accuracy', 'eval_loss', 'eval_accuracy'])
    logging.eval_loss.iloc[0] = logging.train_loss.iloc[0]
    logging.eval_accuracy.iloc[0] = logging.train_accuracy.iloc[0]

    logging.to_pickle(log_dir + '/logging.pkl')

  return logging

# %% [markdown]
# #### Hyperparameter tuning

# %%
def run_tuning(trial):
  """
  Tuning Function - performs multiple model trainings and optimizes hyperparameters
  Args:
    trial (optunia-trial-object): current trial object of the optuna tuning process
  Returns:
    min_eval_loss (float): minimal loss on evaluation set
  """

  # Caution: some parameters have to be set manually to match the given task, input and training specifications
  # (this has to be done within this function, because optuna does not support additional args)

  # Set tuning parameters  
  task_param = {'support_num_per_class': K_SHOT,
                'query_num_per_class': 16,
                'num_classes': N_WAY}

  # Set input parameters  
  input_param = {'sequence_length': 72,
                 'feature_length': 63}

  # Set model parameters (suggestions by optuna)
  num_fc_layers = trial.suggest_int("num_fc_layers", 1, 3, step = 1)
  num_units_fc_relu = []
  for i in range(num_fc_layers):
    num_units = trial.suggest_categorical("num_units_fc_layer{}".format(i), [16, 32, 64, 128, 256])
    num_units_fc_relu.append(num_units)

  model_param = {'num_lstm_layer_encoder': trial.suggest_int("num_lstm_layer_encoder", 1, 3, step=1),
                 'num_units_lstm_encoder': trial.suggest_categorical("num_units_lstm_encoder", [16, 32, 64, 128, 256]),
                 'num_lstm_layer_relationnet': trial.suggest_int("num_lstm_layer_relationnet", 1, 3, step=1),
                 'num_units_lstm_relationnet': trial.suggest_categorical("num_units_lstm_relationnet", [16, 32, 64, 128, 256]),
                 'num_units_fc_relu': num_units_fc_relu}

  # Set training parameters
  training_param = {'learning_rate': trial.suggest_float("learning_rate", 0.00001, 0.01,  log=True),
                    'learning_rate_schedule_rate': trial.suggest_int("learning_rate_schedule_rate", 500, 10000, step = 500),
                    'num_train_episodes': 25000,
                    'update_and_eval_rate': 500,
                    'num_eval_episodes': 200,
                    'save_path': 'tuning',
                    'save_logging': True,
                    'save_all': True,
                    'save_best': True,
                    'tuning_run': True,
                    'trial': trial}

  # run training with parameters of this trial
  logs = run_training(task_param, input_param, model_param, training_param)

  # report minimal evaluation loss to optuna
  min_eval_loss = logs.eval_loss.min()
  return min_eval_loss

# %% [markdown]
# #### Unique tasks calculator

# %%
def get_classcombinations(classes, num_in_comb):
  """
  Generates a set of unique tasks for a given list of classes and a number different of classes in each task
  Args:
    classes (list): list of classes
    num_in_comb (int): number different of classes in each task
  Returns:
    unique_tasks (set): set of unique tasks
  """

  unique_tasks = set(itertools.combinations(classes, num_in_comb))
  return unique_tasks

# %% [markdown]
# #### Task generator

# %%
def gen_task(n_way, n_support, n_query, data_x, data_y, split):
  """
  Generates a task (classify n-query gestures of n_way classes with n_support suppoting samples) for the few shot model.
  Args:
    n_way (int): number of classes
    n_support (int): number of support samples in each class
    n_query (int): batch size of query samples 
    data_x (np.array): hand keypoints (usually X)
    data_y (np.array): labels (usually y)
    split (str): type of split (train, evel or test)
  Returns:
    query_x (torch tensor): query set data
    query_y (torch tensor): query set labels
    support_x (torch tensor): support set data
    support_y (torch tensor): support set labels 
    (classes (np.array)): list of original classes 
  """

  #sample random classes from the predfined list of classes, depended of the split-type
  query_x, query_y, support_x, support_y = [], [], [], []
  if split == 'train':
    classes = np.random.choice(training_classes, n_way, replace=False)
  elif split == 'eval':
    classes = np.random.choice(eval_classes, n_way, replace=False) 
  elif split == 'test':
    classes = np.random.choice(test_classes, n_way, replace=False) 

  #loop over classes of this task, sample X data and generate labels (always 0 to n-classes)
  for i, c in enumerate(classes):
    data_x_c = data_x[data_y == c]

    query_x.append(data_x_c[np.random.choice(data_x_c.shape[0], n_query, replace=False), :, :])
    query_y.append([i] * n_query)

    support_x.append(data_x_c[np.random.choice(data_x_c.shape[0], n_support, replace=False), :, :])
    support_y.append([i] * n_support)

  #reshape Data
  query_x = np.reshape(query_x, (n_way * n_query, np.array(query_x).shape[2], np.array(query_x).shape[3]))
  query_y = np.reshape(query_y, n_way * n_query)
  support_x = np.reshape(support_x, (n_way * n_support, np.array(support_x).shape[2], np.array(support_x).shape[3]))
  support_y = np.reshape(support_y, n_way * n_support)

  #change to torch tensors
  query_x = torch.from_numpy(query_x).float()
  query_y = torch.from_numpy(query_y).float().type(torch.LongTensor) 
  support_x = torch.from_numpy(support_x).float()
  support_y = torch.from_numpy(support_y).float().type(torch.LongTensor) 

  #Return statements
  if split == 'train' or split == 'eval':   
    return query_x, query_y, support_x, support_y
  elif split == 'test':
    return query_x, query_y, support_x, support_y, classes

# %% [markdown]
# #### Model components

# %%
class LSTMEncoder(nn.Module):
  """First part of the model, which encodes the sequence of hand gesture keypoints"""
  def __init__(self, input_size, hidden_lstm_size, num_lstm_layer):
    """
    Object initialization.
    Args:
      input_size (int): size of the input data
      hidden_lstm_size (int): number of units in lstm-cell
      num_lstm_layer (int): number of stacked lstm-layers
    """
    super(LSTMEncoder, self).__init__()
    self.input_size = input_size 
    self.hidden_lstm_size = hidden_lstm_size 
    self.num_lstm_layer = num_lstm_layer

    #create lstm layer(s)
    self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_lstm_size, num_layers = num_lstm_layer, batch_first=True)

  def forward(self,x):
    """
    Forward pass through the LSTM Encoder
    Args:
      x (torch tensor): data input (sequence of hand keypoints as batch)
    Return:
      out (torch tensor): encoded data (encoded sequence of hand keypoints as batch) with size batch, sequence, hidden_size
    """

    #create zeros with size num_layer, sequences, hidden_size 
    #h0 containing the final hidden state for each element in the sequence
    h0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device)  
    #c0 containing the final cell state for each element in the sequence
    c0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device) 

    #pass data through the lstm layer(s)
    out, _ = self.lstm(x, (h0,c0))
    return out 


class RelationNetwork(nn.Module):
  """Second part of the model, which calculates the relation-scores, given the concatenated query and support samples"""
  def __init__(self,input_size, hidden_lstm_size, fc_sizes: list, num_lstm_layer):
    """
    Object initialization.
    Args:
      input_size (int): size of the input data
      hidden_lstm_size (int): number of units in lstm-cell
      fc_sizes (list): number of units per fully connected / linear layer
      num_lstm_layer (int): number of stacked lstm-layers
    """
    super(RelationNetwork, self).__init__()
    self.input_size = input_size 
    self.hidden_lstm_size = hidden_lstm_size
    self.layers = nn.ModuleList()
    self.num_lstm_layer = num_lstm_layer

    #create lstm layer(s)
    self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_lstm_size, num_layers = num_lstm_layer, batch_first=True)
    #next input_size is outputsize of the lstm layer (hidden_lstm_size)
    input_size = hidden_lstm_size

    #loop over fc_sizes, create linear layer + ReLU Activation and adjust the input_size
    for size in fc_sizes:
      self.layers.append(nn.Linear(input_size, size))
      self.layers.append(nn.ReLU())
      input_size = size  
 
    #add a final Linear Layer which reduces the input down to a single number, aka. the relation score, by applieing a sigmoid function
    self.end_layer = nn.Sequential(nn.Linear(input_size,1), nn.Sigmoid())
    
  def forward(self,x):
    """
    Forward pass through the Relation Network
    Args:
      x (torch tensor): concatenated data input of query- and support-samples 
    Return:
      out (torch tensor): relation scores
    """
    
    #create zeros with size num_layer, sequences, hidden_size 
    #h0 containing the final hidden state for each element in the sequence 
    h0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device) 
    #c0 containing the final cell state for each element in the sequence
    c0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device) 

    #pass data through the lstm layer(s)
    out, _ = self.lstm(x, (h0,c0))
    #reduce output to the last sequence-state 
    out = out[:, -1, :]

    #pass data through the fc layer(s)
    for layer in self.layers:
      out = layer(out)
    
    #pass data through the final layer to calculate the relation score
    out = self.end_layer(out) 
    return out

# %% [markdown]
# #### Prediction performer

# %%
def predict(feature_encoder, relation_network, support_x, query_x, query_y, num_classes, support_num_per_class, query_num_per_class, seq_length, num_units_lstm_encoder):
  """
  Prediction-Function 
  Args:
    feature_encoder (LSTMEncoder-object): initialized LSTMEncoder-object
    relation_network (RelationNetwork-object): initialized RelationNetwork-object
    support_x (torch tensor): data for support set
    support_y (torch tensor): labels for support set
    query_x (torch tensor): data for query set
    query_y (torch tensor): labels for query set
    num_classes (int): number of classes in the given task
    support_num_per_class (int): number of support samples per class in support set
    query_num_per_class (int): number of query samples per class in query set
    seq_length (int): length of sequence
    num_units_lstm_encoder (int): number of hidden units in the LSTM-Cells of the feature_encoder
  Returns:
    relations (torch tensor): relation scores 
    query_y_one_hot (torch tensor): predicted classes as one-hot-encoded vector
  """
  # calculate support features by passing the support set through the feature_encoder-module 
  support_features = feature_encoder(Variable(support_x).to(device))
  # calculate query features by passing the query set through the feature_encoder-module 
  query_features = feature_encoder(Variable(query_x).to(device))
          
  #Prepare encoded query and support set for relations calculation (reshaping, transposing)
  support_features = support_features.view(num_classes, support_num_per_class, seq_length, num_units_lstm_encoder)
  support_features = torch.sum(support_features, 1).squeeze(1)
  support_features_ext = support_features.unsqueeze(0).repeat(query_num_per_class*num_classes,1,1,1).to(device)
  query_features_ext = query_features.unsqueeze(0).repeat(num_classes,1,1,1)
  query_features_ext = torch.transpose(query_features_ext,0,1).to(device)

  # concatenated encoded query & support set
  relation_pairs = torch.cat((support_features_ext,query_features_ext),3).view(-1,seq_length, num_units_lstm_encoder*2).to(device)

  # calculate relations by passing the concatenated query & support set through the relation_network-module 
  relations = relation_network(relation_pairs).view(-1,num_classes).to(device)

  # turn relation-scores into one hot encoded predictions 
  query_y_one_hot = Variable(torch.zeros(query_num_per_class*num_classes, num_classes).to(device).scatter_(1, query_y.view(-1,1), 1)).to(device)

  return relations, query_y_one_hot

# %% [markdown]
# #### Logging loader

# %%
def load_logging_and_params_from_file(log_dir):
  """
  Loads the logging and parameters of a single training-run from a given directory
  Args:
    log_dir (str): location of logs and parameters of a single run
  Returns:
    logging (pd.dataframe: logging of the given run
    task_param (dict): task-related parameters of the given run
    input_param (dict): input-related parameters of the given run
    model_param (dict): model-related parameters of the given run
    training_param (dict): training-related paramaters of the given run
  """

  #check is given log_dir exist
  if os.path.isfile(os.path.join(log_dir,'logging.pkl')):
    #load logging and param-dirs
    logging = pd.read_pickle(os.path.join(log_dir, 'logging.pkl'))

    with open(os.path.join(log_dir, 'task_param.pkl'), 'rb') as f:
      task_param = pickle.load(f)

    with open(os.path.join(log_dir, 'input_param.pkl'), 'rb') as f:
      input_param = pickle.load(f)      

    with open(os.path.join(log_dir, 'model_param.pkl'), 'rb') as f:
      model_param = pickle.load(f)

    with open(os.path.join(log_dir, 'training_param.pkl'), 'rb') as f:
      training_param = pickle.load(f)

    #return logging and param-dirs
    return logging, task_param, input_param, model_param, training_param
  
  else:
    print(f'No logging found in {log_dir}')

# %% [markdown]
# #### Training-Curve visualization

# %%
def plot_traincurve(log_dir, metrics, ylabel):
  """
  Plots the training curve of a single train-run
  Args:
    log_dir (str): location of the training run
    metrics (list): metrics to be plotted 
    ylabel (str): label to be plotted on the y-axis
  """

  #Load logging from log_dir
  logging, _, _, _, training_param = load_logging_and_params_from_file(log_dir)

  plt.figure(figsize=(10, 5), dpi=100)
  colors = ['#00406C', '#1ABEA3'] 
  i = 0

  #Loop over metrics and visualize it as a line
  for col in metrics:
    plot_data = logging[col].dropna()
    plt.plot(plot_data.index.values * training_param['update_and_eval_rate'], plot_data.values, label=col, color = colors[i])
    i += 1

  l=plt.legend()
  l.get_texts()[0].set_text('Trainingsdaten')
  l.get_texts()[1].set_text('Validationsdaten')

  #plt.title('Learning Curve')
  plt.xlabel('Episode')
  plt.ylabel(ylabel)
  plt.ylim(0, 1)
  #plt.figlegend(bbox_to_anchor=(0.85,0.5), loc="center left")
  plt.tight_layout(rect=[0,0,0.85,1])

  plt.show()

# %% [markdown]
# #### Tuning-History visualization

# %%
def plot_tuning_history(tuning_dir, metric, y_label, direction):
  """
  Plots the training curves of all training-runs in a tuning dir 
  Args:
    tuning_dir (str): location of the tuning run
    metric (list): metrics to be plotted 
    y_label (str): label to be displayed on the y-axis
    direction (str): maximize or minimize
  """

  # Gather the data from every training-run in the tuning_dir
  tuning_metrics = []
  runs = []
  if os.path.isdir(tuning_dir):
    run_dirs = os.listdir(tuning_dir)

    def extract_nums (elem):
      return int(elem.split('_')[1])
    
    run_dirs.sort(key = extract_nums)

    for i in range(len(run_dirs)):
      if 'run' in run_dirs[i]:
        logging, _, _, _, training_param = load_logging_and_params_from_file(os.path.join(tuning_dir, run_dirs[i]))
        logging = logging[metric]
        tuning_metrics.append(list(logging))
        runs.append(run_dirs[i])  

    max_length = len(max(tuning_metrics, key=len))

    if direction == 'maximize':
      none_marker = 0
    elif direction == 'minimize':
      none_marker = 99
    else:
      return 'invalid direction'

    for i, log in enumerate(tuning_metrics):
      tuning_metrics[i] = (log + max_length * [none_marker])[:max_length]

    tuning_metrics = np.array(tuning_metrics).transpose()
    tuning_logs = pd.DataFrame(tuning_metrics, columns = runs)
    
  else:
    print('tuning_dir does not exist.')

# Check for pruned runs and when a run hits a new best-score
  pruned = []
  new_best = []
  
  if direction == 'maximize':
    best = 0

    for col in tuning_logs:
      if tuning_logs[col].max() > best:
        best = tuning_logs[col].max()
        new_best.append('#E76450')
      else:
        new_best.append('#FFC35E')

      if tuning_logs[col].min() == 0:
        pruned.append('x')
      else:
        pruned.append('o')

      data = tuning_logs.max()
     
  elif direction == 'minimize':
    best = 1
    for col in tuning_logs:
      if tuning_logs[col].min() < best:
        best = tuning_logs[col].min()
        new_best.append('#00406E')
      else:
        new_best.append('#17BEA3')

      if tuning_logs[col].max() == 99:
        pruned.append('x')
      else:
        pruned.append('o')

      data = tuning_logs.min()

  # Visualize history

  plt.figure(figsize=(10, 5), dpi=100)
  plt.plot(data, linestyle = 'dashed', color = '#C8D4D7')

  for i in range(len(data)):
    plt.plot(i, data[i], marker = pruned[i], markersize = 8, color = new_best[i])

  #plt.title('Tuning Entwicklung')
  plt.xlabel('Trainingsläufe')
  plt.xticks(rotation=45, horizontalalignment='center')
  plt.ylabel(y_label)
  plt.ylim(0, 1)

  plt.show()

# %% [markdown]
# #### Tuning-Traincurves visualization

# %%
def plot_tuning_traincurves(tuning_dir, metric, y_label, direction = None, top_n = None):
  """
  Plots the training curves of all training-runs in a tuning dir 
  Args:
    tuning_dir (str): location of the tuning run
    metric (list): metrics to be plotted 
    y_label (str): label to be displayed on the y-axis
    direction (str): maximize or minimize
    top (int): visualize top_n results, either highest or lowest, dependend on arg 'direction'
  """

  # Gather the data from every training-run in the tuning_dir
  tuning_metrics = []
  runs = []
  if os.path.isdir(tuning_dir):
    run_dirs = os.listdir(tuning_dir)

    def extract_nums (elem):
      return int(elem.split('_')[1])
    
    run_dirs.sort(key = extract_nums)

    for i in range(len(run_dirs)):
      if 'run' in run_dirs[i]:
        logging, _, _, _, training_param = load_logging_and_params_from_file(os.path.join(tuning_dir, run_dirs[i]))
        logging = logging[metric]
        tuning_metrics.append(list(logging))
        runs.append(run_dirs[i])  

    max_length = len(max(tuning_metrics, key=len))

    for i, log in enumerate(tuning_metrics):
      tuning_metrics[i] = (log + max_length * [0])[:max_length]

    tuning_metrics = np.array(tuning_metrics).transpose()
    tuning_logs = pd.DataFrame(tuning_metrics, columns = runs)
    
  else:
    print('tuning_dir does not exist.')

  # Filter to visualize only the top_n results

  if direction != None and top_n != None:
    if direction == 'maximize':
      tuning_logs = tuning_logs[tuning_logs.max().nlargest(top_n).index]
    elif direction == 'minimize':
      tuning_logs = tuning_logs[tuning_logs.min().nsmallest(top_n).index]
    else: 
      return 'invalid direction'


  # Visualize results
  plt.figure(figsize=(10, 5), dpi=100)
  for col in list(tuning_logs.columns.values):
    plot_data = tuning_logs[col].dropna()
    plt.plot(plot_data.index.values * training_param['update_and_eval_rate'], plot_data.values, label=col)

  #plt.title('Lernkurve')
  plt.xlabel('Episode')
  plt.ylabel(y_label)

  plt.figlegend(bbox_to_anchor=(0.85,0.5), loc="center left")
  plt.tight_layout(rect=[0,0,0.85,1])
  plt.ylim(0, 1)

  plt.show()

# %% [markdown]
# #### Tuning parameter's importance visualization

# %%
def plot_tuning_parameter_importance(importances):
  """
  Visualizes the importances of every parameter in a tuning run
  Args:
    importances (OrderedDict): importances of the tuning parameters
  """

  # create positions needed for horizontal plot
  y_pos = np.arange(start = len(importances.keys()), stop = 0, step = -1)

  # create plot
  plt.figure(figsize=(10, 5), dpi=100)
  plt.barh(y_pos, importances.values(), color = '#17BEA3')

  i = 0
  for v in reversed(importances.values()):
    plt.text(v + 0.003, i + 0.9, str(round(v, 3)), color = '#00406E')
    i += 1

  # adjust labels and axis
  plt.yticks(y_pos, labels=importances.keys())
  plt.title('')
  plt.xlabel('Relevanz für den Erfolg des Tunings')
  plt.ylabel('Tuning Parameter')
  plt.xlim(0, 0.65)
  plt.tight_layout()

  plt.show()

# %% [markdown]
# #### Zip and push to Google Drive

# %%
def push_zip(source, destination):
  """
  Zip and push a directory to the Google Drive
  Args:
    source (str): current location 
    destination (str): target location 
  """
  base = os.path.basename(destination)
  name = base.split('.')[0]
  format = base.split('.')[1]
  archive_from = os.path.dirname(source)
  archive_to = os.path.basename(source.strip(os.sep))
  shutil.make_archive(name, format, archive_from, archive_to)
  shutil.move('%s.%s'%(name,format), destination)

# %% [markdown]
# #### Model saving

# %%
def push_model_to_gdrive(run_dir, episode, model_name):
  """
  Push a model & the params needed for deployment, located in a local directory, to the Google Drive
  Args:
    run_dir (str): location of the model
    episode (list): episode of the model, either a number or 'best'
    model_name (str): model's name in the Google Drive
  """

  #config target_path
  path = os.path.join(gdrive, 'results', 'models')

  #load model and params
  feature_encoder, relation_network = load_model_from_file(run_dir, episode)
  _, task_param, input_param, model_param, _ = load_logging_and_params_from_file(run_dir)

  #unpack params needed for deployment
  deployment_param = {'support_num_per_class': task_param['support_num_per_class'],
                      'num_classes': task_param['num_classes'],
                      'sequence_length': input_param['sequence_length'],
                      'feature_length': input_param['feature_length'],
                      'num_lstm_layer_encoder': model_param['num_lstm_layer_encoder'],
                      'num_units_lstm_encoder': model_param['num_units_lstm_encoder'],
                      'num_lstm_layer_relationnet': model_param['num_lstm_layer_relationnet'],
                      'num_units_lstm_relationnet': model_param['num_units_lstm_relationnet'],
                      'num_units_fc_relu': model_param['num_units_fc_relu']}

  # Push to Google Drive
  torch.save(feature_encoder.state_dict(),str(os.path.join(path, f'{model_name}_feature_encoder.pkl')))
  torch.save(relation_network.state_dict(),str(os.path.join(path, f'{model_name}_relation_network.pkl')))
  with open(os.path.join(path, f'{model_name}_deployment_param.pkl'), 'wb') as f:
      pickle.dump(deployment_param, f)

# %% [markdown]
# #### Model loading

# %%
def load_model_from_file(run_dir, episode):
  """
  Loads and initializes a model from a given directory
  Args:
    run_dir (str): location of the model
    episode (list): episode of the model, either a number or 'best'
  Returns:
    feature_encoder (LSTMEncoder-object): initialized LSTMEncoder-object
    relation_network (RelationNetwork-object): initialized RelationNetwork-object
  """

  #load params needed for deployment
  _, _, input_param, model_param, _ = load_logging_and_params_from_file(run_dir)

  #initialize feature_encoder and relation_network
  feature_encoder = LSTMEncoder(input_param['feature_length'], model_param['num_units_lstm_encoder'], model_param['num_lstm_layer_encoder']).to(device)
  relation_network = RelationNetwork(model_param['num_units_lstm_encoder']*2, model_param['num_units_lstm_relationnet'], model_param['num_units_fc_relu'], model_param['num_lstm_layer_relationnet']).to(device) 

  #load weights from directory
  feature_encoder.load_state_dict(torch.load(os.path.join(run_dir, 'models', str('feature_encoder_' + episode + '.pkl'))))
  relation_network.load_state_dict(torch.load(os.path.join(run_dir, 'models', str('relation_network_' + episode + '.pkl'))))

  return feature_encoder, relation_network

# %% [markdown]
# #### Model testing

# %%
def run_testing(num_testruns, samples_per_run, run_dir, episode, test_classes):
  """
  Testing Function - performs model testing on test-classes
  Args:
    num_testruns (int): number of test-runs to be performed, each test-run == one task
    samples_per_run (int): number of samples to be drawn as a query set
    run_dir (str): location of the model to be tested
    episode (str): episode of the model to be tests, either a number or 'best'
    test_classes (list): list of test classes
  Returns:
    conf_matrix (np.array): summarized confusion matrix of the test-runs
    classification_report (pd.dataframe): summarized classification report of the test-runs
    accuracy (float): summarized accuracy of the test-runs
  """

  # load and initialize model from dir
  feature_encoder, relation_network = load_model_from_file(run_dir, episode)
  _, task_param, input_param, model_param, training_param = load_logging_and_params_from_file(run_dir)

  # initi empty conf_matrix
  conf_matrix = np.zeros(shape = (len(test_classes),len(test_classes)), dtype = int)

  # loop over num_testruns
  for testrun in range(num_testruns):
    # generate a task with query and support sets
    query_x, query_y, support_x, support_y, tested_classes = gen_task(n_way = task_param['num_classes'], n_support = task_param['support_num_per_class'], 
                                                                      n_query = samples_per_run, data_x = X, data_y = y, split = 'test')
    query_x, query_y, support_x, support_y = query_x.to(device), query_y.to(device), support_x.to(device), support_y.to(device)

    # perform prediction on query and support set
    relations, query_y_one_hot = predict(feature_encoder, relation_network, support_x, query_x, query_y, 
                                        task_param['num_classes'], task_param['support_num_per_class'], 
                                        samples_per_run, input_param['sequence_length'], model_param['num_units_lstm_encoder'])
    _,predict_labels = torch.max(relations.data,1)

    # analyse prediction and adjust conf matrix
    for i in range(len(query_y)):
      cm_index_true = test_classes.index(tested_classes[predict_labels[i].item()])
      cm_index_pred = test_classes.index(tested_classes[query_y[i].item()])

      conf_matrix[cm_index_true][cm_index_pred] += 1

  # Calculate recall, precison and f_score based on conf matrix
  recalls = []
  precisions = []
  f_scores = []

  for i in range(len(test_classes)):
    recalls.append(conf_matrix[i][i] / conf_matrix[:,i].sum())
    precisions.append(conf_matrix[i][i] / conf_matrix[i,:].sum())
    f_scores.append(2 * (precisions[i] * recalls[i]) / (precisions[i] + recalls[i]))

  # Calculate accuracy based on conf matrix
  accuracy = conf_matrix.diagonal().sum() / conf_matrix.sum()

  # save and return metrics
  classification_report = pd.DataFrame((precisions, recalls, f_scores)).transpose()
  classification_report.index = [f'{str(x)} ({str(y_og[x][0])} & {str(y_og[x][1])})' for x in test_classes]
  classification_report.index.names = ['Class']
  classification_report.rename(columns = {0: 'Precision', 1: 'Recall', 2: 'FScore'}, inplace = True)
  
  return conf_matrix, classification_report, accuracy

# %% [markdown]
# #### Confusion matrix visualization

# %%
def plot_conf_matrix (conf_matrix, test_classes, y_og):
  """
  Visualizes a given confusion matrix as a heatmap
  Args:
    conf_matrix (np.array): confustion matrix to be visualized
    test_classes (list): list of classes the model was tested on
    y_og (list): list of original classes (before the combination) matching the test_classes
  """

  true_labels = [f'{str(x)} ({str(y_og[x][0])} & {str(y_og[x][1])})' for x in test_classes]
  pred_labels = [f'{str(x)} ({str(y_og[x][0])} & {str(y_og[x][1])})' for x in test_classes]

  fig, ax = plt.subplots(figsize = (15,15))
  im = ax.imshow(conf_matrix, cmap = 'coolwarm') 

  # Show all ticks and label them with the respective list entries
  ax.set_xticks(np.arange(len(pred_labels)))
  ax.set_yticks(np.arange(len(true_labels)))

  ax.set_xticklabels(pred_labels)
  ax.set_yticklabels(true_labels)

  ax.xaxis.tick_top()
  ax.xaxis.set_label_position('top')

  # Rotate the tick labels and set their alignment
  plt.setp(ax.get_xticklabels(), rotation=45, ha="left",
          rotation_mode="anchor")

  plt.setp(ax.get_yticklabels(), rotation=0, ha="right")

  # Loop over data dimensions and create text annotations
  for i in range(len(true_labels)):
      for j in range(len(pred_labels)):
          text = ax.text(j, i, conf_matrix[i, j],
                        ha="center", va="center", color="w")

  ax.set_title("Confusion matrix", fontsize = 18)
  fig.tight_layout()
  plt.show()

# %% [markdown]
# # Load and split data

# %% [markdown]
# Load X (extraced and combined sequences of hand-keypoints), y (combined classes from 0 to 676) and y_og (original classes from 0 to 25) from Google Drive.

# %%
# Load X, y and y_og from Google Drive.
X = np.load(gdrive + '/data/JESTER/final/X.npy')
y = np.load(gdrive + '/data/JESTER/final/y.npy')
y_og = np.load(gdrive + '/data/JESTER/final/y_og.npy')

# Check shapes 
print(f'Labels shape {y.shape}')
print(f'Data shape {X.shape}')
unique, counts = np.unique(y, return_counts=True)
print(f'\nNumber of unique classes {len(unique)}')
# Out:
# Labels shape (169000,)
# Data shape (169000, 72, 63)
#
# Number of unique classes 676

# %% [markdown]
# ## Configurate Test-strategy

# %% [markdown]
# In contrast to common machine learning approaches, the train-, test-, evaluation-split in Few-Shot Learning use cases splits the data by classes instead of drawing random samples of observations.
#
# Classes are split by their original class labels (not by combined class labels) to prevent the model from seeing bits of the data in more than one of the splits.

# %%
label_map = {'No gesture': 0, #base class, mostly zeros
            'Drumming Fingers': 1, #static
            'Pulling Hand In': 2, #dynamic
            'Pulling Two Fingers In': 3, #dynamic
            'Pushing Hand Away': 4, #dynamic
            'Pushing Two Fingers Away': 5, #dynamic
            'Rolling Hand Backward': 6, #dynamic
            'Rolling Hand Forward': 7, #dynamic
            'Shaking Hand': 8, #static
            'Sliding Two Fingers Down': 9, #dynamic
            'Sliding Two Fingers Left': 10, #dynamic
            'Sliding Two Fingers Right': 11, #dynamic
            'Sliding Two Fingers Up': 12, #dynamic
            'Stop Sign': 13, #static
            'Swiping Down': 14, #dynamic
            'Swiping Left': 15, #dynamic
            'Swiping Right': 16, #dynamic
            'Swiping Up': 17, #dynamic
            'Thumb Down': 18, #static
            'Thumb Up': 19, #static
            'Turning Hand Clockwise': 20, #dynamic
            'Turning Hand Counterclockwise': 21, #dynamic
            'Zooming In With Full Hand': 22, #dynamic
            'Zooming In With Two Fingers': 23, #dynamic
            'Zooming Out With Full Hand': 24, #dynamic
            'Zooming Out With Two Fingers': 25} #dynamic

# %% [markdown]
# Choose original class labels (pre-combination) for training, evaluation and test splits.

# %%
train_y_origin = [0, 1, 4, 5, 6, 7, 9, 10, 16, 17, 22, 25]
eval_y_origin = [0, 2, 8, 11, 14, 18, 20, 23]
test_y_origin = [0, 3, 12, 13, 15, 19, 21, 24]

# %% [markdown]
# Turn splits with original class labels (pre-combination) into training-, evaluation- and test- classes with combined classes.

# %%
training_classes, eval_classes, test_classes  = [], [], []

for i in range(len(y_og)):
  if ((y_og[i][0] == 0) and (y_og[i][1] in eval_y_origin)) or (y_og[i][0] in eval_y_origin or y_og[i][1] in eval_y_origin) and not (y_og[i][0] in train_y_origin or y_og[i][1] in train_y_origin) and not (y_og[i][0] in test_y_origin or y_og[i][1] in test_y_origin):
    eval_classes.append(i)
  if ((y_og[i][0] == 0) and (y_og[i][1] in train_y_origin)) or (y_og[i][0] in train_y_origin or y_og[i][1] in train_y_origin) and not (y_og[i][0] in eval_y_origin or y_og[i][1] in eval_y_origin) and not (y_og[i][0] in test_y_origin or y_og[i][1] in test_y_origin):
    training_classes.append(i)
  if ((y_og[i][0] == 0) and (y_og[i][1] in test_y_origin)) or (y_og[i][0] in test_y_origin or y_og[i][1] in test_y_origin) and not (y_og[i][0] in eval_y_origin or y_og[i][1] in eval_y_origin) and not (y_og[i][0] in train_y_origin or y_og[i][1] in train_y_origin):
    test_classes.append(i)

# %% [markdown]
# Examination of resulting training-, evaluation- and test-split.

# %%
print(f'Number of classes in train-split: {len(training_classes)}')
print(f'Number of classes in eval-split: {len(eval_classes)}')
print(f'Number of classes in test-split: {len(test_classes)}')
# Out:
# Number of classes in train-split: 133
# Number of classes in eval-split: 57
# Number of classes in test-split: 57

# %%
#print(f'Potential number of unique tasks for training: {len(get_classcombinations(training_classes, N_WAY))}')
#print(f'Potential number of unique tasks for evaluation: {len(get_classcombinations(eval_classes, N_WAY))}')
#print(f'Potential number of unique tasks for testing: {len(get_classcombinations(test_classes, N_WAY))}')

# %% [markdown]
# # Model tuning and training

# %% [markdown]
# In this section the model is trained. Initially, this is performed once with parameters defined by the user. Next, the model's hyperparameters are optimized by a tuning process.

# %% [markdown]
# ## Perform a training run

# %% [markdown]
# To ensure that the training function operates flawlessly (& to have a baseline model), training of the model is performed once initially with low parameter complexity.

# %%
task_param = {'support_num_per_class': K_SHOT,
              'query_num_per_class': 16,
              'num_classes': N_WAY}

input_param = {'sequence_length': 72,
               'feature_length': 63}

model_param = {'num_lstm_layer_encoder': 1,
               'num_units_lstm_encoder': 64,
               'num_lstm_layer_relationnet': 1,
               'num_units_lstm_relationnet': 64,
               'num_units_fc_relu': [32]}

training_param = {'learning_rate': 0.001,
                  'learning_rate_schedule_rate': 2000,
                  'num_train_episodes': 25000,
                  'update_and_eval_rate': 200,
                  'num_eval_episodes': 200,
                  'save_path': 'training',
                  'save_logging': True,
                  'save_all': True,
                  'save_best': True,
                  'tuning_run': False,
                  'trial': None}
            
logs = run_training(task_param, input_param, model_param, training_param)
# Out:
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: training/run_0
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.6s (14.69/s)
#     Loss: 0.09851
#     Accuracy: 0.12366
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.17609, Loss: 0.08789
#
# Episode: 200/25000 to 400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.5s (14.83/s)
#     Loss: 0.08779
#     Accuracy: 0.16306
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.18856, Loss: 0.08540
#
# Episode: 400/25000 to 600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.4s (14.91/s)
#     Loss: 0.08634
#     Accuracy: 0.17094
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19684, Loss: 0.08537
#
# Episode: 600/25000 to 800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.49/s)
#     Loss: 0.08617
#     Accuracy: 0.19622
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.22472, Loss: 0.08482
#
# Episode: 800/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.56/s)
#     Loss: 0.08285
#     Accuracy: 0.29134
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.27028, Loss: 0.08371
#
# Episode: 1000/25000 to 1200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.6s (14.66/s)
#     Loss: 0.07761
#     Accuracy: 0.41300
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.30341, Loss: 0.08358
#
# Episode: 1200/25000 to 1400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.59/s)
#     Loss: 0.07178
#     Accuracy: 0.47509
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.33728, Loss: 0.08352
#
# Episode: 1400/25000 to 1600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.61/s)
#     Loss: 0.06826
#     Accuracy: 0.51756
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.37081, Loss: 0.08260
#
# Episode: 1600/25000 to 1800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.49/s)
#     Loss: 0.06511
#     Accuracy: 0.55781
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.35741, Loss: 0.08344
#
# Episode: 1800/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.52/s)
#     Loss: 0.06284
#     Accuracy: 0.58688
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.37522, Loss: 0.08595
#
# Episode: 2000/25000 to 2200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.6s (14.67/s)
#     Loss: 0.06184
#     Accuracy: 0.60172
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.39947, Loss: 0.08174
#
# Episode: 2200/25000 to 2400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.56/s)
#     Loss: 0.05825
#     Accuracy: 0.63178
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.44231, Loss: 0.07356
#
# Episode: 2400/25000 to 2600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.52/s)
#     Loss: 0.05580
#     Accuracy: 0.66213
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.49225, Loss: 0.07491
#
# Episode: 2600/25000 to 2800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.51/s)
#     Loss: 0.05233
#     Accuracy: 0.69369
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.49209, Loss: 0.07152
#
# Episode: 2800/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.6s (14.68/s)
#     Loss: 0.05036
#     Accuracy: 0.71441
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.50916, Loss: 0.07741
#
# Episode: 3000/25000 to 3200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.6s (14.67/s)
#     Loss: 0.04660
#     Accuracy: 0.74212
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.55019, Loss: 0.07109
#
# Episode: 3200/25000 to 3400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.60/s)
#     Loss: 0.04703
#     Accuracy: 0.75028
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.51062, Loss: 0.08498
#
# Episode: 3400/25000 to 3600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.49/s)
#     Loss: 0.04452
#     Accuracy: 0.76700
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.55963, Loss: 0.06822
#
# Episode: 3600/25000 to 3800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.59/s)
#     Loss: 0.04189
#     Accuracy: 0.78222
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.61112, Loss: 0.06306
#
# Episode: 3800/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.52/s)
#     Loss: 0.03996
#     Accuracy: 0.80038
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60644, Loss: 0.06307
#
# Episode: 4000/25000 to 4200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.6s (14.67/s)
#     Loss: 0.03706
#     Accuracy: 0.82038
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.59072, Loss: 0.06384
#
# Episode: 4200/25000 to 4400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.58/s)
#     Loss: 0.03439
#     Accuracy: 0.83803
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60716, Loss: 0.06561
#
# Episode: 4400/25000 to 4600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.6s (14.69/s)
#     Loss: 0.03561
#     Accuracy: 0.82928
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.58550, Loss: 0.07138
#
# Episode: 4600/25000 to 4800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.30/s)
#     Loss: 0.03173
#     Accuracy: 0.84937
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.63391, Loss: 0.06255
#
# Episode: 4800/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.51/s)
#     Loss: 0.03074
#     Accuracy: 0.85950
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.61200, Loss: 0.06297
#
# Episode: 5000/25000 to 5200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.65/s)
#     Loss: 0.03002
#     Accuracy: 0.85853
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.62203, Loss: 0.06404
#
# Episode: 5200/25000 to 5400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.56/s)
#     Loss: 0.02993
#     Accuracy: 0.86347
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.63044, Loss: 0.06074
#
# Episode: 5400/25000 to 5600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.52/s)
#     Loss: 0.02853
#     Accuracy: 0.87644
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65066, Loss: 0.06018
#
# Episode: 5600/25000 to 5800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.61/s)
#     Loss: 0.02949
#     Accuracy: 0.86181
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.59250, Loss: 0.06943
#
# Episode: 5800/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.59/s)
#     Loss: 0.02705
#     Accuracy: 0.88266
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60750, Loss: 0.06279
#
# Episode: 6000/25000 to 6200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.62/s)
#     Loss: 0.02632
#     Accuracy: 0.88559
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64700, Loss: 0.06159
#
# Episode: 6200/25000 to 6400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.56/s)
#     Loss: 0.02846
#     Accuracy: 0.87547
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64409, Loss: 0.05982
#
# Episode: 6400/25000 to 6600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.60/s)
#     Loss: 0.02601
#     Accuracy: 0.88600
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.62725, Loss: 0.06643
#
# Episode: 6600/25000 to 6800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.6s (14.71/s)
#     Loss: 0.02515
#     Accuracy: 0.89331
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66659, Loss: 0.05973
#
# Episode: 6800/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.53/s)
#     Loss: 0.02630
#     Accuracy: 0.89059
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65641, Loss: 0.05973
#
# Episode: 7000/25000 to 7200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.56/s)
#     Loss: 0.02510
#     Accuracy: 0.89319
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66834, Loss: 0.06027
#
# Episode: 7200/25000 to 7400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.57/s)
#     Loss: 0.02472
#     Accuracy: 0.89706
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65234, Loss: 0.06028
#
# Episode: 7400/25000 to 7600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.57/s)
#     Loss: 0.02438
#     Accuracy: 0.89944
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.62794, Loss: 0.06111
#
# Episode: 7600/25000 to 7800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.5s (13.76/s)
#     Loss: 0.02301
#     Accuracy: 0.90691
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64825, Loss: 0.05870
#
# Episode: 7800/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.6s (14.65/s)
#     Loss: 0.02180
#     Accuracy: 0.91731
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64459, Loss: 0.06562
#
# Episode: 8000/25000 to 8200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.6s (14.66/s)
#     Loss: 0.02215
#     Accuracy: 0.91362
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65331, Loss: 0.06215
#
# Episode: 8200/25000 to 8400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.51/s)
#     Loss: 0.02100
#     Accuracy: 0.91884
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65556, Loss: 0.05860
#
# Episode: 8400/25000 to 8600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.54/s)
#     Loss: 0.02224
#     Accuracy: 0.91031
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64447, Loss: 0.06312
#
# Episode: 8600/25000 to 8800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.51/s)
#     Loss: 0.02265
#     Accuracy: 0.90759
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65537, Loss: 0.05971
#
# Episode: 8800/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.51/s)
#     Loss: 0.02145
#     Accuracy: 0.91803
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67400, Loss: 0.05572
#
# Episode: 9000/25000 to 9200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.6s (14.67/s)
#     Loss: 0.01956
#     Accuracy: 0.92188
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66588, Loss: 0.06077
#
# Episode: 9200/25000 to 9400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.6s (14.70/s)
#     Loss: 0.01963
#     Accuracy: 0.92456
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66147, Loss: 0.05982
#
# Episode: 9400/25000 to 9600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.50/s)
#     Loss: 0.02017
#     Accuracy: 0.92353
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66013, Loss: 0.06625
#
# Episode: 9600/25000 to 9800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.52/s)
#     Loss: 0.01874
#     Accuracy: 0.92953
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64912, Loss: 0.06467
#
# Episode: 9800/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.62/s)
#     Loss: 0.01907
#     Accuracy: 0.92853
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66612, Loss: 0.06544
#
# Episode: 10000/25000 to 10200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.60/s)
#     Loss: 0.01917
#     Accuracy: 0.92581
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64703, Loss: 0.06450
#
# Episode: 10200/25000 to 10400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.65/s)
#     Loss: 0.01921
#     Accuracy: 0.92812
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66156, Loss: 0.06144
#
# Episode: 10400/25000 to 10600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.55/s)
#     Loss: 0.01834
#     Accuracy: 0.93150
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.63928, Loss: 0.06242
#
# Episode: 10600/25000 to 10800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.2s (14.06/s)
#     Loss: 0.02021
#     Accuracy: 0.92369
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66269, Loss: 0.06191
#
# Episode: 10800/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.6s (14.67/s)
#     Loss: 0.01852
#     Accuracy: 0.92969
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65494, Loss: 0.06429
#
# Episode: 11000/25000 to 11200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.58/s)
#     Loss: 0.01804
#     Accuracy: 0.92941
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67312, Loss: 0.05880
#
# Episode: 11200/25000 to 11400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.55/s)
#     Loss: 0.01738
#     Accuracy: 0.93784
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66109, Loss: 0.05948
#
# Episode: 11400/25000 to 11600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.51/s)
#     Loss: 0.01816
#     Accuracy: 0.93238
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65156, Loss: 0.06272
#
# Episode: 11600/25000 to 11800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.33/s)
#     Loss: 0.01785
#     Accuracy: 0.93528
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64112, Loss: 0.06440
#
# Episode: 11800/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.32/s)
#     Loss: 0.01623
#     Accuracy: 0.94338
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65522, Loss: 0.07337
#
# Episode: 12000/25000 to 12200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.26/s)
#     Loss: 0.01779
#     Accuracy: 0.93347
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66894, Loss: 0.06735
#
# Episode: 12200/25000 to 12400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.24/s)
#     Loss: 0.01685
#     Accuracy: 0.93963
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66463, Loss: 0.05956
#
# Episode: 12400/25000 to 12600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.18/s)
#     Loss: 0.01646
#     Accuracy: 0.93947
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68088, Loss: 0.05940
#
# Episode: 12600/25000 to 12800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.23/s)
#     Loss: 0.01683
#     Accuracy: 0.94112
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66928, Loss: 0.05597
#
# Episode: 12800/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.9s (14.38/s)
#     Loss: 0.01689
#     Accuracy: 0.93803
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69128, Loss: 0.06232
#
# Episode: 13000/25000 to 13200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.29/s)
#     Loss: 0.01649
#     Accuracy: 0.94072
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65109, Loss: 0.06121
#
# Episode: 13200/25000 to 13400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.28/s)
#     Loss: 0.01578
#     Accuracy: 0.94316
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67859, Loss: 0.06040
#
# Episode: 13400/25000 to 13600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.19/s)
#     Loss: 0.01697
#     Accuracy: 0.94025
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64750, Loss: 0.06532
#
# Episode: 13600/25000 to 13800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.2s (14.13/s)
#     Loss: 0.01610
#     Accuracy: 0.93981
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65850, Loss: 0.06375
#
# Episode: 13800/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.28/s)
#     Loss: 0.01626
#     Accuracy: 0.94231
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65356, Loss: 0.05727
#
# Episode: 14000/25000 to 14200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.23/s)
#     Loss: 0.01691
#     Accuracy: 0.93856
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67959, Loss: 0.06179
#
# Episode: 14200/25000 to 14400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.19/s)
#     Loss: 0.01464
#     Accuracy: 0.94691
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66356, Loss: 0.06120
#
# Episode: 14400/25000 to 14600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.19/s)
#     Loss: 0.01556
#     Accuracy: 0.94487
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64075, Loss: 0.06379
#
# Episode: 14600/25000 to 14800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.24/s)
#     Loss: 0.01561
#     Accuracy: 0.94384
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66787, Loss: 0.06202
#
# Episode: 14800/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.22/s)
#     Loss: 0.01487
#     Accuracy: 0.94584
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67094, Loss: 0.06335
#
# Episode: 15000/25000 to 15200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.21/s)
#     Loss: 0.01608
#     Accuracy: 0.93772
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65341, Loss: 0.06439
#
# Episode: 15200/25000 to 15400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.18/s)
#     Loss: 0.01508
#     Accuracy: 0.94844
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67097, Loss: 0.05701
#
# Episode: 15400/25000 to 15600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.9s (14.34/s)
#     Loss: 0.01479
#     Accuracy: 0.95047
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68284, Loss: 0.05694
#
# Episode: 15600/25000 to 15800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.14/s)
#     Loss: 0.01430
#     Accuracy: 0.94847
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67713, Loss: 0.06165
#
# Episode: 15800/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.23/s)
#     Loss: 0.01528
#     Accuracy: 0.94519
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67728, Loss: 0.05766
#
# Episode: 16000/25000 to 16200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.27/s)
#     Loss: 0.01538
#     Accuracy: 0.94497
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65412, Loss: 0.06406
#
# Episode: 16200/25000 to 16400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.2s (14.09/s)
#     Loss: 0.01471
#     Accuracy: 0.94769
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70041, Loss: 0.05669
#
# Episode: 16400/25000 to 16600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.16/s)
#     Loss: 0.01338
#     Accuracy: 0.95384
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65306, Loss: 0.06667
#
# Episode: 16600/25000 to 16800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.6s (13.70/s)
#     Loss: 0.01658
#     Accuracy: 0.93984
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68575, Loss: 0.05551
#
# Episode: 16800/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.27/s)
#     Loss: 0.01421
#     Accuracy: 0.94966
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67422, Loss: 0.06401
#
# Episode: 17000/25000 to 17200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.2s (14.12/s)
#     Loss: 0.01423
#     Accuracy: 0.95309
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65569, Loss: 0.06161
#
# Episode: 17200/25000 to 17400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.29/s)
#     Loss: 0.01361
#     Accuracy: 0.95500
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65606, Loss: 0.06684
#
# Episode: 17400/25000 to 17600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.24/s)
#     Loss: 0.01456
#     Accuracy: 0.95128
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67447, Loss: 0.05890
#
# Episode: 17600/25000 to 17800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.19/s)
#     Loss: 0.01406
#     Accuracy: 0.95362
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67463, Loss: 0.06238
#
# Episode: 17800/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.16/s)
#     Loss: 0.01372
#     Accuracy: 0.95216
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64872, Loss: 0.06467
#
# Episode: 18000/25000 to 18200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.2s (14.06/s)
#     Loss: 0.01358
#     Accuracy: 0.95681
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68416, Loss: 0.05444
#
# Episode: 18200/25000 to 18400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.25/s)
#     Loss: 0.01398
#     Accuracy: 0.95247
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65919, Loss: 0.06298
#
# Episode: 18400/25000 to 18600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.17/s)
#     Loss: 0.01442
#     Accuracy: 0.94878
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65609, Loss: 0.06636
#
# Episode: 18600/25000 to 18800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.2s (14.07/s)
#     Loss: 0.01277
#     Accuracy: 0.95609
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67869, Loss: 0.05690
#
# Episode: 18800/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.2s (14.07/s)
#     Loss: 0.01277
#     Accuracy: 0.96034
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66741, Loss: 0.05940
#
# Episode: 19000/25000 to 19200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.18/s)
#     Loss: 0.01397
#     Accuracy: 0.95225
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66938, Loss: 0.05883
#
# Episode: 19200/25000 to 19400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.2s (14.10/s)
#     Loss: 0.01288
#     Accuracy: 0.95509
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64050, Loss: 0.06374
#
# Episode: 19400/25000 to 19600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.27/s)
#     Loss: 0.01297
#     Accuracy: 0.95834
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66656, Loss: 0.05996
#
# Episode: 19600/25000 to 19800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.28/s)
#     Loss: 0.01288
#     Accuracy: 0.95575
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65581, Loss: 0.06301
#
# Episode: 19800/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.16/s)
#     Loss: 0.01351
#     Accuracy: 0.95209
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68094, Loss: 0.05783
#
# Episode: 20000/25000 to 20200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.2s (14.13/s)
#     Loss: 0.01305
#     Accuracy: 0.95797
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66697, Loss: 0.06199
#
# Episode: 20200/25000 to 20400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.29/s)
#     Loss: 0.01195
#     Accuracy: 0.95716
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65872, Loss: 0.06187
#
# Episode: 20400/25000 to 20600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.28/s)
#     Loss: 0.01325
#     Accuracy: 0.95375
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66387, Loss: 0.06422
#
# Episode: 20600/25000 to 20800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.17/s)
#     Loss: 0.01163
#     Accuracy: 0.96181
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66056, Loss: 0.06415
#
# Episode: 20800/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.28/s)
#     Loss: 0.01342
#     Accuracy: 0.95491
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64156, Loss: 0.06328
#
# Episode: 21000/25000 to 21200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.16/s)
#     Loss: 0.01293
#     Accuracy: 0.95700
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.63694, Loss: 0.06385
#
# Episode: 21200/25000 to 21400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.28/s)
#     Loss: 0.01361
#     Accuracy: 0.94981
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65034, Loss: 0.06331
#
# Episode: 21400/25000 to 21600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.24/s)
#     Loss: 0.01244
#     Accuracy: 0.95863
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.63669, Loss: 0.06582
#
# Episode: 21600/25000 to 21800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.15/s)
#     Loss: 0.01258
#     Accuracy: 0.96063
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66366, Loss: 0.05908
#
# Episode: 21800/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.2s (14.13/s)
#     Loss: 0.01201
#     Accuracy: 0.96041
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64631, Loss: 0.06231
#
# Episode: 22000/25000 to 22200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.26/s)
#     Loss: 0.01180
#     Accuracy: 0.96516
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64444, Loss: 0.06338
#
# Episode: 22200/25000 to 22400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.65/s)
#     Loss: 0.01278
#     Accuracy: 0.95497
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64372, Loss: 0.06424
#
# Episode: 22400/25000 to 22600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.53/s)
#     Loss: 0.01182
#     Accuracy: 0.96381
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65897, Loss: 0.06547
#
# Episode: 22600/25000 to 22800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.55/s)
#     Loss: 0.01265
#     Accuracy: 0.95609
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64672, Loss: 0.06285
#
# Episode: 22800/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.5s (13.78/s)
#     Loss: 0.01301
#     Accuracy: 0.95581
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64978, Loss: 0.06573
#
# Episode: 23000/25000 to 23200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.47/s)
#     Loss: 0.01148
#     Accuracy: 0.96291
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65534, Loss: 0.06378
#
# Episode: 23200/25000 to 23400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.49/s)
#     Loss: 0.01091
#     Accuracy: 0.96481
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67722, Loss: 0.06083
#
# Episode: 23400/25000 to 23600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.9s (14.41/s)
#     Loss: 0.01093
#     Accuracy: 0.96541
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66316, Loss: 0.05933
#
# Episode: 23600/25000 to 23800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.9s (14.42/s)
#     Loss: 0.01238
#     Accuracy: 0.95813
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64056, Loss: 0.06540
#
# Episode: 23800/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.9s (14.44/s)
#     Loss: 0.01123
#     Accuracy: 0.96513
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66634, Loss: 0.06311
#
# Episode: 24000/25000 to 24200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.46/s)
#     Loss: 0.01214
#     Accuracy: 0.96303
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65194, Loss: 0.06116
#
# Episode: 24200/25000 to 24400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.9s (14.39/s)
#     Loss: 0.01202
#     Accuracy: 0.95838
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.63203, Loss: 0.06265
#
# Episode: 24400/25000 to 24600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.33/s)
#     Loss: 0.01122
#     Accuracy: 0.96419
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67034, Loss: 0.05919
#
# Episode: 24600/25000 to 24800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.9s (14.38/s)
#     Loss: 0.01183
#     Accuracy: 0.96144
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65756, Loss: 0.06155
#
# Episode: 24800/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.45/s)
#     Loss: 0.01205
#     Accuracy: 0.95800
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.63962, Loss: 0.06434

# %% [markdown]
# Success of the training is examined by analyzing the training curve.

# %%
plot_traincurve('training/run_0', ['train_accuracy', 'eval_accuracy'], 'Accuracy')

# %% [markdown]
# ## Perform a tuning run

# %% [markdown]
# The most decisive hyperparameters present in the model are determined by a tuning process, which runs the model training several times and tries to boost the models performance by minimizing the evaluation-loss with adaptations to the hyperparameters.

# %%
tuning = optuna.create_study(direction="minimize", 
                             sampler = optuna.samplers.TPESampler(),
                             pruner = optuna.pruners.MedianPruner(n_startup_trials=5))

tuning.optimize(run_tuning, n_trials=25)

pruned_trials = tuning.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = tuning.get_trials(deepcopy=False, states=[TrialState.COMPLETE])
importances = optuna.importance.get_param_importances(tuning)

print('\n')
print('#######################################################################')
print('########################### FINISHED TUNING ###########################')
print('#######################################################################')
print('\n \n')

print('Tuning statistics: ')
print('  Number of trials: ', len(tuning.trials))
print('  Number of pruned trials: ', len(pruned_trials))
print('  Number of complete trials: ', len(complete_trials), '\n')

print('Best trial:')
trial = tuning.best_trial

print(f'  Run {str(trial.number)} with Loss {min(trial.intermediate_values.values())} at Episode {min(trial.intermediate_values, key=trial.intermediate_values.get)}')

print('  Params: ')
for key, value in trial.params.items():
  print('    {}: {}'.format(key, value))
# Out:
# [I 2022-06-02 13:38:39,140] A new study created in memory with name: no-name-eb1cf74b-5f29-450d-b3ea-d213f86e4f5a
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_0
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.4s (13.38/s)
#     Loss: 0.22462
#     Accuracy: 0.09749
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09941, Loss: 0.16872
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.1s (13.48/s)
#     Loss: 0.12720
#     Accuracy: 0.10071
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10103, Loss: 0.10050
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 36.8s (13.59/s)
#     Loss: 0.09279
#     Accuracy: 0.10071
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10053, Loss: 0.08847
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 36.9s (13.54/s)
#     Loss: 0.08795
#     Accuracy: 0.10115
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10291, Loss: 0.08686
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 36.9s (13.55/s)
#     Loss: 0.08721
#     Accuracy: 0.14616
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.17709, Loss: 0.08607
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.2s (13.44/s)
#     Loss: 0.08662
#     Accuracy: 0.16496
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.18625, Loss: 0.08582
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.0s (13.53/s)
#     Loss: 0.08659
#     Accuracy: 0.16749
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.17538, Loss: 0.08610
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.1s (13.48/s)
#     Loss: 0.08619
#     Accuracy: 0.16859
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.17653, Loss: 0.08549
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 36.9s (13.54/s)
#     Loss: 0.08620
#     Accuracy: 0.16855
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.18369, Loss: 0.08511
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.1s (13.47/s)
#     Loss: 0.08617
#     Accuracy: 0.16646
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.18422, Loss: 0.08477
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.0s (13.51/s)
#     Loss: 0.08569
#     Accuracy: 0.17873
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.18891, Loss: 0.08476
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.1s (13.49/s)
#     Loss: 0.08580
#     Accuracy: 0.18526
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19113, Loss: 0.08487
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.0s (13.50/s)
#     Loss: 0.08509
#     Accuracy: 0.20458
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19984, Loss: 0.08448
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.1s (13.46/s)
#     Loss: 0.08497
#     Accuracy: 0.21755
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21684, Loss: 0.08418
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.7s (13.27/s)
#     Loss: 0.08415
#     Accuracy: 0.23159
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21197, Loss: 0.08453
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 36.9s (13.56/s)
#     Loss: 0.08253
#     Accuracy: 0.25946
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.23584, Loss: 0.08359
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 36.8s (13.57/s)
#     Loss: 0.08139
#     Accuracy: 0.27981
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.23691, Loss: 0.08409
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 36.9s (13.56/s)
#     Loss: 0.08024
#     Accuracy: 0.29946
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.24500, Loss: 0.08475
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.2s (13.43/s)
#     Loss: 0.07940
#     Accuracy: 0.31658
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.25831, Loss: 0.08291
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 36.9s (13.54/s)
#     Loss: 0.07837
#     Accuracy: 0.33141
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.25700, Loss: 0.08302
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.0s (13.51/s)
#     Loss: 0.07836
#     Accuracy: 0.32988
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.27903, Loss: 0.08655
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 36.9s (13.56/s)
#     Loss: 0.07767
#     Accuracy: 0.33885
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.26744, Loss: 0.08366
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.4s (13.37/s)
#     Loss: 0.07713
#     Accuracy: 0.34201
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.26544, Loss: 0.08403
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.1s (13.48/s)
#     Loss: 0.07622
#     Accuracy: 0.36206
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.26941, Loss: 0.08257
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 36.9s (13.54/s)
#     Loss: 0.07629
#     Accuracy: 0.36920
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.27347, Loss: 0.08278
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.0s (13.52/s)
#     Loss: 0.07595
#     Accuracy: 0.37220
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.28528, Loss: 0.08287
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.2s (13.45/s)
#     Loss: 0.07525
#     Accuracy: 0.37966
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.28216, Loss: 0.08263
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.2s (13.43/s)
#     Loss: 0.07496
#     Accuracy: 0.38104
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.28428, Loss: 0.08486
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.1s (13.48/s)
#     Loss: 0.07438
#     Accuracy: 0.40190
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.28413, Loss: 0.08545
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.1s (13.48/s)
#     Loss: 0.07396
#     Accuracy: 0.40279
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.29747, Loss: 0.08498
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.1s (13.48/s)
#     Loss: 0.07349
#     Accuracy: 0.41235
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.28600, Loss: 0.08392
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 36.9s (13.55/s)
#     Loss: 0.07288
#     Accuracy: 0.41895
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.29569, Loss: 0.08292
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.2s (13.43/s)
#     Loss: 0.07264
#     Accuracy: 0.42473
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.29653, Loss: 0.08905
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.2s (13.43/s)
#     Loss: 0.07191
#     Accuracy: 0.43776
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.29647, Loss: 0.08399
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.3s (13.40/s)
#     Loss: 0.07153
#     Accuracy: 0.44189
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.29819, Loss: 0.08473
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.3s (13.41/s)
#     Loss: 0.07119
#     Accuracy: 0.44690
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31488, Loss: 0.08295
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.2s (13.44/s)
#     Loss: 0.07054
#     Accuracy: 0.45400
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.30962, Loss: 0.08349
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.0s (13.50/s)
#     Loss: 0.06918
#     Accuracy: 0.46976
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31312, Loss: 0.08508
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.5s (13.32/s)
#     Loss: 0.06916
#     Accuracy: 0.46906
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.30378, Loss: 0.08425
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.3s (13.42/s)
#     Loss: 0.06901
#     Accuracy: 0.47663
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.29616, Loss: 0.08466
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.4s (13.37/s)
#     Loss: 0.06873
#     Accuracy: 0.48114
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.29534, Loss: 0.08542
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.5s (13.33/s)
#     Loss: 0.06769
#     Accuracy: 0.49508
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31247, Loss: 0.08539
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.2s (13.45/s)
#     Loss: 0.06806
#     Accuracy: 0.49205
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31822, Loss: 0.08386
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.4s (13.37/s)
#     Loss: 0.06804
#     Accuracy: 0.49750
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31547, Loss: 0.08543
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.3s (13.39/s)
#     Loss: 0.06692
#     Accuracy: 0.50482
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31312, Loss: 0.08395
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.5s (13.35/s)
#     Loss: 0.06653
#     Accuracy: 0.51499
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31684, Loss: 0.08518
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.2s (13.43/s)
#     Loss: 0.06587
#     Accuracy: 0.51690
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31875, Loss: 0.08560
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.2s (13.44/s)
#     Loss: 0.06570
#     Accuracy: 0.52612
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31688, Loss: 0.08746
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.3s (13.40/s)
#     Loss: 0.06517
#     Accuracy: 0.52826
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31391, Loss: 0.08591
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.2s (13.42/s)
#     Loss: 0.06544
#     Accuracy: 0.52669
# [I 2022-06-02 14:18:51,570] Trial 0 finished with value: 0.08257320757955312 and parameters: {'num_fc_layers': 3, 'num_units_fc_layer0': 128, 'num_units_fc_layer1': 64, 'num_units_fc_layer2': 32, 'num_lstm_layer_encoder': 1, 'num_units_lstm_encoder': 256, 'num_lstm_layer_relationnet': 1, 'num_units_lstm_relationnet': 32, 'learning_rate': 1.365023415688928e-05, 'learning_rate_schedule_rate': 6500}. Best is trial 0 with value: 0.08257320757955312.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31469, Loss: 0.08792
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_1
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.1 (6.84/s)
#     Loss: 0.09252
#     Accuracy: 0.10015
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09997, Loss: 0.09000
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.4 (6.81/s)
#     Loss: 0.09000
#     Accuracy: 0.10001
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10009, Loss: 0.09000
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.7 (6.79/s)
#     Loss: 0.09000
#     Accuracy: 0.10020
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09994, Loss: 0.09000
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.3 (6.82/s)
#     Loss: 0.09000
#     Accuracy: 0.09994
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10016, Loss: 0.09000
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:16.7 (6.52/s)
#     Loss: 0.09000
#     Accuracy: 0.10008
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10003, Loss: 0.09000
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.76/s)
#     Loss: 0.09000
#     Accuracy: 0.10129
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09988, Loss: 0.09000
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.3 (6.82/s)
#     Loss: 0.09000
#     Accuracy: 0.10550
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10037, Loss: 0.09000
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.3 (6.82/s)
#     Loss: 0.09000
#     Accuracy: 0.10024
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10025, Loss: 0.09000
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.0 (6.85/s)
#     Loss: 0.09000
#     Accuracy: 0.10028
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10181, Loss: 0.09000
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.3 (6.82/s)
#     Loss: 0.09739
#     Accuracy: 0.11426
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10012, Loss: 0.10000
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.8 (6.86/s)
#     Loss: 0.10000
#     Accuracy: 0.10009
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10006, Loss: 0.10000
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.3 (6.82/s)
#     Loss: 0.10000
#     Accuracy: 0.09990
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10009, Loss: 0.10000
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.8 (6.86/s)
#     Loss: 0.10000
#     Accuracy: 0.09980
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09975, Loss: 0.10000
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.0 (6.85/s)
#     Loss: 0.10000
#     Accuracy: 0.10003
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10009, Loss: 0.10000
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.7 (6.88/s)
#     Loss: 0.10000
#     Accuracy: 0.10004
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10003, Loss: 0.10000
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.3 (6.82/s)
#     Loss: 0.10000
#     Accuracy: 0.10008
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10006, Loss: 0.10000
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.8 (6.87/s)
#     Loss: 0.10000
#     Accuracy: 0.10000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09978, Loss: 0.10000
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.9 (6.86/s)
#     Loss: 0.10000
#     Accuracy: 0.09995
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.10000
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.2 (6.83/s)
#     Loss: 0.10000
#     Accuracy: 0.09991
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09997, Loss: 0.10000
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.4 (6.81/s)
#     Loss: 0.10000
#     Accuracy: 0.09985
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09975, Loss: 0.10000
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.8 (6.87/s)
#     Loss: 0.10000
#     Accuracy: 0.10005
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09963, Loss: 0.10000
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.0 (6.85/s)
#     Loss: 0.10000
#     Accuracy: 0.09990
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09984, Loss: 0.10000
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.0 (6.85/s)
#     Loss: 0.10000
#     Accuracy: 0.09995
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.10000
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.8 (6.87/s)
#     Loss: 0.10000
#     Accuracy: 0.09998
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09991, Loss: 0.10000
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.1 (6.84/s)
#     Loss: 0.10000
#     Accuracy: 0.09990
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10009, Loss: 0.10000
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.9 (6.86/s)
#     Loss: 0.10000
#     Accuracy: 0.09989
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10031, Loss: 0.10000
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.8 (6.87/s)
#     Loss: 0.10000
#     Accuracy: 0.09994
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09994, Loss: 0.10000
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.7 (6.87/s)
#     Loss: 0.10000
#     Accuracy: 0.10000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10003, Loss: 0.10000
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.7 (6.88/s)
#     Loss: 0.10000
#     Accuracy: 0.09985
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09994, Loss: 0.10000
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.1 (6.84/s)
#     Loss: 0.10000
#     Accuracy: 0.10001
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09994, Loss: 0.10000
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.6 (6.89/s)
#     Loss: 0.10000
#     Accuracy: 0.09993
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10016, Loss: 0.10000
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.6 (6.88/s)
#     Loss: 0.10000
#     Accuracy: 0.09984
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09994, Loss: 0.10000
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.5 (6.90/s)
#     Loss: 0.10000
#     Accuracy: 0.09994
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10003, Loss: 0.10000
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.9 (6.86/s)
#     Loss: 0.10000
#     Accuracy: 0.09986
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10006, Loss: 0.10000
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.0 (6.85/s)
#     Loss: 0.10000
#     Accuracy: 0.10001
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10003, Loss: 0.10000
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.1 (6.84/s)
#     Loss: 0.10000
#     Accuracy: 0.10001
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09991, Loss: 0.10000
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.3 (6.83/s)
#     Loss: 0.10000
#     Accuracy: 0.09985
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10025, Loss: 0.10000
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.4 (6.81/s)
#     Loss: 0.10000
#     Accuracy: 0.09999
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.10000
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.8 (6.87/s)
#     Loss: 0.10000
#     Accuracy: 0.10004
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09991, Loss: 0.10000
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.0 (6.85/s)
#     Loss: 0.10000
#     Accuracy: 0.09989
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.10000
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.8 (6.87/s)
#     Loss: 0.10000
#     Accuracy: 0.09996
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09994, Loss: 0.10000
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.3 (6.82/s)
#     Loss: 0.10000
#     Accuracy: 0.09990
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09997, Loss: 0.10000
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.0 (6.85/s)
#     Loss: 0.10000
#     Accuracy: 0.09983
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.10000
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.9 (6.86/s)
#     Loss: 0.10000
#     Accuracy: 0.10009
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10006, Loss: 0.10000
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.1 (6.84/s)
#     Loss: 0.10000
#     Accuracy: 0.09995
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.10000
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.2 (6.83/s)
#     Loss: 0.10000
#     Accuracy: 0.09985
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.10000
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.6 (6.80/s)
#     Loss: 0.10000
#     Accuracy: 0.09991
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10019, Loss: 0.10000
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.9 (6.85/s)
#     Loss: 0.10000
#     Accuracy: 0.09990
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09984, Loss: 0.10000
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:12.9 (6.86/s)
#     Loss: 0.10000
#     Accuracy: 0.09996
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10003, Loss: 0.10000
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.5 (6.80/s)
#     Loss: 0.10000
#     Accuracy: 0.10014
# [I 2022-06-02 15:34:14,653] Trial 1 finished with value: 0.0899995968863368 and parameters: {'num_fc_layers': 3, 'num_units_fc_layer0': 128, 'num_units_fc_layer1': 256, 'num_units_fc_layer2': 64, 'num_lstm_layer_encoder': 3, 'num_units_lstm_encoder': 32, 'num_lstm_layer_relationnet': 2, 'num_units_lstm_relationnet': 256, 'learning_rate': 0.0012545608904964557, 'learning_rate_schedule_rate': 9500}. Best is trial 0 with value: 0.08257320757955312.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09988, Loss: 0.10000
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_2
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.9s (10.89/s)
#     Loss: 0.09319
#     Accuracy: 0.09998
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09991, Loss: 0.09000
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.8s (10.91/s)
#     Loss: 0.09000
#     Accuracy: 0.10009
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10003, Loss: 0.09000
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.5s (10.98/s)
#     Loss: 0.09000
#     Accuracy: 0.10003
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10006, Loss: 0.09000
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.7s (10.94/s)
#     Loss: 0.09000
#     Accuracy: 0.10001
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.7s (10.95/s)
#     Loss: 0.09000
#     Accuracy: 0.10004
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09994, Loss: 0.09000
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.7s (10.71/s)
#     Loss: 0.09000
#     Accuracy: 0.09998
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.6s (10.96/s)
#     Loss: 0.08999
#     Accuracy: 0.10023
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10025, Loss: 0.08871
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.4s (11.00/s)
#     Loss: 0.08635
#     Accuracy: 0.17059
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19641, Loss: 0.08435
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.7s (10.95/s)
#     Loss: 0.08520
#     Accuracy: 0.18089
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.18650, Loss: 0.08462
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.7s (10.94/s)
#     Loss: 0.08583
#     Accuracy: 0.17356
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.18756, Loss: 0.08420
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.8s (10.92/s)
#     Loss: 0.08548
#     Accuracy: 0.17614
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.18847, Loss: 0.08413
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.8s (10.91/s)
#     Loss: 0.08535
#     Accuracy: 0.17704
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19159, Loss: 0.08456
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.7s (10.93/s)
#     Loss: 0.08530
#     Accuracy: 0.17964
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19709, Loss: 0.08423
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.8s (10.91/s)
#     Loss: 0.08541
#     Accuracy: 0.17709
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.18434, Loss: 0.08467
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.8s (10.91/s)
#     Loss: 0.08547
#     Accuracy: 0.17703
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.18937, Loss: 0.08459
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.0s (10.87/s)
#     Loss: 0.08559
#     Accuracy: 0.17634
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19359, Loss: 0.08440
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.9s (10.89/s)
#     Loss: 0.08488
#     Accuracy: 0.19499
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.18337, Loss: 0.08544
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.0s (10.87/s)
#     Loss: 0.08492
#     Accuracy: 0.19920
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19503, Loss: 0.08484
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.6s (10.95/s)
#     Loss: 0.08347
#     Accuracy: 0.22241
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.25288, Loss: 0.08168
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.8s (10.91/s)
#     Loss: 0.08269
#     Accuracy: 0.23195
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.25200, Loss: 0.08171
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.1s (10.84/s)
#     Loss: 0.08214
#     Accuracy: 0.24166
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.25700, Loss: 0.08118
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.2s (10.83/s)
#     Loss: 0.08178
#     Accuracy: 0.24003
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20497, Loss: 0.08462
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.2s (10.81/s)
#     Loss: 0.08151
#     Accuracy: 0.24680
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.26084, Loss: 0.08148
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.1s (10.84/s)
#     Loss: 0.08088
#     Accuracy: 0.25362
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.26988, Loss: 0.08125
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.0s (10.87/s)
#     Loss: 0.08041
#     Accuracy: 0.26950
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.26281, Loss: 0.08105
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.0s (10.87/s)
#     Loss: 0.07942
#     Accuracy: 0.28962
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.28322, Loss: 0.08033
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.2s (10.83/s)
#     Loss: 0.07821
#     Accuracy: 0.30670
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.29372, Loss: 0.08042
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.8s (10.92/s)
#     Loss: 0.07758
#     Accuracy: 0.31190
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31359, Loss: 0.07958
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.4s (11.02/s)
#     Loss: 0.07660
#     Accuracy: 0.34168
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.34444, Loss: 0.07963
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.3s (10.79/s)
#     Loss: 0.07082
#     Accuracy: 0.43966
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.41472, Loss: 0.07557
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.8s (10.92/s)
#     Loss: 0.06827
#     Accuracy: 0.47396
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.40484, Loss: 0.07804
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.7s (10.94/s)
#     Loss: 0.06693
#     Accuracy: 0.49947
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.42678, Loss: 0.07534
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.8s (10.92/s)
#     Loss: 0.06539
#     Accuracy: 0.50929
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.45850, Loss: 0.07364
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.3s (10.81/s)
#     Loss: 0.06361
#     Accuracy: 0.52384
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.45184, Loss: 0.07450
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.9s (10.88/s)
#     Loss: 0.06250
#     Accuracy: 0.53966
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.47063, Loss: 0.07397
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.5s (10.75/s)
#     Loss: 0.06208
#     Accuracy: 0.54503
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.46672, Loss: 0.07885
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.1s (10.85/s)
#     Loss: 0.06128
#     Accuracy: 0.56677
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.47116, Loss: 0.07263
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.8s (10.91/s)
#     Loss: 0.05944
#     Accuracy: 0.59124
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.50191, Loss: 0.07071
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.6s (10.96/s)
#     Loss: 0.05716
#     Accuracy: 0.61931
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.51438, Loss: 0.07104
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.8s (10.92/s)
#     Loss: 0.05455
#     Accuracy: 0.64845
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.52131, Loss: 0.07107
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.9s (10.90/s)
#     Loss: 0.05297
#     Accuracy: 0.67050
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.55112, Loss: 0.06794
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 47.0s (10.64/s)
#     Loss: 0.05223
#     Accuracy: 0.68033
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.54837, Loss: 0.06822
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.8s (10.91/s)
#     Loss: 0.04819
#     Accuracy: 0.71695
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.55656, Loss: 0.06826
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.0s (10.88/s)
#     Loss: 0.04588
#     Accuracy: 0.73758
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.55294, Loss: 0.06669
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.9s (10.90/s)
#     Loss: 0.04559
#     Accuracy: 0.73853
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.54775, Loss: 0.06893
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.4s (10.77/s)
#     Loss: 0.04443
#     Accuracy: 0.74544
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.54834, Loss: 0.07168
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.3s (10.80/s)
#     Loss: 0.04302
#     Accuracy: 0.76119
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.53378, Loss: 0.07271
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 47.1s (10.61/s)
#     Loss: 0.04151
#     Accuracy: 0.77396
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.56981, Loss: 0.06652
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.3s (10.79/s)
#     Loss: 0.04065
#     Accuracy: 0.78214
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.56375, Loss: 0.06942
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.3s (10.80/s)
#     Loss: 0.03851
#     Accuracy: 0.79612
# [I 2022-06-02 16:22:57,026] Trial 2 finished with value: 0.0665234418772161 and parameters: {'num_fc_layers': 3, 'num_units_fc_layer0': 64, 'num_units_fc_layer1': 64, 'num_units_fc_layer2': 256, 'num_lstm_layer_encoder': 3, 'num_units_lstm_encoder': 16, 'num_lstm_layer_relationnet': 2, 'num_units_lstm_relationnet': 128, 'learning_rate': 0.0011520067698885994, 'learning_rate_schedule_rate': 3000}. Best is trial 2 with value: 0.0665234418772161.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.56731, Loss: 0.06917
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_3
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.6s (11.73/s)
#     Loss: 0.23217
#     Accuracy: 0.09990
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10019, Loss: 0.19309
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.9s (11.65/s)
#     Loss: 0.12275
#     Accuracy: 0.10105
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10091, Loss: 0.09122
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.9s (11.65/s)
#     Loss: 0.09024
#     Accuracy: 0.10075
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10137, Loss: 0.09001
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.9s (11.66/s)
#     Loss: 0.09000
#     Accuracy: 0.10016
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10022, Loss: 0.09000
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.63/s)
#     Loss: 0.09000
#     Accuracy: 0.10093
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10106, Loss: 0.09000
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.1s (11.61/s)
#     Loss: 0.09000
#     Accuracy: 0.10083
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10131, Loss: 0.09000
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.9s (11.65/s)
#     Loss: 0.09000
#     Accuracy: 0.10066
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10056, Loss: 0.09000
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.63/s)
#     Loss: 0.09000
#     Accuracy: 0.10066
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10284, Loss: 0.09000
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.9s (11.67/s)
#     Loss: 0.08997
#     Accuracy: 0.10073
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10094, Loss: 0.08963
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.63/s)
#     Loss: 0.08843
#     Accuracy: 0.10183
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10350, Loss: 0.08697
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 44.1s (11.35/s)
#     Loss: 0.08748
#     Accuracy: 0.10133
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10019, Loss: 0.08624
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.9s (11.66/s)
#     Loss: 0.08709
#     Accuracy: 0.10340
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10256, Loss: 0.08634
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.62/s)
#     Loss: 0.08674
#     Accuracy: 0.10364
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09956, Loss: 0.08610
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.2s (11.58/s)
#     Loss: 0.08677
#     Accuracy: 0.10250
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10203, Loss: 0.08620
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.7s (11.71/s)
#     Loss: 0.08691
#     Accuracy: 0.10348
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10253, Loss: 0.08644
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.8s (11.68/s)
#     Loss: 0.08692
#     Accuracy: 0.10250
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10134, Loss: 0.08675
#
# Episode: 8000/25000 to 8500/25000
# ...
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64016, Loss: 0.06209
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_23
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.6s (11.73/s)
#     Loss: 0.08768
#     Accuracy: 0.16839
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20603, Loss: 0.08452
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.4s (11.79/s)
#     Loss: 0.08194
#     Accuracy: 0.31067
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.32659, Loss: 0.08184
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.6s (11.74/s)
#     Loss: 0.06905
#     Accuracy: 0.52135
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.40066, Loss: 0.07752
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.2s (11.57/s)
#     Loss: 0.06267
#     Accuracy: 0.59176
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.42566, Loss: 0.07573
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.4s (11.52/s)
#     Loss: 0.05526
#     Accuracy: 0.66504
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.48509, Loss: 0.07095
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.6s (11.74/s)
#     Loss: 0.05113
#     Accuracy: 0.70272
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.54163, Loss: 0.06789
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.6s (11.75/s)
#     Loss: 0.04586
#     Accuracy: 0.74629
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.58437, Loss: 0.06968
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.62/s)
#     Loss: 0.04216
#     Accuracy: 0.78019
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.59359, Loss: 0.06564
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.8s (11.41/s)
#     Loss: 0.03936
#     Accuracy: 0.80665
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.61800, Loss: 0.06184
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.63/s)
#     Loss: 0.03590
#     Accuracy: 0.82803
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64228, Loss: 0.06026
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.9s (11.65/s)
#     Loss: 0.03436
#     Accuracy: 0.83536
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.61966, Loss: 0.06502
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.9s (11.67/s)
#     Loss: 0.03246
#     Accuracy: 0.85197
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66081, Loss: 0.05894
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 44.0s (11.38/s)
#     Loss: 0.03037
#     Accuracy: 0.86690
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66309, Loss: 0.06406
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.63/s)
#     Loss: 0.02827
#     Accuracy: 0.87870
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65197, Loss: 0.07094
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.62/s)
#     Loss: 0.02561
#     Accuracy: 0.89589
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.63419, Loss: 0.06235
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.64/s)
#     Loss: 0.02617
#     Accuracy: 0.89080
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66684, Loss: 0.06512
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.9s (11.65/s)
#     Loss: 0.02488
#     Accuracy: 0.89845
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67537, Loss: 0.06093
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.2s (11.57/s)
#     Loss: 0.02365
#     Accuracy: 0.90701
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68453, Loss: 0.06038
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.1s (11.59/s)
#     Loss: 0.02193
#     Accuracy: 0.91525
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65797, Loss: 0.05804
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.63/s)
#     Loss: 0.02244
#     Accuracy: 0.91266
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67391, Loss: 0.06339
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.64/s)
#     Loss: 0.02211
#     Accuracy: 0.91288
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67478, Loss: 0.06260
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.6s (11.75/s)
#     Loss: 0.02100
#     Accuracy: 0.92016
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71722, Loss: 0.05634
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.8s (11.67/s)
#     Loss: 0.02142
#     Accuracy: 0.91938
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67259, Loss: 0.05809
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.3s (11.56/s)
#     Loss: 0.02072
#     Accuracy: 0.92335
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69506, Loss: 0.05846
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.1s (11.59/s)
#     Loss: 0.01981
#     Accuracy: 0.92425
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67713, Loss: 0.05452
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.5s (11.51/s)
#     Loss: 0.01921
#     Accuracy: 0.92874
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67494, Loss: 0.05984
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.8s (11.68/s)
#     Loss: 0.01953
#     Accuracy: 0.92685
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69025, Loss: 0.06014
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.1s (11.61/s)
#     Loss: 0.01908
#     Accuracy: 0.92881
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68950, Loss: 0.05541
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.6s (11.75/s)
#     Loss: 0.01816
#     Accuracy: 0.93369
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69225, Loss: 0.06188
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.9s (11.38/s)
#     Loss: 0.01799
#     Accuracy: 0.93184
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68116, Loss: 0.06071
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.63/s)
#     Loss: 0.01843
#     Accuracy: 0.93189
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69737, Loss: 0.05594
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.62/s)
#     Loss: 0.01792
#     Accuracy: 0.93442
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69797, Loss: 0.05535
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.64/s)
#     Loss: 0.01758
#     Accuracy: 0.93519
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68103, Loss: 0.06225
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 44.1s (11.34/s)
#     Loss: 0.01698
#     Accuracy: 0.93779
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69041, Loss: 0.05476
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.2s (11.56/s)
#     Loss: 0.01683
#     Accuracy: 0.93920
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68019, Loss: 0.05826
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.62/s)
#     Loss: 0.01582
#     Accuracy: 0.94366
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68463, Loss: 0.05961
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.1s (11.59/s)
#     Loss: 0.01625
#     Accuracy: 0.94225
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65184, Loss: 0.05959
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.3s (11.55/s)
#     Loss: 0.01539
#     Accuracy: 0.94740
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72347, Loss: 0.05210
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.63/s)
#     Loss: 0.01534
#     Accuracy: 0.94819
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67272, Loss: 0.06310
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.9s (11.66/s)
#     Loss: 0.01580
#     Accuracy: 0.94366
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65766, Loss: 0.06792
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.1s (11.60/s)
#     Loss: 0.01614
#     Accuracy: 0.94206
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66222, Loss: 0.06816
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.0s (11.62/s)
#     Loss: 0.01566
#     Accuracy: 0.94594
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68509, Loss: 0.06714
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.3s (11.54/s)
#     Loss: 0.01596
#     Accuracy: 0.94349
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68566, Loss: 0.05795
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.5s (11.50/s)
#     Loss: 0.01549
#     Accuracy: 0.94657
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69662, Loss: 0.05805
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.1s (11.60/s)
#     Loss: 0.01541
#     Accuracy: 0.94661
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69250, Loss: 0.05575
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.1s (11.60/s)
#     Loss: 0.01380
#     Accuracy: 0.95224
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68909, Loss: 0.05725
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.9s (11.39/s)
#     Loss: 0.01447
#     Accuracy: 0.95083
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69172, Loss: 0.05878
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.3s (11.55/s)
#     Loss: 0.01435
#     Accuracy: 0.95150
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66666, Loss: 0.05667
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.4s (11.51/s)
#     Loss: 0.01470
#     Accuracy: 0.95049
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69159, Loss: 0.05543
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.1s (11.59/s)
#     Loss: 0.01419
#     Accuracy: 0.95216
# [I 2022-06-03 02:28:22,585] Trial 23 finished with value: 0.052104835771024226 and parameters: {'num_fc_layers': 1, 'num_units_fc_layer0': 256, 'num_lstm_layer_encoder': 1, 'num_units_lstm_encoder': 32, 'num_lstm_layer_relationnet': 2, 'num_units_lstm_relationnet': 128, 'learning_rate': 0.007215874781248567, 'learning_rate_schedule_rate': 4000}. Best is trial 23 with value: 0.052104835771024226.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66556, Loss: 0.05916
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_24
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 42.8s (11.67/s)
#     Loss: 0.09065
#     Accuracy: 0.12478
# [I 2022-06-03 02:29:18,093] Trial 24 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.16731, Loss: 0.08985
#
#
#
# #######################################################################
# ########################### FINISHED TUNING ###########################
# #######################################################################
#
#
#
# Tuning statistics:
#   Number of trials:  25
#   Number of pruned trials:  9
#   Number of complete trials:  16
#
# Best trial:
#   Run 23 with Loss 0.052104835771024226 at Episode 18500
#   Params:
#     num_fc_layers: 1
#     num_units_fc_layer0: 256
#     num_lstm_layer_encoder: 1
#     num_units_lstm_encoder: 32
#     num_lstm_layer_relationnet: 2
#     num_units_lstm_relationnet: 128
#     learning_rate: 0.007215874781248567
#     learning_rate_schedule_rate: 4000

# %% [markdown]
# Zip and push tuning results to Google Drive.

# %%
push_zip('/content/tuning', gdrive + f'/results/tuning/{N_WAY}way-{K_SHOT}shot.zip')

with open(gdrive + f'/results/tuning/importances_{N_WAY}way-{K_SHOT}shot.pkl', 'wb') as handle:
    pickle.dump(importances, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Analyze the tuning run

# %% [markdown]
# Load and unpack tuning results from Google Drive.

# %%
os.system(f'cp -R /content/drive/MyDrive/ml_projects/STRHANGE/results/tuning/{N_WAY}way-{K_SHOT}shot.zip /content')
shutil.unpack_archive(f'{N_WAY}way-{K_SHOT}shot.zip', '/content')

with open(gdrive + f'/results/tuning/importances_{N_WAY}way-{K_SHOT}shot.pkl', 'rb') as handle:
  importances = pickle.load(handle)

# %% [markdown]
# Success of the tuning process is examined by analyzing the best values in each run and the training curves.

# %%
plot_tuning_history('tuning', 'eval_accuracy', 'Validations Accuracy', 'maximize')

# %%
plot_tuning_traincurves('tuning', 'eval_accuracy', 'Validations Accuracy', 'maximize', 15)

# %%
best_trials = tuning.trials_dataframe().nsmallest(5, 'value').transpose().drop(['number', 'datetime_start', 'datetime_complete'])

print(tabulate(best_trials, tablefmt = 'latex', headers=best_trials.columns, numalign="right", floatfmt=".2f"))
# Out:
# \begin{tabular}{llllll}
# \hline
#                                     & 23                     & 21                     & 22                     & 19                     & 13                     \\
# \hline
#  value                              & 0.052104835771024226   & 0.052287155287340285   & 0.05666003140620887    & 0.05666802514344454    & 0.057747484110295774   \\
#  duration                           & 0 days 00:46:32.249116 & 0 days 00:43:56.440471 & 0 days 00:45:38.430019 & 0 days 00:43:55.048133 & 0 days 00:43:22.855853 \\
#  params\_learning\_rate               & 0.007215874781248567   & 0.0017595408235738703  & 0.00241063307847368    & 0.0019615986633859054  & 0.0003586742187824655  \\
#  params\_learning\_rate\_schedule\_rate & 4000                   & 4000                   & 4000                   & 5500                   & 8000                   \\
#  params\_num\_fc\_layers               & 1                      & 1                      & 1                      & 1                      & 1                      \\
#  params\_num\_lstm\_layer\_encoder      & 1                      & 1                      & 1                      & 1                      & 2                      \\
#  params\_num\_lstm\_layer\_relationnet  & 2                      & 2                      & 2                      & 2                      & 1                      \\
#  params\_num\_units\_fc\_layer0         & 256                    & 256                    & 256                    & 256                    & 256                    \\
#  params\_num\_units\_fc\_layer1         & nan                    & nan                    & nan                    & nan                    & nan                    \\
#  params\_num\_units\_fc\_layer2         & nan                    & nan                    & nan                    & nan                    & nan                    \\
#  params\_num\_units\_lstm\_encoder      & 32                     & 32                     & 32                     & 32                     & 64                     \\
#  params\_num\_units\_lstm\_relationnet  & 128                    & 128                    & 128                    & 128                    & 128                    \\
#  state                              & COMPLETE               & COMPLETE               & COMPLETE               & COMPLETE               & COMPLETE               \\
# \hline
# \end{tabular}

# %%
plot_traincurve('tuning/run_23', ['train_accuracy', 'eval_accuracy'], 'Accuracy')

# %%
plot_tuning_parameter_importance(importances)

# %% [markdown]
# ## Model selection

# %% [markdown]
# Select the final model (run an episode to stop) on the basis of the tuning analyses.

# %%
selected_run = 'run_23'
selected_episode = '10500'

# %% [markdown]
# # Model evaluation

# %% [markdown]
# Evaluate the model on unseen data.

# %%
conf_matrix, classification_report, accuracy = run_testing(num_testruns = 1000, samples_per_run = 32, run_dir = 'tuning/run_23', episode = 'e10500', test_classes = test_classes)

# %%
model_name = f'{N_WAY}-way_{K_SHOT}-sup'
path = os.path.join(gdrive, 'results', 'tests')

np.save(os.path.join(path, f'{model_name}_CM.npy'), conf_matrix)
classification_report.to_pickle(os.path.join(path, f'{model_name}_CR.pkl'))
np.save(os.path.join(path, f'{model_name}_ACC.npy'), accuracy)

# %% [markdown]
# Visualize Confusion Matrix

# %%
plot_conf_matrix (conf_matrix, test_classes, y_og)

# %% [markdown]
# Analyse Accuracy, Precision, Recall and F-Score.

# %%
print(f'Average Accuracy of the model on testdata {accuracy}\n')
print(f'Average Precision of the model on testdata {round(classification_report.Precision.mean(),3)}\n')
print(f'Average Recall of the model on testdata {round(classification_report.Recall.mean(),3)}\n')
print(f'Average F-Score of the model on testdata {round(classification_report.FScore.mean(),3)}\n')

print(tabulate(classification_report, tablefmt = 'latex', headers=classification_report.columns, numalign="right", floatfmt=".2f"))
# Out:
# Average Accuracy of the model on testdata 0.703253125
#
# Average Precision of the model on testdata 0.705
#
# Average Recall of the model on testdata 0.702
#
# Average F-Score of the model on testdata 0.703
#
# \begin{tabular}{lrrr}
# \hline
#                &   Precision &   Recall &   FScore \\
# \hline
#  0 (0 \& 0)     &        0.94 &     0.95 &     0.97 \\
#  3 (0 \& 3)     &        0.83 &     0.91 &     0.87 \\
#  12 (0 \& 12)   &        0.92 &     0.96 &     0.94 \\
#  13 (0 \& 13)   &        0.88 &     0.97 &     0.93 \\
#  15 (0 \& 15)   &        0.81 &     0.84 &     0.82 \\
#  19 (0 \& 19)   &        0.83 &     0.84 &     0.84 \\
#  21 (0 \& 21)   &        0.82 &     0.77 &     0.79 \\
#  24 (0 \& 24)   &        0.87 &     0.90 &     0.88 \\
#  81 (3 \& 3)    &        0.54 &     0.56 &     0.55 \\
#  90 (3 \& 12)   &        0.75 &     0.70 &     0.73 \\
#  91 (3 \& 13)   &        0.66 &     0.71 &     0.68 \\
#  93 (3 \& 15)   &        0.59 &     0.56 &     0.57 \\
#  97 (3 \& 19)   &        0.64 &     0.63 &     0.64 \\
#  99 (3 \& 21)   &        0.57 &     0.54 &     0.55 \\
#  102 (3 \& 24)  &        0.64 &     0.63 &     0.64 \\
#  315 (12 \& 3)  &        0.78 &     0.68 &     0.73 \\
#  324 (12 \& 12) &        0.93 &     0.87 &     0.90 \\
#  325 (12 \& 13) &        0.87 &     0.84 &     0.85 \\
#  327 (12 \& 15) &        0.79 &     0.68 &     0.73 \\
#  331 (12 \& 19) &        0.86 &     0.74 &     0.79 \\
#  333 (12 \& 21) &        0.78 &     0.68 &     0.73 \\
#  336 (12 \& 24) &        0.82 &     0.69 &     0.75 \\
#  341 (13 \& 3)  &        0.61 &     0.72 &     0.66 \\
#  350 (13 \& 12) &        0.82 &     0.85 &     0.83 \\
#  351 (13 \& 13) &        0.79 &     0.95 &     0.88 \\
#  353 (13 \& 15) &        0.67 &     0.73 &     0.70 \\
#  357 (13 \& 19) &        0.69 &     0.71 &     0.70 \\
#  359 (13 \& 21) &        0.61 &     0.65 &     0.63 \\
#  362 (13 \& 24) &        0.71 &     0.79 &     0.75 \\
#  393 (15 \& 3)  &        0.54 &     0.67 &     0.60 \\
#  402 (15 \& 12) &        0.74 &     0.73 &     0.73 \\
#  403 (15 \& 13) &        0.67 &     0.78 &     0.72 \\
#  405 (15 \& 15) &        0.58 &     0.65 &     0.61 \\
#  409 (15 \& 19) &        0.65 &     0.62 &     0.64 \\
#  411 (15 \& 21) &        0.54 &     0.58 &     0.56 \\
#  414 (15 \& 24) &        0.64 &     0.65 &     0.64 \\
#  497 (19 \& 3)  &        0.60 &     0.58 &     0.59 \\
#  506 (19 \& 12) &        0.81 &     0.75 &     0.78 \\
#  507 (19 \& 13) &        0.73 &     0.76 &     0.74 \\
#  509 (19 \& 15) &        0.66 &     0.62 &     0.64 \\
#  513 (19 \& 19) &        0.70 &     0.62 &     0.66 \\
#  515 (19 \& 21) &        0.64 &     0.58 &     0.61 \\
#  518 (19 \& 24) &        0.69 &     0.61 &     0.65 \\
#  549 (21 \& 3)  &        0.48 &     0.55 &     0.51 \\
#  558 (21 \& 12) &        0.77 &     0.75 &     0.76 \\
#  559 (21 \& 13) &        0.68 &     0.74 &     0.71 \\
#  561 (21 \& 15) &        0.53 &     0.55 &     0.54 \\
#  565 (21 \& 19) &        0.57 &     0.56 &     0.57 \\
#  567 (21 \& 21) &        0.55 &     0.58 &     0.57 \\
#  570 (21 \& 24) &        0.63 &     0.56 &     0.60 \\
#  627 (24 \& 3)  &        0.58 &     0.56 &     0.57 \\
#  636 (24 \& 12) &        0.85 &     0.83 &     0.84 \\
#  637 (24 \& 13) &        0.72 &     0.80 &     0.76 \\
#  639 (24 \& 15) &        0.66 &     0.58 &     0.62 \\
#  643 (24 \& 19) &        0.69 &     0.57 &     0.62 \\
#  645 (24 \& 21) &        0.61 &     0.53 &     0.57 \\
#  648 (24 \& 24) &        0.68 &     0.58 &     0.63 \\
# \hline
# \end{tabular}

# %% [markdown]
# # Model saving

# %% [markdown]
# Save the best model to the Google Drive.

# %%
push_model_to_gdrive(f'tuning/{selected_run}', f'e{selected_episode}',f'{N_WAY}way-{K_SHOT}shot')
