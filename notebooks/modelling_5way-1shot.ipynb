# %% [markdown]
# #Environment configuration

# %% [markdown]
# Install packages.

# %%
#Don't run this code unless you really want to install the packages.
#!pip install alive-progress -q
#!pip install optuna -q
# Out:
#      |████████████████████████████████| 80 kB 1.6 MB/s
#      |████████████████████████████████| 207 kB 29.3 MB/s
#   Building wheel for grapheme (setup.py) ... done
#      |████████████████████████████████| 308 kB 5.1 MB/s
#      |████████████████████████████████| 81 kB 8.6 MB/s
#      |████████████████████████████████| 209 kB 48.0 MB/s
#      |████████████████████████████████| 78 kB 7.7 MB/s
#      |████████████████████████████████| 112 kB 52.3 MB/s
#      |████████████████████████████████| 146 kB 58.1 MB/s
#      |████████████████████████████████| 49 kB 6.8 MB/s
#   Building wheel for pyperclip (setup.py) ... done

# %% [markdown]
# Import packages.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR

import optuna
from optuna.trial import TrialState

import numpy as np
import os
import math
import argparse
import random
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import itertools
import shutil

from google.colab import drive
from alive_progress import alive_bar
from tabulate import tabulate
import time

# %% [markdown]
# Mount and config GDrive & paths.

# %%
drive.mount('/content/drive')
gdrive = '/content/drive/My Drive/ml_projects/STRHANGE/'

keypoints_path = gdrive + '/data/JESTER/extracted/'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Experiment configuration

# %%
N_WAY = 5
K_SHOT = 1

# %% [markdown]
# # Set up functions and classes

# %% [markdown]
# This section contains all functions and classes that are important for the remainder of this notebook. An explanation of the functions and their parameters & outputs can be found in the function headers.

# %% [markdown]
# #### Model training

# %%
def run_training(task_param, input_param, model_param, training_param):
  """
  Training Function - performs a single model training for a set of parameters
  Args:
    task_param (dict): task-related parameters
    input_param (dict): input-related parameters
    model_param (dict): model-related parameters
    training_param (dict): training-related paramaters
  Returns:
    logging (pd.dataframe): dataframe with user configurated logging information on the training-history
  """

  ### PARAMETER UNPACKING AND INITIALIZATION ###
  print('Initializing training...\n')

  #task-parameters
  SUPPORT_NUM_PER_CLASS = task_param['support_num_per_class'] 
  QUERY_NUM_PER_CLASS = task_param['query_num_per_class']  
  NUM_CLASSES = task_param['num_classes']  

  #input-parameters
  SEQUENCE_LENGTH = input_param['sequence_length']
  FEATURE_LENGTH = input_param['feature_length'] 

  #model-parameters
  NUM_LSTM_LAYER_ENCODER = model_param['num_lstm_layer_encoder']
  NUM_UNITS_LSTM_ENCODER = model_param['num_units_lstm_encoder']
  NUM_LSTM_LAYER_RELATIONNET = model_param['num_lstm_layer_relationnet']
  NUM_UNITS_LSTM_RELATIONNET = model_param['num_units_lstm_relationnet']
  NUM_UNITS_FC_RELU = model_param['num_units_fc_relu']

  #training-parameters
  LEARNING_RATE = training_param['learning_rate']
  LEARNING_RATE_SCHEDULE_RATE = training_param['learning_rate_schedule_rate']
  NUM_TRAIN_EPISODES = training_param['num_train_episodes']
  UPDATE_AND_EVAL_RATE = training_param['update_and_eval_rate']
  NUM_EVAL_EPISODES = training_param['num_eval_episodes']
  SAVE_PATH = training_param['save_path']
  SAVE_LOGGING = training_param['save_logging']
  SAVE_ALL = training_param['save_all']
  SAVE_BEST = training_param['save_best']
  TUNING_RUN = training_param['tuning_run']
  trial = training_param['trial']

  if NUM_TRAIN_EPISODES % UPDATE_AND_EVAL_RATE != 0:
    raise ValueError(f'Invalid Parameters: UPDATE_AND_EVAL_RATE must be a multiple of NUM_TRAIN_EPISODES.')

  print('  Parameters accepted and set.')

  ### MODEL INITIALIZATION ###
  feature_encoder = LSTMEncoder(FEATURE_LENGTH, NUM_UNITS_LSTM_ENCODER, NUM_LSTM_LAYER_ENCODER).to(device)
  print('  Feature encoder intialized, initial weights set.')
  relation_network = RelationNetwork(NUM_UNITS_LSTM_ENCODER*2, NUM_UNITS_LSTM_RELATIONNET, NUM_UNITS_FC_RELU, NUM_LSTM_LAYER_RELATIONNET).to(device) 
  print('  Relation network intialized, initial weights set.')

  feature_encoder_optim = torch.optim.Adam(feature_encoder.parameters(),lr=LEARNING_RATE)
  feature_encoder_scheduler = StepLR(feature_encoder_optim,step_size=LEARNING_RATE_SCHEDULE_RATE,gamma=0.5) 

  relation_network_optim = torch.optim.Adam(relation_network.parameters(),lr=LEARNING_RATE)
  relation_network_scheduler = StepLR(relation_network_optim,step_size=LEARNING_RATE_SCHEDULE_RATE,gamma=0.5) 

  mse = nn.MSELoss().to(device)

  print('  Optimizer & Learning Rate Scheduler initalized.')

  ### SET UP LOGGING ###

  # Create logging dir for current run
  logging = []
  if SAVE_LOGGING == True or SAVE_ALL == True or SAVE_BEST == True:

    if not os.path.exists(SAVE_PATH):
      os.makedirs(SAVE_PATH)

    run = 0
    run_list = os.listdir(SAVE_PATH)

    for i in range(len(run_list)):
      try:
        run_list[i] = int(run_list[i].split('_')[1])
      except:
        next

    run_list = [num for num in run_list if isinstance(num, (int,float))]

    if run_list:
      run = int(max(run_list)) + 1
    log_dir = os.path.join(SAVE_PATH, 'run_' + str(run))

    if not os.path.exists(log_dir):
      os.makedirs(log_dir)

    #Log params to logging dir
    with open(log_dir + '/task_param.pkl', 'wb') as f:
      pickle.dump(task_param, f)

    with open(log_dir + '/input_param.pkl', 'wb') as f:
      pickle.dump(input_param, f)      

    with open(log_dir + '/model_param.pkl', 'wb') as f:
      pickle.dump(model_param, f)

    with open(log_dir + '/training_param.pkl', 'wb') as f:
      pickle.dump(training_param, f)
  
  print(f'  Created logging folder: {log_dir}')

  print('\nTraining initalized. \n\n')

  print('Start training...\n')

  ### TRAINING ###

  #loop over number of episodes
  for episode in range(int(NUM_TRAIN_EPISODES/UPDATE_AND_EVAL_RATE)):

    print(f'Episode: {episode*UPDATE_AND_EVAL_RATE}/{NUM_TRAIN_EPISODES} to {(episode + 1) * UPDATE_AND_EVAL_RATE}/{NUM_TRAIN_EPISODES}')

    step_train_accuracy = 0
    step_train_loss = 0

    with alive_bar(UPDATE_AND_EVAL_RATE, title=f'  Training...', force_tty = True) as bar:
      for i in range(UPDATE_AND_EVAL_RATE):
        # Generate task and get data
        query_x, query_y, support_x, support_y = gen_task(n_way = NUM_CLASSES, n_support = SUPPORT_NUM_PER_CLASS, n_query = QUERY_NUM_PER_CLASS, data_x = X, data_y = y, split = 'train')
        query_x, query_y, support_x, support_y = query_x.to(device), query_y.to(device), support_x.to(device), support_y.to(device)
          
        # Predict
        relations, query_y_one_hot = predict(feature_encoder, relation_network, support_x, query_x, query_y, NUM_CLASSES, SUPPORT_NUM_PER_CLASS, QUERY_NUM_PER_CLASS, SEQUENCE_LENGTH, NUM_UNITS_LSTM_ENCODER)

        # Calculate loss         
        loss = mse(relations,query_y_one_hot)
        step_train_loss += loss.item()

        # Calculate accuracy 
        _,predict_labels = torch.max(relations.data,1)
        rewards = [1 if predict_labels[j]==query_y[j] else 0 for j in range(NUM_CLASSES*QUERY_NUM_PER_CLASS)]
        accuracy = np.sum(rewards)/1.0/NUM_CLASSES/QUERY_NUM_PER_CLASS
        step_train_accuracy += accuracy

        #backpropagation - adjust the model's parameter
        feature_encoder.zero_grad()
        relation_network.zero_grad()

        loss.backward()

        torch.nn.utils.clip_grad_norm_(feature_encoder.parameters(),0.5)
        torch.nn.utils.clip_grad_norm_(relation_network.parameters(),0.5)

        feature_encoder_optim.step()
        relation_network_optim.step()

        #update status bar
        bar()

    # print loss and acc for episode
    step_train_loss = step_train_loss/UPDATE_AND_EVAL_RATE
    step_train_accuracy = step_train_accuracy/UPDATE_AND_EVAL_RATE

    print(f'    Loss: {step_train_loss:.5f}')
    print(f'    Accuracy: {step_train_accuracy:.5f}')

    # start validation
    with torch.no_grad():

      step_eval_loss = 0
      step_eval_accuracy = 0
      best_eval_accuracy = 0

      for i in range(NUM_EVAL_EPISODES):

        # Generate task and get data
        query_x, query_y, support_x, support_y = gen_task(n_way = NUM_CLASSES, n_support = SUPPORT_NUM_PER_CLASS, n_query = QUERY_NUM_PER_CLASS, data_x = X, data_y = y, split = 'eval')
        query_x, query_y, support_x, support_y = query_x.to(device), query_y.to(device), support_x.to(device), support_y.to(device)

        # Predict
        relations, query_y_one_hot = predict(feature_encoder, relation_network, support_x, query_x, query_y, NUM_CLASSES, SUPPORT_NUM_PER_CLASS, QUERY_NUM_PER_CLASS, SEQUENCE_LENGTH, NUM_UNITS_LSTM_ENCODER)

        # Calculate loss             
        loss = mse(relations,query_y_one_hot)
        step_eval_loss += loss.item()

        # Calculate rewards for accuracy 
        _,predict_labels = torch.max(relations.data,1)
        rewards = [1 if predict_labels[j]==query_y[j] else 0 for j in range(NUM_CLASSES*QUERY_NUM_PER_CLASS)]
        step_eval_accuracy += np.sum(rewards)

      # Calculate and print loss / acc for validation-run
      step_eval_loss = step_eval_loss / NUM_EVAL_EPISODES
      step_eval_accuracy = step_eval_accuracy/1.0/NUM_CLASSES/QUERY_NUM_PER_CLASS/NUM_EVAL_EPISODES

      logging.append([step_train_loss, step_train_accuracy, step_eval_loss, step_eval_accuracy])

      print(f'  Validation with {NUM_EVAL_EPISODES} Evaluation-Episodes. Accuracy: {step_eval_accuracy:.5f}, Loss: {step_eval_loss:.5f}\n' )

      # Report results to optuna-tuning
      if TUNING_RUN == True:
        trial.report(step_eval_loss, episode * UPDATE_AND_EVAL_RATE)

        # Prune trial and save logging if loss-decrease is not promising
        if trial.should_prune():
          if SAVE_LOGGING == True:
            logging = pd.DataFrame(logging, columns=['train_loss', 'train_accuracy', 'eval_loss', 'eval_accuracy'])
            logging.eval_loss.iloc[0] = logging.train_loss.iloc[0]
            logging.eval_accuracy.iloc[0] = logging.train_accuracy.iloc[0]
            logging.to_pickle(log_dir + '/logging.pkl')
          raise optuna.exceptions.TrialPruned()

      # Save network 
      if (SAVE_BEST == True or SAVE_ALL == True) and not os.path.exists(os.path.join(log_dir, 'models')):
        os.makedirs(os.path.join(log_dir, 'models'))

      if SAVE_BEST == True and step_eval_accuracy > best_eval_accuracy:
        torch.save(feature_encoder.state_dict(),str(log_dir + '/models/feature_encoder_best.pkl'))
        torch.save(relation_network.state_dict(),str(log_dir + '/models/relation_network_best.pkl'))

      if SAVE_ALL == True:
        torch.save(feature_encoder.state_dict(),str(log_dir + '/models/feature_encoder_e' + str(episode*UPDATE_AND_EVAL_RATE) + '.pkl'))
        torch.save(relation_network.state_dict(),str(log_dir + '/models/relation_network_e' + str(episode*UPDATE_AND_EVAL_RATE) + '.pkl'))

  # Save logging
  if SAVE_LOGGING == True:
    logging = pd.DataFrame(logging, columns=['train_loss', 'train_accuracy', 'eval_loss', 'eval_accuracy'])
    logging.eval_loss.iloc[0] = logging.train_loss.iloc[0]
    logging.eval_accuracy.iloc[0] = logging.train_accuracy.iloc[0]

    logging.to_pickle(log_dir + '/logging.pkl')

  return logging

# %% [markdown]
# #### Hyperparameter tuning

# %%
def run_tuning(trial):
  """
  Tuning Function - performs multiple model trainings and optimizes hyperparameters
  Args:
    trial (optunia-trial-object): current trial object of the optuna tuning process
  Returns:
    min_eval_loss (float): minimal loss on evaluation set
  """

  # Caution: some parameters have to be set manually to match the given task, input and training specifications
  # (this has to be done within this function, because optuna does not support additional args)

  # Set tuning parameters  
  task_param = {'support_num_per_class': K_SHOT,
                'query_num_per_class': 16,
                'num_classes': N_WAY}

  # Set input parameters  
  input_param = {'sequence_length': 72,
                 'feature_length': 63}

  # Set model parameters (suggestions by optuna)
  num_fc_layers = trial.suggest_int("num_fc_layers", 1, 3, step = 1)
  num_units_fc_relu = []
  for i in range(num_fc_layers):
    num_units = trial.suggest_categorical("num_units_fc_layer{}".format(i), [16, 32, 64, 128, 256])
    num_units_fc_relu.append(num_units)

  model_param = {'num_lstm_layer_encoder': trial.suggest_int("num_lstm_layer_encoder", 1, 3, step=1),
                 'num_units_lstm_encoder': trial.suggest_categorical("num_units_lstm_encoder", [16, 32, 64, 128, 256]),
                 'num_lstm_layer_relationnet': trial.suggest_int("num_lstm_layer_relationnet", 1, 3, step=1),
                 'num_units_lstm_relationnet': trial.suggest_categorical("num_units_lstm_relationnet", [16, 32, 64, 128, 256]),
                 'num_units_fc_relu': num_units_fc_relu}

  # Set training parameters
  training_param = {'learning_rate': trial.suggest_float("learning_rate", 0.00001, 0.01,  log=True),
                    'learning_rate_schedule_rate': trial.suggest_int("learning_rate_schedule_rate", 500, 10000, step = 500),
                    'num_train_episodes': 25000,
                    'update_and_eval_rate': 500,
                    'num_eval_episodes': 200,
                    'save_path': 'tuning',
                    'save_logging': True,
                    'save_all': True,
                    'save_best': True,
                    'tuning_run': True,
                    'trial': trial}

  # run training with parameters of this trial
  logs = run_training(task_param, input_param, model_param, training_param)

  # report minimal evaluation loss to optuna
  min_eval_loss = logs.eval_loss.min()
  return min_eval_loss

# %% [markdown]
# #### Unique tasks calculator

# %%
def get_classcombinations(classes, num_in_comb):
  """
  Generates a set of unique tasks for a given list of classes and a number different of classes in each task
  Args:
    classes (list): list of classes
    num_in_comb (int): number different of classes in each task
  Returns:
    unique_tasks (set): set of unique tasks
  """

  unique_tasks = set(itertools.combinations(classes, num_in_comb))
  return unique_tasks

# %% [markdown]
# #### Task generator

# %%
def gen_task(n_way, n_support, n_query, data_x, data_y, split):
  """
  Generates a task (classify n-query gestures of n_way classes with n_support suppoting samples) for the few shot model.
  Args:
    n_way (int): number of classes
    n_support (int): number of support samples in each class
    n_query (int): batch size of query samples 
    data_x (np.array): hand keypoints (usually X)
    data_y (np.array): labels (usually y)
    split (str): type of split (train, evel or test)
  Returns:
    query_x (torch tensor): query set data
    query_y (torch tensor): query set labels
    support_x (torch tensor): support set data
    support_y (torch tensor): support set labels 
    (classes (np.array)): list of original classes 
  """

  #sample random classes from the predfined list of classes, depended of the split-type
  query_x, query_y, support_x, support_y = [], [], [], []
  if split == 'train':
    classes = np.random.choice(training_classes, n_way, replace=False)
  elif split == 'eval':
    classes = np.random.choice(eval_classes, n_way, replace=False) 
  elif split == 'test':
    classes = np.random.choice(test_classes, n_way, replace=False) 

  #loop over classes of this task, sample X data and generate labels (always 0 to n-classes)
  for i, c in enumerate(classes):
    data_x_c = data_x[data_y == c]

    query_x.append(data_x_c[np.random.choice(data_x_c.shape[0], n_query, replace=False), :, :])
    query_y.append([i] * n_query)

    support_x.append(data_x_c[np.random.choice(data_x_c.shape[0], n_support, replace=False), :, :])
    support_y.append([i] * n_support)

  #reshape Data
  query_x = np.reshape(query_x, (n_way * n_query, np.array(query_x).shape[2], np.array(query_x).shape[3]))
  query_y = np.reshape(query_y, n_way * n_query)
  support_x = np.reshape(support_x, (n_way * n_support, np.array(support_x).shape[2], np.array(support_x).shape[3]))
  support_y = np.reshape(support_y, n_way * n_support)

  #change to torch tensors
  query_x = torch.from_numpy(query_x).float()
  query_y = torch.from_numpy(query_y).float().type(torch.LongTensor) 
  support_x = torch.from_numpy(support_x).float()
  support_y = torch.from_numpy(support_y).float().type(torch.LongTensor) 

  #Return statements
  if split == 'train' or split == 'eval':   
    return query_x, query_y, support_x, support_y
  elif split == 'test':
    return query_x, query_y, support_x, support_y, classes

# %% [markdown]
# #### Model components

# %%
class LSTMEncoder(nn.Module):
  """First part of the model, which encodes the sequence of hand gesture keypoints"""
  def __init__(self, input_size, hidden_lstm_size, num_lstm_layer):
    """
    Object initialization.
    Args:
      input_size (int): size of the input data
      hidden_lstm_size (int): number of units in lstm-cell
      num_lstm_layer (int): number of stacked lstm-layers
    """
    super(LSTMEncoder, self).__init__()
    self.input_size = input_size 
    self.hidden_lstm_size = hidden_lstm_size 
    self.num_lstm_layer = num_lstm_layer

    #create lstm layer(s)
    self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_lstm_size, num_layers = num_lstm_layer, batch_first=True)

  def forward(self,x):
    """
    Forward pass through the LSTM Encoder
    Args:
      x (torch tensor): data input (sequence of hand keypoints as batch)
    Return:
      out (torch tensor): encoded data (encoded sequence of hand keypoints as batch) with size batch, sequence, hidden_size
    """

    #create zeros with size num_layer, sequences, hidden_size 
    #h0 containing the final hidden state for each element in the sequence
    h0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device)  
    #c0 containing the final cell state for each element in the sequence
    c0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device) 

    #pass data through the lstm layer(s)
    out, _ = self.lstm(x, (h0,c0))
    return out 


class RelationNetwork(nn.Module):
  """Second part of the model, which calculates the relation-scores, given the concatenated query and support samples"""
  def __init__(self,input_size, hidden_lstm_size, fc_sizes: list, num_lstm_layer):
    """
    Object initialization.
    Args:
      input_size (int): size of the input data
      hidden_lstm_size (int): number of units in lstm-cell
      fc_sizes (list): number of units per fully connected / linear layer
      num_lstm_layer (int): number of stacked lstm-layers
    """
    super(RelationNetwork, self).__init__()
    self.input_size = input_size 
    self.hidden_lstm_size = hidden_lstm_size
    self.layers = nn.ModuleList()
    self.num_lstm_layer = num_lstm_layer

    #create lstm layer(s)
    self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_lstm_size, num_layers = num_lstm_layer, batch_first=True)
    #next input_size is outputsize of the lstm layer (hidden_lstm_size)
    input_size = hidden_lstm_size

    #loop over fc_sizes, create linear layer + ReLU Activation and adjust the input_size
    for size in fc_sizes:
      self.layers.append(nn.Linear(input_size, size))
      self.layers.append(nn.ReLU())
      input_size = size  
 
    #add a final Linear Layer which reduces the input down to a single number, aka. the relation score, by applieing a sigmoid function
    self.end_layer = nn.Sequential(nn.Linear(input_size,1), nn.Sigmoid())
    
  def forward(self,x):
    """
    Forward pass through the Relation Network
    Args:
      x (torch tensor): concatenated data input of query- and support-samples 
    Return:
      out (torch tensor): relation scores
    """
    
    #create zeros with size num_layer, sequences, hidden_size 
    #h0 containing the final hidden state for each element in the sequence 
    h0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device) 
    #c0 containing the final cell state for each element in the sequence
    c0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device) 

    #pass data through the lstm layer(s)
    out, _ = self.lstm(x, (h0,c0))
    #reduce output to the last sequence-state 
    out = out[:, -1, :]

    #pass data through the fc layer(s)
    for layer in self.layers:
      out = layer(out)
    
    #pass data through the final layer to calculate the relation score
    out = self.end_layer(out) 
    return out

# %% [markdown]
# #### Prediction performer

# %%
def predict(feature_encoder, relation_network, support_x, query_x, query_y, num_classes, support_num_per_class, query_num_per_class, seq_length, num_units_lstm_encoder):
  """
  Prediction-Function 
  Args:
    feature_encoder (LSTMEncoder-object): initialized LSTMEncoder-object
    relation_network (RelationNetwork-object): initialized RelationNetwork-object
    support_x (torch tensor): data for support set
    support_y (torch tensor): labels for support set
    query_x (torch tensor): data for query set
    query_y (torch tensor): labels for query set
    num_classes (int): number of classes in the given task
    support_num_per_class (int): number of support samples per class in support set
    query_num_per_class (int): number of query samples per class in query set
    seq_length (int): length of sequence
    num_units_lstm_encoder (int): number of hidden units in the LSTM-Cells of the feature_encoder
  Returns:
    relations (torch tensor): relation scores 
    query_y_one_hot (torch tensor): predicted classes as one-hot-encoded vector
  """
  # calculate support features by passing the support set through the feature_encoder-module 
  support_features = feature_encoder(Variable(support_x).to(device))
  # calculate query features by passing the query set through the feature_encoder-module 
  query_features = feature_encoder(Variable(query_x).to(device))
          
  #Prepare encoded query and support set for relations calculation (reshaping, transposing)
  support_features = support_features.view(num_classes, support_num_per_class, seq_length, num_units_lstm_encoder)
  support_features = torch.sum(support_features, 1).squeeze(1)
  support_features_ext = support_features.unsqueeze(0).repeat(query_num_per_class*num_classes,1,1,1).to(device)
  query_features_ext = query_features.unsqueeze(0).repeat(num_classes,1,1,1)
  query_features_ext = torch.transpose(query_features_ext,0,1).to(device)

  # concatenated encoded query & support set
  relation_pairs = torch.cat((support_features_ext,query_features_ext),3).view(-1,seq_length, num_units_lstm_encoder*2).to(device)

  # calculate relations by passing the concatenated query & support set through the relation_network-module 
  relations = relation_network(relation_pairs).view(-1,num_classes).to(device)

  # turn relation-scores into one hot encoded predictions 
  query_y_one_hot = Variable(torch.zeros(query_num_per_class*num_classes, num_classes).to(device).scatter_(1, query_y.view(-1,1), 1)).to(device)

  return relations, query_y_one_hot

# %% [markdown]
# #### Logging loader

# %%
def load_logging_and_params_from_file(log_dir):
  """
  Loads the logging and parameters of a single training-run from a given directory
  Args:
    log_dir (str): location of logs and parameters of a single run
  Returns:
    logging (pd.dataframe: logging of the given run
    task_param (dict): task-related parameters of the given run
    input_param (dict): input-related parameters of the given run
    model_param (dict): model-related parameters of the given run
    training_param (dict): training-related paramaters of the given run
  """

  #check is given log_dir exist
  if os.path.isfile(os.path.join(log_dir,'logging.pkl')):
    #load logging and param-dirs
    logging = pd.read_pickle(os.path.join(log_dir, 'logging.pkl'))

    with open(os.path.join(log_dir, 'task_param.pkl'), 'rb') as f:
      task_param = pickle.load(f)

    with open(os.path.join(log_dir, 'input_param.pkl'), 'rb') as f:
      input_param = pickle.load(f)      

    with open(os.path.join(log_dir, 'model_param.pkl'), 'rb') as f:
      model_param = pickle.load(f)

    with open(os.path.join(log_dir, 'training_param.pkl'), 'rb') as f:
      training_param = pickle.load(f)

    #return logging and param-dirs
    return logging, task_param, input_param, model_param, training_param
  
  else:
    print(f'No logging found in {log_dir}')

# %% [markdown]
# #### Training-Curve visualization

# %%
def plot_traincurve(log_dir, metrics, ylabel):
  """
  Plots the training curve of a single train-run
  Args:
    log_dir (str): location of the training run
    metrics (list): metrics to be plotted 
    ylabel (str): label to be plotted on the y-axis
  """

  #Load logging from log_dir
  logging, _, _, _, training_param = load_logging_and_params_from_file(log_dir)

  plt.figure(figsize=(10, 5), dpi=100)
  colors = ['#00406C', '#1ABEA3'] 
  i = 0

  #Loop over metrics and visualize it as a line
  for col in metrics:
    plot_data = logging[col].dropna()
    plt.plot(plot_data.index.values * training_param['update_and_eval_rate'], plot_data.values, label=col, color = colors[i])
    i += 1

  l=plt.legend()
  l.get_texts()[0].set_text('Trainingsdaten')
  l.get_texts()[1].set_text('Validationsdaten')

  #plt.title('Learning Curve')
  plt.xlabel('Episode')
  plt.ylabel(ylabel)
  plt.ylim(0, 1)
  #plt.figlegend(bbox_to_anchor=(0.85,0.5), loc="center left")
  plt.tight_layout(rect=[0,0,0.85,1])

  plt.show()

# %% [markdown]
# #### Tuning-History visualization

# %%
def plot_tuning_history(tuning_dir, metric, y_label, direction):
  """
  Plots the training curves of all training-runs in a tuning dir 
  Args:
    tuning_dir (str): location of the tuning run
    metric (list): metrics to be plotted 
    y_label (str): label to be displayed on the y-axis
    direction (str): maximize or minimize
  """

  # Gather the data from every training-run in the tuning_dir
  tuning_metrics = []
  runs = []
  if os.path.isdir(tuning_dir):
    run_dirs = os.listdir(tuning_dir)

    def extract_nums (elem):
      return int(elem.split('_')[1])
    
    run_dirs.sort(key = extract_nums)

    for i in range(len(run_dirs)):
      if 'run' in run_dirs[i]:
        logging, _, _, _, training_param = load_logging_and_params_from_file(os.path.join(tuning_dir, run_dirs[i]))
        logging = logging[metric]
        tuning_metrics.append(list(logging))
        runs.append(run_dirs[i])  

    max_length = len(max(tuning_metrics, key=len))

    if direction == 'maximize':
      none_marker = 0
    elif direction == 'minimize':
      none_marker = 99
    else:
      return 'invalid direction'

    for i, log in enumerate(tuning_metrics):
      tuning_metrics[i] = (log + max_length * [none_marker])[:max_length]

    tuning_metrics = np.array(tuning_metrics).transpose()
    tuning_logs = pd.DataFrame(tuning_metrics, columns = runs)
    
  else:
    print('tuning_dir does not exist.')

# Check for pruned runs and when a run hits a new best-score
  pruned = []
  new_best = []
  
  if direction == 'maximize':
    best = 0

    for col in tuning_logs:
      if tuning_logs[col].max() > best:
        best = tuning_logs[col].max()
        new_best.append('#E76450')
      else:
        new_best.append('#FFC35E')

      if tuning_logs[col].min() == 0:
        pruned.append('x')
      else:
        pruned.append('o')

      data = tuning_logs.max()
     
  elif direction == 'minimize':
    best = 1
    for col in tuning_logs:
      if tuning_logs[col].min() < best:
        best = tuning_logs[col].min()
        new_best.append('#00406E')
      else:
        new_best.append('#17BEA3')

      if tuning_logs[col].max() == 99:
        pruned.append('x')
      else:
        pruned.append('o')

      data = tuning_logs.min()

  # Visualize history

  plt.figure(figsize=(10, 5), dpi=100)
  plt.plot(data, linestyle = 'dashed', color = '#C8D4D7')

  for i in range(len(data)):
    plt.plot(i, data[i], marker = pruned[i], markersize = 8, color = new_best[i])

  #plt.title('Tuning Entwicklung')
  plt.xlabel('Trainingsläufe')
  plt.xticks(rotation=45, horizontalalignment='center')
  plt.ylabel(y_label)
  plt.ylim(0, 1)

  plt.show()

# %% [markdown]
# #### Tuning-Traincurves visualization

# %%
def plot_tuning_traincurves(tuning_dir, metric, y_label, direction = None, top_n = None):
  """
  Plots the training curves of all training-runs in a tuning dir 
  Args:
    tuning_dir (str): location of the tuning run
    metric (list): metrics to be plotted 
    y_label (str): label to be displayed on the y-axis
    direction (str): maximize or minimize
    top (int): visualize top_n results, either highest or lowest, dependend on arg 'direction'
  """

  # Gather the data from every training-run in the tuning_dir
  tuning_metrics = []
  runs = []
  if os.path.isdir(tuning_dir):
    run_dirs = os.listdir(tuning_dir)

    def extract_nums (elem):
      return int(elem.split('_')[1])
    
    run_dirs.sort(key = extract_nums)

    for i in range(len(run_dirs)):
      if 'run' in run_dirs[i]:
        logging, _, _, _, training_param = load_logging_and_params_from_file(os.path.join(tuning_dir, run_dirs[i]))
        logging = logging[metric]
        tuning_metrics.append(list(logging))
        runs.append(run_dirs[i])  

    max_length = len(max(tuning_metrics, key=len))

    for i, log in enumerate(tuning_metrics):
      tuning_metrics[i] = (log + max_length * [0])[:max_length]

    tuning_metrics = np.array(tuning_metrics).transpose()
    tuning_logs = pd.DataFrame(tuning_metrics, columns = runs)
    
  else:
    print('tuning_dir does not exist.')

  # Filter to visualize only the top_n results

  if direction != None and top_n != None:
    if direction == 'maximize':
      tuning_logs = tuning_logs[tuning_logs.max().nlargest(top_n).index]
    elif direction == 'minimize':
      tuning_logs = tuning_logs[tuning_logs.min().nsmallest(top_n).index]
    else: 
      return 'invalid direction'


  # Visualize results
  plt.figure(figsize=(10, 5), dpi=100)
  for col in list(tuning_logs.columns.values):
    plot_data = tuning_logs[col].dropna()
    plt.plot(plot_data.index.values * training_param['update_and_eval_rate'], plot_data.values, label=col)

  #plt.title('Lernkurve')
  plt.xlabel('Episode')
  plt.ylabel(y_label)

  plt.figlegend(bbox_to_anchor=(0.85,0.5), loc="center left")
  plt.tight_layout(rect=[0,0,0.85,1])
  plt.ylim(0, 1)

  plt.show()

# %% [markdown]
# #### Tuning parameter's importance visualization

# %%
def plot_tuning_parameter_importance(importances):
  """
  Visualizes the importances of every parameter in a tuning run
  Args:
    importances (OrderedDict): importances of the tuning parameters
  """

  # create positions needed for horizontal plot
  y_pos = np.arange(start = len(importances.keys()), stop = 0, step = -1)

  # create plot
  plt.figure(figsize=(10, 5), dpi=100)
  plt.barh(y_pos, importances.values(), color = '#17BEA3')

  i = 0
  for v in reversed(importances.values()):
    plt.text(v + 0.003, i + 0.9, str(round(v, 3)), color = '#00406E')
    i += 1

  # adjust labels and axis
  plt.yticks(y_pos, labels=importances.keys())
  plt.title('')
  plt.xlabel('Relevanz für den Erfolg des Tunings')
  plt.ylabel('Tuning Parameter')
  plt.xlim(0, 0.25)
  plt.tight_layout()

  plt.show()

# %% [markdown]
# #### Zip and push to Google Drive

# %%
def push_zip(source, destination):
  """
  Zip and push a directory to the Google Drive
  Args:
    source (str): current location 
    destination (str): target location 
  """
  base = os.path.basename(destination)
  name = base.split('.')[0]
  format = base.split('.')[1]
  archive_from = os.path.dirname(source)
  archive_to = os.path.basename(source.strip(os.sep))
  shutil.make_archive(name, format, archive_from, archive_to)
  shutil.move('%s.%s'%(name,format), destination)

# %% [markdown]
# #### Model saving

# %%
def push_model_to_gdrive(run_dir, episode, model_name):
  """
  Push a model & the params needed for deployment, located in a local directory, to the Google Drive
  Args:
    run_dir (str): location of the model
    episode (list): episode of the model, either a number or 'best'
    model_name (str): model's name in the Google Drive
  """

  #config target_path
  path = os.path.join(gdrive, 'results', 'models')

  #load model and params
  feature_encoder, relation_network = load_model_from_file(run_dir, episode)
  _, task_param, input_param, model_param, _ = load_logging_and_params_from_file(run_dir)

  #unpack params needed for deployment
  deployment_param = {'support_num_per_class': task_param['support_num_per_class'],
                      'num_classes': task_param['num_classes'],
                      'sequence_length': input_param['sequence_length'],
                      'feature_length': input_param['feature_length'],
                      'num_lstm_layer_encoder': model_param['num_lstm_layer_encoder'],
                      'num_units_lstm_encoder': model_param['num_units_lstm_encoder'],
                      'num_lstm_layer_relationnet': model_param['num_lstm_layer_relationnet'],
                      'num_units_lstm_relationnet': model_param['num_units_lstm_relationnet'],
                      'num_units_fc_relu': model_param['num_units_fc_relu']}

  # Push to Google Drive
  torch.save(feature_encoder.state_dict(),str(os.path.join(path, f'{model_name}_feature_encoder.pkl')))
  torch.save(relation_network.state_dict(),str(os.path.join(path, f'{model_name}_relation_network.pkl')))
  with open(os.path.join(path, f'{model_name}_deployment_param.pkl'), 'wb') as f:
      pickle.dump(deployment_param, f)

# %% [markdown]
# #### Model loading

# %%
def load_model_from_file(run_dir, episode):
  """
  Loads and initializes a model from a given directory
  Args:
    run_dir (str): location of the model
    episode (list): episode of the model, either a number or 'best'
  Returns:
    feature_encoder (LSTMEncoder-object): initialized LSTMEncoder-object
    relation_network (RelationNetwork-object): initialized RelationNetwork-object
  """

  #load params needed for deployment
  _, _, input_param, model_param, _ = load_logging_and_params_from_file(run_dir)

  #initialize feature_encoder and relation_network
  feature_encoder = LSTMEncoder(input_param['feature_length'], model_param['num_units_lstm_encoder'], model_param['num_lstm_layer_encoder']).to(device)
  relation_network = RelationNetwork(model_param['num_units_lstm_encoder']*2, model_param['num_units_lstm_relationnet'], model_param['num_units_fc_relu'], model_param['num_lstm_layer_relationnet']).to(device) 

  #load weights from directory
  feature_encoder.load_state_dict(torch.load(os.path.join(run_dir, 'models', str('feature_encoder_' + episode + '.pkl'))))
  relation_network.load_state_dict(torch.load(os.path.join(run_dir, 'models', str('relation_network_' + episode + '.pkl'))))

  return feature_encoder, relation_network

# %% [markdown]
# #### Model testing

# %%
def run_testing(num_testruns, samples_per_run, run_dir, episode, test_classes):
  """
  Testing Function - performs model testing on test-classes
  Args:
    num_testruns (int): number of test-runs to be performed, each test-run == one task
    samples_per_run (int): number of samples to be drawn as a query set
    run_dir (str): location of the model to be tested
    episode (str): episode of the model to be tests, either a number or 'best'
    test_classes (list): list of test classes
  Returns:
    conf_matrix (np.array): summarized confusion matrix of the test-runs
    classification_report (pd.dataframe): summarized classification report of the test-runs
    accuracy (float): summarized accuracy of the test-runs
  """

  # load and initialize model from dir
  feature_encoder, relation_network = load_model_from_file(run_dir, episode)
  _, task_param, input_param, model_param, training_param = load_logging_and_params_from_file(run_dir)

  # initi empty conf_matrix
  conf_matrix = np.zeros(shape = (len(test_classes),len(test_classes)), dtype = int)

  # loop over num_testruns
  for testrun in range(num_testruns):
    # generate a task with query and support sets
    query_x, query_y, support_x, support_y, tested_classes = gen_task(n_way = task_param['num_classes'], n_support = task_param['support_num_per_class'], 
                                                                      n_query = samples_per_run, data_x = X, data_y = y, split = 'test')
    query_x, query_y, support_x, support_y = query_x.to(device), query_y.to(device), support_x.to(device), support_y.to(device)

    # perform prediction on query and support set
    relations, query_y_one_hot = predict(feature_encoder, relation_network, support_x, query_x, query_y, 
                                        task_param['num_classes'], task_param['support_num_per_class'], 
                                        samples_per_run, input_param['sequence_length'], model_param['num_units_lstm_encoder'])
    _,predict_labels = torch.max(relations.data,1)

    # analyse prediction and adjust conf matrix
    for i in range(len(query_y)):
      cm_index_true = test_classes.index(tested_classes[predict_labels[i].item()])
      cm_index_pred = test_classes.index(tested_classes[query_y[i].item()])

      conf_matrix[cm_index_true][cm_index_pred] += 1

  # Calculate recall, precison and f_score based on conf matrix
  recalls = []
  precisions = []
  f_scores = []

  for i in range(len(test_classes)):
    recalls.append(conf_matrix[i][i] / conf_matrix[:,i].sum())
    precisions.append(conf_matrix[i][i] / conf_matrix[i,:].sum())
    f_scores.append(2 * (precisions[i] * recalls[i]) / (precisions[i] + recalls[i]))

  # Calculate accuracy based on conf matrix
  accuracy = conf_matrix.diagonal().sum() / conf_matrix.sum()

  # save and return metrics
  classification_report = pd.DataFrame((precisions, recalls, f_scores)).transpose()
  classification_report.index = [f'{str(x)} ({str(y_og[x][0])} & {str(y_og[x][1])})' for x in test_classes]
  classification_report.index.names = ['Class']
  classification_report.rename(columns = {0: 'Precision', 1: 'Recall', 2: 'FScore'}, inplace = True)
  
  return conf_matrix, classification_report, accuracy

# %% [markdown]
# #### Confusion matrix visualization

# %%
def plot_conf_matrix (conf_matrix, test_classes, y_og):
  """
  Visualizes a given confusion matrix as a heatmap
  Args:
    conf_matrix (np.array): confustion matrix to be visualized
    test_classes (list): list of classes the model was tested on
    y_og (list): list of original classes (before the combination) matching the test_classes
  """

  true_labels = [f'{str(x)} ({str(y_og[x][0])} & {str(y_og[x][1])})' for x in test_classes]
  pred_labels = [f'{str(x)} ({str(y_og[x][0])} & {str(y_og[x][1])})' for x in test_classes]

  fig, ax = plt.subplots(figsize = (15,15))
  im = ax.imshow(conf_matrix, cmap = 'coolwarm') 

  # Show all ticks and label them with the respective list entries
  ax.set_xticks(np.arange(len(pred_labels)))
  ax.set_yticks(np.arange(len(true_labels)))

  ax.set_xticklabels(pred_labels)
  ax.set_yticklabels(true_labels)

  ax.xaxis.tick_top()
  ax.xaxis.set_label_position('top')

  # Rotate the tick labels and set their alignment
  plt.setp(ax.get_xticklabels(), rotation=45, ha="left",
          rotation_mode="anchor")

  plt.setp(ax.get_yticklabels(), rotation=0, ha="right")

  # Loop over data dimensions and create text annotations
  for i in range(len(true_labels)):
      for j in range(len(pred_labels)):
          text = ax.text(j, i, conf_matrix[i, j],
                        ha="center", va="center", color="w")

  ax.set_title("Confusion matrix", fontsize = 18)
  fig.tight_layout()
  plt.show()

# %% [markdown]
# # Load and split data

# %% [markdown]
# Load X (extraced and combined sequences of hand-keypoints), y (combined classes from 0 to 676) and y_og (original classes from 0 to 25) from Google Drive.

# %%
# Load X, y and y_og from Google Drive.
X = np.load(gdrive + '/data/JESTER/final/X.npy')
y = np.load(gdrive + '/data/JESTER/final/y.npy')
y_og = np.load(gdrive + '/data/JESTER/final/y_og.npy')

# Check shapes 
print(f'Labels shape {y.shape}')
print(f'Data shape {X.shape}')
unique, counts = np.unique(y, return_counts=True)
print(f'\nNumber of unique classes {len(unique)}')
# Out:
# Labels shape (169000,)
# Data shape (169000, 72, 63)
#
# Number of unique classes 676

# %% [markdown]
# ## Configurate Test-strategy

# %% [markdown]
# In contrast to common machine learning approaches, the train-, test-, evaluation-split in Few-Shot Learning use cases splits the data by classes instead of drawing random samples of observations.
#
# Classes are split by their original class labels (not by combined class labels) to prevent the model from seeing bits of the data in more than one of the splits.

# %%
label_map = {'No gesture': 0, #base class, mostly zeros
            'Drumming Fingers': 1, #static
            'Pulling Hand In': 2, #dynamic
            'Pulling Two Fingers In': 3, #dynamic
            'Pushing Hand Away': 4, #dynamic
            'Pushing Two Fingers Away': 5, #dynamic
            'Rolling Hand Backward': 6, #dynamic
            'Rolling Hand Forward': 7, #dynamic
            'Shaking Hand': 8, #static
            'Sliding Two Fingers Down': 9, #dynamic
            'Sliding Two Fingers Left': 10, #dynamic
            'Sliding Two Fingers Right': 11, #dynamic
            'Sliding Two Fingers Up': 12, #dynamic
            'Stop Sign': 13, #static
            'Swiping Down': 14, #dynamic
            'Swiping Left': 15, #dynamic
            'Swiping Right': 16, #dynamic
            'Swiping Up': 17, #dynamic
            'Thumb Down': 18, #static
            'Thumb Up': 19, #static
            'Turning Hand Clockwise': 20, #dynamic
            'Turning Hand Counterclockwise': 21, #dynamic
            'Zooming In With Full Hand': 22, #dynamic
            'Zooming In With Two Fingers': 23, #dynamic
            'Zooming Out With Full Hand': 24, #dynamic
            'Zooming Out With Two Fingers': 25} #dynamic

# %% [markdown]
# Choose original class labels (pre-combination) for training, evaluation and test splits.

# %%
train_y_origin = [0, 1, 4, 5, 6, 7, 9, 10, 16, 17, 22, 25]
eval_y_origin = [0, 2, 8, 11, 14, 18, 20, 23]
test_y_origin = [0, 3, 12, 13, 15, 19, 21, 24]

# %% [markdown]
# Turn splits with original class labels (pre-combination) into training-, evaluation- and test- classes with combined classes.

# %%
training_classes, eval_classes, test_classes  = [], [], []

for i in range(len(y_og)):
  if ((y_og[i][0] == 0) and (y_og[i][1] in eval_y_origin)) or (y_og[i][0] in eval_y_origin or y_og[i][1] in eval_y_origin) and not (y_og[i][0] in train_y_origin or y_og[i][1] in train_y_origin) and not (y_og[i][0] in test_y_origin or y_og[i][1] in test_y_origin):
    eval_classes.append(i)
  if ((y_og[i][0] == 0) and (y_og[i][1] in train_y_origin)) or (y_og[i][0] in train_y_origin or y_og[i][1] in train_y_origin) and not (y_og[i][0] in eval_y_origin or y_og[i][1] in eval_y_origin) and not (y_og[i][0] in test_y_origin or y_og[i][1] in test_y_origin):
    training_classes.append(i)
  if ((y_og[i][0] == 0) and (y_og[i][1] in test_y_origin)) or (y_og[i][0] in test_y_origin or y_og[i][1] in test_y_origin) and not (y_og[i][0] in eval_y_origin or y_og[i][1] in eval_y_origin) and not (y_og[i][0] in train_y_origin or y_og[i][1] in train_y_origin):
    test_classes.append(i)

# %% [markdown]
# Examination of resulting training-, evaluation- and test-split.

# %%
print(f'Number of classes in train-split: {len(training_classes)}')
print(f'Number of classes in eval-split: {len(eval_classes)}')
print(f'Number of classes in test-split: {len(test_classes)}')
# Out:
# Number of classes in train-split: 133
# Number of classes in eval-split: 57
# Number of classes in test-split: 57

# %%
#print(f'Potential number of unique tasks for training: {len(get_classcombinations(training_classes, N_WAY))}')
#print(f'Potential number of unique tasks for evaluation: {len(get_classcombinations(eval_classes, N_WAY))}')
#print(f'Potential number of unique tasks for testing: {len(get_classcombinations(test_classes, N_WAY))}')

# %% [markdown]
# # Model tuning and training

# %% [markdown]
# In this section the model is trained. Initially, this is performed once with parameters defined by the user. Next, the model's hyperparameters are optimized by a tuning process.

# %% [markdown]
# ## Perform a training run

# %% [markdown]
# To ensure that the training function operates flawlessly (& to have a baseline model), training of the model is performed once initially with low parameter complexity.

# %%
task_param = {'support_num_per_class': K_SHOT,
              'query_num_per_class': 16,
              'num_classes': N_WAY}

input_param = {'sequence_length': 72,
               'feature_length': 63}

model_param = {'num_lstm_layer_encoder': 1,
               'num_units_lstm_encoder': 64,
               'num_lstm_layer_relationnet': 1,
               'num_units_lstm_relationnet': 64,
               'num_units_fc_relu': [32]}

training_param = {'learning_rate': 0.001,
                  'learning_rate_schedule_rate': 2000,
                  'num_train_episodes': 25000,
                  'update_and_eval_rate': 200,
                  'num_eval_episodes': 200,
                  'save_path': 'training',
                  'save_logging': True,
                  'save_all': True,
                  'save_best': True,
                  'tuning_run': False,
                  'trial': None}
            
logs = run_training(task_param, input_param, model_param, training_param)
# Out:
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: training/run_0
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.69/s)
#     Loss: 0.16135
#     Accuracy: 0.23350
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.28444, Loss: 0.15039
#
# Episode: 200/25000 to 400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.65/s)
#     Loss: 0.15203
#     Accuracy: 0.27169
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.30256, Loss: 0.14812
#
# Episode: 400/25000 to 600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.60/s)
#     Loss: 0.15019
#     Accuracy: 0.27612
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.32600, Loss: 0.14587
#
# Episode: 600/25000 to 800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.99/s)
#     Loss: 0.14946
#     Accuracy: 0.31219
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.33219, Loss: 0.14514
#
# Episode: 800/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.40/s)
#     Loss: 0.14823
#     Accuracy: 0.35138
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.33969, Loss: 0.14630
#
# Episode: 1000/25000 to 1200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.72/s)
#     Loss: 0.14462
#     Accuracy: 0.40194
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.37975, Loss: 0.14284
#
# Episode: 1200/25000 to 1400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.82/s)
#     Loss: 0.13449
#     Accuracy: 0.51325
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.44806, Loss: 0.14228
#
# Episode: 1400/25000 to 1600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.47/s)
#     Loss: 0.12466
#     Accuracy: 0.59144
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.45044, Loss: 0.14305
#
# Episode: 1600/25000 to 1800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.31/s)
#     Loss: 0.11716
#     Accuracy: 0.62612
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.46956, Loss: 0.14643
#
# Episode: 1800/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.41/s)
#     Loss: 0.10991
#     Accuracy: 0.65269
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.49081, Loss: 0.14455
#
# Episode: 2000/25000 to 2200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.37/s)
#     Loss: 0.11195
#     Accuracy: 0.64963
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.53575, Loss: 0.12817
#
# Episode: 2200/25000 to 2400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.21/s)
#     Loss: 0.10589
#     Accuracy: 0.68175
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.52975, Loss: 0.13211
#
# Episode: 2400/25000 to 2600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.41/s)
#     Loss: 0.10282
#     Accuracy: 0.69563
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.50719, Loss: 0.13632
#
# Episode: 2600/25000 to 2800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.22/s)
#     Loss: 0.09796
#     Accuracy: 0.72131
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.51444, Loss: 0.14766
#
# Episode: 2800/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.14/s)
#     Loss: 0.09394
#     Accuracy: 0.73631
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.55256, Loss: 0.13605
#
# Episode: 3000/25000 to 3200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.21/s)
#     Loss: 0.09611
#     Accuracy: 0.72875
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.55606, Loss: 0.13388
#
# Episode: 3200/25000 to 3400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.14/s)
#     Loss: 0.09230
#     Accuracy: 0.74963
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.57694, Loss: 0.12420
#
# Episode: 3400/25000 to 3600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.39/s)
#     Loss: 0.09219
#     Accuracy: 0.74162
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.56781, Loss: 0.13125
#
# Episode: 3600/25000 to 3800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.37/s)
#     Loss: 0.08377
#     Accuracy: 0.78388
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.58781, Loss: 0.12314
#
# Episode: 3800/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.38/s)
#     Loss: 0.08165
#     Accuracy: 0.79325
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.59025, Loss: 0.12430
#
# Episode: 4000/25000 to 4200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.09/s)
#     Loss: 0.07791
#     Accuracy: 0.81081
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60769, Loss: 0.11944
#
# Episode: 4200/25000 to 4400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.54/s)
#     Loss: 0.08097
#     Accuracy: 0.79075
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60100, Loss: 0.12297
#
# Episode: 4400/25000 to 4600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.41/s)
#     Loss: 0.07683
#     Accuracy: 0.81269
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.62906, Loss: 0.11503
#
# Episode: 4600/25000 to 4800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.84/s)
#     Loss: 0.07770
#     Accuracy: 0.79850
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65444, Loss: 0.11170
#
# Episode: 4800/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.36/s)
#     Loss: 0.06928
#     Accuracy: 0.83850
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64013, Loss: 0.11310
#
# Episode: 5000/25000 to 5200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.43/s)
#     Loss: 0.06903
#     Accuracy: 0.83750
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66456, Loss: 0.10856
#
# Episode: 5200/25000 to 5400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.26/s)
#     Loss: 0.06605
#     Accuracy: 0.84869
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67206, Loss: 0.11360
#
# Episode: 5400/25000 to 5600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.20/s)
#     Loss: 0.06719
#     Accuracy: 0.84631
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67506, Loss: 0.10645
#
# Episode: 5600/25000 to 5800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.13/s)
#     Loss: 0.06602
#     Accuracy: 0.84881
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69156, Loss: 0.10461
#
# Episode: 5800/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.05/s)
#     Loss: 0.06028
#     Accuracy: 0.86838
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69444, Loss: 0.10225
#
# Episode: 6000/25000 to 6200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.91/s)
#     Loss: 0.06196
#     Accuracy: 0.85900
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66725, Loss: 0.11288
#
# Episode: 6200/25000 to 6400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.31/s)
#     Loss: 0.05334
#     Accuracy: 0.88744
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68306, Loss: 0.11354
#
# Episode: 6400/25000 to 6600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.30/s)
#     Loss: 0.05677
#     Accuracy: 0.87919
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67806, Loss: 0.11782
#
# Episode: 6600/25000 to 6800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.87/s)
#     Loss: 0.05747
#     Accuracy: 0.88112
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70838, Loss: 0.11545
#
# Episode: 6800/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.04/s)
#     Loss: 0.06092
#     Accuracy: 0.87300
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71706, Loss: 0.10331
#
# Episode: 7000/25000 to 7200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.38/s)
#     Loss: 0.05593
#     Accuracy: 0.88481
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69206, Loss: 0.10678
#
# Episode: 7200/25000 to 7400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.89/s)
#     Loss: 0.05946
#     Accuracy: 0.87931
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71644, Loss: 0.10112
#
# Episode: 7400/25000 to 7600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.74/s)
#     Loss: 0.05321
#     Accuracy: 0.89713
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71406, Loss: 0.11539
#
# Episode: 7600/25000 to 7800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.40/s)
#     Loss: 0.05073
#     Accuracy: 0.90356
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74287, Loss: 0.09742
#
# Episode: 7800/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.24/s)
#     Loss: 0.04780
#     Accuracy: 0.90906
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71437, Loss: 0.12184
#
# Episode: 8000/25000 to 8200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.04/s)
#     Loss: 0.04554
#     Accuracy: 0.91850
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75200, Loss: 0.09888
#
# Episode: 8200/25000 to 8400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.07/s)
#     Loss: 0.04778
#     Accuracy: 0.90787
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74556, Loss: 0.09341
#
# Episode: 8400/25000 to 8600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.15/s)
#     Loss: 0.04381
#     Accuracy: 0.91713
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75056, Loss: 0.09801
#
# Episode: 8600/25000 to 8800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.24/s)
#     Loss: 0.04215
#     Accuracy: 0.92381
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73431, Loss: 0.09678
#
# Episode: 8800/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.52/s)
#     Loss: 0.04476
#     Accuracy: 0.91225
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71750, Loss: 0.10335
#
# Episode: 9000/25000 to 9200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.48/s)
#     Loss: 0.04237
#     Accuracy: 0.92187
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74138, Loss: 0.09714
#
# Episode: 9200/25000 to 9400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.05/s)
#     Loss: 0.04369
#     Accuracy: 0.91775
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76731, Loss: 0.08967
#
# Episode: 9400/25000 to 9600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.01/s)
#     Loss: 0.03850
#     Accuracy: 0.93488
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74412, Loss: 0.09742
#
# Episode: 9600/25000 to 9800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.11/s)
#     Loss: 0.03781
#     Accuracy: 0.93462
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73169, Loss: 0.11290
#
# Episode: 9800/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.63/s)
#     Loss: 0.03799
#     Accuracy: 0.93344
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75706, Loss: 0.09743
#
# Episode: 10000/25000 to 10200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.08/s)
#     Loss: 0.04278
#     Accuracy: 0.92762
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78438, Loss: 0.08968
#
# Episode: 10200/25000 to 10400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.95/s)
#     Loss: 0.04095
#     Accuracy: 0.92431
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74787, Loss: 0.09951
#
# Episode: 10400/25000 to 10600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.97/s)
#     Loss: 0.04039
#     Accuracy: 0.92556
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75562, Loss: 0.09522
#
# Episode: 10600/25000 to 10800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.39/s)
#     Loss: 0.04012
#     Accuracy: 0.92444
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73050, Loss: 0.10443
#
# Episode: 10800/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.85/s)
#     Loss: 0.04103
#     Accuracy: 0.92450
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76562, Loss: 0.09318
#
# Episode: 11000/25000 to 11200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.11/s)
#     Loss: 0.03890
#     Accuracy: 0.92625
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74963, Loss: 0.10153
#
# Episode: 11200/25000 to 11400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.42/s)
#     Loss: 0.03590
#     Accuracy: 0.93781
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71669, Loss: 0.11662
#
# Episode: 11400/25000 to 11600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.89/s)
#     Loss: 0.04021
#     Accuracy: 0.92794
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74806, Loss: 0.10289
#
# Episode: 11600/25000 to 11800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.92/s)
#     Loss: 0.03976
#     Accuracy: 0.92863
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75338, Loss: 0.09618
#
# Episode: 11800/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.33/s)
#     Loss: 0.03969
#     Accuracy: 0.93144
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76088, Loss: 0.09969
#
# Episode: 12000/25000 to 12200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.36/s)
#     Loss: 0.03433
#     Accuracy: 0.94706
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77325, Loss: 0.09244
#
# Episode: 12200/25000 to 12400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.16/s)
#     Loss: 0.03713
#     Accuracy: 0.93488
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75550, Loss: 0.09498
#
# Episode: 12400/25000 to 12600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.16/s)
#     Loss: 0.03478
#     Accuracy: 0.93956
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75187, Loss: 0.10368
#
# Episode: 12600/25000 to 12800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.92/s)
#     Loss: 0.03417
#     Accuracy: 0.93706
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75369, Loss: 0.09932
#
# Episode: 12800/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.76/s)
#     Loss: 0.03661
#     Accuracy: 0.93481
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77594, Loss: 0.08869
#
# Episode: 13000/25000 to 13200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.5s (26.71/s)
#     Loss: 0.03739
#     Accuracy: 0.93444
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74700, Loss: 0.10389
#
# Episode: 13200/25000 to 13400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.6s (26.32/s)
#     Loss: 0.03633
#     Accuracy: 0.93537
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79112, Loss: 0.08427
#
# Episode: 13400/25000 to 13600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.7s (25.99/s)
#     Loss: 0.03286
#     Accuracy: 0.94506
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78156, Loss: 0.10522
#
# Episode: 13600/25000 to 13800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.6s (26.32/s)
#     Loss: 0.03727
#     Accuracy: 0.93538
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77956, Loss: 0.08669
#
# Episode: 13800/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.6s (26.39/s)
#     Loss: 0.03536
#     Accuracy: 0.94013
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73119, Loss: 0.10312
#
# Episode: 14000/25000 to 14200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.8s (25.58/s)
#     Loss: 0.03263
#     Accuracy: 0.94056
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75469, Loss: 0.09699
#
# Episode: 14200/25000 to 14400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.7s (26.06/s)
#     Loss: 0.03626
#     Accuracy: 0.93988
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77162, Loss: 0.08966
#
# Episode: 14400/25000 to 14600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.6s (26.27/s)
#     Loss: 0.03375
#     Accuracy: 0.94362
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77169, Loss: 0.09389
#
# Episode: 14600/25000 to 14800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.4s (27.02/s)
#     Loss: 0.03231
#     Accuracy: 0.94456
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75975, Loss: 0.09885
#
# Episode: 14800/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.10/s)
#     Loss: 0.03358
#     Accuracy: 0.94238
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77606, Loss: 0.09394
#
# Episode: 15000/25000 to 15200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.57/s)
#     Loss: 0.03332
#     Accuracy: 0.94556
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77887, Loss: 0.09571
#
# Episode: 15200/25000 to 15400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.94/s)
#     Loss: 0.03566
#     Accuracy: 0.93656
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77638, Loss: 0.10267
#
# Episode: 15400/25000 to 15600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.66/s)
#     Loss: 0.02996
#     Accuracy: 0.95038
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79181, Loss: 0.08771
#
# Episode: 15600/25000 to 15800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.1s (28.05/s)
#     Loss: 0.03001
#     Accuracy: 0.95525
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75006, Loss: 0.09782
#
# Episode: 15800/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.99/s)
#     Loss: 0.03288
#     Accuracy: 0.94838
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74006, Loss: 0.11549
#
# Episode: 16000/25000 to 16200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.70/s)
#     Loss: 0.03033
#     Accuracy: 0.95175
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77819, Loss: 0.09508
#
# Episode: 16200/25000 to 16400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.80/s)
#     Loss: 0.03120
#     Accuracy: 0.94850
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75331, Loss: 0.09431
#
# Episode: 16400/25000 to 16600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.90/s)
#     Loss: 0.03181
#     Accuracy: 0.94694
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75938, Loss: 0.09647
#
# Episode: 16600/25000 to 16800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.67/s)
#     Loss: 0.02938
#     Accuracy: 0.95475
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76700, Loss: 0.08868
#
# Episode: 16800/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.46/s)
#     Loss: 0.03116
#     Accuracy: 0.95088
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77713, Loss: 0.09452
#
# Episode: 17000/25000 to 17200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.96/s)
#     Loss: 0.02988
#     Accuracy: 0.95000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78356, Loss: 0.09096
#
# Episode: 17200/25000 to 17400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.92/s)
#     Loss: 0.03173
#     Accuracy: 0.94775
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75281, Loss: 0.09591
#
# Episode: 17400/25000 to 17600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.86/s)
#     Loss: 0.03022
#     Accuracy: 0.94731
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75487, Loss: 0.09547
#
# Episode: 17600/25000 to 17800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.98/s)
#     Loss: 0.03035
#     Accuracy: 0.94706
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76313, Loss: 0.09122
#
# Episode: 17800/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.58/s)
#     Loss: 0.03005
#     Accuracy: 0.95119
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74162, Loss: 0.11316
#
# Episode: 18000/25000 to 18200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.85/s)
#     Loss: 0.03034
#     Accuracy: 0.94725
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75219, Loss: 0.09900
#
# Episode: 18200/25000 to 18400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.1s (28.30/s)
#     Loss: 0.02777
#     Accuracy: 0.95413
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76431, Loss: 0.09529
#
# Episode: 18400/25000 to 18600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.46/s)
#     Loss: 0.02773
#     Accuracy: 0.95869
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77525, Loss: 0.09590
#
# Episode: 18600/25000 to 18800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.90/s)
#     Loss: 0.02931
#     Accuracy: 0.94988
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76675, Loss: 0.09334
#
# Episode: 18800/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.79/s)
#     Loss: 0.02939
#     Accuracy: 0.95037
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76806, Loss: 0.09146
#
# Episode: 19000/25000 to 19200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.73/s)
#     Loss: 0.03040
#     Accuracy: 0.94975
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77581, Loss: 0.09554
#
# Episode: 19200/25000 to 19400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.62/s)
#     Loss: 0.02985
#     Accuracy: 0.95394
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77444, Loss: 0.08870
#
# Episode: 19400/25000 to 19600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.96/s)
#     Loss: 0.02886
#     Accuracy: 0.95700
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78219, Loss: 0.08935
#
# Episode: 19600/25000 to 19800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.54/s)
#     Loss: 0.02627
#     Accuracy: 0.95450
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77131, Loss: 0.09754
#
# Episode: 19800/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.63/s)
#     Loss: 0.02425
#     Accuracy: 0.96069
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79556, Loss: 0.08992
#
# Episode: 20000/25000 to 20200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.80/s)
#     Loss: 0.02789
#     Accuracy: 0.95687
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78556, Loss: 0.08730
#
# Episode: 20200/25000 to 20400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.84/s)
#     Loss: 0.02545
#     Accuracy: 0.95756
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75044, Loss: 0.09972
#
# Episode: 20400/25000 to 20600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.67/s)
#     Loss: 0.02723
#     Accuracy: 0.95888
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76706, Loss: 0.09243
#
# Episode: 20600/25000 to 20800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.98/s)
#     Loss: 0.02791
#     Accuracy: 0.95525
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76081, Loss: 0.10478
#
# Episode: 20800/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.84/s)
#     Loss: 0.02638
#     Accuracy: 0.96013
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77800, Loss: 0.09586
#
# Episode: 21000/25000 to 21200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.1s (28.34/s)
#     Loss: 0.02630
#     Accuracy: 0.96262
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77713, Loss: 0.09593
#
# Episode: 21200/25000 to 21400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.71/s)
#     Loss: 0.02641
#     Accuracy: 0.95825
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78463, Loss: 0.09497
#
# Episode: 21400/25000 to 21600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.46/s)
#     Loss: 0.02504
#     Accuracy: 0.96181
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78775, Loss: 0.08701
#
# Episode: 21600/25000 to 21800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.84/s)
#     Loss: 0.02726
#     Accuracy: 0.95588
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77219, Loss: 0.09195
#
# Episode: 21800/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.68/s)
#     Loss: 0.02431
#     Accuracy: 0.96731
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78531, Loss: 0.09206
#
# Episode: 22000/25000 to 22200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.49/s)
#     Loss: 0.02580
#     Accuracy: 0.95925
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77013, Loss: 0.11037
#
# Episode: 22200/25000 to 22400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.40/s)
#     Loss: 0.02413
#     Accuracy: 0.96200
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75081, Loss: 0.11396
#
# Episode: 22400/25000 to 22600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.42/s)
#     Loss: 0.02755
#     Accuracy: 0.95656
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78106, Loss: 0.10320
#
# Episode: 22600/25000 to 22800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.78/s)
#     Loss: 0.03152
#     Accuracy: 0.94550
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74894, Loss: 0.10206
#
# Episode: 22800/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.49/s)
#     Loss: 0.02658
#     Accuracy: 0.95294
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80100, Loss: 0.08592
#
# Episode: 23000/25000 to 23200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.65/s)
#     Loss: 0.02349
#     Accuracy: 0.97113
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73681, Loss: 0.11429
#
# Episode: 23200/25000 to 23400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.42/s)
#     Loss: 0.02828
#     Accuracy: 0.95719
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77612, Loss: 0.08980
#
# Episode: 23400/25000 to 23600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.1s (28.11/s)
#     Loss: 0.02536
#     Accuracy: 0.96050
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77331, Loss: 0.09346
#
# Episode: 23600/25000 to 23800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.2s (27.74/s)
#     Loss: 0.02243
#     Accuracy: 0.96363
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75100, Loss: 0.09938
#
# Episode: 23800/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.60/s)
#     Loss: 0.02777
#     Accuracy: 0.95606
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78144, Loss: 0.09259
#
# Episode: 24000/25000 to 24200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.70/s)
#     Loss: 0.02423
#     Accuracy: 0.96044
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77513, Loss: 0.09861
#
# Episode: 24200/25000 to 24400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.45/s)
#     Loss: 0.02252
#     Accuracy: 0.96788
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73656, Loss: 0.10625
#
# Episode: 24400/25000 to 24600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.57/s)
#     Loss: 0.02360
#     Accuracy: 0.96519
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77519, Loss: 0.09038
#
# Episode: 24600/25000 to 24800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.1s (28.34/s)
#     Loss: 0.02151
#     Accuracy: 0.96844
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78119, Loss: 0.09059
#
# Episode: 24800/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.0s (28.43/s)
#     Loss: 0.02532
#     Accuracy: 0.96344
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76925, Loss: 0.09196

# %% [markdown]
# Success of the training is examined by analyzing the training curve.

# %%
plot_traincurve('training/run_0', ['train_accuracy', 'eval_accuracy'], 'Accuracy')

# %% [markdown]
# ## Perform a tuning run

# %% [markdown]
# The most decisive hyperparameters present in the model are determined by a tuning process, which runs the model training several times and tries to boost the models performance by minimizing the evaluation-loss with adaptations to the hyperparameters.

# %%
tuning = optuna.create_study(direction="minimize", 
                             sampler = optuna.samplers.TPESampler(),
                             pruner = optuna.pruners.MedianPruner(n_startup_trials=5))

tuning.optimize(run_tuning, n_trials=25)

pruned_trials = tuning.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = tuning.get_trials(deepcopy=False, states=[TrialState.COMPLETE])
importances = optuna.importance.get_param_importances(tuning)

print('\n')
print('#######################################################################')
print('########################### FINISHED TUNING ###########################')
print('#######################################################################')
print('\n \n')

print('Tuning statistics: ')
print('  Number of trials: ', len(tuning.trials))
print('  Number of pruned trials: ', len(pruned_trials))
print('  Number of complete trials: ', len(complete_trials), '\n')

print('Best trial:')
trial = tuning.best_trial

print(f'  Run {str(trial.number)} with Loss {min(trial.intermediate_values.values())} at Episode {min(trial.intermediate_values, key=trial.intermediate_values.get)}')

print('  Params: ')
for key, value in trial.params.items():
  print('    {}: {}'.format(key, value))
# Out:
# [I 2022-06-02 06:51:36,309] A new study created in memory with name: no-name-1b8539ff-e8d9-4f52-9adf-ac0a561978ad
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_0
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.6s (21.20/s)
#     Loss: 0.16110
#     Accuracy: 0.19983
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.6s (20.30/s)
#     Loss: 0.16000
#     Accuracy: 0.19983
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.8s (20.97/s)
#     Loss: 0.16000
#     Accuracy: 0.20018
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.7s (21.08/s)
#     Loss: 0.16000
#     Accuracy: 0.20025
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.6s (21.18/s)
#     Loss: 0.16000
#     Accuracy: 0.20008
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.1s (20.77/s)
#     Loss: 0.16000
#     Accuracy: 0.20075
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.7s (21.12/s)
#     Loss: 0.16000
#     Accuracy: 0.20010
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.7s (20.28/s)
#     Loss: 0.16000
#     Accuracy: 0.19963
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.6s (21.17/s)
#     Loss: 0.16000
#     Accuracy: 0.19855
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.7s (21.10/s)
#     Loss: 0.16000
#     Accuracy: 0.20165
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.5s (21.26/s)
#     Loss: 0.16000
#     Accuracy: 0.19898
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.6s (21.19/s)
#     Loss: 0.16000
#     Accuracy: 0.20135
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.6s (21.17/s)
#     Loss: 0.16000
#     Accuracy: 0.20028
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.8s (20.98/s)
#     Loss: 0.16000
#     Accuracy: 0.20008
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.8s (21.02/s)
#     Loss: 0.16000
#     Accuracy: 0.19958
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.6s (21.17/s)
#     Loss: 0.16000
#     Accuracy: 0.19945
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.9s (20.91/s)
#     Loss: 0.16000
#     Accuracy: 0.19998
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.0s (20.83/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.7s (21.07/s)
#     Loss: 0.16000
#     Accuracy: 0.20008
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.9s (20.95/s)
#     Loss: 0.16000
#     Accuracy: 0.19885
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.7s (21.12/s)
#     Loss: 0.16000
#     Accuracy: 0.20045
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.5s (21.27/s)
#     Loss: 0.16000
#     Accuracy: 0.19968
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.8s (21.00/s)
#     Loss: 0.16000
#     Accuracy: 0.19985
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20119, Loss: 0.16000
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.8s (21.05/s)
#     Loss: 0.16000
#     Accuracy: 0.20075
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.8s (20.15/s)
#     Loss: 0.16000
#     Accuracy: 0.19923
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.18656, Loss: 0.16000
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.8s (20.98/s)
#     Loss: 0.16000
#     Accuracy: 0.20050
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.2s (20.66/s)
#     Loss: 0.16000
#     Accuracy: 0.19978
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21375, Loss: 0.16000
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.8s (20.16/s)
#     Loss: 0.16000
#     Accuracy: 0.20010
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.1s (20.77/s)
#     Loss: 0.16000
#     Accuracy: 0.19963
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.6s (21.20/s)
#     Loss: 0.16000
#     Accuracy: 0.20003
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.6s (21.17/s)
#     Loss: 0.16000
#     Accuracy: 0.19970
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.5s (21.25/s)
#     Loss: 0.16000
#     Accuracy: 0.19943
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.6s (20.30/s)
#     Loss: 0.16000
#     Accuracy: 0.19978
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.9s (20.92/s)
#     Loss: 0.16000
#     Accuracy: 0.19963
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.0s (20.84/s)
#     Loss: 0.16000
#     Accuracy: 0.20040
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.5s (21.27/s)
#     Loss: 0.16000
#     Accuracy: 0.19990
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.9s (20.90/s)
#     Loss: 0.16000
#     Accuracy: 0.20003
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.1s (20.79/s)
#     Loss: 0.16000
#     Accuracy: 0.19943
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.0s (20.79/s)
#     Loss: 0.16000
#     Accuracy: 0.20023
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.5s (21.27/s)
#     Loss: 0.16000
#     Accuracy: 0.19980
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.3s (21.50/s)
#     Loss: 0.16000
#     Accuracy: 0.19983
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.0s (21.70/s)
#     Loss: 0.16000
#     Accuracy: 0.19985
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.4s (21.41/s)
#     Loss: 0.16000
#     Accuracy: 0.19990
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.0s (21.76/s)
#     Loss: 0.16000
#     Accuracy: 0.20013
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.2s (20.67/s)
#     Loss: 0.16000
#     Accuracy: 0.20030
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.1s (21.65/s)
#     Loss: 0.16000
#     Accuracy: 0.19983
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.3s (21.47/s)
#     Loss: 0.16000
#     Accuracy: 0.19965
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.4s (21.40/s)
#     Loss: 0.16000
#     Accuracy: 0.20008
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.2s (20.63/s)
#     Loss: 0.16000
#     Accuracy: 0.19993
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.1s (20.77/s)
#     Loss: 0.16000
#     Accuracy: 0.19998
# [I 2022-06-02 07:16:13,452] Trial 0 finished with value: 0.15999998152256012 and parameters: {'num_fc_layers': 1, 'num_units_fc_layer0': 16, 'num_lstm_layer_encoder': 3, 'num_units_lstm_encoder': 256, 'num_lstm_layer_relationnet': 2, 'num_units_lstm_relationnet': 32, 'learning_rate': 0.0037253684212622123, 'learning_rate_schedule_rate': 2500}. Best is trial 0 with value: 0.15999998152256012.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20025, Loss: 0.16000
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_1
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.38/s)
#     Loss: 0.16946
#     Accuracy: 0.20260
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20325, Loss: 0.15998
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.6s (16.36/s)
#     Loss: 0.15641
#     Accuracy: 0.21990
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.28813, Loss: 0.15267
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.40/s)
#     Loss: 0.15978
#     Accuracy: 0.20678
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20187, Loss: 0.15943
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.40/s)
#     Loss: 0.15955
#     Accuracy: 0.24065
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.28137, Loss: 0.15904
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.42/s)
#     Loss: 0.15441
#     Accuracy: 0.26250
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.32056, Loss: 0.14697
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.8s (16.23/s)
#     Loss: 0.14872
#     Accuracy: 0.29565
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.30781, Loss: 0.14604
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.6s (16.34/s)
#     Loss: 0.14935
#     Accuracy: 0.31393
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.33181, Loss: 0.14481
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.41/s)
#     Loss: 0.14936
#     Accuracy: 0.31948
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.32856, Loss: 0.14480
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.37/s)
#     Loss: 0.14821
#     Accuracy: 0.34670
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.35906, Loss: 0.14371
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.8s (16.26/s)
#     Loss: 0.14544
#     Accuracy: 0.38665
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.36294, Loss: 0.14546
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.39/s)
#     Loss: 0.14436
#     Accuracy: 0.40765
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.37244, Loss: 0.14689
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.37/s)
#     Loss: 0.14075
#     Accuracy: 0.43270
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.38138, Loss: 0.14483
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.6s (16.36/s)
#     Loss: 0.13856
#     Accuracy: 0.46923
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.39463, Loss: 0.14507
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.38/s)
#     Loss: 0.12946
#     Accuracy: 0.52685
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.40956, Loss: 0.14475
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.37/s)
#     Loss: 0.12160
#     Accuracy: 0.58233
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.43775, Loss: 0.14301
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.7s (16.29/s)
#     Loss: 0.11544
#     Accuracy: 0.62483
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.45650, Loss: 0.14302
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.6s (16.35/s)
#     Loss: 0.11299
#     Accuracy: 0.63643
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.48769, Loss: 0.13491
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.39/s)
#     Loss: 0.10952
#     Accuracy: 0.66285
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.47775, Loss: 0.14566
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.40/s)
#     Loss: 0.10690
#     Accuracy: 0.67265
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.49700, Loss: 0.13826
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.40/s)
#     Loss: 0.10464
#     Accuracy: 0.68145
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.50344, Loss: 0.13647
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.41/s)
#     Loss: 0.10239
#     Accuracy: 0.69888
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.50725, Loss: 0.13611
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.37/s)
#     Loss: 0.10064
#     Accuracy: 0.71090
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.51531, Loss: 0.13862
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.41/s)
#     Loss: 0.09727
#     Accuracy: 0.72228
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.53594, Loss: 0.14248
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.37/s)
#     Loss: 0.09258
#     Accuracy: 0.74257
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.52812, Loss: 0.13765
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.37/s)
#     Loss: 0.09235
#     Accuracy: 0.74835
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.51487, Loss: 0.13717
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.7s (16.29/s)
#     Loss: 0.08961
#     Accuracy: 0.76132
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.56075, Loss: 0.12994
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.37/s)
#     Loss: 0.08600
#     Accuracy: 0.77430
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.59562, Loss: 0.12189
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.6s (16.34/s)
#     Loss: 0.08581
#     Accuracy: 0.77795
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.57788, Loss: 0.12958
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.38/s)
#     Loss: 0.08167
#     Accuracy: 0.79420
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60487, Loss: 0.13601
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.6s (16.36/s)
#     Loss: 0.08041
#     Accuracy: 0.80133
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.61369, Loss: 0.12288
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.40/s)
#     Loss: 0.07982
#     Accuracy: 0.80227
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.59919, Loss: 0.13223
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.38/s)
#     Loss: 0.07763
#     Accuracy: 0.80850
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.62500, Loss: 0.11998
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.7s (16.31/s)
#     Loss: 0.07585
#     Accuracy: 0.81692
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60619, Loss: 0.12976
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.6s (16.33/s)
#     Loss: 0.07222
#     Accuracy: 0.82855
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.62750, Loss: 0.12554
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.7s (16.31/s)
#     Loss: 0.07284
#     Accuracy: 0.83192
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.63250, Loss: 0.12464
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.1s (16.06/s)
#     Loss: 0.07204
#     Accuracy: 0.82905
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.63487, Loss: 0.11470
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.6s (16.33/s)
#     Loss: 0.06650
#     Accuracy: 0.84670
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65381, Loss: 0.12095
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.8s (16.25/s)
#     Loss: 0.07002
#     Accuracy: 0.83365
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64819, Loss: 0.11548
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.7s (16.29/s)
#     Loss: 0.06674
#     Accuracy: 0.85165
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66144, Loss: 0.11947
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.7s (16.29/s)
#     Loss: 0.06420
#     Accuracy: 0.86040
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65800, Loss: 0.10960
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.6s (16.37/s)
#     Loss: 0.06381
#     Accuracy: 0.85718
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67019, Loss: 0.12639
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.7s (16.28/s)
#     Loss: 0.06325
#     Accuracy: 0.86797
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66781, Loss: 0.11238
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.6s (16.36/s)
#     Loss: 0.06228
#     Accuracy: 0.86355
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67713, Loss: 0.11695
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.6s (16.35/s)
#     Loss: 0.05994
#     Accuracy: 0.87475
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67656, Loss: 0.11105
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.6s (16.34/s)
#     Loss: 0.06030
#     Accuracy: 0.87145
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68750, Loss: 0.11004
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.7s (16.31/s)
#     Loss: 0.05868
#     Accuracy: 0.87918
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69275, Loss: 0.10728
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.6s (16.35/s)
#     Loss: 0.05912
#     Accuracy: 0.88283
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68412, Loss: 0.11379
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.37/s)
#     Loss: 0.05710
#     Accuracy: 0.88135
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70931, Loss: 0.10991
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.6s (16.35/s)
#     Loss: 0.05606
#     Accuracy: 0.88845
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72475, Loss: 0.10300
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.5s (16.41/s)
#     Loss: 0.05231
#     Accuracy: 0.89862
# [I 2022-06-02 07:47:18,775] Trial 1 finished with value: 0.10300043306313456 and parameters: {'num_fc_layers': 3, 'num_units_fc_layer0': 64, 'num_units_fc_layer1': 32, 'num_units_fc_layer2': 256, 'num_lstm_layer_encoder': 1, 'num_units_lstm_encoder': 32, 'num_lstm_layer_relationnet': 2, 'num_units_lstm_relationnet': 256, 'learning_rate': 8.360111733565294e-05, 'learning_rate_schedule_rate': 7000}. Best is trial 1 with value: 0.10300043306313456.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71194, Loss: 0.10723
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_2
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.8s (25.27/s)
#     Loss: 0.16939
#     Accuracy: 0.20075
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20106, Loss: 0.16000
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.7s (25.34/s)
#     Loss: 0.15390
#     Accuracy: 0.24485
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.32081, Loss: 0.14746
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.6s (25.53/s)
#     Loss: 0.14841
#     Accuracy: 0.30205
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31469, Loss: 0.14512
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.0s (25.03/s)
#     Loss: 0.14841
#     Accuracy: 0.29700
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31712, Loss: 0.14616
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.8s (25.28/s)
#     Loss: 0.14832
#     Accuracy: 0.30227
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.33087, Loss: 0.14441
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.9s (25.17/s)
#     Loss: 0.14924
#     Accuracy: 0.30087
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.32944, Loss: 0.14391
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.9s (25.08/s)
#     Loss: 0.14860
#     Accuracy: 0.29835
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31438, Loss: 0.14649
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.6s (24.32/s)
#     Loss: 0.14969
#     Accuracy: 0.29272
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31531, Loss: 0.14521
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.8s (25.24/s)
#     Loss: 0.14807
#     Accuracy: 0.31018
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.32550, Loss: 0.14474
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.9s (25.14/s)
#     Loss: 0.14937
#     Accuracy: 0.30290
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.33087, Loss: 0.14639
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.7s (25.34/s)
#     Loss: 0.14828
#     Accuracy: 0.31203
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.34469, Loss: 0.14394
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.6s (25.57/s)
#     Loss: 0.14619
#     Accuracy: 0.34137
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.39706, Loss: 0.14300
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.7s (25.40/s)
#     Loss: 0.14287
#     Accuracy: 0.38173
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.42513, Loss: 0.13680
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.7s (25.32/s)
#     Loss: 0.13737
#     Accuracy: 0.43710
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.41163, Loss: 0.14205
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.6s (25.48/s)
#     Loss: 0.13269
#     Accuracy: 0.47012
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.44981, Loss: 0.13755
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.6s (25.53/s)
#     Loss: 0.12758
#     Accuracy: 0.52930
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.47525, Loss: 0.14024
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.8s (25.31/s)
#     Loss: 0.11744
#     Accuracy: 0.61045
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.51062, Loss: 0.13318
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.2s (24.77/s)
#     Loss: 0.10589
#     Accuracy: 0.66387
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.51219, Loss: 0.13964
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.9s (23.95/s)
#     Loss: 0.09908
#     Accuracy: 0.71303
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.54912, Loss: 0.12803
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.4s (24.55/s)
#     Loss: 0.09325
#     Accuracy: 0.73860
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.57888, Loss: 0.12571
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.4s (24.57/s)
#     Loss: 0.08319
#     Accuracy: 0.77725
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.59794, Loss: 0.12255
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.3s (24.67/s)
#     Loss: 0.07591
#     Accuracy: 0.80385
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.62106, Loss: 0.11906
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.1s (23.72/s)
#     Loss: 0.07442
#     Accuracy: 0.82155
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.57550, Loss: 0.12816
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.0s (24.98/s)
#     Loss: 0.07099
#     Accuracy: 0.82863
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.61806, Loss: 0.11805
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.0s (24.95/s)
#     Loss: 0.06962
#     Accuracy: 0.83225
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64088, Loss: 0.11653
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.4s (24.45/s)
#     Loss: 0.06635
#     Accuracy: 0.84968
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64281, Loss: 0.11872
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.5s (24.34/s)
#     Loss: 0.06167
#     Accuracy: 0.86430
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.61875, Loss: 0.13736
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.3s (24.58/s)
#     Loss: 0.05971
#     Accuracy: 0.86732
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64375, Loss: 0.12393
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.4s (24.47/s)
#     Loss: 0.06180
#     Accuracy: 0.86387
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.63919, Loss: 0.11714
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.5s (24.37/s)
#     Loss: 0.05628
#     Accuracy: 0.87727
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67100, Loss: 0.11399
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.4s (24.51/s)
#     Loss: 0.05424
#     Accuracy: 0.88620
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67725, Loss: 0.11114
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.6s (24.27/s)
#     Loss: 0.05227
#     Accuracy: 0.88593
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66650, Loss: 0.11215
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.7s (24.21/s)
#     Loss: 0.04980
#     Accuracy: 0.89493
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66556, Loss: 0.12141
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.6s (24.31/s)
#     Loss: 0.05073
#     Accuracy: 0.89055
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68700, Loss: 0.10672
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.7s (24.18/s)
#     Loss: 0.04877
#     Accuracy: 0.89693
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68050, Loss: 0.11092
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.3s (24.58/s)
#     Loss: 0.04932
#     Accuracy: 0.89788
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65650, Loss: 0.11587
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.5s (24.34/s)
#     Loss: 0.04980
#     Accuracy: 0.90033
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70800, Loss: 0.10906
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.2s (23.58/s)
#     Loss: 0.04934
#     Accuracy: 0.90040
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68250, Loss: 0.12012
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.4s (24.47/s)
#     Loss: 0.04567
#     Accuracy: 0.90633
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69063, Loss: 0.11200
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.5s (24.45/s)
#     Loss: 0.04501
#     Accuracy: 0.91163
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69656, Loss: 0.11327
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.4s (24.55/s)
#     Loss: 0.04254
#     Accuracy: 0.91883
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69381, Loss: 0.10803
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.4s (24.45/s)
#     Loss: 0.04406
#     Accuracy: 0.91320
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69050, Loss: 0.11187
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.6s (24.29/s)
#     Loss: 0.04227
#     Accuracy: 0.91945
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68694, Loss: 0.11208
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.6s (24.32/s)
#     Loss: 0.04101
#     Accuracy: 0.91725
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70606, Loss: 0.11267
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.5s (24.41/s)
#     Loss: 0.04290
#     Accuracy: 0.91505
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68794, Loss: 0.11478
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.6s (24.22/s)
#     Loss: 0.04388
#     Accuracy: 0.91225
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72444, Loss: 0.10111
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.4s (24.45/s)
#     Loss: 0.03988
#     Accuracy: 0.91995
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71050, Loss: 0.10702
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.5s (24.40/s)
#     Loss: 0.03926
#     Accuracy: 0.92200
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70306, Loss: 0.10953
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.6s (24.32/s)
#     Loss: 0.04103
#     Accuracy: 0.92018
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72781, Loss: 0.10006
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.5s (24.43/s)
#     Loss: 0.03952
#     Accuracy: 0.92485
# [I 2022-06-02 08:08:05,104] Trial 2 finished with value: 0.10005863102152944 and parameters: {'num_fc_layers': 1, 'num_units_fc_layer0': 16, 'num_lstm_layer_encoder': 2, 'num_units_lstm_encoder': 32, 'num_lstm_layer_relationnet': 3, 'num_units_lstm_relationnet': 16, 'learning_rate': 0.0007831050774003899, 'learning_rate_schedule_rate': 500}. Best is trial 2 with value: 0.10005863102152944.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71719, Loss: 0.10494
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_3
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.7s (24.13/s)
#     Loss: 0.15432
#     Accuracy: 0.26223
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.30844, Loss: 0.14889
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.9s (23.93/s)
#     Loss: 0.15434
#     Accuracy: 0.24705
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20106, Loss: 0.15972
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.7s (24.16/s)
#     Loss: 0.15439
#     Accuracy: 0.29885
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.36312, Loss: 0.14799
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.7s (24.11/s)
#     Loss: 0.13970
#     Accuracy: 0.46130
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.44975, Loss: 0.14185
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.8s (24.06/s)
#     Loss: 0.12025
#     Accuracy: 0.59778
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.49850, Loss: 0.13320
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.8s (24.06/s)
#     Loss: 0.11006
#     Accuracy: 0.66543
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.52775, Loss: 0.12800
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.8s (24.05/s)
#     Loss: 0.10374
#     Accuracy: 0.69858
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.55044, Loss: 0.13227
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.6s (24.28/s)
#     Loss: 0.09956
#     Accuracy: 0.72080
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60137, Loss: 0.12418
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.1s (23.71/s)
#     Loss: 0.09642
#     Accuracy: 0.73100
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.58300, Loss: 0.13040
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.0s (23.77/s)
#     Loss: 0.08918
#     Accuracy: 0.76042
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.59500, Loss: 0.12055
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.1s (23.65/s)
#     Loss: 0.08752
#     Accuracy: 0.77475
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.63013, Loss: 0.11510
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.8s (24.00/s)
#     Loss: 0.08195
#     Accuracy: 0.79038
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.63725, Loss: 0.11631
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.7s (24.12/s)
#     Loss: 0.07803
#     Accuracy: 0.80805
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65175, Loss: 0.13077
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.8s (24.09/s)
#     Loss: 0.07480
#     Accuracy: 0.82342
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68662, Loss: 0.10353
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.9s (23.97/s)
#     Loss: 0.06999
#     Accuracy: 0.83515
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68081, Loss: 0.10809
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.8s (24.05/s)
#     Loss: 0.06610
#     Accuracy: 0.85137
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71569, Loss: 0.10822
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.4s (23.39/s)
# ...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_23
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.2s (24.71/s)
#     Loss: 0.15477
#     Accuracy: 0.29055
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.35800, Loss: 0.14932
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.8s (24.00/s)
#     Loss: 0.13522
#     Accuracy: 0.49938
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.46019, Loss: 0.14151
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.1s (24.82/s)
#     Loss: 0.11334
#     Accuracy: 0.64370
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.50219, Loss: 0.13536
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.3s (24.62/s)
#     Loss: 0.09998
#     Accuracy: 0.70835
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.52106, Loss: 0.14257
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.6s (23.14/s)
#     Loss: 0.08923
#     Accuracy: 0.75645
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.59537, Loss: 0.13663
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.3s (23.47/s)
#     Loss: 0.08289
#     Accuracy: 0.79200
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.62319, Loss: 0.12841
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.6s (24.25/s)
#     Loss: 0.07365
#     Accuracy: 0.82230
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67419, Loss: 0.13487
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.6s (24.22/s)
#     Loss: 0.06779
#     Accuracy: 0.84330
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69181, Loss: 0.11310
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.4s (23.40/s)
#     Loss: 0.06090
#     Accuracy: 0.86435
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70800, Loss: 0.10199
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.6s (24.24/s)
#     Loss: 0.05876
#     Accuracy: 0.87638
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70306, Loss: 0.10432
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.6s (24.22/s)
#     Loss: 0.05292
#     Accuracy: 0.89047
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70500, Loss: 0.12469
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.8s (24.08/s)
#     Loss: 0.05259
#     Accuracy: 0.88930
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75181, Loss: 0.09619
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.7s (24.12/s)
#     Loss: 0.05175
#     Accuracy: 0.89568
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71150, Loss: 0.10586
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.9s (23.88/s)
#     Loss: 0.04992
#     Accuracy: 0.90048
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75319, Loss: 0.09759
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.6s (24.27/s)
#     Loss: 0.04843
#     Accuracy: 0.90503
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72500, Loss: 0.09956
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.5s (24.43/s)
#     Loss: 0.04807
#     Accuracy: 0.90738
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73300, Loss: 0.09767
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.4s (24.55/s)
#     Loss: 0.04561
#     Accuracy: 0.91375
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73744, Loss: 0.09904
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.4s (24.52/s)
#     Loss: 0.04490
#     Accuracy: 0.91408
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74181, Loss: 0.09733
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.2s (23.58/s)
#     Loss: 0.04332
#     Accuracy: 0.92085
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71906, Loss: 0.10413
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.4s (24.55/s)
#     Loss: 0.04190
#     Accuracy: 0.92258
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75469, Loss: 0.09883
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.7s (24.16/s)
#     Loss: 0.04011
#     Accuracy: 0.92528
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74350, Loss: 0.09349
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.7s (24.18/s)
#     Loss: 0.03644
#     Accuracy: 0.93560
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72450, Loss: 0.10022
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.6s (24.25/s)
#     Loss: 0.03721
#     Accuracy: 0.93515
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75644, Loss: 0.09981
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.4s (24.45/s)
#     Loss: 0.03382
#     Accuracy: 0.94270
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77150, Loss: 0.09341
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.2s (24.70/s)
#     Loss: 0.03552
#     Accuracy: 0.94240
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74800, Loss: 0.09773
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.5s (24.37/s)
#     Loss: 0.03335
#     Accuracy: 0.94555
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76750, Loss: 0.09395
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.7s (23.00/s)
#     Loss: 0.03287
#     Accuracy: 0.94473
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74825, Loss: 0.09514
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.3s (23.44/s)
#     Loss: 0.03230
#     Accuracy: 0.94935
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76350, Loss: 0.09952
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.2s (23.54/s)
#     Loss: 0.03020
#     Accuracy: 0.95638
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75662, Loss: 0.09037
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.0s (23.80/s)
#     Loss: 0.02860
#     Accuracy: 0.95703
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77119, Loss: 0.09102
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.9s (23.91/s)
#     Loss: 0.03131
#     Accuracy: 0.95135
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76519, Loss: 0.09509
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.8s (24.07/s)
#     Loss: 0.02700
#     Accuracy: 0.96018
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76513, Loss: 0.09724
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.9s (23.90/s)
#     Loss: 0.02749
#     Accuracy: 0.95638
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75981, Loss: 0.09738
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.3s (23.50/s)
#     Loss: 0.02717
#     Accuracy: 0.95958
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76331, Loss: 0.09759
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.2s (23.62/s)
#     Loss: 0.02571
#     Accuracy: 0.96378
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75994, Loss: 0.09706
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.4s (23.38/s)
#     Loss: 0.02414
#     Accuracy: 0.96498
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79819, Loss: 0.09093
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.5s (23.27/s)
#     Loss: 0.02601
#     Accuracy: 0.96113
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77938, Loss: 0.09910
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.6s (23.18/s)
#     Loss: 0.02534
#     Accuracy: 0.96533
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79131, Loss: 0.08996
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.4s (23.33/s)
#     Loss: 0.02432
#     Accuracy: 0.96533
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78731, Loss: 0.08674
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.1s (23.72/s)
#     Loss: 0.02488
#     Accuracy: 0.96523
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78800, Loss: 0.09083
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.2s (23.60/s)
#     Loss: 0.02368
#     Accuracy: 0.96475
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79006, Loss: 0.08773
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.1s (23.73/s)
#     Loss: 0.02359
#     Accuracy: 0.96463
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75881, Loss: 0.09704
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.9s (23.96/s)
#     Loss: 0.02313
#     Accuracy: 0.96620
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79206, Loss: 0.08479
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.9s (23.90/s)
#     Loss: 0.02220
#     Accuracy: 0.96605
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78081, Loss: 0.08894
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.0s (23.79/s)
#     Loss: 0.02276
#     Accuracy: 0.96573
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79281, Loss: 0.08909
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.7s (22.99/s)
#     Loss: 0.02263
#     Accuracy: 0.96755
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74438, Loss: 0.10307
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.0s (23.81/s)
#     Loss: 0.02366
#     Accuracy: 0.96453
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77819, Loss: 0.09109
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.0s (23.77/s)
#     Loss: 0.02099
#     Accuracy: 0.96990
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75475, Loss: 0.10153
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.1s (23.72/s)
#     Loss: 0.02192
#     Accuracy: 0.96820
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78037, Loss: 0.10013
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 20.8s (23.98/s)
#     Loss: 0.02144
#     Accuracy: 0.96850
# [I 2022-06-02 11:38:05,180] Trial 23 finished with value: 0.08217962952330708 and parameters: {'num_fc_layers': 3, 'num_units_fc_layer0': 256, 'num_units_fc_layer1': 256, 'num_units_fc_layer2': 256, 'num_lstm_layer_encoder': 1, 'num_units_lstm_encoder': 64, 'num_lstm_layer_relationnet': 3, 'num_units_lstm_relationnet': 32, 'learning_rate': 0.0013020903375178196, 'learning_rate_schedule_rate': 4500}. Best is trial 14 with value: 0.08022754887118935.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80819, Loss: 0.08218
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_24
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.5s (25.65/s)
#     Loss: 0.15593
#     Accuracy: 0.26708
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.32094, Loss: 0.14913
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.6s (25.54/s)
#     Loss: 0.15128
#     Accuracy: 0.31097
# [I 2022-06-02 11:38:54,901] Trial 24 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.35337, Loss: 0.14758
#
#
#
# #######################################################################
# ########################### FINISHED TUNING ###########################
# #######################################################################
#
#
#
# Tuning statistics:
#   Number of trials:  25
#   Number of pruned trials:  13
#   Number of complete trials:  12
#
# Best trial:
#   Run 14 with Loss 0.08022754887118935 at Episode 21500
#   Params:
#     num_fc_layers: 3
#     num_units_fc_layer0: 256
#     num_units_fc_layer1: 256
#     num_units_fc_layer2: 128
#     num_lstm_layer_encoder: 1
#     num_units_lstm_encoder: 64
#     num_lstm_layer_relationnet: 3
#     num_units_lstm_relationnet: 32
#     learning_rate: 0.0005971638092109761
#     learning_rate_schedule_rate: 8500

# %% [markdown]
# Zip and push tuning results to Google Drive.

# %%
push_zip('/content/tuning', gdrive + f'/results/tuning/{N_WAY}way-{K_SHOT}shot.zip')

with open(gdrive + f'/results/tuning/importances_{N_WAY}way-{K_SHOT}shot.pkl', 'wb') as handle:
    pickle.dump(importances, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Analyze the tuning run

# %% [markdown]
# Load and unpack tuning results from Google Drive.

# %%
os.system(f'cp -R /content/drive/MyDrive/ml_projects/STRHANGE/results/tuning/{N_WAY}way-{K_SHOT}shot.zip /content')
shutil.unpack_archive(f'{N_WAY}way-{K_SHOT}shot.zip', '/content')

with open(gdrive + f'/results/tuning/importances_{N_WAY}way-{K_SHOT}shot.pkl', 'rb') as handle:
  importances = pickle.load(handle)

# %% [markdown]
# Success of the tuning process is examined by analyzing the best values in each run and the training curves.

# %%
plot_tuning_history('tuning', 'eval_accuracy', 'Validations Accuracy', 'maximize')

# %%
plot_tuning_traincurves('tuning', 'eval_accuracy', 'Validations Accuracy', 'maximize', 15)

# %%
best_trials = tuning.trials_dataframe().nsmallest(5, 'value').transpose().drop(['number', 'datetime_start', 'datetime_complete'])

print(tabulate(best_trials, tablefmt = 'latex', headers=best_trials.columns, numalign="right", floatfmt=".2f"))
# Out:
# \begin{tabular}{llllll}
# \hline
#                                     & 14                     & 15                     & 23                     & 10                     & 3                      \\
# \hline
#  value                              & 0.08022754887118935    & 0.08068484615534544    & 0.08217962952330708    & 0.08574400572106242    & 0.08596631704829633    \\
#  duration                           & 0 days 00:21:55.327162 & 0 days 00:22:06.936174 & 0 days 00:21:46.063021 & 0 days 00:21:53.909313 & 0 days 00:21:51.063321 \\
#  params\_learning\_rate               & 0.0005971638092109761  & 0.00047957381837833825 & 0.0013020903375178196  & 0.0066892502117050796  & 0.005507534429883377   \\
#  params\_learning\_rate\_schedule\_rate & 8500                   & 9500                   & 4500                   & 6000                   & 1500                   \\
#  params\_num\_fc\_layers               & 3                      & 3                      & 3                      & 3                      & 2                      \\
#  params\_num\_lstm\_layer\_encoder      & 1                      & 1                      & 1                      & 1                      & 2                      \\
#  params\_num\_lstm\_layer\_relationnet  & 3                      & 2                      & 3                      & 3                      & 3                      \\
#  params\_num\_units\_fc\_layer0         & 256                    & 256                    & 256                    & 128                    & 128                    \\
#  params\_num\_units\_fc\_layer1         & 256.0                  & 256.0                  & 256.0                  & 64.0                   & 64.0                   \\
#  params\_num\_units\_fc\_layer2         & 128.0                  & 128.0                  & 256.0                  & 16.0                   & nan                    \\
#  params\_num\_units\_lstm\_encoder      & 64                     & 64                     & 64                     & 64                     & 32                     \\
#  params\_num\_units\_lstm\_relationnet  & 32                     & 128                    & 32                     & 32                     & 32                     \\
#  state                              & COMPLETE               & COMPLETE               & COMPLETE               & COMPLETE               & COMPLETE               \\
# \hline
# \end{tabular}

# %%
plot_traincurve('tuning/run_15', ['train_accuracy', 'eval_accuracy'], 'Accuracy')

# %%
plot_tuning_parameter_importance(importances)

# %% [markdown]
# ## Model selection

# %% [markdown]
# Select the final model (run an episode to stop) on the basis of the tuning analyses.

# %%
selected_run = 'run_15'
selected_episode = '13500'

# %% [markdown]
# # Model evaluation

# %% [markdown]
# Evaluate the model on unseen data.

# %%
conf_matrix, classification_report, accuracy = run_testing(num_testruns = 1000, samples_per_run = 32, run_dir = f'tuning/{selected_run}', episode = f'e{selected_episode}', test_classes = test_classes)

# %%
model_name = f'{N_WAY}-way_{K_SHOT}-sup'
path = os.path.join(gdrive, 'results', 'tests')

np.save(os.path.join(path, f'{model_name}_CM.npy'), conf_matrix)
classification_report.to_pickle(os.path.join(path, f'{model_name}_CR.pkl'))
np.save(os.path.join(path, f'{model_name}_ACC.npy'), accuracy)

# %% [markdown]
# Visualize Confusion Matrix

# %%
plot_conf_matrix (conf_matrix, test_classes, y_og)

# %% [markdown]
# Analyse Accuracy, Precision, Recall and F-Score.

# %%
print(f'Average Accuracy of the model on testdata {accuracy}\n')
print(f'Average Precision of the model on testdata {round(classification_report.Precision.mean(),3)}\n')
print(f'Average Recall of the model on testdata {round(classification_report.Recall.mean(),3)}\n')
print(f'Average F-Score of the model on testdata {round(classification_report.FScore.mean(),3)}\n')

print(tabulate(classification_report, tablefmt = 'latex', headers=classification_report.columns, numalign="right", floatfmt=".2f"))
# Out:
# Average Accuracy of the model on testdata 0.77370625
#
# Average Precision of the model on testdata 0.777
#
# Average Recall of the model on testdata 0.775
#
# Average F-Score of the model on testdata 0.774
#
# \begin{tabular}{lrrr}
# \hline
#                &   Precision &   Recall &   FScore \\
# \hline
#  0 (0 \& 0)     &        0.95 &     0.98 &     0.93 \\
#  3 (0 \& 3)     &        0.89 &     0.88 &     0.88 \\
#  12 (0 \& 12)   &        0.93 &     0.97 &     0.95 \\
#  13 (0 \& 13)   &        0.95 &     0.94 &     0.94 \\
#  15 (0 \& 15)   &        0.88 &     0.75 &     0.81 \\
#  19 (0 \& 19)   &        0.92 &     0.96 &     0.94 \\
#  21 (0 \& 21)   &        0.87 &     0.87 &     0.87 \\
#  24 (0 \& 24)   &        0.90 &     0.88 &     0.89 \\
#  81 (3 \& 3)    &        0.60 &     0.61 &     0.60 \\
#  90 (3 \& 12)   &        0.84 &     0.80 &     0.82 \\
#  91 (3 \& 13)   &        0.79 &     0.76 &     0.78 \\
#  93 (3 \& 15)   &        0.56 &     0.56 &     0.56 \\
#  97 (3 \& 19)   &        0.68 &     0.74 &     0.71 \\
#  99 (3 \& 21)   &        0.65 &     0.66 &     0.65 \\
#  102 (3 \& 24)  &        0.71 &     0.62 &     0.67 \\
#  315 (12 \& 3)  &        0.82 &     0.83 &     0.82 \\
#  324 (12 \& 12) &        0.97 &     0.97 &     0.97 \\
#  325 (12 \& 13) &        0.95 &     0.92 &     0.94 \\
#  327 (12 \& 15) &        0.84 &     0.72 &     0.77 \\
#  331 (12 \& 19) &        0.82 &     0.91 &     0.86 \\
#  333 (12 \& 21) &        0.83 &     0.82 &     0.82 \\
#  336 (12 \& 24) &        0.86 &     0.75 &     0.80 \\
#  341 (13 \& 3)  &        0.75 &     0.81 &     0.78 \\
#  350 (13 \& 12) &        0.92 &     0.91 &     0.91 \\
#  351 (13 \& 13) &        0.90 &     0.97 &     0.94 \\
#  353 (13 \& 15) &        0.77 &     0.84 &     0.80 \\
#  357 (13 \& 19) &        0.84 &     0.91 &     0.87 \\
#  359 (13 \& 21) &        0.81 &     0.83 &     0.82 \\
#  362 (13 \& 24) &        0.78 &     0.79 &     0.79 \\
#  393 (15 \& 3)  &        0.65 &     0.69 &     0.67 \\
#  402 (15 \& 12) &        0.85 &     0.77 &     0.81 \\
#  403 (15 \& 13) &        0.82 &     0.79 &     0.81 \\
#  405 (15 \& 15) &        0.60 &     0.56 &     0.58 \\
#  409 (15 \& 19) &        0.64 &     0.61 &     0.63 \\
#  411 (15 \& 21) &        0.66 &     0.62 &     0.64 \\
#  414 (15 \& 24) &        0.68 &     0.58 &     0.63 \\
#  497 (19 \& 3)  &        0.64 &     0.68 &     0.66 \\
#  506 (19 \& 12) &        0.84 &     0.84 &     0.84 \\
#  507 (19 \& 13) &        0.85 &     0.88 &     0.86 \\
#  509 (19 \& 15) &        0.64 &     0.65 &     0.64 \\
#  513 (19 \& 19) &        0.71 &     0.79 &     0.75 \\
#  515 (19 \& 21) &        0.67 &     0.75 &     0.71 \\
#  518 (19 \& 24) &        0.70 &     0.66 &     0.68 \\
#  549 (21 \& 3)  &        0.61 &     0.66 &     0.63 \\
#  558 (21 \& 12) &        0.85 &     0.84 &     0.85 \\
#  559 (21 \& 13) &        0.83 &     0.85 &     0.84 \\
#  561 (21 \& 15) &        0.62 &     0.67 &     0.64 \\
#  565 (21 \& 19) &        0.66 &     0.68 &     0.67 \\
#  567 (21 \& 21) &        0.72 &     0.72 &     0.72 \\
#  570 (21 \& 24) &        0.73 &     0.62 &     0.67 \\
#  627 (24 \& 3)  &        0.68 &     0.72 &     0.70 \\
#  636 (24 \& 12) &        0.89 &     0.91 &     0.90 \\
#  637 (24 \& 13) &        0.85 &     0.90 &     0.88 \\
#  639 (24 \& 15) &        0.69 &     0.63 &     0.66 \\
#  643 (24 \& 19) &        0.69 &     0.78 &     0.73 \\
#  645 (24 \& 21) &        0.76 &     0.71 &     0.74 \\
#  648 (24 \& 24) &        0.76 &     0.69 &     0.72 \\
# \hline
# \end{tabular}

# %% [markdown]
# # Model saving

# %% [markdown]
# Save the best model to the Google Drive.

# %%
push_model_to_gdrive(f'tuning/{selected_run}', f'e{selected_episode}',f'{N_WAY}way-{K_SHOT}shot')
