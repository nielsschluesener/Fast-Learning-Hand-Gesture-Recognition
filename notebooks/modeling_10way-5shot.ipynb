# %% [markdown]
# #Environment configuration

# %% [markdown]
# Install packages.

# %%
#Don't run this code unless you really want to install the packages.
#!pip install alive-progress -q
#!pip install optuna -q

# %% [markdown]
# Import packages.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR

import optuna
from optuna.trial import TrialState

import numpy as np
import os
import math
import argparse
import random
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import itertools
import shutil

from google.colab import drive
from alive_progress import alive_bar
from tabulate import tabulate
import time

# %% [markdown]
# Mount and config GDrive & paths.

# %%
drive.mount('/content/drive')
gdrive = '/content/drive/My Drive/ml_projects/STRHANGE/'

keypoints_path = gdrive + '/data/JESTER/extracted/'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Experiment configuration

# %%
N_WAY = 10
K_SHOT = 5

# %% [markdown]
# # Set up functions and classes

# %% [markdown]
# This section contains all functions and classes that are important for the remainder of this notebook. An explanation of the functions and their parameters & outputs can be found in the function headers.

# %% [markdown]
# #### Model training

# %%
def run_training(task_param, input_param, model_param, training_param):
  """
  Training Function - performs a single model training for a set of parameters
  Args:
    task_param (dict): task-related parameters
    input_param (dict): input-related parameters
    model_param (dict): model-related parameters
    training_param (dict): training-related paramaters
  Returns:
    logging (pd.dataframe): dataframe with user configurated logging information on the training-history
  """

  ### PARAMETER UNPACKING AND INITIALIZATION ###
  print('Initializing training...\n')

  #task-parameters
  SUPPORT_NUM_PER_CLASS = task_param['support_num_per_class'] 
  QUERY_NUM_PER_CLASS = task_param['query_num_per_class']  
  NUM_CLASSES = task_param['num_classes']  

  #input-parameters
  SEQUENCE_LENGTH = input_param['sequence_length']
  FEATURE_LENGTH = input_param['feature_length'] 

  #model-parameters
  NUM_LSTM_LAYER_ENCODER = model_param['num_lstm_layer_encoder']
  NUM_UNITS_LSTM_ENCODER = model_param['num_units_lstm_encoder']
  NUM_LSTM_LAYER_RELATIONNET = model_param['num_lstm_layer_relationnet']
  NUM_UNITS_LSTM_RELATIONNET = model_param['num_units_lstm_relationnet']
  NUM_UNITS_FC_RELU = model_param['num_units_fc_relu']

  #training-parameters
  LEARNING_RATE = training_param['learning_rate']
  LEARNING_RATE_SCHEDULE_RATE = training_param['learning_rate_schedule_rate']
  NUM_TRAIN_EPISODES = training_param['num_train_episodes']
  UPDATE_AND_EVAL_RATE = training_param['update_and_eval_rate']
  NUM_EVAL_EPISODES = training_param['num_eval_episodes']
  SAVE_PATH = training_param['save_path']
  SAVE_LOGGING = training_param['save_logging']
  SAVE_ALL = training_param['save_all']
  SAVE_BEST = training_param['save_best']
  TUNING_RUN = training_param['tuning_run']
  trial = training_param['trial']

  if NUM_TRAIN_EPISODES % UPDATE_AND_EVAL_RATE != 0:
    raise ValueError(f'Invalid Parameters: UPDATE_AND_EVAL_RATE must be a multiple of NUM_TRAIN_EPISODES.')

  print('  Parameters accepted and set.')

  ### MODEL INITIALIZATION ###
  feature_encoder = LSTMEncoder(FEATURE_LENGTH, NUM_UNITS_LSTM_ENCODER, NUM_LSTM_LAYER_ENCODER).to(device)
  print('  Feature encoder intialized, initial weights set.')
  relation_network = RelationNetwork(NUM_UNITS_LSTM_ENCODER*2, NUM_UNITS_LSTM_RELATIONNET, NUM_UNITS_FC_RELU, NUM_LSTM_LAYER_RELATIONNET).to(device) 
  print('  Relation network intialized, initial weights set.')

  feature_encoder_optim = torch.optim.Adam(feature_encoder.parameters(),lr=LEARNING_RATE)
  feature_encoder_scheduler = StepLR(feature_encoder_optim,step_size=LEARNING_RATE_SCHEDULE_RATE,gamma=0.5) 

  relation_network_optim = torch.optim.Adam(relation_network.parameters(),lr=LEARNING_RATE)
  relation_network_scheduler = StepLR(relation_network_optim,step_size=LEARNING_RATE_SCHEDULE_RATE,gamma=0.5) 

  mse = nn.MSELoss().to(device)

  print('  Optimizer & Learning Rate Scheduler initalized.')

  ### SET UP LOGGING ###

  # Create logging dir for current run
  logging = []
  if SAVE_LOGGING == True or SAVE_ALL == True or SAVE_BEST == True:

    if not os.path.exists(SAVE_PATH):
      os.makedirs(SAVE_PATH)

    run = 0
    run_list = os.listdir(SAVE_PATH)

    for i in range(len(run_list)):
      try:
        run_list[i] = int(run_list[i].split('_')[1])
      except:
        next

    run_list = [num for num in run_list if isinstance(num, (int,float))]

    if run_list:
      run = int(max(run_list)) + 1
    log_dir = os.path.join(SAVE_PATH, 'run_' + str(run))

    if not os.path.exists(log_dir):
      os.makedirs(log_dir)

    #Log params to logging dir
    with open(log_dir + '/task_param.pkl', 'wb') as f:
      pickle.dump(task_param, f)

    with open(log_dir + '/input_param.pkl', 'wb') as f:
      pickle.dump(input_param, f)      

    with open(log_dir + '/model_param.pkl', 'wb') as f:
      pickle.dump(model_param, f)

    with open(log_dir + '/training_param.pkl', 'wb') as f:
      pickle.dump(training_param, f)
  
  print(f'  Created logging folder: {log_dir}')

  print('\nTraining initalized. \n\n')

  print('Start training...\n')

  ### TRAINING ###

  #loop over number of episodes
  for episode in range(int(NUM_TRAIN_EPISODES/UPDATE_AND_EVAL_RATE)):

    print(f'Episode: {episode*UPDATE_AND_EVAL_RATE}/{NUM_TRAIN_EPISODES} to {(episode + 1) * UPDATE_AND_EVAL_RATE}/{NUM_TRAIN_EPISODES}')

    step_train_accuracy = 0
    step_train_loss = 0

    with alive_bar(UPDATE_AND_EVAL_RATE, title=f'  Training...', force_tty = True) as bar:
      for i in range(UPDATE_AND_EVAL_RATE):
        # Generate task and get data
        query_x, query_y, support_x, support_y = gen_task(n_way = NUM_CLASSES, n_support = SUPPORT_NUM_PER_CLASS, n_query = QUERY_NUM_PER_CLASS, data_x = X, data_y = y, split = 'train')
        query_x, query_y, support_x, support_y = query_x.to(device), query_y.to(device), support_x.to(device), support_y.to(device)
          
        # Predict
        relations, query_y_one_hot = predict(feature_encoder, relation_network, support_x, query_x, query_y, NUM_CLASSES, SUPPORT_NUM_PER_CLASS, QUERY_NUM_PER_CLASS, SEQUENCE_LENGTH, NUM_UNITS_LSTM_ENCODER)

        # Calculate loss         
        loss = mse(relations,query_y_one_hot)
        step_train_loss += loss.item()

        # Calculate accuracy 
        _,predict_labels = torch.max(relations.data,1)
        rewards = [1 if predict_labels[j]==query_y[j] else 0 for j in range(NUM_CLASSES*QUERY_NUM_PER_CLASS)]
        accuracy = np.sum(rewards)/1.0/NUM_CLASSES/QUERY_NUM_PER_CLASS
        step_train_accuracy += accuracy

        #backpropagation - adjust the model's parameter
        feature_encoder.zero_grad()
        relation_network.zero_grad()

        loss.backward()

        torch.nn.utils.clip_grad_norm_(feature_encoder.parameters(),0.5)
        torch.nn.utils.clip_grad_norm_(relation_network.parameters(),0.5)

        feature_encoder_optim.step()
        relation_network_optim.step()

        #update status bar
        bar()

    # print loss and acc for episode
    step_train_loss = step_train_loss/UPDATE_AND_EVAL_RATE
    step_train_accuracy = step_train_accuracy/UPDATE_AND_EVAL_RATE

    print(f'    Loss: {step_train_loss:.5f}')
    print(f'    Accuracy: {step_train_accuracy:.5f}')

    # start validation
    with torch.no_grad():

      step_eval_loss = 0
      step_eval_accuracy = 0
      best_eval_accuracy = 0

      for i in range(NUM_EVAL_EPISODES):

        # Generate task and get data
        query_x, query_y, support_x, support_y = gen_task(n_way = NUM_CLASSES, n_support = SUPPORT_NUM_PER_CLASS, n_query = QUERY_NUM_PER_CLASS, data_x = X, data_y = y, split = 'eval')
        query_x, query_y, support_x, support_y = query_x.to(device), query_y.to(device), support_x.to(device), support_y.to(device)

        # Predict
        relations, query_y_one_hot = predict(feature_encoder, relation_network, support_x, query_x, query_y, NUM_CLASSES, SUPPORT_NUM_PER_CLASS, QUERY_NUM_PER_CLASS, SEQUENCE_LENGTH, NUM_UNITS_LSTM_ENCODER)

        # Calculate loss             
        loss = mse(relations,query_y_one_hot)
        step_eval_loss += loss.item()

        # Calculate rewards for accuracy 
        _,predict_labels = torch.max(relations.data,1)
        rewards = [1 if predict_labels[j]==query_y[j] else 0 for j in range(NUM_CLASSES*QUERY_NUM_PER_CLASS)]
        step_eval_accuracy += np.sum(rewards)

      # Calculate and print loss / acc for validation-run
      step_eval_loss = step_eval_loss / NUM_EVAL_EPISODES
      step_eval_accuracy = step_eval_accuracy/1.0/NUM_CLASSES/QUERY_NUM_PER_CLASS/NUM_EVAL_EPISODES

      logging.append([step_train_loss, step_train_accuracy, step_eval_loss, step_eval_accuracy])

      print(f'  Validation with {NUM_EVAL_EPISODES} Evaluation-Episodes. Accuracy: {step_eval_accuracy:.5f}, Loss: {step_eval_loss:.5f}\n' )

      # Report results to optuna-tuning
      if TUNING_RUN == True:
        trial.report(step_eval_loss, episode * UPDATE_AND_EVAL_RATE)

        # Prune trial and save logging if loss-decrease is not promising
        if trial.should_prune():
          if SAVE_LOGGING == True:
            logging = pd.DataFrame(logging, columns=['train_loss', 'train_accuracy', 'eval_loss', 'eval_accuracy'])
            logging.eval_loss.iloc[0] = logging.train_loss.iloc[0]
            logging.eval_accuracy.iloc[0] = logging.train_accuracy.iloc[0]
            logging.to_pickle(log_dir + '/logging.pkl')
          raise optuna.exceptions.TrialPruned()

      # Save network 
      if (SAVE_BEST == True or SAVE_ALL == True) and not os.path.exists(os.path.join(log_dir, 'models')):
        os.makedirs(os.path.join(log_dir, 'models'))

      if SAVE_BEST == True and step_eval_accuracy > best_eval_accuracy:
        torch.save(feature_encoder.state_dict(),str(log_dir + '/models/feature_encoder_best.pkl'))
        torch.save(relation_network.state_dict(),str(log_dir + '/models/relation_network_best.pkl'))

      if SAVE_ALL == True:
        torch.save(feature_encoder.state_dict(),str(log_dir + '/models/feature_encoder_e' + str(episode*UPDATE_AND_EVAL_RATE) + '.pkl'))
        torch.save(relation_network.state_dict(),str(log_dir + '/models/relation_network_e' + str(episode*UPDATE_AND_EVAL_RATE) + '.pkl'))

  # Save logging
  if SAVE_LOGGING == True:
    logging = pd.DataFrame(logging, columns=['train_loss', 'train_accuracy', 'eval_loss', 'eval_accuracy'])
    logging.eval_loss.iloc[0] = logging.train_loss.iloc[0]
    logging.eval_accuracy.iloc[0] = logging.train_accuracy.iloc[0]

    logging.to_pickle(log_dir + '/logging.pkl')

  return logging

# %% [markdown]
# #### Hyperparameter tuning

# %%
def run_tuning(trial):
  """
  Tuning Function - performs multiple model trainings and optimizes hyperparameters
  Args:
    trial (optunia-trial-object): current trial object of the optuna tuning process
  Returns:
    min_eval_loss (float): minimal loss on evaluation set
  """

  # Caution: some parameters have to be set manually to match the given task, input and training specifications
  # (this has to be done within this function, because optuna does not support additional args)

  # Set tuning parameters  
  task_param = {'support_num_per_class': K_SHOT,
                'query_num_per_class': 16,
                'num_classes': N_WAY}

  # Set input parameters  
  input_param = {'sequence_length': 72,
                 'feature_length': 63}

  # Set model parameters (suggestions by optuna)
  num_fc_layers = trial.suggest_int("num_fc_layers", 1, 3, step = 1)
  num_units_fc_relu = []
  for i in range(num_fc_layers):
    num_units = trial.suggest_categorical("num_units_fc_layer{}".format(i), [16, 32, 64, 128, 256])
    num_units_fc_relu.append(num_units)

  model_param = {'num_lstm_layer_encoder': trial.suggest_int("num_lstm_layer_encoder", 1, 3, step=1),
                 'num_units_lstm_encoder': trial.suggest_categorical("num_units_lstm_encoder", [16, 32, 64, 128, 256]),
                 'num_lstm_layer_relationnet': trial.suggest_int("num_lstm_layer_relationnet", 1, 3, step=1),
                 'num_units_lstm_relationnet': trial.suggest_categorical("num_units_lstm_relationnet", [16, 32, 64, 128, 256]),
                 'num_units_fc_relu': num_units_fc_relu}

  # Set training parameters
  training_param = {'learning_rate': trial.suggest_float("learning_rate", 0.00001, 0.01,  log=True),
                    'learning_rate_schedule_rate': trial.suggest_int("learning_rate_schedule_rate", 500, 10000, step = 500),
                    'num_train_episodes': 25000,
                    'update_and_eval_rate': 500,
                    'num_eval_episodes': 200,
                    'save_path': 'tuning',
                    'save_logging': True,
                    'save_all': True,
                    'save_best': True,
                    'tuning_run': True,
                    'trial': trial}

  # run training with parameters of this trial
  logs = run_training(task_param, input_param, model_param, training_param)

  # report minimal evaluation loss to optuna
  min_eval_loss = logs.eval_loss.min()
  return min_eval_loss

# %% [markdown]
# #### Unique tasks calculator

# %%
def get_classcombinations(classes, num_in_comb):
  """
  Generates a set of unique tasks for a given list of classes and a number different of classes in each task
  Args:
    classes (list): list of classes
    num_in_comb (int): number different of classes in each task
  Returns:
    unique_tasks (set): set of unique tasks
  """

  unique_tasks = set(itertools.combinations(classes, num_in_comb))
  return unique_tasks

# %% [markdown]
# #### Task generator

# %%
def gen_task(n_way, n_support, n_query, data_x, data_y, split):
  """
  Generates a task (classify n-query gestures of n_way classes with n_support suppoting samples) for the few shot model.
  Args:
    n_way (int): number of classes
    n_support (int): number of support samples in each class
    n_query (int): batch size of query samples 
    data_x (np.array): hand keypoints (usually X)
    data_y (np.array): labels (usually y)
    split (str): type of split (train, evel, test or jester)
  Returns:
    query_x (torch tensor): query set data
    query_y (torch tensor): query set labels
    support_x (torch tensor): support set data
    support_y (torch tensor): support set labels 
    (classes (np.array)): list of original classes 
  """

  #sample random classes from the predfined list of classes, depended of the split-type
  query_x, query_y, support_x, support_y = [], [], [], []
  if split == 'train':
    classes = np.random.choice(training_classes, n_way, replace=False)
  elif split == 'eval':
    classes = np.random.choice(eval_classes, n_way, replace=False) 
  elif split == 'test':
    classes = np.random.choice(test_classes, n_way, replace=False) 
  elif split == 'jester':
    classes = np.random.choice(jester_comp_classes, n_way, replace=False) 

  #loop over classes of this task, sample X data and generate labels (always 0 to n-classes)
  for i, c in enumerate(classes):
    data_x_c = data_x[data_y == c]

    query_x.append(data_x_c[np.random.choice(data_x_c.shape[0], n_query, replace=False), :, :])
    query_y.append([i] * n_query)

    support_x.append(data_x_c[np.random.choice(data_x_c.shape[0], n_support, replace=False), :, :])
    support_y.append([i] * n_support)

  #reshape Data
  query_x = np.reshape(query_x, (n_way * n_query, np.array(query_x).shape[2], np.array(query_x).shape[3]))
  query_y = np.reshape(query_y, n_way * n_query)
  support_x = np.reshape(support_x, (n_way * n_support, np.array(support_x).shape[2], np.array(support_x).shape[3]))
  support_y = np.reshape(support_y, n_way * n_support)

  #change to torch tensors
  query_x = torch.from_numpy(query_x).float()
  query_y = torch.from_numpy(query_y).float().type(torch.LongTensor) 
  support_x = torch.from_numpy(support_x).float()
  support_y = torch.from_numpy(support_y).float().type(torch.LongTensor) 

  #Return statements
  if split == 'train' or split == 'eval':   
    return query_x, query_y, support_x, support_y
  elif split == 'test' or split == 'jester':
    return query_x, query_y, support_x, support_y, classes

# %% [markdown]
# #### Model components

# %%
class LSTMEncoder(nn.Module):
  """First part of the model, which encodes the sequence of hand gesture keypoints"""
  def __init__(self, input_size, hidden_lstm_size, num_lstm_layer):
    """
    Object initialization.
    Args:
      input_size (int): size of the input data
      hidden_lstm_size (int): number of units in lstm-cell
      num_lstm_layer (int): number of stacked lstm-layers
    """
    super(LSTMEncoder, self).__init__()
    self.input_size = input_size 
    self.hidden_lstm_size = hidden_lstm_size 
    self.num_lstm_layer = num_lstm_layer

    #create lstm layer(s)
    self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_lstm_size, num_layers = num_lstm_layer, batch_first=True)

  def forward(self,x):
    """
    Forward pass through the LSTM Encoder
    Args:
      x (torch tensor): data input (sequence of hand keypoints as batch)
    Return:
      out (torch tensor): encoded data (encoded sequence of hand keypoints as batch) with size batch, sequence, hidden_size
    """

    #create zeros with size num_layer, sequences, hidden_size 
    #h0 containing the final hidden state for each element in the sequence
    h0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device)  
    #c0 containing the final cell state for each element in the sequence
    c0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device) 

    #pass data through the lstm layer(s)
    out, _ = self.lstm(x, (h0,c0))
    return out 


class RelationNetwork(nn.Module):
  """Second part of the model, which calculates the relation-scores, given the concatenated query and support samples"""
  def __init__(self,input_size, hidden_lstm_size, fc_sizes: list, num_lstm_layer):
    """
    Object initialization.
    Args:
      input_size (int): size of the input data
      hidden_lstm_size (int): number of units in lstm-cell
      fc_sizes (list): number of units per fully connected / linear layer
      num_lstm_layer (int): number of stacked lstm-layers
    """
    super(RelationNetwork, self).__init__()
    self.input_size = input_size 
    self.hidden_lstm_size = hidden_lstm_size
    self.layers = nn.ModuleList()
    self.num_lstm_layer = num_lstm_layer

    #create lstm layer(s)
    self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_lstm_size, num_layers = num_lstm_layer, batch_first=True)
    #next input_size is outputsize of the lstm layer (hidden_lstm_size)
    input_size = hidden_lstm_size

    #loop over fc_sizes, create linear layer + ReLU Activation and adjust the input_size
    for size in fc_sizes:
      self.layers.append(nn.Linear(input_size, size))
      self.layers.append(nn.ReLU())
      input_size = size  
 
    #add a final Linear Layer which reduces the input down to a single number, aka. the relation score, by applieing a sigmoid function
    self.end_layer = nn.Sequential(nn.Linear(input_size,1), nn.Sigmoid())
    
  def forward(self,x):
    """
    Forward pass through the Relation Network
    Args:
      x (torch tensor): concatenated data input of query- and support-samples 
    Return:
      out (torch tensor): relation scores
    """
    
    #create zeros with size num_layer, sequences, hidden_size 
    #h0 containing the final hidden state for each element in the sequence 
    h0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device) 
    #c0 containing the final cell state for each element in the sequence
    c0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device) 

    #pass data through the lstm layer(s)
    out, _ = self.lstm(x, (h0,c0))
    #reduce output to the last sequence-state 
    out = out[:, -1, :]

    #pass data through the fc layer(s)
    for layer in self.layers:
      out = layer(out)
    
    #pass data through the final layer to calculate the relation score
    out = self.end_layer(out) 
    return out

# %% [markdown]
# #### Prediction performer

# %%
def predict(feature_encoder, relation_network, support_x, query_x, query_y, num_classes, support_num_per_class, query_num_per_class, seq_length, num_units_lstm_encoder):
  """
  Prediction-Function 
  Args:
    feature_encoder (LSTMEncoder-object): initialized LSTMEncoder-object
    relation_network (RelationNetwork-object): initialized RelationNetwork-object
    support_x (torch tensor): data for support set
    support_y (torch tensor): labels for support set
    query_x (torch tensor): data for query set
    query_y (torch tensor): labels for query set
    num_classes (int): number of classes in the given task
    support_num_per_class (int): number of support samples per class in support set
    query_num_per_class (int): number of query samples per class in query set
    seq_length (int): length of sequence
    num_units_lstm_encoder (int): number of hidden units in the LSTM-Cells of the feature_encoder
  Returns:
    relations (torch tensor): relation scores 
    query_y_one_hot (torch tensor): predicted classes as one-hot-encoded vector
  """
  # calculate support features by passing the support set through the feature_encoder-module 
  support_features = feature_encoder(Variable(support_x).to(device))
  # calculate query features by passing the query set through the feature_encoder-module 
  query_features = feature_encoder(Variable(query_x).to(device))
          
  #Prepare encoded query and support set for relations calculation (reshaping, transposing)
  support_features = support_features.view(num_classes, support_num_per_class, seq_length, num_units_lstm_encoder)
  support_features = torch.sum(support_features, 1).squeeze(1)
  support_features_ext = support_features.unsqueeze(0).repeat(query_num_per_class*num_classes,1,1,1).to(device)
  query_features_ext = query_features.unsqueeze(0).repeat(num_classes,1,1,1)
  query_features_ext = torch.transpose(query_features_ext,0,1).to(device)

  # concatenated encoded query & support set
  relation_pairs = torch.cat((support_features_ext,query_features_ext),3).view(-1,seq_length, num_units_lstm_encoder*2).to(device)

  # calculate relations by passing the concatenated query & support set through the relation_network-module 
  relations = relation_network(relation_pairs).view(-1,num_classes).to(device)

  # turn relation-scores into one hot encoded predictions 
  query_y_one_hot = Variable(torch.zeros(query_num_per_class*num_classes, num_classes).to(device).scatter_(1, query_y.view(-1,1), 1)).to(device)

  return relations, query_y_one_hot

# %% [markdown]
# #### Logging loader

# %%
def load_logging_and_params_from_file(log_dir):
  """
  Loads the logging and parameters of a single training-run from a given directory
  Args:
    log_dir (str): location of logs and parameters of a single run
  Returns:
    logging (pd.dataframe: logging of the given run
    task_param (dict): task-related parameters of the given run
    input_param (dict): input-related parameters of the given run
    model_param (dict): model-related parameters of the given run
    training_param (dict): training-related paramaters of the given run
  """

  #check is given log_dir exist
  if os.path.isfile(os.path.join(log_dir,'logging.pkl')):
    #load logging and param-dirs
    logging = pd.read_pickle(os.path.join(log_dir, 'logging.pkl'))

    with open(os.path.join(log_dir, 'task_param.pkl'), 'rb') as f:
      task_param = pickle.load(f)

    with open(os.path.join(log_dir, 'input_param.pkl'), 'rb') as f:
      input_param = pickle.load(f)      

    with open(os.path.join(log_dir, 'model_param.pkl'), 'rb') as f:
      model_param = pickle.load(f)

    with open(os.path.join(log_dir, 'training_param.pkl'), 'rb') as f:
      training_param = pickle.load(f)

    #return logging and param-dirs
    return logging, task_param, input_param, model_param, training_param
  
  else:
    print(f'No logging found in {log_dir}')

# %% [markdown]
# #### Training-Curve visualization

# %%
def plot_traincurve(log_dir, metrics, ylabel):
  """
  Plots the training curve of a single train-run
  Args:
    log_dir (str): location of the training run
    metrics (list): metrics to be plotted 
    ylabel (str): label to be plotted on the y-axis
  """

  #Load logging from log_dir
  logging, _, _, _, training_param = load_logging_and_params_from_file(log_dir)

  plt.figure(figsize=(10, 5), dpi=100)
  colors = ['#00406C', '#1ABEA3'] 
  i = 0

  #Loop over metrics and visualize it as a line
  for col in metrics:
    plot_data = logging[col].dropna()
    plt.plot(plot_data.index.values * training_param['update_and_eval_rate'], plot_data.values, label=col, color = colors[i])
    i += 1

  l=plt.legend()
  l.get_texts()[0].set_text('Trainingsdaten')
  l.get_texts()[1].set_text('Validationsdaten')

  #plt.title('Learning Curve')
  plt.xlabel('Episode')
  plt.ylabel(ylabel)
  plt.ylim(0, 1)
  #plt.figlegend(bbox_to_anchor=(0.85,0.5), loc="center left")
  plt.tight_layout(rect=[0,0,0.85,1])

  plt.show()

# %% [markdown]
# #### Tuning-History visualization

# %%
def plot_tuning_history(tuning_dir, metric, y_label, direction):
  """
  Plots the training curves of all training-runs in a tuning dir 
  Args:
    tuning_dir (str): location of the tuning run
    metric (list): metrics to be plotted 
    y_label (str): label to be displayed on the y-axis
    direction (str): maximize or minimize
  """

  # Gather the data from every training-run in the tuning_dir
  tuning_metrics = []
  runs = []
  if os.path.isdir(tuning_dir):
    run_dirs = os.listdir(tuning_dir)

    def extract_nums (elem):
      return int(elem.split('_')[1])
    
    run_dirs.sort(key = extract_nums)

    for i in range(len(run_dirs)):
      if 'run' in run_dirs[i]:
        logging, _, _, _, training_param = load_logging_and_params_from_file(os.path.join(tuning_dir, run_dirs[i]))
        logging = logging[metric]
        tuning_metrics.append(list(logging))
        runs.append(run_dirs[i])  

    max_length = len(max(tuning_metrics, key=len))

    if direction == 'maximize':
      none_marker = 0
    elif direction == 'minimize':
      none_marker = 99
    else:
      return 'invalid direction'

    for i, log in enumerate(tuning_metrics):
      tuning_metrics[i] = (log + max_length * [none_marker])[:max_length]

    tuning_metrics = np.array(tuning_metrics).transpose()
    tuning_logs = pd.DataFrame(tuning_metrics, columns = runs)
    
  else:
    print('tuning_dir does not exist.')

# Check for pruned runs and when a run hits a new best-score
  pruned = []
  new_best = []
  
  if direction == 'maximize':
    best = 0

    for col in tuning_logs:
      if tuning_logs[col].max() > best:
        best = tuning_logs[col].max()
        new_best.append('#E76450')
      else:
        new_best.append('#FFC35E')

      if tuning_logs[col].min() == 0:
        pruned.append('x')
      else:
        pruned.append('o')

      data = tuning_logs.max()
     
  elif direction == 'minimize':
    best = 1
    for col in tuning_logs:
      if tuning_logs[col].min() < best:
        best = tuning_logs[col].min()
        new_best.append('#00406E')
      else:
        new_best.append('#17BEA3')

      if tuning_logs[col].max() == 99:
        pruned.append('x')
      else:
        pruned.append('o')

      data = tuning_logs.min()

  # Visualize history

  plt.figure(figsize=(10, 5), dpi=100)
  plt.plot(data, linestyle = 'dashed', color = '#C8D4D7')

  for i in range(len(data)):
    plt.plot(i, data[i], marker = pruned[i], markersize = 8, color = new_best[i])

  #plt.title('Tuning Entwicklung')
  plt.xlabel('Trainingsläufe')
  plt.xticks(rotation=45, horizontalalignment='center')
  plt.ylabel(y_label)
  plt.ylim(0, 1)

  plt.show()

# %% [markdown]
# #### Tuning-Traincurves visualization

# %%
def plot_tuning_traincurves(tuning_dir, metric, y_label, direction = None, top_n = None):
  """
  Plots the training curves of all training-runs in a tuning dir 
  Args:
    tuning_dir (str): location of the tuning run
    metric (list): metrics to be plotted 
    y_label (str): label to be displayed on the y-axis
    direction (str): maximize or minimize
    top (int): visualize top_n results, either highest or lowest, dependend on arg 'direction'
  """

  # Gather the data from every training-run in the tuning_dir
  tuning_metrics = []
  runs = []
  if os.path.isdir(tuning_dir):
    run_dirs = os.listdir(tuning_dir)

    def extract_nums (elem):
      return int(elem.split('_')[1])
    
    run_dirs.sort(key = extract_nums)

    for i in range(len(run_dirs)):
      if 'run' in run_dirs[i]:
        logging, _, _, _, training_param = load_logging_and_params_from_file(os.path.join(tuning_dir, run_dirs[i]))
        logging = logging[metric]
        tuning_metrics.append(list(logging))
        runs.append(run_dirs[i])  

    max_length = len(max(tuning_metrics, key=len))

    for i, log in enumerate(tuning_metrics):
      tuning_metrics[i] = (log + max_length * [0])[:max_length]

    tuning_metrics = np.array(tuning_metrics).transpose()
    tuning_logs = pd.DataFrame(tuning_metrics, columns = runs)
    
  else:
    print('tuning_dir does not exist.')

  # Filter to visualize only the top_n results

  if direction != None and top_n != None:
    if direction == 'maximize':
      tuning_logs = tuning_logs[tuning_logs.max().nlargest(top_n).index]
    elif direction == 'minimize':
      tuning_logs = tuning_logs[tuning_logs.min().nsmallest(top_n).index]
    else: 
      return 'invalid direction'


  # Visualize results
  plt.figure(figsize=(10, 5), dpi=100)
  for col in list(tuning_logs.columns.values):
    plot_data = tuning_logs[col].dropna()
    plt.plot(plot_data.index.values * training_param['update_and_eval_rate'], plot_data.values, label=col)

  #plt.title('Lernkurve')
  plt.xlabel('Episode')
  plt.ylabel(y_label)

  plt.figlegend(bbox_to_anchor=(0.85,0.5), loc="center left")
  plt.tight_layout(rect=[0,0,0.85,1])
  plt.ylim(0, 1)

  plt.show()

# %% [markdown]
# #### Tuning parameter's importance visualization

# %%
def plot_tuning_parameter_importance(importances):
  """
  Visualizes the importances of every parameter in a tuning run
  Args:
    importances (OrderedDict): importances of the tuning parameters
  """

  # create positions needed for horizontal plot
  y_pos = np.arange(start = len(importances.keys()), stop = 0, step = -1)

  # create plot
  plt.figure(figsize=(10, 5), dpi=100)
  plt.barh(y_pos, importances.values(), color = '#17BEA3')

  i = 0
  for v in reversed(importances.values()):
    plt.text(v + 0.003, i + 0.9, str(round(v, 3)), color = '#00406E')
    i += 1

  # adjust labels and axis
  plt.yticks(y_pos, labels=importances.keys())
  plt.title('')
  plt.xlabel('Relevanz für den Erfolg des Tunings')
  plt.ylabel('Tuning Parameter')
  plt.xlim(0, 0.75)
  plt.tight_layout()

  plt.show()

# %% [markdown]
# #### Zip and push to Google Drive

# %%
def push_zip(source, destination):
  """
  Zip and push a directory to the Google Drive
  Args:
    source (str): current location 
    destination (str): target location 
  """
  base = os.path.basename(destination)
  name = base.split('.')[0]
  format = base.split('.')[1]
  archive_from = os.path.dirname(source)
  archive_to = os.path.basename(source.strip(os.sep))
  shutil.make_archive(name, format, archive_from, archive_to)
  shutil.move('%s.%s'%(name,format), destination)

# %% [markdown]
# #### Model saving

# %%
def push_model_to_gdrive(run_dir, episode, model_name):
  """
  Push a model & the params needed for deployment, located in a local directory, to the Google Drive
  Args:
    run_dir (str): location of the model
    episode (list): episode of the model, either a number or 'best'
    model_name (str): model's name in the Google Drive
  """

  #config target_path
  path = os.path.join(gdrive, 'results', 'models')

  #load model and params
  feature_encoder, relation_network = load_model_from_file(run_dir, episode)
  _, task_param, input_param, model_param, _ = load_logging_and_params_from_file(run_dir)

  #unpack params needed for deployment
  deployment_param = {'support_num_per_class': task_param['support_num_per_class'],
                      'num_classes': task_param['num_classes'],
                      'sequence_length': input_param['sequence_length'],
                      'feature_length': input_param['feature_length'],
                      'num_lstm_layer_encoder': model_param['num_lstm_layer_encoder'],
                      'num_units_lstm_encoder': model_param['num_units_lstm_encoder'],
                      'num_lstm_layer_relationnet': model_param['num_lstm_layer_relationnet'],
                      'num_units_lstm_relationnet': model_param['num_units_lstm_relationnet'],
                      'num_units_fc_relu': model_param['num_units_fc_relu']}

  # Push to Google Drive
  torch.save(feature_encoder.state_dict(),str(os.path.join(path, f'{model_name}_feature_encoder.pkl')))
  torch.save(relation_network.state_dict(),str(os.path.join(path, f'{model_name}_relation_network.pkl')))
  with open(os.path.join(path, f'{model_name}_deployment_param.pkl'), 'wb') as f:
      pickle.dump(deployment_param, f)

# %% [markdown]
# #### Model loading

# %%
def load_model_from_file(run_dir, episode):
  """
  Loads and initializes a model from a given directory
  Args:
    run_dir (str): location of the model
    episode (list): episode of the model, either a number or 'best'
  Returns:
    feature_encoder (LSTMEncoder-object): initialized LSTMEncoder-object
    relation_network (RelationNetwork-object): initialized RelationNetwork-object
  """

  #load params needed for deployment
  _, _, input_param, model_param, _ = load_logging_and_params_from_file(run_dir)

  #initialize feature_encoder and relation_network
  feature_encoder = LSTMEncoder(input_param['feature_length'], model_param['num_units_lstm_encoder'], model_param['num_lstm_layer_encoder']).to(device)
  relation_network = RelationNetwork(model_param['num_units_lstm_encoder']*2, model_param['num_units_lstm_relationnet'], model_param['num_units_fc_relu'], model_param['num_lstm_layer_relationnet']).to(device) 

  #load weights from directory
  feature_encoder.load_state_dict(torch.load(os.path.join(run_dir, 'models', str('feature_encoder_' + episode + '.pkl'))))
  relation_network.load_state_dict(torch.load(os.path.join(run_dir, 'models', str('relation_network_' + episode + '.pkl'))))

  return feature_encoder, relation_network

# %% [markdown]
# #### Model testing

# %%
def run_testing(num_testruns, samples_per_run, run_dir, episode, test_classes, split):
  """
  Testing Function - performs model testing on test-classes
  Args:
    num_testruns (int): number of test-runs to be performed, each test-run == one task
    samples_per_run (int): number of samples to be drawn as a query set
    run_dir (str): location of the model to be tested
    episode (str): episode of the model to be tests, either a number or 'best'
    test_classes (list): list of test classes
    split (str): split for task_gen
  Returns:
    conf_matrix (np.array): summarized confusion matrix of the test-runs
    classification_report (pd.dataframe): summarized classification report of the test-runs
    accuracy (float): summarized accuracy of the test-runs
  """

  # load and initialize model from dir
  feature_encoder, relation_network = load_model_from_file(run_dir, episode)
  _, task_param, input_param, model_param, training_param = load_logging_and_params_from_file(run_dir)

  # initi empty conf_matrix
  conf_matrix = np.zeros(shape = (len(test_classes),len(test_classes)), dtype = int)

  # loop over num_testruns
  for testrun in range(num_testruns):
    # generate a task with query and support sets
    query_x, query_y, support_x, support_y, tested_classes = gen_task(n_way = task_param['num_classes'], n_support = task_param['support_num_per_class'], 
                                                                      n_query = samples_per_run, data_x = X, data_y = y, split = split)
    query_x, query_y, support_x, support_y = query_x.to(device), query_y.to(device), support_x.to(device), support_y.to(device)

    # perform prediction on query and support set
    relations, query_y_one_hot = predict(feature_encoder, relation_network, support_x, query_x, query_y, 
                                        task_param['num_classes'], task_param['support_num_per_class'], 
                                        samples_per_run, input_param['sequence_length'], model_param['num_units_lstm_encoder'])
    _,predict_labels = torch.max(relations.data,1)

    # analyse prediction and adjust conf matrix
    for i in range(len(query_y)):
      cm_index_true = test_classes.index(tested_classes[predict_labels[i].item()])
      cm_index_pred = test_classes.index(tested_classes[query_y[i].item()])

      conf_matrix[cm_index_true][cm_index_pred] += 1

  # Calculate recall, precison and f_score based on conf matrix
  recalls = []
  precisions = []
  f_scores = []

  for i in range(len(test_classes)):
    recalls.append(conf_matrix[i][i] / conf_matrix[:,i].sum())
    precisions.append(conf_matrix[i][i] / conf_matrix[i,:].sum())
    f_scores.append(2 * (precisions[i] * recalls[i]) / (precisions[i] + recalls[i]))

  # Calculate accuracy based on conf matrix
  accuracy = conf_matrix.diagonal().sum() / conf_matrix.sum()

  # save and return metrics
  classification_report = pd.DataFrame((precisions, recalls, f_scores)).transpose()
  classification_report.index = [f'{str(x)} ({str(y_og[x][0])} & {str(y_og[x][1])})' for x in test_classes]
  classification_report.index.names = ['Class']
  classification_report.rename(columns = {0: 'Precision', 1: 'Recall', 2: 'FScore'}, inplace = True)
  
  return conf_matrix, classification_report, accuracy

# %% [markdown]
# #### Confusion matrix visualization

# %%
def plot_conf_matrix (conf_matrix, test_classes, y_og):
  """
  Visualizes a given confusion matrix as a heatmap
  Args:
    conf_matrix (np.array): confustion matrix to be visualized
    test_classes (list): list of classes the model was tested on
    y_og (list): list of original classes (before the combination) matching the test_classes
  """

  true_labels = [f'{str(x)} ({str(y_og[x][0])} & {str(y_og[x][1])})' for x in test_classes]
  pred_labels = [f'{str(x)} ({str(y_og[x][0])} & {str(y_og[x][1])})' for x in test_classes]

  fig, ax = plt.subplots(figsize = (15,15))
  im = ax.imshow(conf_matrix, cmap = 'coolwarm') 

  # Show all ticks and label them with the respective list entries
  ax.set_xticks(np.arange(len(pred_labels)))
  ax.set_yticks(np.arange(len(true_labels)))

  ax.set_xticklabels(pred_labels)
  ax.set_yticklabels(true_labels)

  ax.xaxis.tick_top()
  ax.xaxis.set_label_position('top')

  # Rotate the tick labels and set their alignment
  plt.setp(ax.get_xticklabels(), rotation=45, ha="left",
          rotation_mode="anchor")

  plt.setp(ax.get_yticklabels(), rotation=0, ha="right")

  # Loop over data dimensions and create text annotations
  for i in range(len(true_labels)):
      for j in range(len(pred_labels)):
          text = ax.text(j, i, conf_matrix[i, j],
                        ha="center", va="center", color="w")

  ax.set_title("Confusion matrix", fontsize = 18)
  fig.tight_layout()
  plt.show()

# %% [markdown]
# # Load and split data

# %% [markdown]
# Load X (extraced and combined sequences of hand-keypoints), y (combined classes from 0 to 676) and y_og (original classes from 0 to 25) from Google Drive.

# %%
# Load X, y and y_og from Google Drive.
X = np.load(gdrive + '/data/JESTER/final/X.npy')
y = np.load(gdrive + '/data/JESTER/final/y.npy')
y_og = np.load(gdrive + '/data/JESTER/final/y_og.npy')

# Check shapes 
print(f'Labels shape {y.shape}')
print(f'Data shape {X.shape}')
unique, counts = np.unique(y, return_counts=True)
print(f'\nNumber of unique classes {len(unique)}')
# Out:
# Labels shape (169000,)
# Data shape (169000, 72, 63)
#
# Number of unique classes 676

# %% [markdown]
# ## Configurate Test-strategy

# %% [markdown]
# In contrast to common machine learning approaches, the train-, test-, evaluation-split in Few-Shot Learning use cases splits the data by classes instead of drawing random samples of observations.
#
# Classes are split by their original class labels (not by combined class labels) to prevent the model from seeing bits of the data in more than one of the splits.

# %%
label_map = {'No gesture': 0, #base class, mostly zeros
            'Drumming Fingers': 1, #static
            'Pulling Hand In': 2, #dynamic
            'Pulling Two Fingers In': 3, #dynamic
            'Pushing Hand Away': 4, #dynamic
            'Pushing Two Fingers Away': 5, #dynamic
            'Rolling Hand Backward': 6, #dynamic
            'Rolling Hand Forward': 7, #dynamic
            'Shaking Hand': 8, #static
            'Sliding Two Fingers Down': 9, #dynamic
            'Sliding Two Fingers Left': 10, #dynamic
            'Sliding Two Fingers Right': 11, #dynamic
            'Sliding Two Fingers Up': 12, #dynamic
            'Stop Sign': 13, #static
            'Swiping Down': 14, #dynamic
            'Swiping Left': 15, #dynamic
            'Swiping Right': 16, #dynamic
            'Swiping Up': 17, #dynamic
            'Thumb Down': 18, #static
            'Thumb Up': 19, #static
            'Turning Hand Clockwise': 20, #dynamic
            'Turning Hand Counterclockwise': 21, #dynamic
            'Zooming In With Full Hand': 22, #dynamic
            'Zooming In With Two Fingers': 23, #dynamic
            'Zooming Out With Full Hand': 24, #dynamic
            'Zooming Out With Two Fingers': 25} #dynamic

# %% [markdown]
# Choose original class labels (pre-combination) for training, evaluation and test splits.

# %%
train_y_origin = [0, 1, 4, 5, 6, 7, 9, 10, 16, 17, 22, 25]
eval_y_origin = [0, 2, 8, 11, 14, 18, 20, 23]
test_y_origin = [0, 3, 12, 13, 15, 19, 21, 24]
jester_comp_y = [0, 2, 8, 11, 14, 18, 20, 23, 3, 12, 13, 15, 19, 21, 24]

# %% [markdown]
# Turn splits with original class labels (pre-combination) into training-, evaluation- and test- classes with combined classes.

# %%
training_classes, eval_classes, test_classes, jester_comp_classes  = [], [], [], []

for i in range(len(y_og)):
  if ((y_og[i][0] == 0) and (y_og[i][1] in eval_y_origin)) or (y_og[i][0] in eval_y_origin or y_og[i][1] in eval_y_origin) and not (y_og[i][0] in train_y_origin or y_og[i][1] in train_y_origin) and not (y_og[i][0] in test_y_origin or y_og[i][1] in test_y_origin):
    eval_classes.append(i)
  if ((y_og[i][0] == 0) and (y_og[i][1] in train_y_origin)) or (y_og[i][0] in train_y_origin or y_og[i][1] in train_y_origin) and not (y_og[i][0] in eval_y_origin or y_og[i][1] in eval_y_origin) and not (y_og[i][0] in test_y_origin or y_og[i][1] in test_y_origin):
    training_classes.append(i)
  if ((y_og[i][0] == 0) and (y_og[i][1] in test_y_origin)) or (y_og[i][0] in test_y_origin or y_og[i][1] in test_y_origin) and not (y_og[i][0] in eval_y_origin or y_og[i][1] in eval_y_origin) and not (y_og[i][0] in train_y_origin or y_og[i][1] in train_y_origin):
    test_classes.append(i)
  if ((y_og[i][0] == 0) and (y_og[i][1] in jester_comp_y)):
    jester_comp_classes.append(i)

# %% [markdown]
# Examination of resulting training-, evaluation- and test-split.

# %%
print(f'Number of classes in train-split: {len(training_classes)}')
print(f'Number of classes in eval-split: {len(eval_classes)}')
print(f'Number of classes in test-split: {len(test_classes)}')
print(f'Number of classes in JESTER-evaluation-dataset: {len(jester_comp_classes)}')
# Out:
# Number of classes in train-split: 133
# Number of classes in eval-split: 57
# Number of classes in test-split: 57

# %%
#print(f'Potential number of unique tasks for training: {len(get_classcombinations(training_classes, N_WAY))}')
#print(f'Potential number of unique tasks for evaluation: {len(get_classcombinations(eval_classes, N_WAY))}')
#print(f'Potential number of unique tasks for testing: {len(get_classcombinations(test_classes, N_WAY))}')

# %% [markdown]
# # Model tuning and training

# %% [markdown]
# In this section the model is trained. Initially, this is performed once with parameters defined by the user. Next, the model's hyperparameters are optimized by a tuning process.

# %% [markdown]
# ## Perform a training run

# %% [markdown]
# To ensure that the training function operates flawlessly (& to have a baseline model), training of the model is performed once initially with low parameter complexity.

# %%
task_param = {'support_num_per_class': K_SHOT,
              'query_num_per_class': 16,
              'num_classes': N_WAY}

input_param = {'sequence_length': 72,
               'feature_length': 63}

model_param = {'num_lstm_layer_encoder': 1,
               'num_units_lstm_encoder': 64,
               'num_lstm_layer_relationnet': 1,
               'num_units_lstm_relationnet': 64,
               'num_units_fc_relu': [32]}

training_param = {'learning_rate': 0.001,
                  'learning_rate_schedule_rate': 2000,
                  'num_train_episodes': 25000,
                  'update_and_eval_rate': 200,
                  'num_eval_episodes': 200,
                  'save_path': 'training',
                  'save_logging': True,
                  'save_all': True,
                  'save_best': True,
                  'tuning_run': False,
                  'trial': None}
            
logs = run_training(task_param, input_param, model_param, training_param)
# Out:
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: training/run_0
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.41/s)
#     Loss: 0.09808
#     Accuracy: 0.12275
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20978, Loss: 0.08694
#
# Episode: 200/25000 to 400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.54/s)
#     Loss: 0.08583
#     Accuracy: 0.20497
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.22419, Loss: 0.08444
#
# Episode: 400/25000 to 600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.8s (15.65/s)
#     Loss: 0.08204
#     Accuracy: 0.32753
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.34663, Loss: 0.08011
#
# Episode: 600/25000 to 800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.41/s)
#     Loss: 0.06757
#     Accuracy: 0.55119
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.43775, Loss: 0.07543
#
# Episode: 800/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.7s (15.78/s)
#     Loss: 0.06054
#     Accuracy: 0.63550
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.46153, Loss: 0.07502
#
# Episode: 1000/25000 to 1200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.8s (15.62/s)
#     Loss: 0.05443
#     Accuracy: 0.68837
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.47828, Loss: 0.07373
#
# Episode: 1200/25000 to 1400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.41/s)
#     Loss: 0.05114
#     Accuracy: 0.72062
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.54319, Loss: 0.06643
#
# Episode: 1400/25000 to 1600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.26/s)
#     Loss: 0.04493
#     Accuracy: 0.76678
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60316, Loss: 0.06247
#
# Episode: 1600/25000 to 1800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.24/s)
#     Loss: 0.04123
#     Accuracy: 0.79284
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66200, Loss: 0.06770
#
# Episode: 1800/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.3s (15.00/s)
#     Loss: 0.03782
#     Accuracy: 0.81628
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71069, Loss: 0.05666
#
# Episode: 2000/25000 to 2200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.4s (14.96/s)
#     Loss: 0.03539
#     Accuracy: 0.83522
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69081, Loss: 0.05809
#
# Episode: 2200/25000 to 2400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.3s (15.09/s)
#     Loss: 0.03289
#     Accuracy: 0.84691
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72616, Loss: 0.05902
#
# Episode: 2400/25000 to 2600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.23/s)
#     Loss: 0.03135
#     Accuracy: 0.85919
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71847, Loss: 0.06393
#
# Episode: 2600/25000 to 2800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.2s (15.16/s)
#     Loss: 0.02778
#     Accuracy: 0.87713
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74303, Loss: 0.05029
#
# Episode: 2800/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.22/s)
#     Loss: 0.02805
#     Accuracy: 0.87950
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69838, Loss: 0.05644
#
# Episode: 3000/25000 to 3200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.3s (15.09/s)
#     Loss: 0.02689
#     Accuracy: 0.88475
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75141, Loss: 0.05023
#
# Episode: 3200/25000 to 3400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.2s (15.10/s)
#     Loss: 0.02519
#     Accuracy: 0.89384
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76422, Loss: 0.05439
#
# Episode: 3400/25000 to 3600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.31/s)
#     Loss: 0.02381
#     Accuracy: 0.90347
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74756, Loss: 0.05633
#
# Episode: 3600/25000 to 3800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.30/s)
#     Loss: 0.02292
#     Accuracy: 0.90794
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76619, Loss: 0.05102
#
# Episode: 3800/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.31/s)
#     Loss: 0.02110
#     Accuracy: 0.91863
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76772, Loss: 0.04764
#
# Episode: 4000/25000 to 4200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.8s (15.64/s)
#     Loss: 0.01874
#     Accuracy: 0.92897
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79369, Loss: 0.04474
#
# Episode: 4200/25000 to 4400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.4s (16.12/s)
#     Loss: 0.01825
#     Accuracy: 0.93050
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77563, Loss: 0.04997
#
# Episode: 4400/25000 to 4600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.32/s)
#     Loss: 0.01645
#     Accuracy: 0.93719
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79441, Loss: 0.04314
#
# Episode: 4600/25000 to 4800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.46/s)
#     Loss: 0.01790
#     Accuracy: 0.93059
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78853, Loss: 0.04622
#
# Episode: 4800/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.50/s)
#     Loss: 0.01559
#     Accuracy: 0.94028
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80484, Loss: 0.04341
#
# Episode: 5000/25000 to 5200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.52/s)
#     Loss: 0.01503
#     Accuracy: 0.94359
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80737, Loss: 0.04039
#
# Episode: 5200/25000 to 5400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.2s (15.17/s)
#     Loss: 0.01496
#     Accuracy: 0.94341
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80275, Loss: 0.04301
#
# Episode: 5400/25000 to 5600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.2s (15.14/s)
#     Loss: 0.01472
#     Accuracy: 0.94262
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81419, Loss: 0.04055
#
# Episode: 5600/25000 to 5800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.23/s)
#     Loss: 0.01454
#     Accuracy: 0.94628
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81169, Loss: 0.04603
#
# Episode: 5800/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.2s (15.11/s)
#     Loss: 0.01239
#     Accuracy: 0.95394
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82256, Loss: 0.04524
#
# Episode: 6000/25000 to 6200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.53/s)
#     Loss: 0.01271
#     Accuracy: 0.95150
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81031, Loss: 0.04486
#
# Episode: 6200/25000 to 6400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.54/s)
#     Loss: 0.01335
#     Accuracy: 0.94631
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81650, Loss: 0.04113
#
# Episode: 6400/25000 to 6600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.37/s)
#     Loss: 0.01248
#     Accuracy: 0.95316
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81031, Loss: 0.04310
#
# Episode: 6600/25000 to 6800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.27/s)
#     Loss: 0.01166
#     Accuracy: 0.95691
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79619, Loss: 0.04734
#
# Episode: 6800/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.60/s)
#     Loss: 0.01167
#     Accuracy: 0.95656
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80988, Loss: 0.04257
#
# Episode: 7000/25000 to 7200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.24/s)
#     Loss: 0.01108
#     Accuracy: 0.95956
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79669, Loss: 0.04414
#
# Episode: 7200/25000 to 7400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.4s (14.93/s)
#     Loss: 0.01160
#     Accuracy: 0.95628
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80722, Loss: 0.03942
#
# Episode: 7400/25000 to 7600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.53/s)
#     Loss: 0.01058
#     Accuracy: 0.95953
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82162, Loss: 0.04289
#
# Episode: 7600/25000 to 7800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.29/s)
#     Loss: 0.01016
#     Accuracy: 0.96425
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80259, Loss: 0.04790
#
# Episode: 7800/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.28/s)
#     Loss: 0.01102
#     Accuracy: 0.95763
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80056, Loss: 0.04594
#
# Episode: 8000/25000 to 8200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.40/s)
#     Loss: 0.01076
#     Accuracy: 0.95944
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79353, Loss: 0.04442
#
# Episode: 8200/25000 to 8400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.50/s)
#     Loss: 0.01063
#     Accuracy: 0.96166
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81106, Loss: 0.04274
#
# Episode: 8400/25000 to 8600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.43/s)
#     Loss: 0.00859
#     Accuracy: 0.96869
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82959, Loss: 0.03799
#
# Episode: 8600/25000 to 8800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.8s (15.67/s)
#     Loss: 0.00955
#     Accuracy: 0.96509
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79509, Loss: 0.04727
#
# Episode: 8800/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.24/s)
#     Loss: 0.01018
#     Accuracy: 0.96247
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80278, Loss: 0.04696
#
# Episode: 9000/25000 to 9200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.8s (15.57/s)
#     Loss: 0.01004
#     Accuracy: 0.96191
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81956, Loss: 0.04351
#
# Episode: 9200/25000 to 9400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.56/s)
#     Loss: 0.00929
#     Accuracy: 0.96513
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80088, Loss: 0.04833
#
# Episode: 9400/25000 to 9600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.8s (15.63/s)
#     Loss: 0.00965
#     Accuracy: 0.96350
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81369, Loss: 0.04469
#
# Episode: 9600/25000 to 9800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.3s (16.21/s)
#     Loss: 0.00957
#     Accuracy: 0.96534
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82950, Loss: 0.03873
#
# Episode: 9800/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.3s (16.30/s)
#     Loss: 0.00868
#     Accuracy: 0.96691
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80022, Loss: 0.04857
#
# Episode: 10000/25000 to 10200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.0s (16.68/s)
#     Loss: 0.00899
#     Accuracy: 0.96766
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81391, Loss: 0.04376
#
# Episode: 10200/25000 to 10400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.1s (16.59/s)
#     Loss: 0.00810
#     Accuracy: 0.97031
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82269, Loss: 0.03955
#
# Episode: 10400/25000 to 10600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.6s (15.81/s)
#     Loss: 0.00852
#     Accuracy: 0.96872
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80775, Loss: 0.04705
#
# Episode: 10600/25000 to 10800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.7s (15.75/s)
#     Loss: 0.00868
#     Accuracy: 0.96787
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81659, Loss: 0.04010
#
# Episode: 10800/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.25/s)
#     Loss: 0.00832
#     Accuracy: 0.96931
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82937, Loss: 0.04360
#
# Episode: 11000/25000 to 11200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.44/s)
#     Loss: 0.00860
#     Accuracy: 0.96728
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81159, Loss: 0.04772
#
# Episode: 11200/25000 to 11400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.48/s)
#     Loss: 0.00857
#     Accuracy: 0.96816
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79384, Loss: 0.04847
#
# Episode: 11400/25000 to 11600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.51/s)
#     Loss: 0.00820
#     Accuracy: 0.96891
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80350, Loss: 0.05217
#
# Episode: 11600/25000 to 11800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.37/s)
#     Loss: 0.00725
#     Accuracy: 0.97375
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81559, Loss: 0.04751
#
# Episode: 11800/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.40/s)
#     Loss: 0.00912
#     Accuracy: 0.96431
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81647, Loss: 0.04348
#
# Episode: 12000/25000 to 12200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.35/s)
#     Loss: 0.00793
#     Accuracy: 0.96928
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.83194, Loss: 0.04032
#
# Episode: 12200/25000 to 12400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.46/s)
#     Loss: 0.00753
#     Accuracy: 0.97134
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82641, Loss: 0.04084
#
# Episode: 12400/25000 to 12600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.2s (15.12/s)
#     Loss: 0.00755
#     Accuracy: 0.97409
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81966, Loss: 0.04266
#
# Episode: 12600/25000 to 12800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.4s (14.90/s)
#     Loss: 0.00886
#     Accuracy: 0.96622
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81322, Loss: 0.04500
#
# Episode: 12800/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.2s (15.13/s)
#     Loss: 0.00740
#     Accuracy: 0.97128
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81162, Loss: 0.05269
#
# Episode: 13000/25000 to 13200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.6s (14.74/s)
#     Loss: 0.00812
#     Accuracy: 0.96903
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81459, Loss: 0.04264
#
# Episode: 13200/25000 to 13400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.2s (15.18/s)
#     Loss: 0.00713
#     Accuracy: 0.97341
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81600, Loss: 0.04427
#
# Episode: 13400/25000 to 13600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.22/s)
#     Loss: 0.00704
#     Accuracy: 0.97481
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80900, Loss: 0.05505
#
# Episode: 13600/25000 to 13800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.38/s)
#     Loss: 0.00734
#     Accuracy: 0.97141
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81869, Loss: 0.04206
#
# Episode: 13800/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.52/s)
#     Loss: 0.00716
#     Accuracy: 0.97256
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.83444, Loss: 0.04178
#
# Episode: 14000/25000 to 14200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.8s (15.68/s)
#     Loss: 0.00741
#     Accuracy: 0.97219
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80666, Loss: 0.04732
#
# Episode: 14200/25000 to 14400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.53/s)
#     Loss: 0.00606
#     Accuracy: 0.97863
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82259, Loss: 0.04131
#
# Episode: 14400/25000 to 14600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.42/s)
#     Loss: 0.00756
#     Accuracy: 0.97209
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79556, Loss: 0.05698
#
# Episode: 14600/25000 to 14800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.8s (15.64/s)
#     Loss: 0.00753
#     Accuracy: 0.97197
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82403, Loss: 0.04412
#
# Episode: 14800/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.6s (15.82/s)
#     Loss: 0.00721
#     Accuracy: 0.97266
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81625, Loss: 0.04254
#
# Episode: 15000/25000 to 15200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.7s (15.78/s)
#     Loss: 0.00679
#     Accuracy: 0.97313
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80647, Loss: 0.04504
#
# Episode: 15200/25000 to 15400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.43/s)
#     Loss: 0.00745
#     Accuracy: 0.97213
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81269, Loss: 0.04312
#
# Episode: 15400/25000 to 15600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.37/s)
#     Loss: 0.00622
#     Accuracy: 0.97803
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.83531, Loss: 0.03944
#
# Episode: 15600/25000 to 15800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.8s (15.57/s)
#     Loss: 0.00639
#     Accuracy: 0.97731
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82778, Loss: 0.04080
#
# Episode: 15800/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.5s (14.85/s)
#     Loss: 0.00713
#     Accuracy: 0.97125
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82259, Loss: 0.04233
#
# Episode: 16000/25000 to 16200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.8s (15.63/s)
#     Loss: 0.00627
#     Accuracy: 0.97781
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81669, Loss: 0.04295
#
# Episode: 16200/25000 to 16400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.6s (15.87/s)
#     Loss: 0.00726
#     Accuracy: 0.97231
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81666, Loss: 0.04291
#
# Episode: 16400/25000 to 16600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.4s (16.11/s)
#     Loss: 0.00718
#     Accuracy: 0.97072
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81494, Loss: 0.04495
#
# Episode: 16600/25000 to 16800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.42/s)
#     Loss: 0.00655
#     Accuracy: 0.97497
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80237, Loss: 0.05570
#
# Episode: 16800/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.7s (15.78/s)
#     Loss: 0.00610
#     Accuracy: 0.97691
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78628, Loss: 0.04776
#
# Episode: 17000/25000 to 17200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.8s (15.57/s)
#     Loss: 0.00622
#     Accuracy: 0.97666
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82237, Loss: 0.04745
#
# Episode: 17200/25000 to 17400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.35/s)
#     Loss: 0.00647
#     Accuracy: 0.97478
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.83053, Loss: 0.03923
#
# Episode: 17400/25000 to 17600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.49/s)
#     Loss: 0.00610
#     Accuracy: 0.97759
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81028, Loss: 0.04539
#
# Episode: 17600/25000 to 17800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.55/s)
#     Loss: 0.00625
#     Accuracy: 0.97644
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81919, Loss: 0.04347
#
# Episode: 17800/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.7s (15.73/s)
#     Loss: 0.00520
#     Accuracy: 0.98066
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82853, Loss: 0.03904
#
# Episode: 18000/25000 to 18200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.51/s)
#     Loss: 0.00587
#     Accuracy: 0.97838
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80850, Loss: 0.04703
#
# Episode: 18200/25000 to 18400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.6s (15.90/s)
#     Loss: 0.00594
#     Accuracy: 0.97628
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82203, Loss: 0.04535
#
# Episode: 18400/25000 to 18600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.5s (15.98/s)
#     Loss: 0.00606
#     Accuracy: 0.97738
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81766, Loss: 0.04061
#
# Episode: 18600/25000 to 18800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.6s (15.92/s)
#     Loss: 0.00596
#     Accuracy: 0.97666
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80875, Loss: 0.04275
#
# Episode: 18800/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.55/s)
#     Loss: 0.00698
#     Accuracy: 0.97350
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79263, Loss: 0.04358
#
# Episode: 19000/25000 to 19200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.24/s)
#     Loss: 0.00584
#     Accuracy: 0.97950
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81237, Loss: 0.04477
#
# Episode: 19200/25000 to 19400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.32/s)
#     Loss: 0.00647
#     Accuracy: 0.97400
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78947, Loss: 0.05290
#
# Episode: 19400/25000 to 19600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.30/s)
#     Loss: 0.00600
#     Accuracy: 0.97566
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80709, Loss: 0.04500
#
# Episode: 19600/25000 to 19800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.22/s)
#     Loss: 0.00593
#     Accuracy: 0.97569
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82134, Loss: 0.04108
#
# Episode: 19800/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.3s (15.04/s)
#     Loss: 0.00549
#     Accuracy: 0.97975
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82394, Loss: 0.04258
#
# Episode: 20000/25000 to 20200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.32/s)
#     Loss: 0.00582
#     Accuracy: 0.97709
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79103, Loss: 0.05456
#
# Episode: 20200/25000 to 20400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.1s (15.21/s)
#     Loss: 0.00595
#     Accuracy: 0.97488
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80506, Loss: 0.04622
#
# Episode: 20400/25000 to 20600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.52/s)
#     Loss: 0.00540
#     Accuracy: 0.97931
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81203, Loss: 0.04535
#
# Episode: 20600/25000 to 20800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.37/s)
#     Loss: 0.00644
#     Accuracy: 0.97297
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79794, Loss: 0.05099
#
# Episode: 20800/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.2s (15.20/s)
#     Loss: 0.00576
#     Accuracy: 0.97678
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78559, Loss: 0.05980
#
# Episode: 21000/25000 to 21200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.2s (15.16/s)
#     Loss: 0.00523
#     Accuracy: 0.98013
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79537, Loss: 0.05408
#
# Episode: 21200/25000 to 21400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.6s (14.67/s)
#     Loss: 0.00522
#     Accuracy: 0.97903
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81584, Loss: 0.04296
#
# Episode: 21400/25000 to 21600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.2s (15.11/s)
#     Loss: 0.00505
#     Accuracy: 0.97963
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79725, Loss: 0.04737
#
# Episode: 21600/25000 to 21800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.3s (15.02/s)
#     Loss: 0.00532
#     Accuracy: 0.98025
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78581, Loss: 0.05206
#
# Episode: 21800/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.46/s)
#     Loss: 0.00497
#     Accuracy: 0.98103
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79684, Loss: 0.05132
#
# Episode: 22000/25000 to 22200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 12.9s (15.53/s)
#     Loss: 0.00590
#     Accuracy: 0.97497
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79878, Loss: 0.05084
#
# Episode: 22200/25000 to 22400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.0s (15.44/s)
#     Loss: 0.00467
#     Accuracy: 0.98222
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80097, Loss: 0.05057
#
# Episode: 22400/25000 to 22600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.3s (15.06/s)
#     Loss: 0.00514
#     Accuracy: 0.97953
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80559, Loss: 0.04632
#
# Episode: 22600/25000 to 22800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.7s (14.65/s)
#     Loss: 0.00584
#     Accuracy: 0.97491
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81681, Loss: 0.04189
#
# Episode: 22800/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.9s (14.42/s)
#     Loss: 0.00495
#     Accuracy: 0.98066
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80119, Loss: 0.04704
#
# Episode: 23000/25000 to 23200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.5s (14.84/s)
#     Loss: 0.00537
#     Accuracy: 0.97872
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79903, Loss: 0.04782
#
# Episode: 23200/25000 to 23400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.8s (14.53/s)
#     Loss: 0.00597
#     Accuracy: 0.97494
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80250, Loss: 0.04404
#
# Episode: 23400/25000 to 23600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.6s (14.66/s)
#     Loss: 0.00564
#     Accuracy: 0.97703
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80216, Loss: 0.05063
#
# Episode: 23600/25000 to 23800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.3s (15.00/s)
#     Loss: 0.00466
#     Accuracy: 0.98241
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79694, Loss: 0.05197
#
# Episode: 23800/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.4s (14.96/s)
#     Loss: 0.00622
#     Accuracy: 0.97409
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81266, Loss: 0.04380
#
# Episode: 24000/25000 to 24200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.5s (14.78/s)
#     Loss: 0.00547
#     Accuracy: 0.97628
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80766, Loss: 0.04426
#
# Episode: 24200/25000 to 24400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.4s (13.87/s)
#     Loss: 0.00497
#     Accuracy: 0.98047
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78694, Loss: 0.05536
#
# Episode: 24400/25000 to 24600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 13.9s (14.36/s)
#     Loss: 0.00445
#     Accuracy: 0.98334
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82028, Loss: 0.04449
#
# Episode: 24600/25000 to 24800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.1s (14.16/s)
#     Loss: 0.00460
#     Accuracy: 0.98313
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82366, Loss: 0.04371
#
# Episode: 24800/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 14.0s (14.26/s)
#     Loss: 0.00468
#     Accuracy: 0.98116
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79284, Loss: 0.04950

# %% [markdown]
# Success of the training is examined by analyzing the training curve.

# %%
plot_traincurve('training/run_0', ['train_accuracy', 'eval_accuracy'], 'Accuracy')

# %% [markdown]
# ## Perform a tuning run

# %% [markdown]
# The most decisive hyperparameters present in the model are determined by a tuning process, which runs the model training several times and tries to boost the models performance by minimizing the evaluation-loss with adaptations to the hyperparameters.

# %%
tuning = optuna.create_study(direction="minimize", 
                             sampler = optuna.samplers.TPESampler(),
                             pruner = optuna.pruners.MedianPruner(n_startup_trials=5))

tuning.optimize(run_tuning, n_trials=25)

pruned_trials = tuning.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = tuning.get_trials(deepcopy=False, states=[TrialState.COMPLETE])
importances = optuna.importance.get_param_importances(tuning)

print('\n')
print('#######################################################################')
print('########################### FINISHED TUNING ###########################')
print('#######################################################################')
print('\n \n')

print('Tuning statistics: ')
print('  Number of trials: ', len(tuning.trials))
print('  Number of pruned trials: ', len(pruned_trials))
print('  Number of complete trials: ', len(complete_trials), '\n')

print('Best trial:')
trial = tuning.best_trial

print(f'  Run {str(trial.number)} with Loss {min(trial.intermediate_values.values())} at Episode {min(trial.intermediate_values, key=trial.intermediate_values.get)}')

print('  Params: ')
for key, value in trial.params.items():
  print('    {}: {}'.format(key, value))
# Out:
# [I 2022-06-03 08:23:19,129] A new study created in memory with name: no-name-92e94018-7bd6-4ce9-b67d-9a2502e29ed9
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_0
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:36.8 (5.16/s)
#     Loss: 0.15542
#     Accuracy: 0.10001
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.4 (5.13/s)
#     Loss: 0.09000
#     Accuracy: 0.10011
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10025, Loss: 0.09000
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.7 (5.12/s)
#     Loss: 0.09000
#     Accuracy: 0.09996
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10022, Loss: 0.09000
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.4 (5.13/s)
#     Loss: 0.09000
#     Accuracy: 0.10015
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.7 (5.12/s)
#     Loss: 0.09000
#     Accuracy: 0.10000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.6 (5.12/s)
#     Loss: 0.09000
#     Accuracy: 0.09996
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.5 (5.13/s)
#     Loss: 0.09000
#     Accuracy: 0.09998
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10034, Loss: 0.09000
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.6 (5.12/s)
#     Loss: 0.09000
#     Accuracy: 0.10001
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10003, Loss: 0.09000
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.4 (5.13/s)
#     Loss: 0.09000
#     Accuracy: 0.10000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10003, Loss: 0.09000
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.5 (5.13/s)
#     Loss: 0.09000
#     Accuracy: 0.10014
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10041, Loss: 0.09000
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.4 (5.13/s)
#     Loss: 0.09000
#     Accuracy: 0.10004
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10006, Loss: 0.09000
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.4 (5.13/s)
#     Loss: 0.09000
#     Accuracy: 0.10003
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10025, Loss: 0.08999
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.5 (5.13/s)
#     Loss: 0.08998
#     Accuracy: 0.10010
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10012, Loss: 0.08977
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.7 (5.12/s)
#     Loss: 0.08789
#     Accuracy: 0.10861
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.16575, Loss: 0.08677
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.6 (5.12/s)
#     Loss: 0.08655
#     Accuracy: 0.15603
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.18525, Loss: 0.08489
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.8 (5.11/s)
#     Loss: 0.08557
#     Accuracy: 0.16963
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19222, Loss: 0.08469
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.6 (5.13/s)
#     Loss: 0.08555
#     Accuracy: 0.17957
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20328, Loss: 0.08430
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.4 (5.13/s)
#     Loss: 0.08543
#     Accuracy: 0.18257
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19913, Loss: 0.08420
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.2 (5.14/s)
#     Loss: 0.08476
#     Accuracy: 0.19286
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20319, Loss: 0.08424
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.1 (5.15/s)
#     Loss: 0.08513
#     Accuracy: 0.19119
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20047, Loss: 0.08429
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.4 (5.13/s)
#     Loss: 0.08508
#     Accuracy: 0.19142
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20572, Loss: 0.08367
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.7 (5.12/s)
#     Loss: 0.08488
#     Accuracy: 0.19554
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20356, Loss: 0.08411
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.5 (5.13/s)
#     Loss: 0.08452
#     Accuracy: 0.19641
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20584, Loss: 0.08405
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.7 (5.12/s)
#     Loss: 0.08474
#     Accuracy: 0.19599
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21025, Loss: 0.08405
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.3 (5.14/s)
#     Loss: 0.08461
#     Accuracy: 0.19651
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20806, Loss: 0.08387
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.5 (5.13/s)
#     Loss: 0.08513
#     Accuracy: 0.19163
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20997, Loss: 0.08376
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.7 (5.12/s)
#     Loss: 0.08475
#     Accuracy: 0.19365
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20719, Loss: 0.08353
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.6 (5.13/s)
#     Loss: 0.08473
#     Accuracy: 0.19526
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20791, Loss: 0.08402
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.5 (5.13/s)
#     Loss: 0.08479
#     Accuracy: 0.19534
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20688, Loss: 0.08433
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.7 (5.12/s)
#     Loss: 0.08470
#     Accuracy: 0.19576
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20584, Loss: 0.08403
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.4 (5.14/s)
#     Loss: 0.08482
#     Accuracy: 0.19559
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20638, Loss: 0.08410
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.6 (5.12/s)
#     Loss: 0.08476
#     Accuracy: 0.19644
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20381, Loss: 0.08396
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.8 (5.11/s)
#     Loss: 0.08447
#     Accuracy: 0.19889
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20619, Loss: 0.08371
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.5 (5.13/s)
#     Loss: 0.08475
#     Accuracy: 0.19536
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20219, Loss: 0.08438
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.6 (5.12/s)
#     Loss: 0.08433
#     Accuracy: 0.20040
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21113, Loss: 0.08333
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.4 (5.13/s)
#     Loss: 0.08479
#     Accuracy: 0.19629
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21275, Loss: 0.08304
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.3 (5.14/s)
#     Loss: 0.08409
#     Accuracy: 0.20456
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21028, Loss: 0.08349
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.7 (5.12/s)
#     Loss: 0.08471
#     Accuracy: 0.19870
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20506, Loss: 0.08384
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.6 (5.12/s)
#     Loss: 0.08456
#     Accuracy: 0.19931
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20775, Loss: 0.08374
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.6 (5.12/s)
#     Loss: 0.08481
#     Accuracy: 0.19829
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20638, Loss: 0.08411
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.7 (5.12/s)
#     Loss: 0.08423
#     Accuracy: 0.20414
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20819, Loss: 0.08334
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.8 (5.11/s)
#     Loss: 0.08449
#     Accuracy: 0.20103
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20981, Loss: 0.08371
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.6 (5.12/s)
#     Loss: 0.08487
#     Accuracy: 0.20075
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21019, Loss: 0.08406
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.8 (5.11/s)
#     Loss: 0.08454
#     Accuracy: 0.20509
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21331, Loss: 0.08332
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.9 (5.11/s)
#     Loss: 0.08469
#     Accuracy: 0.20576
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21128, Loss: 0.08379
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:38.0 (5.10/s)
#     Loss: 0.08441
#     Accuracy: 0.21185
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21719, Loss: 0.08373
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.8 (5.11/s)
#     Loss: 0.08394
#     Accuracy: 0.22359
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21653, Loss: 0.08401
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.8 (5.11/s)
#     Loss: 0.08410
#     Accuracy: 0.22958
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21616, Loss: 0.08396
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:38.0 (5.10/s)
#     Loss: 0.08342
#     Accuracy: 0.24024
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21444, Loss: 0.08466
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:37.8 (5.11/s)
#     Loss: 0.08286
#     Accuracy: 0.25229
# [I 2022-06-03 10:03:25,673] Trial 0 finished with value: 0.08303643759340047 and parameters: {'num_fc_layers': 1, 'num_units_fc_layer0': 64, 'num_lstm_layer_encoder': 3, 'num_units_lstm_encoder': 16, 'num_lstm_layer_relationnet': 3, 'num_units_lstm_relationnet': 256, 'learning_rate': 1.034389196248901e-05, 'learning_rate_schedule_rate': 6000}. Best is trial 0 with value: 0.08303643759340047.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.22200, Loss: 0.08349
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_1
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.1s (12.46/s)
#     Loss: 0.08966
#     Accuracy: 0.17958
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21247, Loss: 0.08387
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 41.1s (12.17/s)
#     Loss: 0.08193
#     Accuracy: 0.31966
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31262, Loss: 0.08390
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.7s (12.59/s)
#     Loss: 0.06558
#     Accuracy: 0.57000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.45466, Loss: 0.08090
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.7s (12.59/s)
#     Loss: 0.05566
#     Accuracy: 0.67376
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.47391, Loss: 0.09208
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.4s (12.69/s)
#     Loss: 0.04516
#     Accuracy: 0.76000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.61041, Loss: 0.07198
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.5s (12.64/s)
#     Loss: 0.03383
#     Accuracy: 0.84231
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65719, Loss: 0.06708
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.4s (12.68/s)
#     Loss: 0.02763
#     Accuracy: 0.87914
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68884, Loss: 0.05576
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.9s (12.85/s)
#     Loss: 0.02382
#     Accuracy: 0.90030
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69753, Loss: 0.08040
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.0s (13.16/s)
#     Loss: 0.01953
#     Accuracy: 0.92117
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73188, Loss: 0.05956
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.6s (12.95/s)
#     Loss: 0.01665
#     Accuracy: 0.93648
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75056, Loss: 0.05480
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.6s (12.95/s)
#     Loss: 0.01401
#     Accuracy: 0.94742
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76575, Loss: 0.04779
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.1s (12.80/s)
#     Loss: 0.01267
#     Accuracy: 0.95174
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76459, Loss: 0.05315
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.4s (12.68/s)
#     Loss: 0.01107
#     Accuracy: 0.95778
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77000, Loss: 0.04958
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.4s (12.68/s)
#     Loss: 0.00949
#     Accuracy: 0.96461
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76847, Loss: 0.05644
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.1s (12.80/s)
#     Loss: 0.00956
#     Accuracy: 0.96381
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76809, Loss: 0.05601
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.1s (13.12/s)
#     Loss: 0.00960
#     Accuracy: 0.96177
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78094, Loss: 0.04937
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.0s (12.81/s)
#     Loss: 0.00783
#     Accuracy: 0.97127
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77500, Loss: 0.04986
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.7s (12.59/s)
#     Loss: 0.00760
#     Accuracy: 0.97195
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79694, Loss: 0.04398
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.2s (12.45/s)
#     Loss: 0.00751
#     Accuracy: 0.97086
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78597, Loss: 0.04628
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.6s (12.63/s)
#     Loss: 0.00695
#     Accuracy: 0.97460
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77072, Loss: 0.04834
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.3s (12.73/s)
#     Loss: 0.00717
#     Accuracy: 0.97229
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77694, Loss: 0.04830
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.0s (12.81/s)
#     Loss: 0.00604
#     Accuracy: 0.97811
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77684, Loss: 0.05292
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.1s (12.79/s)
#     Loss: 0.00630
#     Accuracy: 0.97584
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78478, Loss: 0.04682
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.0s (12.50/s)
#     Loss: 0.00561
#     Accuracy: 0.97885
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76987, Loss: 0.05165
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.7s (12.59/s)
#     Loss: 0.00636
#     Accuracy: 0.97432
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76506, Loss: 0.05136
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.5s (12.97/s)
#     Loss: 0.00505
#     Accuracy: 0.98125
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79578, Loss: 0.04624
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.5s (13.00/s)
#     Loss: 0.00568
#     Accuracy: 0.97756
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75091, Loss: 0.06379
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.5s (12.98/s)
#     Loss: 0.00471
#     Accuracy: 0.98237
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79253, Loss: 0.04648
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.8s (12.89/s)
#     Loss: 0.00538
#     Accuracy: 0.97822
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77994, Loss: 0.04961
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.3s (13.06/s)
#     Loss: 0.00463
#     Accuracy: 0.98159
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77528, Loss: 0.05052
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.4s (13.03/s)
#     Loss: 0.00487
#     Accuracy: 0.98029
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78197, Loss: 0.05278
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.2s (13.08/s)
#     Loss: 0.00463
#     Accuracy: 0.98242
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76872, Loss: 0.05226
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.2s (13.09/s)
#     Loss: 0.00439
#     Accuracy: 0.98170
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76831, Loss: 0.04907
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.3s (13.05/s)
#     Loss: 0.00454
#     Accuracy: 0.98276
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76850, Loss: 0.04911
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.7s (13.25/s)
#     Loss: 0.00454
#     Accuracy: 0.98099
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77572, Loss: 0.04972
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.0s (13.17/s)
#     Loss: 0.00468
#     Accuracy: 0.98052
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78825, Loss: 0.04875
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.7s (12.91/s)
#     Loss: 0.00479
#     Accuracy: 0.97942
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79119, Loss: 0.05142
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.5s (12.97/s)
#     Loss: 0.00470
#     Accuracy: 0.98062
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77150, Loss: 0.05283
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.1s (12.78/s)
#     Loss: 0.00408
#     Accuracy: 0.98247
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76550, Loss: 0.05112
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.7s (12.92/s)
#     Loss: 0.00410
#     Accuracy: 0.98206
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78934, Loss: 0.04982
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.0s (12.83/s)
#     Loss: 0.00414
#     Accuracy: 0.98220
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78819, Loss: 0.04402
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 37.6s (13.31/s)
#     Loss: 0.00447
#     Accuracy: 0.98104
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77750, Loss: 0.05137
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.1s (12.78/s)
#     Loss: 0.00421
#     Accuracy: 0.98151
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77344, Loss: 0.05429
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.3s (12.71/s)
#     Loss: 0.00386
#     Accuracy: 0.98325
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76156, Loss: 0.05341
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.0s (12.81/s)
#     Loss: 0.00404
#     Accuracy: 0.98189
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76000, Loss: 0.05321
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.5s (12.67/s)
#     Loss: 0.00389
#     Accuracy: 0.98305
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76928, Loss: 0.05729
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.4s (12.70/s)
#     Loss: 0.00416
#     Accuracy: 0.98230
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74003, Loss: 0.05445
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.7s (12.59/s)
#     Loss: 0.00394
#     Accuracy: 0.98174
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76172, Loss: 0.05289
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.2s (12.75/s)
#     Loss: 0.00351
#     Accuracy: 0.98427
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75644, Loss: 0.05543
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.0s (13.15/s)
#     Loss: 0.00314
#     Accuracy: 0.98695
# [I 2022-06-03 10:45:53,830] Trial 1 finished with value: 0.04397585624828935 and parameters: {'num_fc_layers': 2, 'num_units_fc_layer0': 128, 'num_units_fc_layer1': 256, 'num_lstm_layer_encoder': 1, 'num_units_lstm_encoder': 256, 'num_lstm_layer_relationnet': 3, 'num_units_lstm_relationnet': 16, 'learning_rate': 0.000982063519849094, 'learning_rate_schedule_rate': 7500}. Best is trial 1 with value: 0.04397585624828935.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74344, Loss: 0.05808
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_2
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.9s (16.20/s)
#     Loss: 0.18239
#     Accuracy: 0.10056
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10391, Loss: 0.12016
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.9s (16.18/s)
#     Loss: 0.09849
#     Accuracy: 0.10339
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10306, Loss: 0.09145
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.7s (15.77/s)
#     Loss: 0.09019
#     Accuracy: 0.10430
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10441, Loss: 0.08943
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 32.1s (15.60/s)
#     Loss: 0.08876
#     Accuracy: 0.10675
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10906, Loss: 0.08752
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.1s (16.06/s)
#     Loss: 0.08810
#     Accuracy: 0.10665
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10694, Loss: 0.08698
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.1s (16.09/s)
#     Loss: 0.08753
#     Accuracy: 0.10434
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10387, Loss: 0.08655
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.5s (15.86/s)
#     Loss: 0.08712
#     Accuracy: 0.10370
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10278, Loss: 0.08621
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.9s (16.20/s)
#     Loss: 0.08694
#     Accuracy: 0.10374
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10291, Loss: 0.08634
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.9s (16.19/s)
#     Loss: 0.08672
#     Accuracy: 0.10180
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10341, Loss: 0.08619
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.1s (16.08/s)
#     Loss: 0.08697
#     Accuracy: 0.10320
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10088, Loss: 0.08650
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.7s (15.76/s)
#     Loss: 0.08683
#     Accuracy: 0.10364
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10375, Loss: 0.08623
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.6s (16.33/s)
#     Loss: 0.08655
#     Accuracy: 0.10226
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10297, Loss: 0.08666
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.8s (16.22/s)
#     Loss: 0.08655
#     Accuracy: 0.10206
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10469, Loss: 0.08658
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.9s (16.17/s)
#     Loss: 0.08668
#     Accuracy: 0.10194
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10478, Loss: 0.08678
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.0s (16.11/s)
#     Loss: 0.08657
#     Accuracy: 0.10395
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10794, Loss: 0.08688
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.7s (15.77/s)
#     Loss: 0.08667
#     Accuracy: 0.11434
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.13737, Loss: 0.08625
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.9s (16.16/s)
#     Loss: 0.08683
#     Accuracy: 0.14210
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.17087, Loss: 0.08663
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.8s (15.70/s)
#     Loss: 0.08648
#     Accuracy: 0.16020
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.17925, Loss: 0.08644
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.8s (16.26/s)
#     Loss: 0.08672
#     Accuracy: 0.17153
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19587, Loss: 0.08601
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.0s (16.13/s)
#     Loss: 0.08635
#     Accuracy: 0.17948
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19850, Loss: 0.08628
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.0s (16.11/s)
#     Loss: 0.08655
#     Accuracy: 0.17240
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19559, Loss: 0.08635
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.8s (16.24/s)
#     Loss: 0.08630
#     Accuracy: 0.17604
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20419, Loss: 0.08535
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.0s (16.65/s)
#     Loss: 0.08569
#     Accuracy: 0.19178
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20169, Loss: 0.08545
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 29.7s (16.84/s)
#     Loss: 0.08551
#     Accuracy: 0.19162
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21247, Loss: 0.08480
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.0s (16.67/s)
#     Loss: 0.08529
#     Accuracy: 0.19461
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20938, Loss: 0.08446
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.2s (16.56/s)
#     Loss: 0.08489
#     Accuracy: 0.20035
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20691, Loss: 0.08472
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.8s (16.24/s)
#     Loss: 0.08498
#     Accuracy: 0.19872
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21366, Loss: 0.08450
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.5s (15.90/s)
#     Loss: 0.08478
#     Accuracy: 0.20612
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21078, Loss: 0.08443
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.4s (15.94/s)
#     Loss: 0.08477
#     Accuracy: 0.20785
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21769, Loss: 0.08440
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.0s (16.14/s)
#     Loss: 0.08479
#     Accuracy: 0.20576
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21972, Loss: 0.08395
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.7s (16.28/s)
#     Loss: 0.08519
#     Accuracy: 0.20225
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.22106, Loss: 0.08406
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.4s (16.44/s)
#     Loss: 0.08470
#     Accuracy: 0.21099
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21881, Loss: 0.08371
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 29.7s (16.82/s)
#     Loss: 0.08426
#     Accuracy: 0.22110
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.22694, Loss: 0.08396
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.8s (16.21/s)
#     Loss: 0.08442
#     Accuracy: 0.22271
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.23009, Loss: 0.08425
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.0s (16.12/s)
#     Loss: 0.08361
#     Accuracy: 0.24302
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.23294, Loss: 0.08387
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.0s (16.15/s)
#     Loss: 0.08278
#     Accuracy: 0.26219
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.24906, Loss: 0.08336
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.3s (15.97/s)
#     Loss: 0.08194
#     Accuracy: 0.27883
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.24238, Loss: 0.08324
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 32.4s (15.42/s)
#     Loss: 0.08136
#     Accuracy: 0.28910
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.24928, Loss: 0.08327
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.5s (15.90/s)
#     Loss: 0.08048
#     Accuracy: 0.30546
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.26044, Loss: 0.08334
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.5s (15.88/s)
#     Loss: 0.07968
#     Accuracy: 0.31585
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.27247, Loss: 0.08279
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 32.7s (15.28/s)
#     Loss: 0.07896
#     Accuracy: 0.32925
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.26978, Loss: 0.08283
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 32.7s (15.30/s)
#     Loss: 0.07862
#     Accuracy: 0.33394
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.27587, Loss: 0.08301
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.6s (15.85/s)
#     Loss: 0.07851
#     Accuracy: 0.33342
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.27725, Loss: 0.08270
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 32.5s (15.40/s)
#     Loss: 0.07756
#     Accuracy: 0.34617
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.27763, Loss: 0.08241
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.3s (15.97/s)
#     Loss: 0.07711
#     Accuracy: 0.35375
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.28878, Loss: 0.08230
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.7s (16.28/s)
#     Loss: 0.07665
#     Accuracy: 0.36199
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.27987, Loss: 0.08263
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.6s (16.31/s)
#     Loss: 0.07690
#     Accuracy: 0.36154
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.28397, Loss: 0.08318
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.0s (16.66/s)
#     Loss: 0.07644
#     Accuracy: 0.36826
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.29447, Loss: 0.08269
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 29.7s (16.85/s)
#     Loss: 0.07633
#     Accuracy: 0.36797
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.30550, Loss: 0.08223
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.2s (16.57/s)
#     Loss: 0.07615
#     Accuracy: 0.38184
# [I 2022-06-03 11:19:41,370] Trial 2 finished with value: 0.08223098166286945 and parameters: {'num_fc_layers': 1, 'num_units_fc_layer0': 128, 'num_lstm_layer_encoder': 1, 'num_units_lstm_encoder': 64, 'num_lstm_layer_relationnet': 1, 'num_units_lstm_relationnet': 16, 'learning_rate': 2.3767370801930045e-05, 'learning_rate_schedule_rate': 6000}. Best is trial 1 with value: 0.04397585624828935.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.29750, Loss: 0.08257
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_3
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.6s (10.96/s)
#     Loss: 0.10841
#     Accuracy: 0.10084
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10131, Loss: 0.08998
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 44.6s (11.20/s)
#     Loss: 0.08732
#     Accuracy: 0.12164
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19444, Loss: 0.08654
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.4s (11.52/s)
#     Loss: 0.08635
#     Accuracy: 0.18509
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.22006, Loss: 0.08367
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 44.1s (11.34/s)
#     Loss: 0.08504
#     Accuracy: 0.20041
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21866, Loss: 0.08455
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.8s (11.42/s)
#     Loss: 0.08156
#     Accuracy: 0.31125
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.32319, Loss: 0.08381
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 44.5s (11.23/s)
#     Loss: 0.06557
#     Accuracy: 0.55452
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.41513, Loss: 0.08784
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.0s (11.11/s)
#     Loss: 0.05798
#     Accuracy: 0.63625
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.44991, Loss: 0.08090
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.2s (11.06/s)
#     Loss: 0.05271
#     Accuracy: 0.68464
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.50800, Loss: 0.07177
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.2s (11.07/s)
#     Loss: 0.04718
#     Accuracy: 0.73773
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.54228, Loss: 0.07764
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 46.2s (10.83/s)
#     Loss: 0.04251
#     Accuracy: 0.77314
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.58253, Loss: 0.07618
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.1s (11.09/s)
#     Loss: 0.03876
#     Accuracy: 0.79991
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60359, Loss: 0.06751
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 44.5s (11.22/s)
#     Loss: 0.03576
#     Accuracy: 0.81999
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65206, Loss: 0.05893
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.2s (11.07/s)
#     Loss: 0.03307
#     Accuracy: 0.84206
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65544, Loss: 0.05826
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 43.6s (11.47/s)
#     Loss: 0.03097
#     Accuracy: 0.85257
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68675, Loss: 0.06044
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 44.4s (11.27/s)
#     Loss: 0.02772
#     Accuracy: 0.87361
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71400, Loss: 0.05481
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 45.0s (11.10/s)
#     Loss: 0.02555
#     Accuracy: 0.88884
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73906, Loss: 0.05985
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 44.3s (11.30/s)
#     Loss: 0.02437
# ...
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:03.6 (7.86/s)
#     Loss: 0.08373
#     Accuracy: 0.26119
# [I 2022-06-03 18:40:44,247] Trial 22 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.26663, Loss: 0.08437
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_23
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 41.2s (12.13/s)
#     Loss: 0.08388
#     Accuracy: 0.29346
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.41044, Loss: 0.08060
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.7s (12.28/s)
#     Loss: 0.06080
#     Accuracy: 0.62260
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.49141, Loss: 0.08471
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.4s (12.39/s)
#     Loss: 0.04454
#     Accuracy: 0.77215
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66422, Loss: 0.06018
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.6s (12.32/s)
#     Loss: 0.03174
#     Accuracy: 0.85824
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75266, Loss: 0.05146
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.1s (12.48/s)
#     Loss: 0.02373
#     Accuracy: 0.90141
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73762, Loss: 0.05684
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 41.0s (12.20/s)
#     Loss: 0.02054
#     Accuracy: 0.91539
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76744, Loss: 0.06580
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.8s (12.24/s)
#     Loss: 0.01782
#     Accuracy: 0.92812
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77784, Loss: 0.04461
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.2s (12.45/s)
#     Loss: 0.01627
#     Accuracy: 0.93485
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78806, Loss: 0.04562
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.8s (12.57/s)
#     Loss: 0.01488
#     Accuracy: 0.93995
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80153, Loss: 0.04339
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 41.0s (12.18/s)
#     Loss: 0.01284
#     Accuracy: 0.95079
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78450, Loss: 0.04385
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.3s (12.40/s)
#     Loss: 0.01278
#     Accuracy: 0.95024
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79906, Loss: 0.04723
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.5s (12.36/s)
#     Loss: 0.01125
#     Accuracy: 0.95767
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78938, Loss: 0.04669
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.7s (12.28/s)
#     Loss: 0.01075
#     Accuracy: 0.95863
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77919, Loss: 0.05081
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.7s (12.28/s)
#     Loss: 0.01002
#     Accuracy: 0.96302
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79359, Loss: 0.04827
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.6s (12.32/s)
#     Loss: 0.01083
#     Accuracy: 0.95860
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79584, Loss: 0.05090
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.7s (12.28/s)
#     Loss: 0.01003
#     Accuracy: 0.96240
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79044, Loss: 0.04818
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.6s (12.33/s)
#     Loss: 0.00920
#     Accuracy: 0.96546
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78700, Loss: 0.05228
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 41.0s (12.18/s)
#     Loss: 0.00895
#     Accuracy: 0.96768
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79862, Loss: 0.04436
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 41.3s (12.12/s)
#     Loss: 0.00878
#     Accuracy: 0.96728
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78528, Loss: 0.04477
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.6s (12.32/s)
#     Loss: 0.00857
#     Accuracy: 0.96813
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80878, Loss: 0.04783
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.3s (12.39/s)
#     Loss: 0.00831
#     Accuracy: 0.96909
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80531, Loss: 0.04684
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.3s (12.40/s)
#     Loss: 0.00835
#     Accuracy: 0.96887
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78528, Loss: 0.05233
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 41.0s (12.20/s)
#     Loss: 0.00773
#     Accuracy: 0.97252
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82597, Loss: 0.04116
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.6s (12.32/s)
#     Loss: 0.00752
#     Accuracy: 0.97172
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81053, Loss: 0.04586
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.6s (12.31/s)
#     Loss: 0.00770
#     Accuracy: 0.97075
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78059, Loss: 0.05256
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.6s (12.32/s)
#     Loss: 0.00754
#     Accuracy: 0.97195
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79378, Loss: 0.04291
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.9s (12.53/s)
#     Loss: 0.00688
#     Accuracy: 0.97497
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78909, Loss: 0.04411
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.0s (12.51/s)
#     Loss: 0.00656
#     Accuracy: 0.97569
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78950, Loss: 0.04694
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.8s (12.56/s)
#     Loss: 0.00645
#     Accuracy: 0.97607
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79169, Loss: 0.05083
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.2s (12.42/s)
#     Loss: 0.00684
#     Accuracy: 0.97376
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79756, Loss: 0.04360
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.2s (12.43/s)
#     Loss: 0.00674
#     Accuracy: 0.97424
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78341, Loss: 0.05297
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.6s (12.32/s)
#     Loss: 0.00597
#     Accuracy: 0.97734
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79216, Loss: 0.04808
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.3s (12.41/s)
#     Loss: 0.00666
#     Accuracy: 0.97501
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78469, Loss: 0.04462
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.9s (12.22/s)
#     Loss: 0.00662
#     Accuracy: 0.97355
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78484, Loss: 0.04654
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.6s (12.32/s)
#     Loss: 0.00604
#     Accuracy: 0.97717
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78391, Loss: 0.05107
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 41.0s (12.20/s)
#     Loss: 0.00611
#     Accuracy: 0.97617
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76772, Loss: 0.05219
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.7s (12.28/s)
#     Loss: 0.00560
#     Accuracy: 0.97865
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78409, Loss: 0.04575
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.5s (12.34/s)
#     Loss: 0.00575
#     Accuracy: 0.97825
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78412, Loss: 0.05556
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.8s (12.26/s)
#     Loss: 0.00568
#     Accuracy: 0.97765
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77969, Loss: 0.04855
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 41.1s (12.18/s)
#     Loss: 0.00582
#     Accuracy: 0.97776
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78950, Loss: 0.04977
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 41.1s (12.16/s)
#     Loss: 0.00514
#     Accuracy: 0.98022
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76403, Loss: 0.05220
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 41.0s (12.20/s)
#     Loss: 0.00576
#     Accuracy: 0.97655
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77525, Loss: 0.04728
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 41.1s (12.16/s)
#     Loss: 0.00566
#     Accuracy: 0.97742
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78716, Loss: 0.04916
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 40.4s (12.37/s)
#     Loss: 0.00495
#     Accuracy: 0.98057
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78597, Loss: 0.05175
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.5s (12.65/s)
#     Loss: 0.00538
#     Accuracy: 0.97805
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76300, Loss: 0.05486
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.6s (12.61/s)
#     Loss: 0.00531
#     Accuracy: 0.97849
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77106, Loss: 0.04946
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 39.4s (12.71/s)
#     Loss: 0.00531
#     Accuracy: 0.97866
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77853, Loss: 0.04800
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.9s (12.86/s)
#     Loss: 0.00485
#     Accuracy: 0.98165
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77787, Loss: 0.04896
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.2s (13.10/s)
#     Loss: 0.00481
#     Accuracy: 0.98059
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79672, Loss: 0.04682
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 38.7s (12.93/s)
#     Loss: 0.00483
#     Accuracy: 0.98095
# [I 2022-06-03 19:25:12,464] Trial 23 finished with value: 0.041162190129980444 and parameters: {'num_fc_layers': 1, 'num_units_fc_layer0': 128, 'num_lstm_layer_encoder': 1, 'num_units_lstm_encoder': 32, 'num_lstm_layer_relationnet': 1, 'num_units_lstm_relationnet': 256, 'learning_rate': 0.0014822545281445738, 'learning_rate_schedule_rate': 1000}. Best is trial 17 with value: 0.03964953071437776.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77609, Loss: 0.04978
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_24
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:04.5 (7.75/s)
#     Loss: 0.09120
#     Accuracy: 0.09899
# [I 2022-06-03 19:26:33,246] Trial 24 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10194, Loss: 0.09000
#
#
#
# #######################################################################
# ########################### FINISHED TUNING ###########################
# #######################################################################
#
#
#
# Tuning statistics:
#   Number of trials:  25
#   Number of pruned trials:  14
#   Number of complete trials:  11
#
# Best trial:
#   Run 17 with Loss 0.03964953071437776 at Episode 13000
#   Params:
#     num_fc_layers: 2
#     num_units_fc_layer0: 128
#     num_units_fc_layer1: 128
#     num_lstm_layer_encoder: 1
#     num_units_lstm_encoder: 64
#     num_lstm_layer_relationnet: 2
#     num_units_lstm_relationnet: 256
#     learning_rate: 0.0002594966233989617
#     learning_rate_schedule_rate: 2000

# %% [markdown]
# Zip and push tuning results to Google Drive.

# %%
push_zip('/content/tuning', gdrive + f'/results/tuning/{N_WAY}way-{K_SHOT}shot.zip')

with open(gdrive + f'/results/tuning/importances_{N_WAY}way-{K_SHOT}shot.pkl', 'wb') as handle:
    pickle.dump(importances, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Analyze the tuning run

# %% [markdown]
# Load and unpack tuning results from Google Drive.

# %%
os.system(f'cp -R /content/drive/MyDrive/ml_projects/STRHANGE/results/tuning/{N_WAY}way-{K_SHOT}shot.zip /content')
shutil.unpack_archive(f'{N_WAY}way-{K_SHOT}shot.zip', '/content')

with open(gdrive + f'/results/tuning/importances_{N_WAY}way-{K_SHOT}shot.pkl', 'rb') as handle:
  importances = pickle.load(handle)

# %% [markdown]
# Success of the tuning process is examined by analyzing the best values in each run and the training curves.

# %%
plot_tuning_history('tuning', 'eval_accuracy', 'Validations Accuracy', 'maximize')

# %%
plot_tuning_traincurves('tuning', 'eval_accuracy', 'Validations Accuracy', 'maximize', 15)

# %%
best_trials = tuning.trials_dataframe().nsmallest(5, 'value').transpose().drop(['number', 'datetime_start', 'datetime_complete'])

print(tabulate(best_trials, tablefmt = 'latex', headers=best_trials.columns, numalign="right", floatfmt=".2f"))
# Out:
# \begin{tabular}{llllll}
# \hline
#                                     & 17                     & 9                      & 23                     & 18                     & 20                     \\
# \hline
#  value                              & 0.03964953071437776    & 0.04048242246732116    & 0.041162190129980444   & 0.04201844174414873    & 0.04324133366346359    \\
#  duration                           & 0 days 01:10:20.899307 & 0 days 01:14:23.629501 & 0 days 00:44:28.215438 & 0 days 01:07:22.523981 & 0 days 01:22:14.777828 \\
#  params\_learning\_rate               & 0.0002594966233989617  & 7.35690559509388e-05   & 0.0014822545281445738  & 0.00036861425462226687 & 0.0005133972980725728  \\
#  params\_learning\_rate\_schedule\_rate & 2000                   & 2500                   & 1000                   & 2500                   & 4500                   \\
#  params\_num\_fc\_layers               & 2                      & 1                      & 1                      & 1                      & 1                      \\
#  params\_num\_lstm\_layer\_encoder      & 1                      & 2                      & 1                      & 1                      & 1                      \\
#  params\_num\_lstm\_layer\_relationnet  & 2                      & 1                      & 1                      & 2                      & 2                      \\
#  params\_num\_units\_fc\_layer0         & 128                    & 128                    & 128                    & 128                    & 256                    \\
#  params\_num\_units\_fc\_layer1         & 128.0                  & nan                    & nan                    & nan                    & nan                    \\
#  params\_num\_units\_fc\_layer2         & nan                    & nan                    & nan                    & nan                    & nan                    \\
#  params\_num\_units\_lstm\_encoder      & 64                     & 256                    & 32                     & 32                     & 128                    \\
#  params\_num\_units\_lstm\_relationnet  & 256                    & 256                    & 256                    & 256                    & 256                    \\
#  state                              & COMPLETE               & COMPLETE               & COMPLETE               & COMPLETE               & COMPLETE               \\
# \hline
# \end{tabular}

# %%
plot_traincurve('tuning/run_23', ['train_accuracy', 'eval_accuracy'], 'Accuracy')

# %%
plot_tuning_parameter_importance(importances)

# %% [markdown]
# ## Model selection

# %% [markdown]
# Select the final model (run an episode to stop) on the basis of the tuning analyses.

# %%
selected_run = 'run_23'
selected_episode = '11000'

# %% [markdown]
# # Model evaluation

# %% [markdown]
# Evaluate the model on unseen data.

# %%
conf_matrix, classification_report, accuracy = run_testing(num_testruns = 1000, samples_per_run = 32, run_dir = f'tuning/{selected_run}', episode = f'e{selected_episode}', test_classes = test_classes)

# %%
model_name = f'{N_WAY}-way_{K_SHOT}-sup'
path = os.path.join(gdrive, 'results', 'tests')

np.save(os.path.join(path, f'{model_name}_CM.npy'), conf_matrix)
classification_report.to_pickle(os.path.join(path, f'{model_name}_CR.pkl'))
np.save(os.path.join(path, f'{model_name}_ACC.npy'), accuracy)

# %% [markdown]
# Visualize Confusion Matrix

# %%
plot_conf_matrix (conf_matrix, test_classes, y_og)

# %% [markdown]
# Analyse Accuracy, Precision, Recall and F-Score.

# %%
print(f'Average Accuracy of the model on testdata {accuracy}\n')
print(f'Average Precision of the model on testdata {round(classification_report.Precision.mean(),3)}\n')
print(f'Average Recall of the model on testdata {round(classification_report.Recall.mean(),3)}\n')
print(f'Average F-Score of the model on testdata {round(classification_report.FScore.mean(),3)}\n')

print(tabulate(classification_report, tablefmt = 'latex', headers=classification_report.columns, numalign="right", floatfmt=".2f"))
# Out:
# Average Accuracy of the model on testdata 0.8177593750000001
#
# Average Precision of the model on testdata 0.814
#
# Average Recall of the model on testdata 0.813
#
# Average F-Score of the model on testdata 0.812
#
# \begin{tabular}{lrrr}
# \hline
#                &   Precision &   Recall &   FScore \\
# \hline
#  0 (0 \& 0)     &        0.94 &     0.99 &     0.96 \\
#  3 (0 \& 3)     &        0.85 &     0.92 &     0.88 \\
#  12 (0 \& 12)   &        0.96 &     0.95 &     0.93 \\
#  13 (0 \& 13)   &        0.94 &     0.97 &     0.92 \\
#  15 (0 \& 15)   &        0.81 &     0.95 &     0.87 \\
#  19 (0 \& 19)   &        0.88 &     0.90 &     0.89 \\
#  21 (0 \& 21)   &        0.87 &     0.87 &     0.87 \\
#  24 (0 \& 24)   &        0.94 &     0.97 &     0.95 \\
#  81 (3 \& 3)    &        0.77 &     0.71 &     0.73 \\
#  90 (3 \& 12)   &        0.84 &     0.82 &     0.83 \\
#  91 (3 \& 13)   &        0.81 &     0.91 &     0.86 \\
#  93 (3 \& 15)   &        0.72 &     0.78 &     0.75 \\
#  97 (3 \& 19)   &        0.75 &     0.73 &     0.74 \\
#  99 (3 \& 21)   &        0.76 &     0.67 &     0.71 \\
#  102 (3 \& 24)  &        0.81 &     0.72 &     0.76 \\
#  315 (12 \& 3)  &        0.82 &     0.74 &     0.78 \\
#  324 (12 \& 12) &        0.92 &     0.90 &     0.91 \\
#  325 (12 \& 13) &        0.88 &     0.93 &     0.93 \\
#  327 (12 \& 15) &        0.79 &     0.85 &     0.82 \\
#  331 (12 \& 19) &        0.80 &     0.86 &     0.83 \\
#  333 (12 \& 21) &        0.82 &     0.75 &     0.78 \\
#  336 (12 \& 24) &        0.87 &     0.82 &     0.84 \\
#  341 (13 \& 3)  &        0.87 &     0.81 &     0.84 \\
#  350 (13 \& 12) &        0.93 &     0.97 &     0.95 \\
#  351 (13 \& 13) &        0.92 &     0.94 &     0.96 \\
#  353 (13 \& 15) &        0.84 &     0.95 &     0.89 \\
#  357 (13 \& 19) &        0.84 &     0.85 &     0.85 \\
#  359 (13 \& 21) &        0.84 &     0.78 &     0.81 \\
#  362 (13 \& 24) &        0.90 &     0.89 &     0.89 \\
#  393 (15 \& 3)  &        0.77 &     0.75 &     0.76 \\
#  402 (15 \& 12) &        0.84 &     0.80 &     0.82 \\
#  403 (15 \& 13) &        0.82 &     0.90 &     0.86 \\
#  405 (15 \& 15) &        0.72 &     0.77 &     0.74 \\
#  409 (15 \& 19) &        0.75 &     0.68 &     0.71 \\
#  411 (15 \& 21) &        0.73 &     0.64 &     0.68 \\
#  414 (15 \& 24) &        0.83 &     0.75 &     0.79 \\
#  497 (19 \& 3)  &        0.71 &     0.62 &     0.66 \\
#  506 (19 \& 12) &        0.84 &     0.84 &     0.84 \\
#  507 (19 \& 13) &        0.79 &     0.91 &     0.85 \\
#  509 (19 \& 15) &        0.72 &     0.80 &     0.76 \\
#  513 (19 \& 19) &        0.71 &     0.72 &     0.71 \\
#  515 (19 \& 21) &        0.71 &     0.67 &     0.69 \\
#  518 (19 \& 24) &        0.81 &     0.75 &     0.78 \\
#  549 (21 \& 3)  &        0.73 &     0.60 &     0.66 \\
#  558 (21 \& 12) &        0.85 &     0.76 &     0.80 \\
#  559 (21 \& 13) &        0.81 &     0.86 &     0.84 \\
#  561 (21 \& 15) &        0.72 &     0.71 &     0.72 \\
#  565 (21 \& 19) &        0.74 &     0.66 &     0.70 \\
#  567 (21 \& 21) &        0.76 &     0.66 &     0.71 \\
#  570 (21 \& 24) &        0.81 &     0.69 &     0.74 \\
#  627 (24 \& 3)  &        0.75 &     0.76 &     0.76 \\
#  636 (24 \& 12) &        0.87 &     0.96 &     0.91 \\
#  637 (24 \& 13) &        0.84 &     0.94 &     0.88 \\
#  639 (24 \& 15) &        0.76 &     0.85 &     0.81 \\
#  643 (24 \& 19) &        0.76 &     0.85 &     0.80 \\
#  645 (24 \& 21) &        0.80 &     0.73 &     0.76 \\
#  648 (24 \& 24) &        0.84 &     0.83 &     0.84 \\
# \hline
# \end{tabular}

# %% [markdown]
# Test the model on origial Jester-Data.

# %%
conf_matrix, classification_report, accuracy = run_testing(num_testruns = 500, samples_per_run = 32, run_dir = f'tuning/{selected_run}', episode = f'e{selected_episode}', test_classes = jester_comp_classes, split = 'jester')

# %%
print(f'Average Accuracy of the model on Jester: {accuracy}\n')
# Out:
# Average Accuracy of the model on Jester: 0.89872391

# %% [markdown]
# # Model saving

# %% [markdown]
# Save the best model to the Google Drive.

# %%
push_model_to_gdrive(f'tuning/{selected_run}', f'e{selected_episode}',f'{N_WAY}way-{K_SHOT}shot')
