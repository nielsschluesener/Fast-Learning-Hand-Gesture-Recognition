# %% [markdown]
# #Environment configuration

# %% [markdown]
# Install packages.

# %%
#Don't run this code unless you really want to install the packages.
#!pip install alive-progress -q
#!pip install optuna -q
# Out:
#      |████████████████████████████████| 80 kB 3.5 MB/s
#      |████████████████████████████████| 207 kB 19.6 MB/s
#   Building wheel for grapheme (setup.py) ... done
#      |████████████████████████████████| 308 kB 8.8 MB/s
#      |████████████████████████████████| 81 kB 8.4 MB/s
#      |████████████████████████████████| 209 kB 48.5 MB/s
#      |████████████████████████████████| 78 kB 7.0 MB/s
#      |████████████████████████████████| 146 kB 59.2 MB/s
#      |████████████████████████████████| 49 kB 5.9 MB/s
#      |████████████████████████████████| 112 kB 55.0 MB/s
#   Building wheel for pyperclip (setup.py) ... done

# %% [markdown]
# Import packages.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR

import optuna
from optuna.trial import TrialState

import numpy as np
import os
import math
import argparse
import random
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import itertools
import shutil

from google.colab import drive
from alive_progress import alive_bar
from tabulate import tabulate
import time

# %% [markdown]
# Mount and config GDrive & paths.

# %%
drive.mount('/content/drive')
gdrive = '/content/drive/My Drive/ml_projects/STRHANGE/'

keypoints_path = gdrive + '/data/JESTER/extracted/'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Experiment configuration

# %%
N_WAY = 10
K_SHOT = 2

# %% [markdown]
# # Set up functions and classes

# %% [markdown]
# This section contains all functions and classes that are important for the remainder of this notebook. An explanation of the functions and their parameters & outputs can be found in the function headers.

# %% [markdown]
# #### Model training

# %%
def run_training(task_param, input_param, model_param, training_param):
  """
  Training Function - performs a single model training for a set of parameters
  Args:
    task_param (dict): task-related parameters
    input_param (dict): input-related parameters
    model_param (dict): model-related parameters
    training_param (dict): training-related paramaters
  Returns:
    logging (pd.dataframe): dataframe with user configurated logging information on the training-history
  """

  ### PARAMETER UNPACKING AND INITIALIZATION ###
  print('Initializing training...\n')

  #task-parameters
  SUPPORT_NUM_PER_CLASS = task_param['support_num_per_class'] 
  QUERY_NUM_PER_CLASS = task_param['query_num_per_class']  
  NUM_CLASSES = task_param['num_classes']  

  #input-parameters
  SEQUENCE_LENGTH = input_param['sequence_length']
  FEATURE_LENGTH = input_param['feature_length'] 

  #model-parameters
  NUM_LSTM_LAYER_ENCODER = model_param['num_lstm_layer_encoder']
  NUM_UNITS_LSTM_ENCODER = model_param['num_units_lstm_encoder']
  NUM_LSTM_LAYER_RELATIONNET = model_param['num_lstm_layer_relationnet']
  NUM_UNITS_LSTM_RELATIONNET = model_param['num_units_lstm_relationnet']
  NUM_UNITS_FC_RELU = model_param['num_units_fc_relu']

  #training-parameters
  LEARNING_RATE = training_param['learning_rate']
  LEARNING_RATE_SCHEDULE_RATE = training_param['learning_rate_schedule_rate']
  NUM_TRAIN_EPISODES = training_param['num_train_episodes']
  UPDATE_AND_EVAL_RATE = training_param['update_and_eval_rate']
  NUM_EVAL_EPISODES = training_param['num_eval_episodes']
  SAVE_PATH = training_param['save_path']
  SAVE_LOGGING = training_param['save_logging']
  SAVE_ALL = training_param['save_all']
  SAVE_BEST = training_param['save_best']
  TUNING_RUN = training_param['tuning_run']
  trial = training_param['trial']

  if NUM_TRAIN_EPISODES % UPDATE_AND_EVAL_RATE != 0:
    raise ValueError(f'Invalid Parameters: UPDATE_AND_EVAL_RATE must be a multiple of NUM_TRAIN_EPISODES.')

  print('  Parameters accepted and set.')

  ### MODEL INITIALIZATION ###
  feature_encoder = LSTMEncoder(FEATURE_LENGTH, NUM_UNITS_LSTM_ENCODER, NUM_LSTM_LAYER_ENCODER).to(device)
  print('  Feature encoder intialized, initial weights set.')
  relation_network = RelationNetwork(NUM_UNITS_LSTM_ENCODER*2, NUM_UNITS_LSTM_RELATIONNET, NUM_UNITS_FC_RELU, NUM_LSTM_LAYER_RELATIONNET).to(device) 
  print('  Relation network intialized, initial weights set.')

  feature_encoder_optim = torch.optim.Adam(feature_encoder.parameters(),lr=LEARNING_RATE)
  feature_encoder_scheduler = StepLR(feature_encoder_optim,step_size=LEARNING_RATE_SCHEDULE_RATE,gamma=0.5) 

  relation_network_optim = torch.optim.Adam(relation_network.parameters(),lr=LEARNING_RATE)
  relation_network_scheduler = StepLR(relation_network_optim,step_size=LEARNING_RATE_SCHEDULE_RATE,gamma=0.5) 

  mse = nn.MSELoss().to(device)

  print('  Optimizer & Learning Rate Scheduler initalized.')

  ### SET UP LOGGING ###

  # Create logging dir for current run
  logging = []
  if SAVE_LOGGING == True or SAVE_ALL == True or SAVE_BEST == True:

    if not os.path.exists(SAVE_PATH):
      os.makedirs(SAVE_PATH)

    run = 0
    run_list = os.listdir(SAVE_PATH)

    for i in range(len(run_list)):
      try:
        run_list[i] = int(run_list[i].split('_')[1])
      except:
        next

    run_list = [num for num in run_list if isinstance(num, (int,float))]

    if run_list:
      run = int(max(run_list)) + 1
    log_dir = os.path.join(SAVE_PATH, 'run_' + str(run))

    if not os.path.exists(log_dir):
      os.makedirs(log_dir)

    #Log params to logging dir
    with open(log_dir + '/task_param.pkl', 'wb') as f:
      pickle.dump(task_param, f)

    with open(log_dir + '/input_param.pkl', 'wb') as f:
      pickle.dump(input_param, f)      

    with open(log_dir + '/model_param.pkl', 'wb') as f:
      pickle.dump(model_param, f)

    with open(log_dir + '/training_param.pkl', 'wb') as f:
      pickle.dump(training_param, f)
  
  print(f'  Created logging folder: {log_dir}')

  print('\nTraining initalized. \n\n')

  print('Start training...\n')

  ### TRAINING ###

  #loop over number of episodes
  for episode in range(int(NUM_TRAIN_EPISODES/UPDATE_AND_EVAL_RATE)):

    print(f'Episode: {episode*UPDATE_AND_EVAL_RATE}/{NUM_TRAIN_EPISODES} to {(episode + 1) * UPDATE_AND_EVAL_RATE}/{NUM_TRAIN_EPISODES}')

    step_train_accuracy = 0
    step_train_loss = 0

    with alive_bar(UPDATE_AND_EVAL_RATE, title=f'  Training...', force_tty = True) as bar:
      for i in range(UPDATE_AND_EVAL_RATE):
        # Generate task and get data
        query_x, query_y, support_x, support_y = gen_task(n_way = NUM_CLASSES, n_support = SUPPORT_NUM_PER_CLASS, n_query = QUERY_NUM_PER_CLASS, data_x = X, data_y = y, split = 'train')
        query_x, query_y, support_x, support_y = query_x.to(device), query_y.to(device), support_x.to(device), support_y.to(device)
          
        # Predict
        relations, query_y_one_hot = predict(feature_encoder, relation_network, support_x, query_x, query_y, NUM_CLASSES, SUPPORT_NUM_PER_CLASS, QUERY_NUM_PER_CLASS, SEQUENCE_LENGTH, NUM_UNITS_LSTM_ENCODER)

        # Calculate loss         
        loss = mse(relations,query_y_one_hot)
        step_train_loss += loss.item()

        # Calculate accuracy 
        _,predict_labels = torch.max(relations.data,1)
        rewards = [1 if predict_labels[j]==query_y[j] else 0 for j in range(NUM_CLASSES*QUERY_NUM_PER_CLASS)]
        accuracy = np.sum(rewards)/1.0/NUM_CLASSES/QUERY_NUM_PER_CLASS
        step_train_accuracy += accuracy

        #backpropagation - adjust the model's parameter
        feature_encoder.zero_grad()
        relation_network.zero_grad()

        loss.backward()

        torch.nn.utils.clip_grad_norm_(feature_encoder.parameters(),0.5)
        torch.nn.utils.clip_grad_norm_(relation_network.parameters(),0.5)

        feature_encoder_optim.step()
        relation_network_optim.step()

        #update status bar
        bar()

    # print loss and acc for episode
    step_train_loss = step_train_loss/UPDATE_AND_EVAL_RATE
    step_train_accuracy = step_train_accuracy/UPDATE_AND_EVAL_RATE

    print(f'    Loss: {step_train_loss:.5f}')
    print(f'    Accuracy: {step_train_accuracy:.5f}')

    # start validation
    with torch.no_grad():

      step_eval_loss = 0
      step_eval_accuracy = 0
      best_eval_accuracy = 0

      for i in range(NUM_EVAL_EPISODES):

        # Generate task and get data
        query_x, query_y, support_x, support_y = gen_task(n_way = NUM_CLASSES, n_support = SUPPORT_NUM_PER_CLASS, n_query = QUERY_NUM_PER_CLASS, data_x = X, data_y = y, split = 'eval')
        query_x, query_y, support_x, support_y = query_x.to(device), query_y.to(device), support_x.to(device), support_y.to(device)

        # Predict
        relations, query_y_one_hot = predict(feature_encoder, relation_network, support_x, query_x, query_y, NUM_CLASSES, SUPPORT_NUM_PER_CLASS, QUERY_NUM_PER_CLASS, SEQUENCE_LENGTH, NUM_UNITS_LSTM_ENCODER)

        # Calculate loss             
        loss = mse(relations,query_y_one_hot)
        step_eval_loss += loss.item()

        # Calculate rewards for accuracy 
        _,predict_labels = torch.max(relations.data,1)
        rewards = [1 if predict_labels[j]==query_y[j] else 0 for j in range(NUM_CLASSES*QUERY_NUM_PER_CLASS)]
        step_eval_accuracy += np.sum(rewards)

      # Calculate and print loss / acc for validation-run
      step_eval_loss = step_eval_loss / NUM_EVAL_EPISODES
      step_eval_accuracy = step_eval_accuracy/1.0/NUM_CLASSES/QUERY_NUM_PER_CLASS/NUM_EVAL_EPISODES

      logging.append([step_train_loss, step_train_accuracy, step_eval_loss, step_eval_accuracy])

      print(f'  Validation with {NUM_EVAL_EPISODES} Evaluation-Episodes. Accuracy: {step_eval_accuracy:.5f}, Loss: {step_eval_loss:.5f}\n' )

      # Report results to optuna-tuning
      if TUNING_RUN == True:
        trial.report(step_eval_loss, episode * UPDATE_AND_EVAL_RATE)

        # Prune trial and save logging if loss-decrease is not promising
        if trial.should_prune():
          if SAVE_LOGGING == True:
            logging = pd.DataFrame(logging, columns=['train_loss', 'train_accuracy', 'eval_loss', 'eval_accuracy'])
            logging.eval_loss.iloc[0] = logging.train_loss.iloc[0]
            logging.eval_accuracy.iloc[0] = logging.train_accuracy.iloc[0]
            logging.to_pickle(log_dir + '/logging.pkl')
          raise optuna.exceptions.TrialPruned()

      # Save network 
      if (SAVE_BEST == True or SAVE_ALL == True) and not os.path.exists(os.path.join(log_dir, 'models')):
        os.makedirs(os.path.join(log_dir, 'models'))

      if SAVE_BEST == True and step_eval_accuracy > best_eval_accuracy:
        torch.save(feature_encoder.state_dict(),str(log_dir + '/models/feature_encoder_best.pkl'))
        torch.save(relation_network.state_dict(),str(log_dir + '/models/relation_network_best.pkl'))

      if SAVE_ALL == True:
        torch.save(feature_encoder.state_dict(),str(log_dir + '/models/feature_encoder_e' + str(episode*UPDATE_AND_EVAL_RATE) + '.pkl'))
        torch.save(relation_network.state_dict(),str(log_dir + '/models/relation_network_e' + str(episode*UPDATE_AND_EVAL_RATE) + '.pkl'))

  # Save logging
  if SAVE_LOGGING == True:
    logging = pd.DataFrame(logging, columns=['train_loss', 'train_accuracy', 'eval_loss', 'eval_accuracy'])
    logging.eval_loss.iloc[0] = logging.train_loss.iloc[0]
    logging.eval_accuracy.iloc[0] = logging.train_accuracy.iloc[0]

    logging.to_pickle(log_dir + '/logging.pkl')

  return logging

# %% [markdown]
# #### Hyperparameter tuning

# %%
def run_tuning(trial):
  """
  Tuning Function - performs multiple model trainings and optimizes hyperparameters
  Args:
    trial (optunia-trial-object): current trial object of the optuna tuning process
  Returns:
    min_eval_loss (float): minimal loss on evaluation set
  """

  # Caution: some parameters have to be set manually to match the given task, input and training specifications
  # (this has to be done within this function, because optuna does not support additional args)

  # Set tuning parameters  
  task_param = {'support_num_per_class': K_SHOT,
                'query_num_per_class': 16,
                'num_classes': N_WAY}

  # Set input parameters  
  input_param = {'sequence_length': 72,
                 'feature_length': 63}

  # Set model parameters (suggestions by optuna)
  num_fc_layers = trial.suggest_int("num_fc_layers", 1, 3, step = 1)
  num_units_fc_relu = []
  for i in range(num_fc_layers):
    num_units = trial.suggest_categorical("num_units_fc_layer{}".format(i), [16, 32, 64, 128, 256])
    num_units_fc_relu.append(num_units)

  model_param = {'num_lstm_layer_encoder': trial.suggest_int("num_lstm_layer_encoder", 1, 3, step=1),
                 'num_units_lstm_encoder': trial.suggest_categorical("num_units_lstm_encoder", [16, 32, 64, 128, 256]),
                 'num_lstm_layer_relationnet': trial.suggest_int("num_lstm_layer_relationnet", 1, 3, step=1),
                 'num_units_lstm_relationnet': trial.suggest_categorical("num_units_lstm_relationnet", [16, 32, 64, 128, 256]),
                 'num_units_fc_relu': num_units_fc_relu}

  # Set training parameters
  training_param = {'learning_rate': trial.suggest_float("learning_rate", 0.00001, 0.01,  log=True),
                    'learning_rate_schedule_rate': trial.suggest_int("learning_rate_schedule_rate", 500, 10000, step = 500),
                    'num_train_episodes': 25000,
                    'update_and_eval_rate': 500,
                    'num_eval_episodes': 200,
                    'save_path': 'tuning',
                    'save_logging': True,
                    'save_all': True,
                    'save_best': True,
                    'tuning_run': True,
                    'trial': trial}

  # run training with parameters of this trial
  logs = run_training(task_param, input_param, model_param, training_param)

  # report minimal evaluation loss to optuna
  min_eval_loss = logs.eval_loss.min()
  return min_eval_loss

# %% [markdown]
# #### Unique tasks calculator

# %%
def get_classcombinations(classes, num_in_comb):
  """
  Generates a set of unique tasks for a given list of classes and a number different of classes in each task
  Args:
    classes (list): list of classes
    num_in_comb (int): number different of classes in each task
  Returns:
    unique_tasks (set): set of unique tasks
  """

  unique_tasks = set(itertools.combinations(classes, num_in_comb))
  return unique_tasks

# %% [markdown]
# #### Task generator

# %%
def gen_task(n_way, n_support, n_query, data_x, data_y, split):
  """
  Generates a task (classify n-query gestures of n_way classes with n_support suppoting samples) for the few shot model.
  Args:
    n_way (int): number of classes
    n_support (int): number of support samples in each class
    n_query (int): batch size of query samples 
    data_x (np.array): hand keypoints (usually X)
    data_y (np.array): labels (usually y)
    split (str): type of split (train, evel, test or jester)
  Returns:
    query_x (torch tensor): query set data
    query_y (torch tensor): query set labels
    support_x (torch tensor): support set data
    support_y (torch tensor): support set labels 
    (classes (np.array)): list of original classes 
  """

  #sample random classes from the predfined list of classes, depended of the split-type
  query_x, query_y, support_x, support_y = [], [], [], []
  if split == 'train':
    classes = np.random.choice(training_classes, n_way, replace=False)
  elif split == 'eval':
    classes = np.random.choice(eval_classes, n_way, replace=False) 
  elif split == 'test':
    classes = np.random.choice(test_classes, n_way, replace=False) 
  elif split == 'jester':
    classes = np.random.choice(jester_comp_classes, n_way, replace=False) 

  #loop over classes of this task, sample X data and generate labels (always 0 to n-classes)
  for i, c in enumerate(classes):
    data_x_c = data_x[data_y == c]

    query_x.append(data_x_c[np.random.choice(data_x_c.shape[0], n_query, replace=False), :, :])
    query_y.append([i] * n_query)

    support_x.append(data_x_c[np.random.choice(data_x_c.shape[0], n_support, replace=False), :, :])
    support_y.append([i] * n_support)

  #reshape Data
  query_x = np.reshape(query_x, (n_way * n_query, np.array(query_x).shape[2], np.array(query_x).shape[3]))
  query_y = np.reshape(query_y, n_way * n_query)
  support_x = np.reshape(support_x, (n_way * n_support, np.array(support_x).shape[2], np.array(support_x).shape[3]))
  support_y = np.reshape(support_y, n_way * n_support)

  #change to torch tensors
  query_x = torch.from_numpy(query_x).float()
  query_y = torch.from_numpy(query_y).float().type(torch.LongTensor) 
  support_x = torch.from_numpy(support_x).float()
  support_y = torch.from_numpy(support_y).float().type(torch.LongTensor) 

  #Return statements
  if split == 'train' or split == 'eval':   
    return query_x, query_y, support_x, support_y
  elif split == 'test' or split == 'jester':
    return query_x, query_y, support_x, support_y, classes

# %% [markdown]
# #### Model components

# %%
class LSTMEncoder(nn.Module):
  """First part of the model, which encodes the sequence of hand gesture keypoints"""
  def __init__(self, input_size, hidden_lstm_size, num_lstm_layer):
    """
    Object initialization.
    Args:
      input_size (int): size of the input data
      hidden_lstm_size (int): number of units in lstm-cell
      num_lstm_layer (int): number of stacked lstm-layers
    """
    super(LSTMEncoder, self).__init__()
    self.input_size = input_size 
    self.hidden_lstm_size = hidden_lstm_size 
    self.num_lstm_layer = num_lstm_layer

    #create lstm layer(s)
    self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_lstm_size, num_layers = num_lstm_layer, batch_first=True)

  def forward(self,x):
    """
    Forward pass through the LSTM Encoder
    Args:
      x (torch tensor): data input (sequence of hand keypoints as batch)
    Return:
      out (torch tensor): encoded data (encoded sequence of hand keypoints as batch) with size batch, sequence, hidden_size
    """

    #create zeros with size num_layer, sequences, hidden_size 
    #h0 containing the final hidden state for each element in the sequence
    h0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device)  
    #c0 containing the final cell state for each element in the sequence
    c0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device) 

    #pass data through the lstm layer(s)
    out, _ = self.lstm(x, (h0,c0))
    return out 


class RelationNetwork(nn.Module):
  """Second part of the model, which calculates the relation-scores, given the concatenated query and support samples"""
  def __init__(self,input_size, hidden_lstm_size, fc_sizes: list, num_lstm_layer):
    """
    Object initialization.
    Args:
      input_size (int): size of the input data
      hidden_lstm_size (int): number of units in lstm-cell
      fc_sizes (list): number of units per fully connected / linear layer
      num_lstm_layer (int): number of stacked lstm-layers
    """
    super(RelationNetwork, self).__init__()
    self.input_size = input_size 
    self.hidden_lstm_size = hidden_lstm_size
    self.layers = nn.ModuleList()
    self.num_lstm_layer = num_lstm_layer

    #create lstm layer(s)
    self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_lstm_size, num_layers = num_lstm_layer, batch_first=True)
    #next input_size is outputsize of the lstm layer (hidden_lstm_size)
    input_size = hidden_lstm_size

    #loop over fc_sizes, create linear layer + ReLU Activation and adjust the input_size
    for size in fc_sizes:
      self.layers.append(nn.Linear(input_size, size))
      self.layers.append(nn.ReLU())
      input_size = size  
 
    #add a final Linear Layer which reduces the input down to a single number, aka. the relation score, by applieing a sigmoid function
    self.end_layer = nn.Sequential(nn.Linear(input_size,1), nn.Sigmoid())
    
  def forward(self,x):
    """
    Forward pass through the Relation Network
    Args:
      x (torch tensor): concatenated data input of query- and support-samples 
    Return:
      out (torch tensor): relation scores
    """
    
    #create zeros with size num_layer, sequences, hidden_size 
    #h0 containing the final hidden state for each element in the sequence 
    h0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device) 
    #c0 containing the final cell state for each element in the sequence
    c0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device) 

    #pass data through the lstm layer(s)
    out, _ = self.lstm(x, (h0,c0))
    #reduce output to the last sequence-state 
    out = out[:, -1, :]

    #pass data through the fc layer(s)
    for layer in self.layers:
      out = layer(out)
    
    #pass data through the final layer to calculate the relation score
    out = self.end_layer(out) 
    return out

# %% [markdown]
# #### Prediction performer

# %%
def predict(feature_encoder, relation_network, support_x, query_x, query_y, num_classes, support_num_per_class, query_num_per_class, seq_length, num_units_lstm_encoder):
  """
  Prediction-Function 
  Args:
    feature_encoder (LSTMEncoder-object): initialized LSTMEncoder-object
    relation_network (RelationNetwork-object): initialized RelationNetwork-object
    support_x (torch tensor): data for support set
    support_y (torch tensor): labels for support set
    query_x (torch tensor): data for query set
    query_y (torch tensor): labels for query set
    num_classes (int): number of classes in the given task
    support_num_per_class (int): number of support samples per class in support set
    query_num_per_class (int): number of query samples per class in query set
    seq_length (int): length of sequence
    num_units_lstm_encoder (int): number of hidden units in the LSTM-Cells of the feature_encoder
  Returns:
    relations (torch tensor): relation scores 
    query_y_one_hot (torch tensor): predicted classes as one-hot-encoded vector
  """
  # calculate support features by passing the support set through the feature_encoder-module 
  support_features = feature_encoder(Variable(support_x).to(device))
  # calculate query features by passing the query set through the feature_encoder-module 
  query_features = feature_encoder(Variable(query_x).to(device))
          
  #Prepare encoded query and support set for relations calculation (reshaping, transposing)
  support_features = support_features.view(num_classes, support_num_per_class, seq_length, num_units_lstm_encoder)
  support_features = torch.sum(support_features, 1).squeeze(1)
  support_features_ext = support_features.unsqueeze(0).repeat(query_num_per_class*num_classes,1,1,1).to(device)
  query_features_ext = query_features.unsqueeze(0).repeat(num_classes,1,1,1)
  query_features_ext = torch.transpose(query_features_ext,0,1).to(device)

  # concatenated encoded query & support set
  relation_pairs = torch.cat((support_features_ext,query_features_ext),3).view(-1,seq_length, num_units_lstm_encoder*2).to(device)

  # calculate relations by passing the concatenated query & support set through the relation_network-module 
  relations = relation_network(relation_pairs).view(-1,num_classes).to(device)

  # turn relation-scores into one hot encoded predictions 
  query_y_one_hot = Variable(torch.zeros(query_num_per_class*num_classes, num_classes).to(device).scatter_(1, query_y.view(-1,1), 1)).to(device)

  return relations, query_y_one_hot

# %% [markdown]
# #### Logging loader

# %%
def load_logging_and_params_from_file(log_dir):
  """
  Loads the logging and parameters of a single training-run from a given directory
  Args:
    log_dir (str): location of logs and parameters of a single run
  Returns:
    logging (pd.dataframe: logging of the given run
    task_param (dict): task-related parameters of the given run
    input_param (dict): input-related parameters of the given run
    model_param (dict): model-related parameters of the given run
    training_param (dict): training-related paramaters of the given run
  """

  #check is given log_dir exist
  if os.path.isfile(os.path.join(log_dir,'logging.pkl')):
    #load logging and param-dirs
    logging = pd.read_pickle(os.path.join(log_dir, 'logging.pkl'))

    with open(os.path.join(log_dir, 'task_param.pkl'), 'rb') as f:
      task_param = pickle.load(f)

    with open(os.path.join(log_dir, 'input_param.pkl'), 'rb') as f:
      input_param = pickle.load(f)      

    with open(os.path.join(log_dir, 'model_param.pkl'), 'rb') as f:
      model_param = pickle.load(f)

    with open(os.path.join(log_dir, 'training_param.pkl'), 'rb') as f:
      training_param = pickle.load(f)

    #return logging and param-dirs
    return logging, task_param, input_param, model_param, training_param
  
  else:
    print(f'No logging found in {log_dir}')

# %% [markdown]
# #### Training-Curve visualization

# %%
def plot_traincurve(log_dir, metrics, ylabel):
  """
  Plots the training curve of a single train-run
  Args:
    log_dir (str): location of the training run
    metrics (list): metrics to be plotted 
    ylabel (str): label to be plotted on the y-axis
  """

  #Load logging from log_dir
  logging, _, _, _, training_param = load_logging_and_params_from_file(log_dir)

  plt.figure(figsize=(10, 5), dpi=100)
  colors = ['#00406C', '#1ABEA3'] 
  i = 0

  #Loop over metrics and visualize it as a line
  for col in metrics:
    plot_data = logging[col].dropna()
    plt.plot(plot_data.index.values * training_param['update_and_eval_rate'], plot_data.values, label=col, color = colors[i])
    i += 1

  l=plt.legend()
  l.get_texts()[0].set_text('Trainingsdaten')
  l.get_texts()[1].set_text('Validationsdaten')

  #plt.title('Learning Curve')
  plt.xlabel('Episode')
  plt.ylabel(ylabel)
  plt.ylim(0, 1)
  #plt.figlegend(bbox_to_anchor=(0.85,0.5), loc="center left")
  plt.tight_layout(rect=[0,0,0.85,1])

  plt.show()

# %% [markdown]
# #### Tuning-History visualization

# %%
def plot_tuning_history(tuning_dir, metric, y_label, direction):
  """
  Plots the training curves of all training-runs in a tuning dir 
  Args:
    tuning_dir (str): location of the tuning run
    metric (list): metrics to be plotted 
    y_label (str): label to be displayed on the y-axis
    direction (str): maximize or minimize
  """

  # Gather the data from every training-run in the tuning_dir
  tuning_metrics = []
  runs = []
  if os.path.isdir(tuning_dir):
    run_dirs = os.listdir(tuning_dir)

    def extract_nums (elem):
      return int(elem.split('_')[1])
    
    run_dirs.sort(key = extract_nums)

    for i in range(len(run_dirs)):
      if 'run' in run_dirs[i]:
        logging, _, _, _, training_param = load_logging_and_params_from_file(os.path.join(tuning_dir, run_dirs[i]))
        logging = logging[metric]
        tuning_metrics.append(list(logging))
        runs.append(run_dirs[i])  

    max_length = len(max(tuning_metrics, key=len))

    if direction == 'maximize':
      none_marker = 0
    elif direction == 'minimize':
      none_marker = 99
    else:
      return 'invalid direction'

    for i, log in enumerate(tuning_metrics):
      tuning_metrics[i] = (log + max_length * [none_marker])[:max_length]

    tuning_metrics = np.array(tuning_metrics).transpose()
    tuning_logs = pd.DataFrame(tuning_metrics, columns = runs)
    
  else:
    print('tuning_dir does not exist.')

# Check for pruned runs and when a run hits a new best-score
  pruned = []
  new_best = []
  
  if direction == 'maximize':
    best = 0

    for col in tuning_logs:
      if tuning_logs[col].max() > best:
        best = tuning_logs[col].max()
        new_best.append('#E76450')
      else:
        new_best.append('#FFC35E')

      if tuning_logs[col].min() == 0:
        pruned.append('x')
      else:
        pruned.append('o')

      data = tuning_logs.max()
     
  elif direction == 'minimize':
    best = 1
    for col in tuning_logs:
      if tuning_logs[col].min() < best:
        best = tuning_logs[col].min()
        new_best.append('#00406E')
      else:
        new_best.append('#17BEA3')

      if tuning_logs[col].max() == 99:
        pruned.append('x')
      else:
        pruned.append('o')

      data = tuning_logs.min()

  # Visualize history

  plt.figure(figsize=(10, 5), dpi=100)
  plt.plot(data, linestyle = 'dashed', color = '#C8D4D7')

  for i in range(len(data)):
    plt.plot(i, data[i], marker = pruned[i], markersize = 8, color = new_best[i])

  #plt.title('Tuning Entwicklung')
  plt.xlabel('Trainingsläufe')
  plt.xticks(rotation=45, horizontalalignment='center')
  plt.ylabel(y_label)
  plt.ylim(0, 1)

  plt.show()

# %% [markdown]
# #### Tuning-Traincurves visualization

# %%
def plot_tuning_traincurves(tuning_dir, metric, y_label, direction = None, top_n = None):
  """
  Plots the training curves of all training-runs in a tuning dir 
  Args:
    tuning_dir (str): location of the tuning run
    metric (list): metrics to be plotted 
    y_label (str): label to be displayed on the y-axis
    direction (str): maximize or minimize
    top (int): visualize top_n results, either highest or lowest, dependend on arg 'direction'
  """

  # Gather the data from every training-run in the tuning_dir
  tuning_metrics = []
  runs = []
  if os.path.isdir(tuning_dir):
    run_dirs = os.listdir(tuning_dir)

    def extract_nums (elem):
      return int(elem.split('_')[1])
    
    run_dirs.sort(key = extract_nums)

    for i in range(len(run_dirs)):
      if 'run' in run_dirs[i]:
        logging, _, _, _, training_param = load_logging_and_params_from_file(os.path.join(tuning_dir, run_dirs[i]))
        logging = logging[metric]
        tuning_metrics.append(list(logging))
        runs.append(run_dirs[i])  

    max_length = len(max(tuning_metrics, key=len))

    for i, log in enumerate(tuning_metrics):
      tuning_metrics[i] = (log + max_length * [0])[:max_length]

    tuning_metrics = np.array(tuning_metrics).transpose()
    tuning_logs = pd.DataFrame(tuning_metrics, columns = runs)
    
  else:
    print('tuning_dir does not exist.')

  # Filter to visualize only the top_n results

  if direction != None and top_n != None:
    if direction == 'maximize':
      tuning_logs = tuning_logs[tuning_logs.max().nlargest(top_n).index]
    elif direction == 'minimize':
      tuning_logs = tuning_logs[tuning_logs.min().nsmallest(top_n).index]
    else: 
      return 'invalid direction'


  # Visualize results
  plt.figure(figsize=(10, 5), dpi=100)
  for col in list(tuning_logs.columns.values):
    plot_data = tuning_logs[col].dropna()
    plt.plot(plot_data.index.values * training_param['update_and_eval_rate'], plot_data.values, label=col)

  #plt.title('Lernkurve')
  plt.xlabel('Episode')
  plt.ylabel(y_label)

  plt.figlegend(bbox_to_anchor=(0.85,0.5), loc="center left")
  plt.tight_layout(rect=[0,0,0.85,1])
  plt.ylim(0, 1)

  plt.show()

# %% [markdown]
# #### Tuning parameter's importance visualization

# %%
def plot_tuning_parameter_importance(importances):
  """
  Visualizes the importances of every parameter in a tuning run
  Args:
    importances (OrderedDict): importances of the tuning parameters
  """

  # create positions needed for horizontal plot
  y_pos = np.arange(start = len(importances.keys()), stop = 0, step = -1)

  # create plot
  plt.figure(figsize=(10, 5), dpi=100)
  plt.barh(y_pos, importances.values(), color = '#17BEA3')

  i = 0
  for v in reversed(importances.values()):
    plt.text(v + 0.003, i + 0.9, str(round(v, 3)), color = '#00406E')
    i += 1

  # adjust labels and axis
  plt.yticks(y_pos, labels=importances.keys())
  plt.title('')
  plt.xlabel('Relevanz für den Erfolg des Tunings')
  plt.ylabel('Tuning Parameter')
  plt.xlim(0, 0.25)
  plt.tight_layout()

  plt.show()

# %% [markdown]
# #### Zip and push to Google Drive

# %%
def push_zip(source, destination):
  """
  Zip and push a directory to the Google Drive
  Args:
    source (str): current location 
    destination (str): target location 
  """
  base = os.path.basename(destination)
  name = base.split('.')[0]
  format = base.split('.')[1]
  archive_from = os.path.dirname(source)
  archive_to = os.path.basename(source.strip(os.sep))
  shutil.make_archive(name, format, archive_from, archive_to)
  shutil.move('%s.%s'%(name,format), destination)

# %% [markdown]
# #### Model saving

# %%
def push_model_to_gdrive(run_dir, episode, model_name):
  """
  Push a model & the params needed for deployment, located in a local directory, to the Google Drive
  Args:
    run_dir (str): location of the model
    episode (list): episode of the model, either a number or 'best'
    model_name (str): model's name in the Google Drive
  """

  #config target_path
  path = os.path.join(gdrive, 'results', 'models')

  #load model and params
  feature_encoder, relation_network = load_model_from_file(run_dir, episode)
  _, task_param, input_param, model_param, _ = load_logging_and_params_from_file(run_dir)

  #unpack params needed for deployment
  deployment_param = {'support_num_per_class': task_param['support_num_per_class'],
                      'num_classes': task_param['num_classes'],
                      'sequence_length': input_param['sequence_length'],
                      'feature_length': input_param['feature_length'],
                      'num_lstm_layer_encoder': model_param['num_lstm_layer_encoder'],
                      'num_units_lstm_encoder': model_param['num_units_lstm_encoder'],
                      'num_lstm_layer_relationnet': model_param['num_lstm_layer_relationnet'],
                      'num_units_lstm_relationnet': model_param['num_units_lstm_relationnet'],
                      'num_units_fc_relu': model_param['num_units_fc_relu']}

  # Push to Google Drive
  torch.save(feature_encoder.state_dict(),str(os.path.join(path, f'{model_name}_feature_encoder.pkl')))
  torch.save(relation_network.state_dict(),str(os.path.join(path, f'{model_name}_relation_network.pkl')))
  with open(os.path.join(path, f'{model_name}_deployment_param.pkl'), 'wb') as f:
      pickle.dump(deployment_param, f)

# %% [markdown]
# #### Model loading

# %%
def load_model_from_file(run_dir, episode):
  """
  Loads and initializes a model from a given directory
  Args:
    run_dir (str): location of the model
    episode (list): episode of the model, either a number or 'best'
  Returns:
    feature_encoder (LSTMEncoder-object): initialized LSTMEncoder-object
    relation_network (RelationNetwork-object): initialized RelationNetwork-object
  """

  #load params needed for deployment
  _, _, input_param, model_param, _ = load_logging_and_params_from_file(run_dir)

  #initialize feature_encoder and relation_network
  feature_encoder = LSTMEncoder(input_param['feature_length'], model_param['num_units_lstm_encoder'], model_param['num_lstm_layer_encoder']).to(device)
  relation_network = RelationNetwork(model_param['num_units_lstm_encoder']*2, model_param['num_units_lstm_relationnet'], model_param['num_units_fc_relu'], model_param['num_lstm_layer_relationnet']).to(device) 

  #load weights from directory
  feature_encoder.load_state_dict(torch.load(os.path.join(run_dir, 'models', str('feature_encoder_' + episode + '.pkl'))))
  relation_network.load_state_dict(torch.load(os.path.join(run_dir, 'models', str('relation_network_' + episode + '.pkl'))))

  return feature_encoder, relation_network

# %% [markdown]
# #### Model testing

# %%
def run_testing(num_testruns, samples_per_run, run_dir, episode, test_classes, split):
  """
  Testing Function - performs model testing on test-classes
  Args:
    num_testruns (int): number of test-runs to be performed, each test-run == one task
    samples_per_run (int): number of samples to be drawn as a query set
    run_dir (str): location of the model to be tested
    episode (str): episode of the model to be tests, either a number or 'best'
    test_classes (list): list of test classes
    split (str): split for task_gen
  Returns:
    conf_matrix (np.array): summarized confusion matrix of the test-runs
    classification_report (pd.dataframe): summarized classification report of the test-runs
    accuracy (float): summarized accuracy of the test-runs
  """

  # load and initialize model from dir
  feature_encoder, relation_network = load_model_from_file(run_dir, episode)
  _, task_param, input_param, model_param, training_param = load_logging_and_params_from_file(run_dir)

  # initi empty conf_matrix
  conf_matrix = np.zeros(shape = (len(test_classes),len(test_classes)), dtype = int)

  # loop over num_testruns
  for testrun in range(num_testruns):
    # generate a task with query and support sets
    query_x, query_y, support_x, support_y, tested_classes = gen_task(n_way = task_param['num_classes'], n_support = task_param['support_num_per_class'], 
                                                                      n_query = samples_per_run, data_x = X, data_y = y, split = split)
    query_x, query_y, support_x, support_y = query_x.to(device), query_y.to(device), support_x.to(device), support_y.to(device)

    # perform prediction on query and support set
    relations, query_y_one_hot = predict(feature_encoder, relation_network, support_x, query_x, query_y, 
                                        task_param['num_classes'], task_param['support_num_per_class'], 
                                        samples_per_run, input_param['sequence_length'], model_param['num_units_lstm_encoder'])
    _,predict_labels = torch.max(relations.data,1)

    # analyse prediction and adjust conf matrix
    for i in range(len(query_y)):
      cm_index_true = test_classes.index(tested_classes[predict_labels[i].item()])
      cm_index_pred = test_classes.index(tested_classes[query_y[i].item()])

      conf_matrix[cm_index_true][cm_index_pred] += 1

  # Calculate recall, precison and f_score based on conf matrix
  recalls = []
  precisions = []
  f_scores = []

  for i in range(len(test_classes)):
    recalls.append(conf_matrix[i][i] / conf_matrix[:,i].sum())
    precisions.append(conf_matrix[i][i] / conf_matrix[i,:].sum())
    f_scores.append(2 * (precisions[i] * recalls[i]) / (precisions[i] + recalls[i]))

  # Calculate accuracy based on conf matrix
  accuracy = conf_matrix.diagonal().sum() / conf_matrix.sum()

  # save and return metrics
  classification_report = pd.DataFrame((precisions, recalls, f_scores)).transpose()
  classification_report.index = [f'{str(x)} ({str(y_og[x][0])} & {str(y_og[x][1])})' for x in test_classes]
  classification_report.index.names = ['Class']
  classification_report.rename(columns = {0: 'Precision', 1: 'Recall', 2: 'FScore'}, inplace = True)
  
  return conf_matrix, classification_report, accuracy

# %% [markdown]
# #### Confusion matrix visualization

# %%
def plot_conf_matrix (conf_matrix, test_classes, y_og):
  """
  Visualizes a given confusion matrix as a heatmap
  Args:
    conf_matrix (np.array): confustion matrix to be visualized
    test_classes (list): list of classes the model was tested on
    y_og (list): list of original classes (before the combination) matching the test_classes
  """

  true_labels = [f'{str(x)} ({str(y_og[x][0])} & {str(y_og[x][1])})' for x in test_classes]
  pred_labels = [f'{str(x)} ({str(y_og[x][0])} & {str(y_og[x][1])})' for x in test_classes]

  fig, ax = plt.subplots(figsize = (15,15))
  im = ax.imshow(conf_matrix, cmap = 'coolwarm') 

  # Show all ticks and label them with the respective list entries
  ax.set_xticks(np.arange(len(pred_labels)))
  ax.set_yticks(np.arange(len(true_labels)))

  ax.set_xticklabels(pred_labels)
  ax.set_yticklabels(true_labels)

  ax.xaxis.tick_top()
  ax.xaxis.set_label_position('top')

  # Rotate the tick labels and set their alignment
  plt.setp(ax.get_xticklabels(), rotation=45, ha="left",
          rotation_mode="anchor")

  plt.setp(ax.get_yticklabels(), rotation=0, ha="right")

  # Loop over data dimensions and create text annotations
  for i in range(len(true_labels)):
      for j in range(len(pred_labels)):
          text = ax.text(j, i, conf_matrix[i, j],
                        ha="center", va="center", color="w")

  ax.set_title("Confusion matrix", fontsize = 18)
  fig.tight_layout()
  plt.show()

# %% [markdown]
# # Load and split data

# %% [markdown]
# Load X (extraced and combined sequences of hand-keypoints), y (combined classes from 0 to 676) and y_og (original classes from 0 to 25) from Google Drive.

# %%
# Load X, y and y_og from Google Drive.
X = np.load(gdrive + '/data/JESTER/final/X.npy')
y = np.load(gdrive + '/data/JESTER/final/y.npy')
y_og = np.load(gdrive + '/data/JESTER/final/y_og.npy')

# Check shapes 
print(f'Labels shape {y.shape}')
print(f'Data shape {X.shape}')
unique, counts = np.unique(y, return_counts=True)
print(f'\nNumber of unique classes {len(unique)}')
# Out:
# Labels shape (169000,)
# Data shape (169000, 72, 63)
#
# Number of unique classes 676

# %% [markdown]
# ## Configurate Test-strategy

# %% [markdown]
# In contrast to common machine learning approaches, the train-, test-, evaluation-split in Few-Shot Learning use cases splits the data by classes instead of drawing random samples of observations.
#
# Classes are split by their original class labels (not by combined class labels) to prevent the model from seeing bits of the data in more than one of the splits.

# %%
label_map = {'No gesture': 0, #base class, mostly zeros
            'Drumming Fingers': 1, #static
            'Pulling Hand In': 2, #dynamic
            'Pulling Two Fingers In': 3, #dynamic
            'Pushing Hand Away': 4, #dynamic
            'Pushing Two Fingers Away': 5, #dynamic
            'Rolling Hand Backward': 6, #dynamic
            'Rolling Hand Forward': 7, #dynamic
            'Shaking Hand': 8, #static
            'Sliding Two Fingers Down': 9, #dynamic
            'Sliding Two Fingers Left': 10, #dynamic
            'Sliding Two Fingers Right': 11, #dynamic
            'Sliding Two Fingers Up': 12, #dynamic
            'Stop Sign': 13, #static
            'Swiping Down': 14, #dynamic
            'Swiping Left': 15, #dynamic
            'Swiping Right': 16, #dynamic
            'Swiping Up': 17, #dynamic
            'Thumb Down': 18, #static
            'Thumb Up': 19, #static
            'Turning Hand Clockwise': 20, #dynamic
            'Turning Hand Counterclockwise': 21, #dynamic
            'Zooming In With Full Hand': 22, #dynamic
            'Zooming In With Two Fingers': 23, #dynamic
            'Zooming Out With Full Hand': 24, #dynamic
            'Zooming Out With Two Fingers': 25} #dynamic

# %% [markdown]
# Choose original class labels (pre-combination) for training, evaluation and test splits.

# %%
train_y_origin = [0, 1, 4, 5, 6, 7, 9, 10, 16, 17, 22, 25]
eval_y_origin = [0, 2, 8, 11, 14, 18, 20, 23]
test_y_origin = [0, 3, 12, 13, 15, 19, 21, 24]
jester_comp_y = [0, 2, 8, 11, 14, 18, 20, 23, 3, 12, 13, 15, 19, 21, 24]

# %% [markdown]
# Turn splits with original class labels (pre-combination) into training-, evaluation- and test- classes with combined classes.

# %%
training_classes, eval_classes, test_classes, jester_comp_classes  = [], [], [], []

for i in range(len(y_og)):
  if ((y_og[i][0] == 0) and (y_og[i][1] in eval_y_origin)) or (y_og[i][0] in eval_y_origin or y_og[i][1] in eval_y_origin) and not (y_og[i][0] in train_y_origin or y_og[i][1] in train_y_origin) and not (y_og[i][0] in test_y_origin or y_og[i][1] in test_y_origin):
    eval_classes.append(i)
  if ((y_og[i][0] == 0) and (y_og[i][1] in train_y_origin)) or (y_og[i][0] in train_y_origin or y_og[i][1] in train_y_origin) and not (y_og[i][0] in eval_y_origin or y_og[i][1] in eval_y_origin) and not (y_og[i][0] in test_y_origin or y_og[i][1] in test_y_origin):
    training_classes.append(i)
  if ((y_og[i][0] == 0) and (y_og[i][1] in test_y_origin)) or (y_og[i][0] in test_y_origin or y_og[i][1] in test_y_origin) and not (y_og[i][0] in eval_y_origin or y_og[i][1] in eval_y_origin) and not (y_og[i][0] in train_y_origin or y_og[i][1] in train_y_origin):
    test_classes.append(i)
  if ((y_og[i][0] == 0) and (y_og[i][1] in jester_comp_y)):
    jester_comp_classes.append(i)

# %% [markdown]
# Examination of resulting training-, evaluation- and test-split.

# %%
print(f'Number of classes in train-split: {len(training_classes)}')
print(f'Number of classes in eval-split: {len(eval_classes)}')
print(f'Number of classes in test-split: {len(test_classes)}')
print(f'Number of classes in JESTER-evaluation-dataset: {len(jester_comp_classes)}')
# Out:
# Number of classes in train-split: 133
# Number of classes in eval-split: 57
# Number of classes in test-split: 57

# %%
#print(f'Potential number of unique tasks for training: {len(get_classcombinations(training_classes, N_WAY))}')
#print(f'Potential number of unique tasks for evaluation: {len(get_classcombinations(eval_classes, N_WAY))}')
#print(f'Potential number of unique tasks for testing: {len(get_classcombinations(test_classes, N_WAY))}')

# %% [markdown]
# # Model tuning and training

# %% [markdown]
# In this section the model is trained. Initially, this is performed once with parameters defined by the user. Next, the model's hyperparameters are optimized by a tuning process.

# %% [markdown]
# ## Perform a training run

# %% [markdown]
# To ensure that the training function operates flawlessly (& to have a baseline model), training of the model is performed once initially with low parameter complexity.

# %%
task_param = {'support_num_per_class': K_SHOT,
              'query_num_per_class': 16,
              'num_classes': N_WAY}

input_param = {'sequence_length': 72,
               'feature_length': 63}

model_param = {'num_lstm_layer_encoder': 1,
               'num_units_lstm_encoder': 64,
               'num_lstm_layer_relationnet': 1,
               'num_units_lstm_relationnet': 64,
               'num_units_fc_relu': [32]}

training_param = {'learning_rate': 0.001,
                  'learning_rate_schedule_rate': 2000,
                  'num_train_episodes': 25000,
                  'update_and_eval_rate': 200,
                  'num_eval_episodes': 200,
                  'save_path': 'training',
                  'save_logging': True,
                  'save_all': True,
                  'save_best': True,
                  'tuning_run': False,
                  'trial': None}
            
logs = run_training(task_param, input_param, model_param, training_param)
# Out:
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: training/run_0
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.21/s)
#     Loss: 0.09919
#     Accuracy: 0.11462
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.18400, Loss: 0.08881
#
# Episode: 200/25000 to 400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.8s (18.50/s)
#     Loss: 0.08748
#     Accuracy: 0.17912
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19663, Loss: 0.08510
#
# Episode: 400/25000 to 600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.7s (18.66/s)
#     Loss: 0.08554
#     Accuracy: 0.18459
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19684, Loss: 0.08417
#
# Episode: 600/25000 to 800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.8s (18.45/s)
#     Loss: 0.08555
#     Accuracy: 0.18250
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20900, Loss: 0.08395
#
# Episode: 800/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.6s (18.87/s)
#     Loss: 0.08474
#     Accuracy: 0.22938
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.23191, Loss: 0.08440
#
# Episode: 1000/25000 to 1200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.9s (18.36/s)
#     Loss: 0.07854
#     Accuracy: 0.37503
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31212, Loss: 0.08260
#
# Episode: 1200/25000 to 1400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.8s (18.54/s)
#     Loss: 0.06929
#     Accuracy: 0.51447
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.38781, Loss: 0.08159
#
# Episode: 1400/25000 to 1600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.7s (18.63/s)
#     Loss: 0.06388
#     Accuracy: 0.58178
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.40756, Loss: 0.07788
#
# Episode: 1600/25000 to 1800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.9s (18.31/s)
#     Loss: 0.05872
#     Accuracy: 0.63437
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.42616, Loss: 0.08117
#
# Episode: 1800/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.6s (18.85/s)
#     Loss: 0.05496
#     Accuracy: 0.66675
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.49866, Loss: 0.07025
#
# Episode: 2000/25000 to 2200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.6s (18.89/s)
#     Loss: 0.05113
#     Accuracy: 0.71344
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.53866, Loss: 0.06833
#
# Episode: 2200/25000 to 2400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.7s (18.71/s)
#     Loss: 0.04657
#     Accuracy: 0.74922
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.57481, Loss: 0.06682
#
# Episode: 2400/25000 to 2600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.6s (18.85/s)
#     Loss: 0.04414
#     Accuracy: 0.76806
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.59531, Loss: 0.07176
#
# Episode: 2600/25000 to 2800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.7s (18.64/s)
#     Loss: 0.04126
#     Accuracy: 0.79256
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.62484, Loss: 0.06394
#
# Episode: 2800/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.6s (18.82/s)
#     Loss: 0.03812
#     Accuracy: 0.81591
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65406, Loss: 0.06387
#
# Episode: 3000/25000 to 3200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.6s (18.83/s)
#     Loss: 0.03708
#     Accuracy: 0.82444
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67037, Loss: 0.06892
#
# Episode: 3200/25000 to 3400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.7s (18.68/s)
#     Loss: 0.03373
#     Accuracy: 0.84409
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70397, Loss: 0.06156
#
# Episode: 3400/25000 to 3600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.6s (18.94/s)
#     Loss: 0.03112
#     Accuracy: 0.85712
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71081, Loss: 0.05465
#
# Episode: 3600/25000 to 3800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.8s (18.50/s)
#     Loss: 0.02845
#     Accuracy: 0.87691
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70753, Loss: 0.05977
#
# Episode: 3800/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.6s (18.89/s)
#     Loss: 0.02814
#     Accuracy: 0.87872
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70437, Loss: 0.05307
#
# Episode: 4000/25000 to 4200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.7s (18.76/s)
#     Loss: 0.02650
#     Accuracy: 0.88481
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72156, Loss: 0.05350
#
# Episode: 4200/25000 to 4400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.7s (18.65/s)
#     Loss: 0.02542
#     Accuracy: 0.89206
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70362, Loss: 0.06122
#
# Episode: 4400/25000 to 4600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.6s (18.82/s)
#     Loss: 0.02316
#     Accuracy: 0.90350
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72381, Loss: 0.05374
#
# Episode: 4600/25000 to 4800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.7s (18.66/s)
#     Loss: 0.02307
#     Accuracy: 0.90675
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72134, Loss: 0.05683
#
# Episode: 4800/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.9s (18.36/s)
#     Loss: 0.02111
#     Accuracy: 0.91728
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74516, Loss: 0.04993
#
# Episode: 5000/25000 to 5200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.89/s)
#     Loss: 0.01972
#     Accuracy: 0.92025
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74200, Loss: 0.05082
#
# Episode: 5200/25000 to 5400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.9s (18.30/s)
#     Loss: 0.01935
#     Accuracy: 0.92109
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73647, Loss: 0.05132
#
# Episode: 5400/25000 to 5600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.03/s)
#     Loss: 0.01930
#     Accuracy: 0.92181
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75222, Loss: 0.04743
#
# Episode: 5600/25000 to 5800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (17.97/s)
#     Loss: 0.01805
#     Accuracy: 0.92866
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73628, Loss: 0.05300
#
# Episode: 5800/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.16/s)
#     Loss: 0.01927
#     Accuracy: 0.92403
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76062, Loss: 0.04621
#
# Episode: 6000/25000 to 6200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.12/s)
#     Loss: 0.01697
#     Accuracy: 0.93575
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74403, Loss: 0.04900
#
# Episode: 6200/25000 to 6400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.07/s)
#     Loss: 0.01750
#     Accuracy: 0.93003
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74900, Loss: 0.05395
#
# Episode: 6400/25000 to 6600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.9s (18.39/s)
#     Loss: 0.01613
#     Accuracy: 0.93925
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75166, Loss: 0.05039
#
# Episode: 6600/25000 to 6800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.10/s)
#     Loss: 0.01490
#     Accuracy: 0.94587
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74853, Loss: 0.05259
#
# Episode: 6800/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.90/s)
#     Loss: 0.01579
#     Accuracy: 0.93778
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77528, Loss: 0.04686
#
# Episode: 7000/25000 to 7200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.9s (18.27/s)
#     Loss: 0.01420
#     Accuracy: 0.94644
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75600, Loss: 0.05182
#
# Episode: 7200/25000 to 7400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (17.99/s)
#     Loss: 0.01464
#     Accuracy: 0.94628
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76241, Loss: 0.04989
#
# Episode: 7400/25000 to 7600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (17.96/s)
#     Loss: 0.01402
#     Accuracy: 0.94678
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75741, Loss: 0.04971
#
# Episode: 7600/25000 to 7800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.13/s)
#     Loss: 0.01456
#     Accuracy: 0.94350
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76325, Loss: 0.04774
#
# Episode: 7800/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.17/s)
#     Loss: 0.01397
#     Accuracy: 0.94853
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74709, Loss: 0.05481
#
# Episode: 8000/25000 to 8200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.16/s)
#     Loss: 0.01349
#     Accuracy: 0.95219
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74219, Loss: 0.05200
#
# Episode: 8200/25000 to 8400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 10.9s (18.28/s)
#     Loss: 0.01313
#     Accuracy: 0.94962
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77250, Loss: 0.04762
#
# Episode: 8400/25000 to 8600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (17.95/s)
#     Loss: 0.01267
#     Accuracy: 0.95209
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76503, Loss: 0.04726
#
# Episode: 8600/25000 to 8800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (17.96/s)
#     Loss: 0.01441
#     Accuracy: 0.94375
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73888, Loss: 0.06395
#
# Episode: 8800/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.14/s)
#     Loss: 0.01238
#     Accuracy: 0.95247
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76847, Loss: 0.05110
#
# Episode: 9000/25000 to 9200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.89/s)
#     Loss: 0.01140
#     Accuracy: 0.95869
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78147, Loss: 0.04612
#
# Episode: 9200/25000 to 9400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.05/s)
#     Loss: 0.01150
#     Accuracy: 0.95781
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75606, Loss: 0.05480
#
# Episode: 9400/25000 to 9600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.03/s)
#     Loss: 0.01242
#     Accuracy: 0.94953
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77662, Loss: 0.04565
#
# Episode: 9600/25000 to 9800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.10/s)
#     Loss: 0.01174
#     Accuracy: 0.95609
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77044, Loss: 0.05186
#
# Episode: 9800/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.05/s)
#     Loss: 0.01261
#     Accuracy: 0.95325
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75856, Loss: 0.05365
#
# Episode: 10000/25000 to 10200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (17.96/s)
#     Loss: 0.01162
#     Accuracy: 0.95588
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77816, Loss: 0.04757
#
# Episode: 10200/25000 to 10400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.18/s)
#     Loss: 0.01221
#     Accuracy: 0.95328
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75162, Loss: 0.05743
#
# Episode: 10400/25000 to 10600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.90/s)
#     Loss: 0.01097
#     Accuracy: 0.95969
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74194, Loss: 0.06428
#
# Episode: 10600/25000 to 10800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.11/s)
#     Loss: 0.01113
#     Accuracy: 0.96009
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76794, Loss: 0.04773
#
# Episode: 10800/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.05/s)
#     Loss: 0.01177
#     Accuracy: 0.95734
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75075, Loss: 0.06051
#
# Episode: 11000/25000 to 11200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.06/s)
#     Loss: 0.01100
#     Accuracy: 0.96247
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74991, Loss: 0.05508
#
# Episode: 11200/25000 to 11400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.20/s)
#     Loss: 0.01012
#     Accuracy: 0.96459
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75341, Loss: 0.05968
#
# Episode: 11400/25000 to 11600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.80/s)
#     Loss: 0.01092
#     Accuracy: 0.96003
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75516, Loss: 0.05225
#
# Episode: 11600/25000 to 11800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (17.99/s)
#     Loss: 0.01100
#     Accuracy: 0.96056
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76500, Loss: 0.04902
#
# Episode: 11800/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.13/s)
#     Loss: 0.01011
#     Accuracy: 0.96391
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77506, Loss: 0.05017
#
# Episode: 12000/25000 to 12200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.91/s)
#     Loss: 0.00989
#     Accuracy: 0.96269
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76250, Loss: 0.05131
#
# Episode: 12200/25000 to 12400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.15/s)
#     Loss: 0.01004
#     Accuracy: 0.96344
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73612, Loss: 0.05097
#
# Episode: 12400/25000 to 12600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.89/s)
#     Loss: 0.01141
#     Accuracy: 0.95681
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77938, Loss: 0.04955
#
# Episode: 12600/25000 to 12800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.87/s)
#     Loss: 0.01023
#     Accuracy: 0.96466
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75313, Loss: 0.05387
#
# Episode: 12800/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.11/s)
#     Loss: 0.01040
#     Accuracy: 0.96328
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75628, Loss: 0.05059
#
# Episode: 13000/25000 to 13200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.10/s)
#     Loss: 0.00987
#     Accuracy: 0.96409
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76228, Loss: 0.04800
#
# Episode: 13200/25000 to 13400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.00/s)
#     Loss: 0.01128
#     Accuracy: 0.96241
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78103, Loss: 0.04512
#
# Episode: 13400/25000 to 13600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.26/s)
#     Loss: 0.00912
#     Accuracy: 0.96656
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77141, Loss: 0.04781
#
# Episode: 13600/25000 to 13800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.87/s)
#     Loss: 0.00764
#     Accuracy: 0.97547
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77138, Loss: 0.04860
#
# Episode: 13800/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.02/s)
#     Loss: 0.00813
#     Accuracy: 0.97253
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76744, Loss: 0.04919
#
# Episode: 14000/25000 to 14200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.90/s)
#     Loss: 0.00915
#     Accuracy: 0.96694
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76487, Loss: 0.05055
#
# Episode: 14200/25000 to 14400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.3s (17.70/s)
#     Loss: 0.01056
#     Accuracy: 0.96353
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75847, Loss: 0.04961
#
# Episode: 14400/25000 to 14600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (17.96/s)
#     Loss: 0.00887
#     Accuracy: 0.96981
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77456, Loss: 0.04576
#
# Episode: 14600/25000 to 14800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (17.97/s)
#     Loss: 0.00881
#     Accuracy: 0.97044
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77797, Loss: 0.04773
#
# Episode: 14800/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.3s (17.72/s)
#     Loss: 0.00785
#     Accuracy: 0.97256
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77566, Loss: 0.04870
#
# Episode: 15000/25000 to 15200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.85/s)
#     Loss: 0.00918
#     Accuracy: 0.96844
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76562, Loss: 0.05076
#
# Episode: 15200/25000 to 15400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.94/s)
#     Loss: 0.00834
#     Accuracy: 0.96947
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75044, Loss: 0.05285
#
# Episode: 15400/25000 to 15600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.4s (17.59/s)
#     Loss: 0.00808
#     Accuracy: 0.97003
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73963, Loss: 0.05541
#
# Episode: 15600/25000 to 15800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.09/s)
#     Loss: 0.00842
#     Accuracy: 0.97263
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75991, Loss: 0.05103
#
# Episode: 15800/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.3s (17.76/s)
#     Loss: 0.00868
#     Accuracy: 0.96966
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74272, Loss: 0.05115
#
# Episode: 16000/25000 to 16200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.12/s)
#     Loss: 0.00812
#     Accuracy: 0.97134
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73866, Loss: 0.05601
#
# Episode: 16200/25000 to 16400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.00/s)
#     Loss: 0.00864
#     Accuracy: 0.96841
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76422, Loss: 0.04820
#
# Episode: 16400/25000 to 16600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.02/s)
#     Loss: 0.00809
#     Accuracy: 0.97091
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76687, Loss: 0.05175
#
# Episode: 16600/25000 to 16800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (17.97/s)
#     Loss: 0.00736
#     Accuracy: 0.97678
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77116, Loss: 0.04763
#
# Episode: 16800/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.01/s)
#     Loss: 0.00827
#     Accuracy: 0.97053
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74653, Loss: 0.05539
#
# Episode: 17000/25000 to 17200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.05/s)
#     Loss: 0.00838
#     Accuracy: 0.97050
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74100, Loss: 0.05797
#
# Episode: 17200/25000 to 17400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.93/s)
#     Loss: 0.00821
#     Accuracy: 0.96953
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76781, Loss: 0.04836
#
# Episode: 17400/25000 to 17600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (17.94/s)
#     Loss: 0.00811
#     Accuracy: 0.97175
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74306, Loss: 0.05389
#
# Episode: 17600/25000 to 17800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.92/s)
#     Loss: 0.00799
#     Accuracy: 0.97253
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75947, Loss: 0.04962
#
# Episode: 17800/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (17.99/s)
#     Loss: 0.00757
#     Accuracy: 0.97469
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77013, Loss: 0.05432
#
# Episode: 18000/25000 to 18200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.91/s)
#     Loss: 0.00805
#     Accuracy: 0.97216
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76872, Loss: 0.04969
#
# Episode: 18200/25000 to 18400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.82/s)
#     Loss: 0.00683
#     Accuracy: 0.97731
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74725, Loss: 0.05077
#
# Episode: 18400/25000 to 18600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.06/s)
#     Loss: 0.00828
#     Accuracy: 0.97047
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77916, Loss: 0.04665
#
# Episode: 18600/25000 to 18800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.83/s)
#     Loss: 0.00772
#     Accuracy: 0.97156
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75416, Loss: 0.05257
#
# Episode: 18800/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.02/s)
#     Loss: 0.00785
#     Accuracy: 0.97266
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76366, Loss: 0.05236
#
# Episode: 19000/25000 to 19200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.79/s)
#     Loss: 0.00670
#     Accuracy: 0.97891
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76347, Loss: 0.05209
#
# Episode: 19200/25000 to 19400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (17.96/s)
#     Loss: 0.00782
#     Accuracy: 0.97278
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73153, Loss: 0.05566
#
# Episode: 19400/25000 to 19600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.07/s)
#     Loss: 0.00789
#     Accuracy: 0.97019
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74841, Loss: 0.04926
#
# Episode: 19600/25000 to 19800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.83/s)
#     Loss: 0.00710
#     Accuracy: 0.97406
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73453, Loss: 0.05132
#
# Episode: 19800/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.88/s)
#     Loss: 0.00759
#     Accuracy: 0.97238
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76381, Loss: 0.05274
#
# Episode: 20000/25000 to 20200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.07/s)
#     Loss: 0.00828
#     Accuracy: 0.97106
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76162, Loss: 0.05120
#
# Episode: 20200/25000 to 20400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (18.07/s)
#     Loss: 0.00752
#     Accuracy: 0.97313
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73494, Loss: 0.06060
#
# Episode: 20400/25000 to 20600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (17.95/s)
#     Loss: 0.00727
#     Accuracy: 0.97481
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76509, Loss: 0.04863
#
# Episode: 20600/25000 to 20800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.86/s)
#     Loss: 0.00685
#     Accuracy: 0.97575
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74494, Loss: 0.05545
#
# Episode: 20800/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.90/s)
#     Loss: 0.00791
#     Accuracy: 0.97219
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77403, Loss: 0.05031
#
# Episode: 21000/25000 to 21200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.0s (18.10/s)
#     Loss: 0.00686
#     Accuracy: 0.97569
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76900, Loss: 0.04844
#
# Episode: 21200/25000 to 21400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.91/s)
#     Loss: 0.00835
#     Accuracy: 0.96684
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75369, Loss: 0.05003
#
# Episode: 21400/25000 to 21600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.89/s)
#     Loss: 0.00675
#     Accuracy: 0.97534
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74941, Loss: 0.05327
#
# Episode: 21600/25000 to 21800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.78/s)
#     Loss: 0.00650
#     Accuracy: 0.97584
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75831, Loss: 0.04968
#
# Episode: 21800/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.93/s)
#     Loss: 0.00601
#     Accuracy: 0.97906
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74422, Loss: 0.05445
#
# Episode: 22000/25000 to 22200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.3s (17.72/s)
#     Loss: 0.00682
#     Accuracy: 0.97419
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77216, Loss: 0.05397
#
# Episode: 22200/25000 to 22400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.78/s)
#     Loss: 0.00647
#     Accuracy: 0.97844
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75972, Loss: 0.05022
#
# Episode: 22400/25000 to 22600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.92/s)
#     Loss: 0.00591
#     Accuracy: 0.97747
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73716, Loss: 0.05591
#
# Episode: 22600/25000 to 22800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.85/s)
#     Loss: 0.00679
#     Accuracy: 0.97738
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75231, Loss: 0.05281
#
# Episode: 22800/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.3s (17.77/s)
#     Loss: 0.00698
#     Accuracy: 0.97556
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73978, Loss: 0.05853
#
# Episode: 23000/25000 to 23200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.86/s)
#     Loss: 0.00675
#     Accuracy: 0.97591
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75669, Loss: 0.05860
#
# Episode: 23200/25000 to 23400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.3s (17.77/s)
#     Loss: 0.00724
#     Accuracy: 0.97256
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76319, Loss: 0.04955
#
# Episode: 23400/25000 to 23600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.3s (17.70/s)
#     Loss: 0.00676
#     Accuracy: 0.97563
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74019, Loss: 0.05516
#
# Episode: 23600/25000 to 23800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.83/s)
#     Loss: 0.00739
#     Accuracy: 0.97072
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75819, Loss: 0.05870
#
# Episode: 23800/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.91/s)
#     Loss: 0.00584
#     Accuracy: 0.97916
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72787, Loss: 0.05845
#
# Episode: 24000/25000 to 24200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.3s (17.68/s)
#     Loss: 0.00723
#     Accuracy: 0.97219
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74347, Loss: 0.05188
#
# Episode: 24200/25000 to 24400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.1s (17.96/s)
#     Loss: 0.00663
#     Accuracy: 0.97431
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74425, Loss: 0.05891
#
# Episode: 24400/25000 to 24600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.3s (17.76/s)
#     Loss: 0.00679
#     Accuracy: 0.97497
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74894, Loss: 0.06323
#
# Episode: 24600/25000 to 24800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.2s (17.88/s)
#     Loss: 0.00714
#     Accuracy: 0.97331
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75553, Loss: 0.05012
#
# Episode: 24800/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 11.3s (17.76/s)
#     Loss: 0.00593
#     Accuracy: 0.97772
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76319, Loss: 0.05154

# %% [markdown]
# Success of the training is examined by analyzing the training curve.

# %%
plot_traincurve('training/run_0', ['train_accuracy', 'eval_accuracy'], 'Accuracy')

# %% [markdown]
# ## Perform a tuning run

# %% [markdown]
# The most decisive hyperparameters present in the model are determined by a tuning process, which runs the model training several times and tries to boost the models performance by minimizing the evaluation-loss with adaptations to the hyperparameters.

# %%
tuning = optuna.create_study(direction="minimize", 
                             sampler = optuna.samplers.TPESampler(),
                             pruner = optuna.pruners.MedianPruner(n_startup_trials=5))

tuning.optimize(run_tuning, n_trials=25)

pruned_trials = tuning.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = tuning.get_trials(deepcopy=False, states=[TrialState.COMPLETE])
importances = optuna.importance.get_param_importances(tuning)

print('\n')
print('#######################################################################')
print('########################### FINISHED TUNING ###########################')
print('#######################################################################')
print('\n \n')

print('Tuning statistics: ')
print('  Number of trials: ', len(tuning.trials))
print('  Number of pruned trials: ', len(pruned_trials))
print('  Number of complete trials: ', len(complete_trials), '\n')

print('Best trial:')
trial = tuning.best_trial

print(f'  Run {str(trial.number)} with Loss {min(trial.intermediate_values.values())} at Episode {min(trial.intermediate_values, key=trial.intermediate_values.get)}')

print('  Params: ')
for key, value in trial.params.items():
  print('    {}: {}'.format(key, value))
# Out:
# [I 2022-06-02 18:18:35,371] A new study created in memory with name: no-name-2c31fd0e-a160-4f24-b9ae-ba566de13766
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_0
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.5 (4.05/s)
#     Loss: 0.09123
#     Accuracy: 0.10000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10006
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:04.0 (4.03/s)
#     Loss: 0.09000
#     Accuracy: 0.10068
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.8 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10006
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10081, Loss: 0.09000
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10031
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09947, Loss: 0.09000
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.8 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.09961
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.8 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10046
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09859, Loss: 0.09000
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.8 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.09996
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.8 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.09984
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.8 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09872, Loss: 0.09000
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10003
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.8 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.09981
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.8 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.09984
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.8 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.03/s)
#     Loss: 0.09000
#     Accuracy: 0.09994
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10009
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10004
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:04.0 (4.03/s)
#     Loss: 0.09000
#     Accuracy: 0.10020
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.8 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.09983
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10797, Loss: 0.09000
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.09988
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.09995
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.03/s)
#     Loss: 0.09000
#     Accuracy: 0.09998
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:04.1 (4.03/s)
#     Loss: 0.09000
#     Accuracy: 0.10028
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09001
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:04.1 (4.03/s)
#     Loss: 0.09000
#     Accuracy: 0.10003
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:04.0 (4.03/s)
#     Loss: 0.09000
#     Accuracy: 0.09990
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:05.0 (4.00/s)
#     Loss: 0.09000
#     Accuracy: 0.09995
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:04.5 (4.02/s)
#     Loss: 0.09000
#     Accuracy: 0.10019
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:04.3 (4.02/s)
#     Loss: 0.09000
#     Accuracy: 0.10001
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:04.1 (4.03/s)
#     Loss: 0.09000
#     Accuracy: 0.10015
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.03/s)
#     Loss: 0.09000
#     Accuracy: 0.10008
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.03/s)
#     Loss: 0.09000
#     Accuracy: 0.09999
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10006
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.03/s)
#     Loss: 0.09000
#     Accuracy: 0.09994
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10004
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10005
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.09995
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.09994
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.8 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.8 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.09993
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.03/s)
#     Loss: 0.09000
#     Accuracy: 0.10000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.8 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:04.0 (4.03/s)
#     Loss: 0.09000
#     Accuracy: 0.10001
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.03/s)
#     Loss: 0.09000
#     Accuracy: 0.10000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.10000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:04.0 (4.03/s)
#     Loss: 0.09000
#     Accuracy: 0.10000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:03.9 (4.04/s)
#     Loss: 0.09000
#     Accuracy: 0.09995
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 2:04.0 (4.03/s)
#     Loss: 0.09000
#     Accuracy: 0.10004
# [I 2022-06-02 20:22:10,793] Trial 0 finished with value: 0.08999998867511749 and parameters: {'num_fc_layers': 2, 'num_units_fc_layer0': 32, 'num_units_fc_layer1': 64, 'num_lstm_layer_encoder': 2, 'num_units_lstm_encoder': 256, 'num_lstm_layer_relationnet': 3, 'num_units_lstm_relationnet': 256, 'learning_rate': 0.0031833192952184677, 'learning_rate_schedule_rate': 500}. Best is trial 0 with value: 0.08999998867511749.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10000, Loss: 0.09000
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_1
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.77/s)
#     Loss: 0.11460
#     Accuracy: 0.10041
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10250, Loss: 0.08755
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.75/s)
#     Loss: 0.08695
#     Accuracy: 0.16452
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19406, Loss: 0.08505
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.2 (6.74/s)
#     Loss: 0.08547
#     Accuracy: 0.18296
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19684, Loss: 0.08388
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.1 (6.75/s)
#     Loss: 0.08519
#     Accuracy: 0.18388
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19956, Loss: 0.08427
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.75/s)
#     Loss: 0.08484
#     Accuracy: 0.19683
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20816, Loss: 0.08421
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.76/s)
#     Loss: 0.08448
#     Accuracy: 0.22304
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21600, Loss: 0.08435
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.77/s)
#     Loss: 0.08299
#     Accuracy: 0.26467
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.24866, Loss: 0.08308
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.76/s)
#     Loss: 0.07881
#     Accuracy: 0.33784
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31019, Loss: 0.08171
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.76/s)
#     Loss: 0.07239
#     Accuracy: 0.43412
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.35994, Loss: 0.08116
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.76/s)
#     Loss: 0.06832
#     Accuracy: 0.48515
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.36603, Loss: 0.07938
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.76/s)
#     Loss: 0.06600
#     Accuracy: 0.52153
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.40303, Loss: 0.07870
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.76/s)
#     Loss: 0.06356
#     Accuracy: 0.55964
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.41216, Loss: 0.08275
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.76/s)
#     Loss: 0.05988
#     Accuracy: 0.60704
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.44212, Loss: 0.07677
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.8 (6.77/s)
#     Loss: 0.05518
#     Accuracy: 0.66402
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.50028, Loss: 0.07205
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.76/s)
#     Loss: 0.05046
#     Accuracy: 0.70924
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.53603, Loss: 0.06967
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.76/s)
#     Loss: 0.04578
#     Accuracy: 0.74726
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.56816, Loss: 0.06557
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.76/s)
#     Loss: 0.04335
#     Accuracy: 0.77102
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.58125, Loss: 0.07056
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.1 (6.75/s)
#     Loss: 0.04101
#     Accuracy: 0.78301
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60309, Loss: 0.06592
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.76/s)
#     Loss: 0.03998
#     Accuracy: 0.79355
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60137, Loss: 0.07107
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.76/s)
#     Loss: 0.03751
#     Accuracy: 0.80890
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.61156, Loss: 0.06369
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.77/s)
#     Loss: 0.03587
#     Accuracy: 0.82046
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.59372, Loss: 0.06712
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.76/s)
#     Loss: 0.03418
#     Accuracy: 0.83630
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60959, Loss: 0.06896
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.76/s)
#     Loss: 0.03343
#     Accuracy: 0.83859
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.63600, Loss: 0.06550
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.76/s)
#     Loss: 0.03262
#     Accuracy: 0.84434
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.63497, Loss: 0.06131
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.75/s)
#     Loss: 0.03200
#     Accuracy: 0.84620
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65316, Loss: 0.05998
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.75/s)
#     Loss: 0.03044
#     Accuracy: 0.85675
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64728, Loss: 0.06449
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.1 (6.75/s)
#     Loss: 0.02861
#     Accuracy: 0.86647
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66297, Loss: 0.06794
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.75/s)
#     Loss: 0.02824
#     Accuracy: 0.86846
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66269, Loss: 0.05853
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.76/s)
#     Loss: 0.02749
#     Accuracy: 0.87930
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66234, Loss: 0.06169
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.2 (6.74/s)
#     Loss: 0.02495
#     Accuracy: 0.89387
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66200, Loss: 0.06443
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.77/s)
#     Loss: 0.02395
#     Accuracy: 0.89835
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67375, Loss: 0.05996
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.76/s)
#     Loss: 0.02420
#     Accuracy: 0.89706
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66072, Loss: 0.06788
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.76/s)
#     Loss: 0.02246
#     Accuracy: 0.90654
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68253, Loss: 0.06275
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.77/s)
#     Loss: 0.02238
#     Accuracy: 0.90524
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68853, Loss: 0.06448
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.76/s)
#     Loss: 0.02196
#     Accuracy: 0.90856
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70228, Loss: 0.05712
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.76/s)
#     Loss: 0.02152
#     Accuracy: 0.91112
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70431, Loss: 0.05963
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.76/s)
#     Loss: 0.02064
#     Accuracy: 0.91490
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69316, Loss: 0.05729
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.77/s)
#     Loss: 0.02014
#     Accuracy: 0.91812
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68806, Loss: 0.05742
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.77/s)
#     Loss: 0.01958
#     Accuracy: 0.92141
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70419, Loss: 0.06002
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.75/s)
#     Loss: 0.01845
#     Accuracy: 0.92617
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71531, Loss: 0.05932
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:13.9 (6.76/s)
#     Loss: 0.01826
#     Accuracy: 0.92655
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69556, Loss: 0.06136
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.76/s)
#     Loss: 0.01712
#     Accuracy: 0.93271
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70572, Loss: 0.06228
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.76/s)
#     Loss: 0.01717
#     Accuracy: 0.93236
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70525, Loss: 0.05983
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.76/s)
#     Loss: 0.01743
#     Accuracy: 0.93205
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70500, Loss: 0.06266
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.76/s)
#     Loss: 0.01618
#     Accuracy: 0.93710
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70347, Loss: 0.05835
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.1 (6.75/s)
#     Loss: 0.01614
#     Accuracy: 0.93844
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71009, Loss: 0.05640
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.1 (6.75/s)
#     Loss: 0.01546
#     Accuracy: 0.94092
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72356, Loss: 0.05719
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.76/s)
#     Loss: 0.01648
#     Accuracy: 0.93648
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70119, Loss: 0.06448
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.1 (6.75/s)
#     Loss: 0.01503
#     Accuracy: 0.94375
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71391, Loss: 0.05795
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:14.0 (6.75/s)
#     Loss: 0.01398
#     Accuracy: 0.94684
# [I 2022-06-02 21:37:47,111] Trial 1 finished with value: 0.05455995471216738 and parameters: {'num_fc_layers': 2, 'num_units_fc_layer0': 128, 'num_units_fc_layer1': 16, 'num_lstm_layer_encoder': 3, 'num_units_lstm_encoder': 256, 'num_lstm_layer_relationnet': 1, 'num_units_lstm_relationnet': 256, 'learning_rate': 3.7176546692949616e-05, 'learning_rate_schedule_rate': 5000}. Best is trial 1 with value: 0.05455995471216738.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72956, Loss: 0.05456
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_2
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.0s (17.87/s)
#     Loss: 0.20909
#     Accuracy: 0.10175
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10322, Loss: 0.10072
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.9s (17.93/s)
#     Loss: 0.09075
#     Accuracy: 0.10496
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10338, Loss: 0.08654
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.1s (17.81/s)
#     Loss: 0.08697
#     Accuracy: 0.10263
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10003, Loss: 0.08600
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.0s (17.88/s)
#     Loss: 0.08681
#     Accuracy: 0.10179
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09906, Loss: 0.08717
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.9s (17.91/s)
#     Loss: 0.08678
#     Accuracy: 0.10154
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09975, Loss: 0.08655
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.8s (18.00/s)
#     Loss: 0.08679
#     Accuracy: 0.10498
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.17712, Loss: 0.08613
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.9s (17.93/s)
#     Loss: 0.08663
#     Accuracy: 0.15999
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.17722, Loss: 0.08505
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.6s (17.50/s)
#     Loss: 0.08574
#     Accuracy: 0.16670
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19203, Loss: 0.08482
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.0s (17.89/s)
#     Loss: 0.08575
#     Accuracy: 0.17380
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19541, Loss: 0.08520
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.9s (17.90/s)
#     Loss: 0.08544
#     Accuracy: 0.17814
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19366, Loss: 0.08470
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.9s (17.90/s)
#     Loss: 0.08551
#     Accuracy: 0.17250
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19419, Loss: 0.08452
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.1s (17.81/s)
#     Loss: 0.08533
#     Accuracy: 0.18000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20297, Loss: 0.08410
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.0s (17.83/s)
#     Loss: 0.08483
#     Accuracy: 0.18903
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20975, Loss: 0.08381
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 29.1s (17.19/s)
#     Loss: 0.08490
#     Accuracy: 0.19374
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21163, Loss: 0.08370
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.8s (17.36/s)
#     Loss: 0.08485
#     Accuracy: 0.19906
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21322, Loss: 0.08438
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.2s (17.76/s)
#     Loss: 0.08429
#     Accuracy: 0.20480
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21325, Loss: 0.08407
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.1s (17.80/s)
#     Loss: 0.08427
#     Accuracy: 0.21114
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20800, Loss: 0.08453
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.0s (17.86/s)
#     Loss: 0.08380
#     Accuracy: 0.22922
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21863, Loss: 0.08379
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.0s (17.84/s)
#     Loss: 0.08319
#     Accuracy: 0.25662
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.23022, Loss: 0.08415
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.2s (17.74/s)
#     Loss: 0.08225
#     Accuracy: 0.28008
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.22966, Loss: 0.08446
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.2s (17.74/s)
#     Loss: 0.08152
#     Accuracy: 0.29981
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.23700, Loss: 0.08409
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.0s (17.84/s)
#     Loss: 0.08055
#     Accuracy: 0.32382
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.24384, Loss: 0.08455
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.1s (17.79/s)
#     Loss: 0.07932
#     Accuracy: 0.34406
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.25406, Loss: 0.08367
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.3s (17.66/s)
#     Loss: 0.07788
#     Accuracy: 0.37150
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.26997, Loss: 0.08366
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.2s (17.74/s)
#     Loss: 0.07564
#     Accuracy: 0.41616
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.29091, Loss: 0.08257
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.8s (17.35/s)
#     Loss: 0.07333
#     Accuracy: 0.44737
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.30156, Loss: 0.08770
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.1s (17.79/s)
#     Loss: 0.07213
#     Accuracy: 0.46716
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.31503, Loss: 0.08171
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.3s (17.68/s)
#     Loss: 0.07051
#     Accuracy: 0.49419
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.34388, Loss: 0.07980
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.4s (16.44/s)
#     Loss: 0.06854
#     Accuracy: 0.51513
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.35622, Loss: 0.08013
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.2s (17.73/s)
#     Loss: 0.06694
#     Accuracy: 0.53194
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.36506, Loss: 0.07994
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.8s (17.34/s)
#     Loss: 0.06563
#     Accuracy: 0.55474
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.39247, Loss: 0.09235
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.2s (17.73/s)
#     Loss: 0.06370
#     Accuracy: 0.57308
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.40038, Loss: 0.08003
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.1s (17.79/s)
#     Loss: 0.06270
#     Accuracy: 0.58586
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.41313, Loss: 0.07714
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.3s (17.65/s)
#     Loss: 0.06141
#     Accuracy: 0.60052
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.41900, Loss: 0.07618
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.5s (17.52/s)
#     Loss: 0.06003
#     Accuracy: 0.61742
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.43659, Loss: 0.08065
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 29.2s (17.14/s)
#     Loss: 0.05840
#     Accuracy: 0.63643
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.46469, Loss: 0.07671
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 29.8s (16.80/s)
#     Loss: 0.05759
#     Accuracy: 0.64709
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.48222, Loss: 0.07276
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 29.5s (16.93/s)
#     Loss: 0.05537
#     Accuracy: 0.66965
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.49222, Loss: 0.07089
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 29.6s (16.87/s)
#     Loss: 0.05395
#     Accuracy: 0.68244
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.51244, Loss: 0.07362
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.3s (17.65/s)
#     Loss: 0.05292
#     Accuracy: 0.69231
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.52634, Loss: 0.06940
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.5s (17.57/s)
#     Loss: 0.05127
#     Accuracy: 0.70985
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.53603, Loss: 0.06732
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 29.6s (16.91/s)
#     Loss: 0.05109
#     Accuracy: 0.71016
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.54087, Loss: 0.06860
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 29.9s (16.72/s)
#     Loss: 0.05032
#     Accuracy: 0.71390
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.55538, Loss: 0.06678
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 29.1s (17.19/s)
#     Loss: 0.04998
#     Accuracy: 0.71996
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.54800, Loss: 0.06709
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 30.1s (16.64/s)
#     Loss: 0.04931
#     Accuracy: 0.72429
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.55369, Loss: 0.06686
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.7s (17.45/s)
#     Loss: 0.04848
#     Accuracy: 0.73392
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.56791, Loss: 0.06696
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.3s (17.65/s)
#     Loss: 0.04806
#     Accuracy: 0.73302
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.56609, Loss: 0.07007
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 29.0s (17.22/s)
#     Loss: 0.04683
#     Accuracy: 0.74700
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.58397, Loss: 0.06998
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.5s (17.57/s)
#     Loss: 0.04604
#     Accuracy: 0.75074
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.58359, Loss: 0.06317
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.8s (17.36/s)
#     Loss: 0.04643
#     Accuracy: 0.74760
# [I 2022-06-02 22:08:13,821] Trial 2 finished with value: 0.06316822577267885 and parameters: {'num_fc_layers': 2, 'num_units_fc_layer0': 32, 'num_units_fc_layer1': 16, 'num_lstm_layer_encoder': 1, 'num_units_lstm_encoder': 32, 'num_lstm_layer_relationnet': 3, 'num_units_lstm_relationnet': 16, 'learning_rate': 7.73471749558484e-05, 'learning_rate_schedule_rate': 6000}. Best is trial 1 with value: 0.05455995471216738.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.58188, Loss: 0.06852
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_3
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:39.2 (5.04/s)
#     Loss: 0.11149
#     Accuracy: 0.10055
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10059, Loss: 0.08741
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:39.9 (5.00/s)
#     Loss: 0.08690
#     Accuracy: 0.17073
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20191, Loss: 0.08481
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:40.0 (5.00/s)
#     Loss: 0.08551
#     Accuracy: 0.18394
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20522, Loss: 0.08378
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:40.2 (4.99/s)
#     Loss: 0.08508
#     Accuracy: 0.19190
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19859, Loss: 0.08451
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:40.7 (4.97/s)
#     Loss: 0.08520
#     Accuracy: 0.19248
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20694, Loss: 0.08365
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:40.2 (4.99/s)
#     Loss: 0.08403
#     Accuracy: 0.24278
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.22913, Loss: 0.08382
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:40.2 (4.99/s)
#     Loss: 0.07830
#     Accuracy: 0.36431
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.27794, Loss: 0.08491
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:40.0 (5.00/s)
#     Loss: 0.07116
#     Accuracy: 0.47863
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.32631, Loss: 0.08184
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:40.1 (4.99/s)
#     Loss: 0.06739
#     Accuracy: 0.53344
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.33897, Loss: 0.08032
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:40.1 (4.99/s)
#     Loss: 0.06249
#     Accuracy: 0.59008
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.38950, Loss: 0.07906
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:40.1 (5.00/s)
#     Loss: 0.05631
#     Accuracy: 0.65678
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.45831, Loss: 0.07626
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:40.2 (4.99/s)
#     Loss: 0.05176
#     Accuracy: 0.70093
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.48831, Loss: 0.09148
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:40.1 (4.99/s)
#     Loss: 0.04949
#     Accuracy: 0.72339
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.53138, Loss: 0.06858
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:40.3 (4.98/s)
#     Loss: 0.04503
#     Accuracy: 0.76121
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.53609, Loss: 0.07574
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:40.2 (4.99/s)
#     Loss: 0.04371
#     Accuracy: 0.77326
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.58009, Loss: 0.06754
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:40.1 (4.99/s)
#     Loss: 0.04181
#     Accuracy: 0.78574
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60047, Loss: 0.06299
#
# Episode: 8000/25000 to 8500/25000
# ...
#     Loss: 0.02447
#     Accuracy: 0.89900
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72369, Loss: 0.05999
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 33.9s (14.77/s)
#     Loss: 0.02323
#     Accuracy: 0.90525
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69703, Loss: 0.06488
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.0s (14.70/s)
#     Loss: 0.02156
#     Accuracy: 0.91269
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71356, Loss: 0.06307
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.0s (14.70/s)
#     Loss: 0.02005
#     Accuracy: 0.92201
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73088, Loss: 0.05186
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.0s (14.71/s)
#     Loss: 0.01863
#     Accuracy: 0.92736
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73359, Loss: 0.05176
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.1s (14.65/s)
#     Loss: 0.01776
#     Accuracy: 0.93075
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73644, Loss: 0.05472
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.8s (14.36/s)
#     Loss: 0.01749
#     Accuracy: 0.93185
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74209, Loss: 0.05656
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 35.9s (13.94/s)
#     Loss: 0.01689
#     Accuracy: 0.93614
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74431, Loss: 0.05575
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 35.9s (13.94/s)
#     Loss: 0.01524
#     Accuracy: 0.94311
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71700, Loss: 0.05890
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 35.8s (13.95/s)
#     Loss: 0.01504
#     Accuracy: 0.94512
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71394, Loss: 0.06881
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 36.0s (13.90/s)
#     Loss: 0.01483
#     Accuracy: 0.94444
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72931, Loss: 0.05580
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 35.4s (14.11/s)
#     Loss: 0.01488
#     Accuracy: 0.94410
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73906, Loss: 0.04986
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.1s (14.68/s)
#     Loss: 0.01432
#     Accuracy: 0.94589
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75191, Loss: 0.04925
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.0s (14.70/s)
#     Loss: 0.01337
#     Accuracy: 0.94996
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73434, Loss: 0.05279
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.4s (14.55/s)
#     Loss: 0.01286
#     Accuracy: 0.95320
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70941, Loss: 0.05732
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.1s (14.66/s)
#     Loss: 0.01295
#     Accuracy: 0.95038
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74231, Loss: 0.05018
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.1s (14.68/s)
#     Loss: 0.01315
#     Accuracy: 0.95214
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73225, Loss: 0.05429
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.0s (14.70/s)
#     Loss: 0.01275
#     Accuracy: 0.95265
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74122, Loss: 0.05105
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.1s (14.68/s)
#     Loss: 0.01203
#     Accuracy: 0.95634
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76647, Loss: 0.04934
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.2s (14.64/s)
#     Loss: 0.01207
#     Accuracy: 0.95704
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71928, Loss: 0.05506
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.0s (14.70/s)
#     Loss: 0.01186
#     Accuracy: 0.95810
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74066, Loss: 0.05000
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.7s (14.43/s)
#     Loss: 0.01109
#     Accuracy: 0.96012
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71544, Loss: 0.06120
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.0s (14.69/s)
#     Loss: 0.01098
#     Accuracy: 0.96094
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73047, Loss: 0.05348
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.1s (14.64/s)
#     Loss: 0.01114
#     Accuracy: 0.96023
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73203, Loss: 0.05327
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.1s (14.67/s)
#     Loss: 0.01074
#     Accuracy: 0.96196
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75069, Loss: 0.04826
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.0s (14.69/s)
#     Loss: 0.01023
#     Accuracy: 0.96442
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73484, Loss: 0.05544
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.0s (14.70/s)
#     Loss: 0.01078
#     Accuracy: 0.96165
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71912, Loss: 0.05546
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.2s (14.64/s)
#     Loss: 0.01105
#     Accuracy: 0.95956
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72366, Loss: 0.05044
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.1s (14.68/s)
#     Loss: 0.01023
#     Accuracy: 0.96440
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74881, Loss: 0.04960
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.0s (14.68/s)
#     Loss: 0.01001
#     Accuracy: 0.96521
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73047, Loss: 0.05469
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 33.9s (14.73/s)
#     Loss: 0.00913
#     Accuracy: 0.96752
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70537, Loss: 0.06217
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.1s (14.65/s)
#     Loss: 0.00980
#     Accuracy: 0.96476
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73297, Loss: 0.05193
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 33.9s (14.74/s)
#     Loss: 0.00942
#     Accuracy: 0.96900
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73419, Loss: 0.05285
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.1s (14.65/s)
#     Loss: 0.00882
#     Accuracy: 0.96852
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72400, Loss: 0.06070
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.6s (14.44/s)
#     Loss: 0.00941
#     Accuracy: 0.96804
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74100, Loss: 0.05272
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.0s (14.70/s)
#     Loss: 0.00892
#     Accuracy: 0.96969
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73847, Loss: 0.05013
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.1s (14.68/s)
#     Loss: 0.00950
#     Accuracy: 0.96724
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74066, Loss: 0.05038
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.0s (14.69/s)
#     Loss: 0.00841
#     Accuracy: 0.97245
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72500, Loss: 0.05756
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 34.0s (14.71/s)
#     Loss: 0.00884
#     Accuracy: 0.96865
# [I 2022-06-03 03:11:14,142] Trial 19 finished with value: 0.04825589357875287 and parameters: {'num_fc_layers': 1, 'num_units_fc_layer0': 128, 'num_lstm_layer_encoder': 1, 'num_units_lstm_encoder': 16, 'num_lstm_layer_relationnet': 1, 'num_units_lstm_relationnet': 256, 'learning_rate': 0.0010206148559879368, 'learning_rate_schedule_rate': 1500}. Best is trial 13 with value: 0.045372815635055304.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70947, Loss: 0.05587
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_20
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 31.8s (15.74/s)
#     Loss: 0.10658
#     Accuracy: 0.10548
# [I 2022-06-03 03:11:55,041] Trial 20 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.16637, Loss: 0.08757
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_21
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:07.4 (7.42/s)
#     Loss: 0.12842
#     Accuracy: 0.10074
# [I 2022-06-03 03:13:19,181] Trial 21 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.10244, Loss: 0.08998
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_22
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:07.7 (7.38/s)
#     Loss: 0.09196
#     Accuracy: 0.10828
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.18769, Loss: 0.08525
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:07.9 (7.36/s)
#     Loss: 0.08502
#     Accuracy: 0.18877
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19962, Loss: 0.08427
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:07.9 (7.36/s)
#     Loss: 0.08516
#     Accuracy: 0.18643
# [I 2022-06-03 03:17:31,640] Trial 22 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19406, Loss: 0.08428
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_23
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:07.3 (7.43/s)
#     Loss: 0.09612
#     Accuracy: 0.11929
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.18019, Loss: 0.08487
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:07.5 (7.41/s)
#     Loss: 0.08550
#     Accuracy: 0.18554
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20666, Loss: 0.08453
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 1:07.8 (7.38/s)
#     Loss: 0.08520
#     Accuracy: 0.19454
# [I 2022-06-03 03:21:42,463] Trial 23 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20647, Loss: 0.08417
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_24
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 29.9s (16.70/s)
#     Loss: 0.10793
#     Accuracy: 0.10269
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09972, Loss: 0.08741
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 29.6s (16.86/s)
#     Loss: 0.08719
#     Accuracy: 0.10076
# [I 2022-06-03 03:22:58,264] Trial 24 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.09997, Loss: 0.08624
#
#
#
# #######################################################################
# ########################### FINISHED TUNING ###########################
# #######################################################################
#
#
#
# Tuning statistics:
#   Number of trials:  25
#   Number of pruned trials:  17
#   Number of complete trials:  8
#
# Best trial:
#   Run 13 with Loss 0.045372815635055304 at Episode 7000
#   Params:
#     num_fc_layers: 1
#     num_units_fc_layer0: 128
#     num_lstm_layer_encoder: 2
#     num_units_lstm_encoder: 64
#     num_lstm_layer_relationnet: 1
#     num_units_lstm_relationnet: 256
#     learning_rate: 0.0002930556959432307
#     learning_rate_schedule_rate: 2000

# %% [markdown]
# Zip and push tuning results to Google Drive.

# %%
push_zip('/content/tuning', gdrive + f'/results/tuning/{N_WAY}way-{K_SHOT}shot.zip')

with open(gdrive + f'/results/tuning/importances_{N_WAY}way-{K_SHOT}shot.pkl', 'wb') as handle:
    pickle.dump(importances, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Analyze the tuning run

# %% [markdown]
# Load and unpack tuning results from Google Drive.

# %%
os.system(f'cp -R /content/drive/MyDrive/ml_projects/STRHANGE/results/tuning/{N_WAY}way-{K_SHOT}shot.zip /content')
shutil.unpack_archive(f'{N_WAY}way-{K_SHOT}shot.zip', '/content')

with open(gdrive + f'/results/tuning/importances_{N_WAY}way-{K_SHOT}shot.pkl', 'rb') as handle:
  importances = pickle.load(handle)

# %% [markdown]
# Success of the tuning process is examined by analyzing the best values in each run and the training curves.

# %%
plot_tuning_history('tuning', 'eval_accuracy', 'Validations Accuracy', 'maximize')

# %%
plot_tuning_traincurves('tuning', 'eval_accuracy', 'Validations Accuracy', 'maximize', 15)

# %%
best_trials = tuning.trials_dataframe().nsmallest(5, 'value').transpose().drop(['number', 'datetime_start', 'datetime_complete'])

print(tabulate(best_trials, tablefmt = 'latex', headers=best_trials.columns, numalign="right", floatfmt=".2f"))
# Out:
# \begin{tabular}{llllll}
# \hline
#                                     & 13                     & 14                     & 3                      & 19                     & 1                      \\
# \hline
#  value                              & 0.045372815635055304   & 0.048080068081617355   & 0.048137924196198584   & 0.04825589357875287    & 0.05455995471216738    \\
#  duration                           & 0 days 00:43:40.541734 & 0 days 01:09:51.444624 & 0 days 01:40:31.860591 & 0 days 00:37:39.498168 & 0 days 01:15:36.315713 \\
#  params\_learning\_rate               & 0.0002930556959432307  & 0.0003167145850876967  & 2.776573392252364e-05  & 0.0010206148559879368  & 3.7176546692949616e-05 \\
#  params\_learning\_rate\_schedule\_rate & 2000                   & 2000                   & 1000                   & 1500                   & 5000                   \\
#  params\_num\_fc\_layers               & 1                      & 1                      & 1                      & 1                      & 2                      \\
#  params\_num\_lstm\_layer\_encoder      & 2                      & 2                      & 2                      & 1                      & 3                      \\
#  params\_num\_lstm\_layer\_relationnet  & 1                      & 2                      & 2                      & 1                      & 1                      \\
#  params\_num\_units\_fc\_layer0         & 128                    & 256                    & 64                     & 128                    & 128                    \\
#  params\_num\_units\_fc\_layer1         & nan                    & nan                    & nan                    & nan                    & 16.0                   \\
#  params\_num\_units\_fc\_layer2         & nan                    & nan                    & nan                    & nan                    & nan                    \\
#  params\_num\_units\_lstm\_encoder      & 64                     & 64                     & 256                    & 16                     & 256                    \\
#  params\_num\_units\_lstm\_relationnet  & 256                    & 256                    & 256                    & 256                    & 256                    \\
#  state                              & COMPLETE               & COMPLETE               & COMPLETE               & COMPLETE               & COMPLETE               \\
# \hline
# \end{tabular}

# %%
plot_traincurve('tuning/run_13', ['train_accuracy', 'eval_accuracy'], 'Accuracy')

# %%
plot_tuning_parameter_importance(importances)

# %% [markdown]
# ## Model selection

# %% [markdown]
# Select the final model (run an episode to stop) on the basis of the tuning analyses.

# %%
selected_run = 'run_13'
selected_episode = '10000'

# %% [markdown]
# # Model evaluation

# %% [markdown]
# Evaluate the model on unseen data.

# %%
conf_matrix, classification_report, accuracy = run_testing(num_testruns = 1000, samples_per_run = 32, run_dir = f'tuning/{selected_run}', episode = f'e{selected_episode}', test_classes = test_classes)

# %%
model_name = f'{N_WAY}-way_{K_SHOT}-sup'
path = os.path.join(gdrive, 'results', 'tests')

np.save(os.path.join(path, f'{model_name}_CM.npy'), conf_matrix)
classification_report.to_pickle(os.path.join(path, f'{model_name}_CR.pkl'))
np.save(os.path.join(path, f'{model_name}_ACC.npy'), accuracy)

# %% [markdown]
# Visualize Confusion Matrix

# %%
plot_conf_matrix (conf_matrix, test_classes, y_og)

# %% [markdown]
# Analyse Accuracy, Precision, Recall and F-Score.

# %%
print(f'Average Accuracy of the model on testdata {accuracy}\n')
print(f'Average Precision of the model on testdata {round(classification_report.Precision.mean(),3)}\n')
print(f'Average Recall of the model on testdata {round(classification_report.Recall.mean(),3)}\n')
print(f'Average F-Score of the model on testdata {round(classification_report.FScore.mean(),3)}\n')

print(tabulate(classification_report, tablefmt = 'latex', headers=classification_report.columns, numalign="right", floatfmt=".2f"))
# Out:
# Average Accuracy of the model on testdata 0.75715625
#
# Average Precision of the model on testdata 0.751
#
# Average Recall of the model on testdata 0.752
#
# Average F-Score of the model on testdata 0.749
#
# \begin{tabular}{lrrr}
# \hline
#                &   Precision &   Recall &   FScore \\
# \hline
#  0 (0 \& 0)     &        0.94 &     0.98 &     0.92 \\
#  3 (0 \& 3)     &        0.83 &     0.89 &     0.86 \\
#  12 (0 \& 12)   &        0.99 &     0.94 &     0.92 \\
#  13 (0 \& 13)   &        0.89 &     0.95 &     0.96 \\
#  15 (0 \& 15)   &        0.86 &     0.87 &     0.86 \\
#  19 (0 \& 19)   &        0.86 &     0.80 &     0.83 \\
#  21 (0 \& 21)   &        0.91 &     0.85 &     0.88 \\
#  24 (0 \& 24)   &        0.90 &     0.96 &     0.93 \\
#  81 (3 \& 3)    &        0.62 &     0.58 &     0.60 \\
#  90 (3 \& 12)   &        0.78 &     0.77 &     0.77 \\
#  91 (3 \& 13)   &        0.75 &     0.77 &     0.76 \\
#  93 (3 \& 15)   &        0.60 &     0.57 &     0.59 \\
#  97 (3 \& 19)   &        0.57 &     0.55 &     0.56 \\
#  99 (3 \& 21)   &        0.61 &     0.55 &     0.58 \\
#  102 (3 \& 24)  &        0.68 &     0.69 &     0.69 \\
#  315 (12 \& 3)  &        0.76 &     0.76 &     0.76 \\
#  324 (12 \& 12) &        0.88 &     0.97 &     0.93 \\
#  325 (12 \& 13) &        0.91 &     0.98 &     0.94 \\
#  327 (12 \& 15) &        0.80 &     0.78 &     0.79 \\
#  331 (12 \& 19) &        0.76 &     0.84 &     0.80 \\
#  333 (12 \& 21) &        0.78 &     0.79 &     0.78 \\
#  336 (12 \& 24) &        0.83 &     0.85 &     0.84 \\
#  341 (13 \& 3)  &        0.77 &     0.77 &     0.77 \\
#  350 (13 \& 12) &        0.90 &     0.96 &     0.93 \\
#  351 (13 \& 13) &        0.90 &     0.98 &     0.94 \\
#  353 (13 \& 15) &        0.83 &     0.87 &     0.85 \\
#  357 (13 \& 19) &        0.75 &     0.80 &     0.78 \\
#  359 (13 \& 21) &        0.86 &     0.78 &     0.81 \\
#  362 (13 \& 24) &        0.85 &     0.86 &     0.85 \\
#  393 (15 \& 3)  &        0.71 &     0.70 &     0.71 \\
#  402 (15 \& 12) &        0.83 &     0.81 &     0.82 \\
#  403 (15 \& 13) &        0.77 &     0.85 &     0.81 \\
#  405 (15 \& 15) &        0.67 &     0.70 &     0.68 \\
#  409 (15 \& 19) &        0.60 &     0.64 &     0.62 \\
#  411 (15 \& 21) &        0.66 &     0.62 &     0.64 \\
#  414 (15 \& 24) &        0.68 &     0.72 &     0.70 \\
#  497 (19 \& 3)  &        0.57 &     0.48 &     0.52 \\
#  506 (19 \& 12) &        0.76 &     0.79 &     0.78 \\
#  507 (19 \& 13) &        0.79 &     0.78 &     0.78 \\
#  509 (19 \& 15) &        0.64 &     0.53 &     0.58 \\
#  513 (19 \& 19) &        0.55 &     0.52 &     0.53 \\
#  515 (19 \& 21) &        0.67 &     0.58 &     0.62 \\
#  518 (19 \& 24) &        0.62 &     0.56 &     0.59 \\
#  549 (21 \& 3)  &        0.61 &     0.53 &     0.57 \\
#  558 (21 \& 12) &        0.79 &     0.78 &     0.78 \\
#  559 (21 \& 13) &        0.77 &     0.76 &     0.76 \\
#  561 (21 \& 15) &        0.65 &     0.58 &     0.61 \\
#  565 (21 \& 19) &        0.55 &     0.51 &     0.53 \\
#  567 (21 \& 21) &        0.70 &     0.55 &     0.62 \\
#  570 (21 \& 24) &        0.65 &     0.56 &     0.60 \\
#  627 (24 \& 3)  &        0.68 &     0.75 &     0.72 \\
#  636 (24 \& 12) &        0.84 &     0.93 &     0.88 \\
#  637 (24 \& 13) &        0.79 &     0.90 &     0.84 \\
#  639 (24 \& 15) &        0.72 &     0.74 &     0.73 \\
#  643 (24 \& 19) &        0.67 &     0.70 &     0.69 \\
#  645 (24 \& 21) &        0.73 &     0.72 &     0.73 \\
#  648 (24 \& 24) &        0.73 &     0.87 &     0.79 \\
# \hline
# \end{tabular}

# %% [markdown]
# Test the model on origial Jester-Data.

# %%
conf_matrix, classification_report, accuracy = run_testing(num_testruns = 500, samples_per_run = 32, run_dir = f'tuning/{selected_run}', episode = f'e{selected_episode}', test_classes = jester_comp_classes, split = 'jester')

# %%
print(f'Average Accuracy of the model on Jester: {accuracy}\n')
# Out:
# Average Accuracy of the model on Jester: 0.8587402

# %% [markdown]
# # Model saving

# %% [markdown]
# Save the best model to the Google Drive.

# %%
push_model_to_gdrive(f'tuning/{selected_run}', f'e{selected_episode}',f'{N_WAY}way-{K_SHOT}shot')
