# %% [markdown]
# #Environment configuration

# %% [markdown]
# Install packages.

# %%
#Don't run this code unless you really want to install the packages.
# !pip install alive-progress -q
# !pip install optuna -q
# Out:
#      |████████████████████████████████| 80 kB 8.1 MB/s
#      |████████████████████████████████| 207 kB 63.2 MB/s
#   Building wheel for grapheme (setup.py) ... done
#      |████████████████████████████████| 348 kB 17.8 MB/s
#      |████████████████████████████████| 209 kB 46.8 MB/s
#      |████████████████████████████████| 81 kB 4.0 MB/s
#      |████████████████████████████████| 78 kB 4.0 MB/s
#      |████████████████████████████████| 112 kB 50.3 MB/s
#      |████████████████████████████████| 50 kB 4.8 MB/s
#      |████████████████████████████████| 147 kB 56.2 MB/s
#   Building wheel for pyperclip (setup.py) ... done

# %% [markdown]
# Import packages.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.optim.lr_scheduler import StepLR

import optuna
from optuna.trial import TrialState

import numpy as np
import os
import math
import argparse
import random
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import itertools
import shutil

from google.colab import drive
from alive_progress import alive_bar
from tabulate import tabulate
import time

# %% [markdown]
# Mount and config GDrive & paths.

# %%
drive.mount('/content/drive')
gdrive = '/content/drive/My Drive/ml_projects/STRHANGE/'

keypoints_path = gdrive + '/data/JESTER/extracted/'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Experiment configuration

# %%
N_WAY = 5
K_SHOT = 5

# %% [markdown]
# # Set up functions and classes

# %% [markdown]
# This section contains all functions and classes that are important for the remainder of this notebook. An explanation of the functions and their parameters & outputs can be found in the function headers.

# %% [markdown]
# #### Model training

# %%
def run_training(task_param, input_param, model_param, training_param):
  """
  Training Function - performs a single model training for a set of parameters
  Args:
    task_param (dict): task-related parameters
    input_param (dict): input-related parameters
    model_param (dict): model-related parameters
    training_param (dict): training-related paramaters
  Returns:
    logging (pd.dataframe): dataframe with user configurated logging information on the training-history
  """

  ### PARAMETER UNPACKING AND INITIALIZATION ###
  print('Initializing training...\n')

  #task-parameters
  SUPPORT_NUM_PER_CLASS = task_param['support_num_per_class'] 
  QUERY_NUM_PER_CLASS = task_param['query_num_per_class']  
  NUM_CLASSES = task_param['num_classes']  

  #input-parameters
  SEQUENCE_LENGTH = input_param['sequence_length']
  FEATURE_LENGTH = input_param['feature_length'] 

  #model-parameters
  NUM_LSTM_LAYER_ENCODER = model_param['num_lstm_layer_encoder']
  NUM_UNITS_LSTM_ENCODER = model_param['num_units_lstm_encoder']
  NUM_LSTM_LAYER_RELATIONNET = model_param['num_lstm_layer_relationnet']
  NUM_UNITS_LSTM_RELATIONNET = model_param['num_units_lstm_relationnet']
  NUM_UNITS_FC_RELU = model_param['num_units_fc_relu']

  #training-parameters
  LEARNING_RATE = training_param['learning_rate']
  LEARNING_RATE_SCHEDULE_RATE = training_param['learning_rate_schedule_rate']
  NUM_TRAIN_EPISODES = training_param['num_train_episodes']
  UPDATE_AND_EVAL_RATE = training_param['update_and_eval_rate']
  NUM_EVAL_EPISODES = training_param['num_eval_episodes']
  SAVE_PATH = training_param['save_path']
  SAVE_LOGGING = training_param['save_logging']
  SAVE_ALL = training_param['save_all']
  SAVE_BEST = training_param['save_best']
  TUNING_RUN = training_param['tuning_run']
  trial = training_param['trial']

  if NUM_TRAIN_EPISODES % UPDATE_AND_EVAL_RATE != 0:
    raise ValueError(f'Invalid Parameters: UPDATE_AND_EVAL_RATE must be a multiple of NUM_TRAIN_EPISODES.')

  print('  Parameters accepted and set.')

  ### MODEL INITIALIZATION ###
  feature_encoder = LSTMEncoder(FEATURE_LENGTH, NUM_UNITS_LSTM_ENCODER, NUM_LSTM_LAYER_ENCODER).to(device)
  print('  Feature encoder intialized, initial weights set.')
  relation_network = RelationNetwork(NUM_UNITS_LSTM_ENCODER*2, NUM_UNITS_LSTM_RELATIONNET, NUM_UNITS_FC_RELU, NUM_LSTM_LAYER_RELATIONNET).to(device) 
  print('  Relation network intialized, initial weights set.')

  feature_encoder_optim = torch.optim.Adam(feature_encoder.parameters(),lr=LEARNING_RATE)
  feature_encoder_scheduler = StepLR(feature_encoder_optim,step_size=LEARNING_RATE_SCHEDULE_RATE,gamma=0.5) 

  relation_network_optim = torch.optim.Adam(relation_network.parameters(),lr=LEARNING_RATE)
  relation_network_scheduler = StepLR(relation_network_optim,step_size=LEARNING_RATE_SCHEDULE_RATE,gamma=0.5) 

  mse = nn.MSELoss().to(device)

  print('  Optimizer & Learning Rate Scheduler initalized.')

  ### SET UP LOGGING ###

  # Create logging dir for current run
  logging = []
  if SAVE_LOGGING == True or SAVE_ALL == True or SAVE_BEST == True:

    if not os.path.exists(SAVE_PATH):
      os.makedirs(SAVE_PATH)

    run = 0
    run_list = os.listdir(SAVE_PATH)

    for i in range(len(run_list)):
      try:
        run_list[i] = int(run_list[i].split('_')[1])
      except:
        next

    run_list = [num for num in run_list if isinstance(num, (int,float))]

    if run_list:
      run = int(max(run_list)) + 1
    log_dir = os.path.join(SAVE_PATH, 'run_' + str(run))

    if not os.path.exists(log_dir):
      os.makedirs(log_dir)

    #Log params to logging dir
    with open(log_dir + '/task_param.pkl', 'wb') as f:
      pickle.dump(task_param, f)

    with open(log_dir + '/input_param.pkl', 'wb') as f:
      pickle.dump(input_param, f)      

    with open(log_dir + '/model_param.pkl', 'wb') as f:
      pickle.dump(model_param, f)

    with open(log_dir + '/training_param.pkl', 'wb') as f:
      pickle.dump(training_param, f)
  
  print(f'  Created logging folder: {log_dir}')

  print('\nTraining initalized. \n\n')

  print('Start training...\n')

  ### TRAINING ###

  #loop over number of episodes
  for episode in range(int(NUM_TRAIN_EPISODES/UPDATE_AND_EVAL_RATE)):

    print(f'Episode: {episode*UPDATE_AND_EVAL_RATE}/{NUM_TRAIN_EPISODES} to {(episode + 1) * UPDATE_AND_EVAL_RATE}/{NUM_TRAIN_EPISODES}')

    step_train_accuracy = 0
    step_train_loss = 0

    with alive_bar(UPDATE_AND_EVAL_RATE, title=f'  Training...', force_tty = True) as bar:
      for i in range(UPDATE_AND_EVAL_RATE):
        # Generate task and get data
        query_x, query_y, support_x, support_y = gen_task(n_way = NUM_CLASSES, n_support = SUPPORT_NUM_PER_CLASS, n_query = QUERY_NUM_PER_CLASS, data_x = X, data_y = y, split = 'train')
        query_x, query_y, support_x, support_y = query_x.to(device), query_y.to(device), support_x.to(device), support_y.to(device)
          
        # Predict
        relations, query_y_one_hot = predict(feature_encoder, relation_network, support_x, query_x, query_y, NUM_CLASSES, SUPPORT_NUM_PER_CLASS, QUERY_NUM_PER_CLASS, SEQUENCE_LENGTH, NUM_UNITS_LSTM_ENCODER)

        # Calculate loss         
        loss = mse(relations,query_y_one_hot)
        step_train_loss += loss.item()

        # Calculate accuracy 
        _,predict_labels = torch.max(relations.data,1)
        rewards = [1 if predict_labels[j]==query_y[j] else 0 for j in range(NUM_CLASSES*QUERY_NUM_PER_CLASS)]
        accuracy = np.sum(rewards)/1.0/NUM_CLASSES/QUERY_NUM_PER_CLASS
        step_train_accuracy += accuracy

        #backpropagation - adjust the model's parameter
        feature_encoder.zero_grad()
        relation_network.zero_grad()

        loss.backward()

        torch.nn.utils.clip_grad_norm_(feature_encoder.parameters(),0.5)
        torch.nn.utils.clip_grad_norm_(relation_network.parameters(),0.5)

        feature_encoder_optim.step()
        relation_network_optim.step()

        #update status bar
        bar()

    # print loss and acc for episode
    step_train_loss = step_train_loss/UPDATE_AND_EVAL_RATE
    step_train_accuracy = step_train_accuracy/UPDATE_AND_EVAL_RATE

    print(f'    Loss: {step_train_loss:.5f}')
    print(f'    Accuracy: {step_train_accuracy:.5f}')

    # start validation
    with torch.no_grad():

      step_eval_loss = 0
      step_eval_accuracy = 0
      best_eval_accuracy = 0

      for i in range(NUM_EVAL_EPISODES):

        # Generate task and get data
        query_x, query_y, support_x, support_y = gen_task(n_way = NUM_CLASSES, n_support = SUPPORT_NUM_PER_CLASS, n_query = QUERY_NUM_PER_CLASS, data_x = X, data_y = y, split = 'eval')
        query_x, query_y, support_x, support_y = query_x.to(device), query_y.to(device), support_x.to(device), support_y.to(device)

        # Predict
        relations, query_y_one_hot = predict(feature_encoder, relation_network, support_x, query_x, query_y, NUM_CLASSES, SUPPORT_NUM_PER_CLASS, QUERY_NUM_PER_CLASS, SEQUENCE_LENGTH, NUM_UNITS_LSTM_ENCODER)

        # Calculate loss             
        loss = mse(relations,query_y_one_hot)
        step_eval_loss += loss.item()

        # Calculate rewards for accuracy 
        _,predict_labels = torch.max(relations.data,1)
        rewards = [1 if predict_labels[j]==query_y[j] else 0 for j in range(NUM_CLASSES*QUERY_NUM_PER_CLASS)]
        step_eval_accuracy += np.sum(rewards)

      # Calculate and print loss / acc for validation-run
      step_eval_loss = step_eval_loss / NUM_EVAL_EPISODES
      step_eval_accuracy = step_eval_accuracy/1.0/NUM_CLASSES/QUERY_NUM_PER_CLASS/NUM_EVAL_EPISODES

      logging.append([step_train_loss, step_train_accuracy, step_eval_loss, step_eval_accuracy])

      print(f'  Validation with {NUM_EVAL_EPISODES} Evaluation-Episodes. Accuracy: {step_eval_accuracy:.5f}, Loss: {step_eval_loss:.5f}\n' )

      # Report results to optuna-tuning
      if TUNING_RUN == True:
        trial.report(step_eval_loss, episode * UPDATE_AND_EVAL_RATE)

        # Prune trial and save logging if loss-decrease is not promising
        if trial.should_prune():
          if SAVE_LOGGING == True:
            logging = pd.DataFrame(logging, columns=['train_loss', 'train_accuracy', 'eval_loss', 'eval_accuracy'])
            logging.eval_loss.iloc[0] = logging.train_loss.iloc[0]
            logging.eval_accuracy.iloc[0] = logging.train_accuracy.iloc[0]
            logging.to_pickle(log_dir + '/logging.pkl')
          raise optuna.exceptions.TrialPruned()

      # Save network 
      if (SAVE_BEST == True or SAVE_ALL == True) and not os.path.exists(os.path.join(log_dir, 'models')):
        os.makedirs(os.path.join(log_dir, 'models'))

      if SAVE_BEST == True and step_eval_accuracy > best_eval_accuracy:
        torch.save(feature_encoder.state_dict(),str(log_dir + '/models/feature_encoder_best.pkl'))
        torch.save(relation_network.state_dict(),str(log_dir + '/models/relation_network_best.pkl'))

      if SAVE_ALL == True:
        torch.save(feature_encoder.state_dict(),str(log_dir + '/models/feature_encoder_e' + str(episode*UPDATE_AND_EVAL_RATE) + '.pkl'))
        torch.save(relation_network.state_dict(),str(log_dir + '/models/relation_network_e' + str(episode*UPDATE_AND_EVAL_RATE) + '.pkl'))

  # Save logging
  if SAVE_LOGGING == True:
    logging = pd.DataFrame(logging, columns=['train_loss', 'train_accuracy', 'eval_loss', 'eval_accuracy'])
    logging.eval_loss.iloc[0] = logging.train_loss.iloc[0]
    logging.eval_accuracy.iloc[0] = logging.train_accuracy.iloc[0]

    logging.to_pickle(log_dir + '/logging.pkl')

  return logging

# %% [markdown]
# #### Hyperparameter tuning

# %%
def run_tuning(trial):
  """
  Tuning Function - performs multiple model trainings and optimizes hyperparameters
  Args:
    trial (optunia-trial-object): current trial object of the optuna tuning process
  Returns:
    min_eval_loss (float): minimal loss on evaluation set
  """

  # Caution: some parameters have to be set manually to match the given task, input and training specifications
  # (this has to be done within this function, because optuna does not support additional args)

  # Set tuning parameters  
  task_param = {'support_num_per_class': K_SHOT,
                'query_num_per_class': 16,
                'num_classes': N_WAY}

  # Set input parameters  
  input_param = {'sequence_length': 72,
                 'feature_length': 63}

  # Set model parameters (suggestions by optuna)
  num_fc_layers = trial.suggest_int("num_fc_layers", 1, 3, step = 1)
  num_units_fc_relu = []
  for i in range(num_fc_layers):
    num_units = trial.suggest_categorical("num_units_fc_layer{}".format(i), [16, 32, 64, 128, 256])
    num_units_fc_relu.append(num_units)

  model_param = {'num_lstm_layer_encoder': trial.suggest_int("num_lstm_layer_encoder", 1, 3, step=1),
                 'num_units_lstm_encoder': trial.suggest_categorical("num_units_lstm_encoder", [16, 32, 64, 128, 256]),
                 'num_lstm_layer_relationnet': trial.suggest_int("num_lstm_layer_relationnet", 1, 3, step=1),
                 'num_units_lstm_relationnet': trial.suggest_categorical("num_units_lstm_relationnet", [16, 32, 64, 128, 256]),
                 'num_units_fc_relu': num_units_fc_relu}

  # Set training parameters
  training_param = {'learning_rate': trial.suggest_float("learning_rate", 0.00001, 0.01,  log=True),
                    'learning_rate_schedule_rate': trial.suggest_int("learning_rate_schedule_rate", 500, 10000, step = 500),
                    'num_train_episodes': 25000,
                    'update_and_eval_rate': 500,
                    'num_eval_episodes': 200,
                    'save_path': 'tuning',
                    'save_logging': True,
                    'save_all': True,
                    'save_best': True,
                    'tuning_run': True,
                    'trial': trial}

  # run training with parameters of this trial
  logs = run_training(task_param, input_param, model_param, training_param)

  # report minimal evaluation loss to optuna
  min_eval_loss = logs.eval_loss.min()
  return min_eval_loss

# %% [markdown]
# #### Unique tasks calculator

# %%
def get_classcombinations(classes, num_in_comb):
  """
  Generates a set of unique tasks for a given list of classes and a number different of classes in each task
  Args:
    classes (list): list of classes
    num_in_comb (int): number different of classes in each task
  Returns:
    unique_tasks (set): set of unique tasks
  """

  unique_tasks = set(itertools.combinations(classes, num_in_comb))
  return unique_tasks

# %% [markdown]
# #### Task generator

# %%
def gen_task(n_way, n_support, n_query, data_x, data_y, split):
  """
  Generates a task (classify n-query gestures of n_way classes with n_support suppoting samples) for the few shot model.
  Args:
    n_way (int): number of classes
    n_support (int): number of support samples in each class
    n_query (int): batch size of query samples 
    data_x (np.array): hand keypoints (usually X)
    data_y (np.array): labels (usually y)
    split (str): type of split (train, evel, test or jester)
  Returns:
    query_x (torch tensor): query set data
    query_y (torch tensor): query set labels
    support_x (torch tensor): support set data
    support_y (torch tensor): support set labels 
    (classes (np.array)): list of original classes 
  """

  #sample random classes from the predfined list of classes, depended of the split-type
  query_x, query_y, support_x, support_y = [], [], [], []
  if split == 'train':
    classes = np.random.choice(training_classes, n_way, replace=False)
  elif split == 'eval':
    classes = np.random.choice(eval_classes, n_way, replace=False) 
  elif split == 'test':
    classes = np.random.choice(test_classes, n_way, replace=False) 
  elif split == 'jester':
    classes = np.random.choice(jester_comp_classes, n_way, replace=False) 

  #loop over classes of this task, sample X data and generate labels (always 0 to n-classes)
  for i, c in enumerate(classes):
    data_x_c = data_x[data_y == c]

    query_x.append(data_x_c[np.random.choice(data_x_c.shape[0], n_query, replace=False), :, :])
    query_y.append([i] * n_query)

    support_x.append(data_x_c[np.random.choice(data_x_c.shape[0], n_support, replace=False), :, :])
    support_y.append([i] * n_support)

  #reshape Data
  query_x = np.reshape(query_x, (n_way * n_query, np.array(query_x).shape[2], np.array(query_x).shape[3]))
  query_y = np.reshape(query_y, n_way * n_query)
  support_x = np.reshape(support_x, (n_way * n_support, np.array(support_x).shape[2], np.array(support_x).shape[3]))
  support_y = np.reshape(support_y, n_way * n_support)

  #change to torch tensors
  query_x = torch.from_numpy(query_x).float()
  query_y = torch.from_numpy(query_y).float().type(torch.LongTensor) 
  support_x = torch.from_numpy(support_x).float()
  support_y = torch.from_numpy(support_y).float().type(torch.LongTensor) 

  #Return statements
  if split == 'train' or split == 'eval':   
    return query_x, query_y, support_x, support_y
  elif split == 'test' or split == 'jester':
    return query_x, query_y, support_x, support_y, classes

# %% [markdown]
# #### Model components

# %%
class LSTMEncoder(nn.Module):
  """First part of the model, which encodes the sequence of hand gesture keypoints"""
  def __init__(self, input_size, hidden_lstm_size, num_lstm_layer):
    """
    Object initialization.
    Args:
      input_size (int): size of the input data
      hidden_lstm_size (int): number of units in lstm-cell
      num_lstm_layer (int): number of stacked lstm-layers
    """
    super(LSTMEncoder, self).__init__()
    self.input_size = input_size 
    self.hidden_lstm_size = hidden_lstm_size 
    self.num_lstm_layer = num_lstm_layer

    #create lstm layer(s)
    self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_lstm_size, num_layers = num_lstm_layer, batch_first=True)

  def forward(self,x):
    """
    Forward pass through the LSTM Encoder
    Args:
      x (torch tensor): data input (sequence of hand keypoints as batch)
    Return:
      out (torch tensor): encoded data (encoded sequence of hand keypoints as batch) with size batch, sequence, hidden_size
    """

    #create zeros with size num_layer, sequences, hidden_size 
    #h0 containing the final hidden state for each element in the sequence
    h0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device)  
    #c0 containing the final cell state for each element in the sequence
    c0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device) 

    #pass data through the lstm layer(s)
    out, _ = self.lstm(x, (h0,c0))
    return out 


class RelationNetwork(nn.Module):
  """Second part of the model, which calculates the relation-scores, given the concatenated query and support samples"""
  def __init__(self,input_size, hidden_lstm_size, fc_sizes: list, num_lstm_layer):
    """
    Object initialization.
    Args:
      input_size (int): size of the input data
      hidden_lstm_size (int): number of units in lstm-cell
      fc_sizes (list): number of units per fully connected / linear layer
      num_lstm_layer (int): number of stacked lstm-layers
    """
    super(RelationNetwork, self).__init__()
    self.input_size = input_size 
    self.hidden_lstm_size = hidden_lstm_size
    self.layers = nn.ModuleList()
    self.num_lstm_layer = num_lstm_layer

    #create lstm layer(s)
    self.lstm = nn.LSTM(input_size = input_size, hidden_size = hidden_lstm_size, num_layers = num_lstm_layer, batch_first=True)
    #next input_size is outputsize of the lstm layer (hidden_lstm_size)
    input_size = hidden_lstm_size

    #loop over fc_sizes, create linear layer + ReLU Activation and adjust the input_size
    for size in fc_sizes:
      self.layers.append(nn.Linear(input_size, size))
      self.layers.append(nn.ReLU())
      input_size = size  
 
    #add a final Linear Layer which reduces the input down to a single number, aka. the relation score, by applieing a sigmoid function
    self.end_layer = nn.Sequential(nn.Linear(input_size,1), nn.Sigmoid())
    
  def forward(self,x):
    """
    Forward pass through the Relation Network
    Args:
      x (torch tensor): concatenated data input of query- and support-samples 
    Return:
      out (torch tensor): relation scores
    """
    
    #create zeros with size num_layer, sequences, hidden_size 
    #h0 containing the final hidden state for each element in the sequence 
    h0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device) 
    #c0 containing the final cell state for each element in the sequence
    c0 = torch.zeros(self.num_lstm_layer, x.size(0), self.hidden_lstm_size).to(device) 

    #pass data through the lstm layer(s)
    out, _ = self.lstm(x, (h0,c0))
    #reduce output to the last sequence-state 
    out = out[:, -1, :]

    #pass data through the fc layer(s)
    for layer in self.layers:
      out = layer(out)
    
    #pass data through the final layer to calculate the relation score
    out = self.end_layer(out) 
    return out

# %% [markdown]
# #### Prediction performer

# %%
def predict(feature_encoder, relation_network, support_x, query_x, query_y, num_classes, support_num_per_class, query_num_per_class, seq_length, num_units_lstm_encoder):
  """
  Prediction-Function 
  Args:
    feature_encoder (LSTMEncoder-object): initialized LSTMEncoder-object
    relation_network (RelationNetwork-object): initialized RelationNetwork-object
    support_x (torch tensor): data for support set
    support_y (torch tensor): labels for support set
    query_x (torch tensor): data for query set
    query_y (torch tensor): labels for query set
    num_classes (int): number of classes in the given task
    support_num_per_class (int): number of support samples per class in support set
    query_num_per_class (int): number of query samples per class in query set
    seq_length (int): length of sequence
    num_units_lstm_encoder (int): number of hidden units in the LSTM-Cells of the feature_encoder
  Returns:
    relations (torch tensor): relation scores 
    query_y_one_hot (torch tensor): predicted classes as one-hot-encoded vector
  """
  # calculate support features by passing the support set through the feature_encoder-module 
  support_features = feature_encoder(Variable(support_x).to(device))
  # calculate query features by passing the query set through the feature_encoder-module 
  query_features = feature_encoder(Variable(query_x).to(device))
          
  #Prepare encoded query and support set for relations calculation (reshaping, transposing)
  support_features = support_features.view(num_classes, support_num_per_class, seq_length, num_units_lstm_encoder)
  support_features = torch.sum(support_features, 1).squeeze(1)
  support_features_ext = support_features.unsqueeze(0).repeat(query_num_per_class*num_classes,1,1,1).to(device)
  query_features_ext = query_features.unsqueeze(0).repeat(num_classes,1,1,1)
  query_features_ext = torch.transpose(query_features_ext,0,1).to(device)

  # concatenated encoded query & support set
  relation_pairs = torch.cat((support_features_ext,query_features_ext),3).view(-1,seq_length, num_units_lstm_encoder*2).to(device)

  # calculate relations by passing the concatenated query & support set through the relation_network-module 
  relations = relation_network(relation_pairs).view(-1,num_classes).to(device)

  # turn relation-scores into one hot encoded predictions 
  query_y_one_hot = Variable(torch.zeros(query_num_per_class*num_classes, num_classes).to(device).scatter_(1, query_y.view(-1,1), 1)).to(device)

  return relations, query_y_one_hot

# %% [markdown]
# #### Logging loader

# %%
def load_logging_and_params_from_file(log_dir):
  """
  Loads the logging and parameters of a single training-run from a given directory
  Args:
    log_dir (str): location of logs and parameters of a single run
  Returns:
    logging (pd.dataframe: logging of the given run
    task_param (dict): task-related parameters of the given run
    input_param (dict): input-related parameters of the given run
    model_param (dict): model-related parameters of the given run
    training_param (dict): training-related paramaters of the given run
  """

  #check is given log_dir exist
  if os.path.isfile(os.path.join(log_dir,'logging.pkl')):
    #load logging and param-dirs
    logging = pd.read_pickle(os.path.join(log_dir, 'logging.pkl'))

    with open(os.path.join(log_dir, 'task_param.pkl'), 'rb') as f:
      task_param = pickle.load(f)

    with open(os.path.join(log_dir, 'input_param.pkl'), 'rb') as f:
      input_param = pickle.load(f)      

    with open(os.path.join(log_dir, 'model_param.pkl'), 'rb') as f:
      model_param = pickle.load(f)

    with open(os.path.join(log_dir, 'training_param.pkl'), 'rb') as f:
      training_param = pickle.load(f)

    #return logging and param-dirs
    return logging, task_param, input_param, model_param, training_param
  
  else:
    print(f'No logging found in {log_dir}')

# %% [markdown]
# #### Training-Curve visualization

# %%
def plot_traincurve(log_dir, metrics, ylabel):
  """
  Plots the training curve of a single train-run
  Args:
    log_dir (str): location of the training run
    metrics (list): metrics to be plotted 
    ylabel (str): label to be plotted on the y-axis
  """

  #Load logging from log_dir
  logging, _, _, _, training_param = load_logging_and_params_from_file(log_dir)

  plt.figure(figsize=(10, 5), dpi=100)
  colors = ['#00406C', '#1ABEA3'] 
  i = 0

  #Loop over metrics and visualize it as a line
  for col in metrics:
    plot_data = logging[col].dropna()
    plt.plot(plot_data.index.values * training_param['update_and_eval_rate'], plot_data.values, label=col, color = colors[i])
    i += 1

  l=plt.legend()
  l.get_texts()[0].set_text('Trainingsdaten')
  l.get_texts()[1].set_text('Validationsdaten')

  #plt.title('Learning Curve')
  plt.xlabel('Episode')
  plt.ylabel(ylabel)
  plt.ylim(0, 1)
  #plt.figlegend(bbox_to_anchor=(0.85,0.5), loc="center left")
  plt.tight_layout(rect=[0,0,0.85,1])

  plt.show()

# %% [markdown]
# #### Tuning-History visualization

# %%
def plot_tuning_history(tuning_dir, metric, y_label, direction):
  """
  Plots the training curves of all training-runs in a tuning dir 
  Args:
    tuning_dir (str): location of the tuning run
    metric (list): metrics to be plotted 
    y_label (str): label to be displayed on the y-axis
    direction (str): maximize or minimize
  """

  # Gather the data from every training-run in the tuning_dir
  tuning_metrics = []
  runs = []
  if os.path.isdir(tuning_dir):
    run_dirs = os.listdir(tuning_dir)

    def extract_nums (elem):
      return int(elem.split('_')[1])
    
    run_dirs.sort(key = extract_nums)

    for i in range(len(run_dirs)):
      if 'run' in run_dirs[i]:
        logging, _, _, _, training_param = load_logging_and_params_from_file(os.path.join(tuning_dir, run_dirs[i]))
        logging = logging[metric]
        tuning_metrics.append(list(logging))
        runs.append(run_dirs[i])  

    max_length = len(max(tuning_metrics, key=len))

    if direction == 'maximize':
      none_marker = 0
    elif direction == 'minimize':
      none_marker = 99
    else:
      return 'invalid direction'

    for i, log in enumerate(tuning_metrics):
      tuning_metrics[i] = (log + max_length * [none_marker])[:max_length]

    tuning_metrics = np.array(tuning_metrics).transpose()
    tuning_logs = pd.DataFrame(tuning_metrics, columns = runs)
    
  else:
    print('tuning_dir does not exist.')

# Check for pruned runs and when a run hits a new best-score
  pruned = []
  new_best = []
  
  if direction == 'maximize':
    best = 0

    for col in tuning_logs:
      if tuning_logs[col].max() > best:
        best = tuning_logs[col].max()
        new_best.append('#E76450')
      else:
        new_best.append('#FFC35E')

      if tuning_logs[col].min() == 0:
        pruned.append('x')
      else:
        pruned.append('o')

      data = tuning_logs.max()
     
  elif direction == 'minimize':
    best = 1
    for col in tuning_logs:
      if tuning_logs[col].min() < best:
        best = tuning_logs[col].min()
        new_best.append('#00406E')
      else:
        new_best.append('#17BEA3')

      if tuning_logs[col].max() == 99:
        pruned.append('x')
      else:
        pruned.append('o')

      data = tuning_logs.min()

  # Visualize history

  plt.figure(figsize=(10, 5), dpi=100)
  plt.plot(data, linestyle = 'dashed', color = '#C8D4D7')

  for i in range(len(data)):
    plt.plot(i, data[i], marker = pruned[i], markersize = 8, color = new_best[i])

  #plt.title('Tuning Entwicklung')
  plt.xlabel('Trainingsläufe')
  plt.xticks(rotation=45, horizontalalignment='center')
  plt.ylabel(y_label)
  plt.ylim(0, 1)

  plt.show()

# %% [markdown]
# #### Tuning-Traincurves visualization

# %%
def plot_tuning_traincurves(tuning_dir, metric, y_label, direction = None, top_n = None):
  """
  Plots the training curves of all training-runs in a tuning dir 
  Args:
    tuning_dir (str): location of the tuning run
    metric (list): metrics to be plotted 
    y_label (str): label to be displayed on the y-axis
    direction (str): maximize or minimize
    top (int): visualize top_n results, either highest or lowest, dependend on arg 'direction'
  """

  # Gather the data from every training-run in the tuning_dir
  tuning_metrics = []
  runs = []
  if os.path.isdir(tuning_dir):
    run_dirs = os.listdir(tuning_dir)

    def extract_nums (elem):
      return int(elem.split('_')[1])
    
    run_dirs.sort(key = extract_nums)

    for i in range(len(run_dirs)):
      if 'run' in run_dirs[i]:
        logging, _, _, _, training_param = load_logging_and_params_from_file(os.path.join(tuning_dir, run_dirs[i]))
        logging = logging[metric]
        tuning_metrics.append(list(logging))
        runs.append(run_dirs[i])  

    max_length = len(max(tuning_metrics, key=len))

    for i, log in enumerate(tuning_metrics):
      tuning_metrics[i] = (log + max_length * [0])[:max_length]

    tuning_metrics = np.array(tuning_metrics).transpose()
    tuning_logs = pd.DataFrame(tuning_metrics, columns = runs)
    
  else:
    print('tuning_dir does not exist.')

  # Filter to visualize only the top_n results

  if direction != None and top_n != None:
    if direction == 'maximize':
      tuning_logs = tuning_logs[tuning_logs.max().nlargest(top_n).index]
    elif direction == 'minimize':
      tuning_logs = tuning_logs[tuning_logs.min().nsmallest(top_n).index]
    else: 
      return 'invalid direction'


  # Visualize results
  plt.figure(figsize=(10, 5), dpi=100)
  for col in list(tuning_logs.columns.values):
    plot_data = tuning_logs[col].dropna()
    plt.plot(plot_data.index.values * training_param['update_and_eval_rate'], plot_data.values, label=col)

  #plt.title('Lernkurve')
  plt.xlabel('Episode')
  plt.ylabel(y_label)

  plt.figlegend(bbox_to_anchor=(0.85,0.5), loc="center left")
  plt.tight_layout(rect=[0,0,0.85,1])
  plt.ylim(0, 1)

  plt.show()

# %% [markdown]
# #### Tuning parameter's importance visualization

# %%
def plot_tuning_parameter_importance(importances):
  """
  Visualizes the importances of every parameter in a tuning run
  Args:
    importances (OrderedDict): importances of the tuning parameters
  """

  # create positions needed for horizontal plot
  y_pos = np.arange(start = len(importances.keys()), stop = 0, step = -1)

  # create plot
  plt.figure(figsize=(10, 5), dpi=100)
  plt.barh(y_pos, importances.values(), color = '#17BEA3')

  i = 0
  for v in reversed(importances.values()):
    plt.text(v + 0.003, i + 0.9, str(round(v, 3)), color = '#00406E')
    i += 1

  # adjust labels and axis
  plt.yticks(y_pos, labels=importances.keys())
  plt.title('')
  plt.xlabel('Relevanz für den Erfolg des Tunings')
  plt.ylabel('Tuning Parameter')
  plt.xlim(0, round(max(importances.values()) * 1.2, 1))
  plt.tight_layout()

  plt.show()

# %% [markdown]
# #### Zip and push to Google Drive

# %%
def push_zip(source, destination):
  """
  Zip and push a directory to the Google Drive
  Args:
    source (str): current location 
    destination (str): target location 
  """
  base = os.path.basename(destination)
  name = base.split('.')[0]
  format = base.split('.')[1]
  archive_from = os.path.dirname(source)
  archive_to = os.path.basename(source.strip(os.sep))
  shutil.make_archive(name, format, archive_from, archive_to)
  shutil.move('%s.%s'%(name,format), destination)

# %% [markdown]
# #### Model saving

# %%
def push_model_to_gdrive(run_dir, episode, model_name):
  """
  Push a model & the params needed for deployment, located in a local directory, to the Google Drive
  Args:
    run_dir (str): location of the model
    episode (list): episode of the model, either a number or 'best'
    model_name (str): model's name in the Google Drive
  """

  #config target_path
  path = os.path.join(gdrive, 'results', 'models')

  #load model and params
  feature_encoder, relation_network = load_model_from_file(run_dir, episode)
  _, task_param, input_param, model_param, _ = load_logging_and_params_from_file(run_dir)

  #unpack params needed for deployment
  deployment_param = {'support_num_per_class': task_param['support_num_per_class'],
                      'num_classes': task_param['num_classes'],
                      'sequence_length': input_param['sequence_length'],
                      'feature_length': input_param['feature_length'],
                      'num_lstm_layer_encoder': model_param['num_lstm_layer_encoder'],
                      'num_units_lstm_encoder': model_param['num_units_lstm_encoder'],
                      'num_lstm_layer_relationnet': model_param['num_lstm_layer_relationnet'],
                      'num_units_lstm_relationnet': model_param['num_units_lstm_relationnet'],
                      'num_units_fc_relu': model_param['num_units_fc_relu']}

  # Push to Google Drive
  torch.save(feature_encoder.state_dict(),str(os.path.join(path, f'{model_name}_feature_encoder.pkl')))
  torch.save(relation_network.state_dict(),str(os.path.join(path, f'{model_name}_relation_network.pkl')))
  with open(os.path.join(path, f'{model_name}_deployment_param.pkl'), 'wb') as f:
      pickle.dump(deployment_param, f)

# %% [markdown]
# #### Model loading

# %%
def load_model_from_file(run_dir, episode):
  """
  Loads and initializes a model from a given directory
  Args:
    run_dir (str): location of the model
    episode (list): episode of the model, either a number or 'best'
  Returns:
    feature_encoder (LSTMEncoder-object): initialized LSTMEncoder-object
    relation_network (RelationNetwork-object): initialized RelationNetwork-object
  """

  #load params needed for deployment
  _, _, input_param, model_param, _ = load_logging_and_params_from_file(run_dir)

  #initialize feature_encoder and relation_network
  feature_encoder = LSTMEncoder(input_param['feature_length'], model_param['num_units_lstm_encoder'], model_param['num_lstm_layer_encoder']).to(device)
  relation_network = RelationNetwork(model_param['num_units_lstm_encoder']*2, model_param['num_units_lstm_relationnet'], model_param['num_units_fc_relu'], model_param['num_lstm_layer_relationnet']).to(device) 

  #load weights from directory
  feature_encoder.load_state_dict(torch.load(os.path.join(run_dir, 'models', str('feature_encoder_' + episode + '.pkl'))))
  relation_network.load_state_dict(torch.load(os.path.join(run_dir, 'models', str('relation_network_' + episode + '.pkl'))))

  return feature_encoder, relation_network

# %% [markdown]
# #### Model testing

# %%
def run_testing(num_testruns, samples_per_run, run_dir, episode, test_classes, split):
  """
  Testing Function - performs model testing on test-classes
  Args:
    num_testruns (int): number of test-runs to be performed, each test-run == one task
    samples_per_run (int): number of samples to be drawn as a query set
    run_dir (str): location of the model to be tested
    episode (str): episode of the model to be tests, either a number or 'best'
    test_classes (list): list of test classes
    split (str): split for task_gen
  Returns:
    conf_matrix (np.array): summarized confusion matrix of the test-runs
    classification_report (pd.dataframe): summarized classification report of the test-runs
    accuracy (float): summarized accuracy of the test-runs
  """

  # load and initialize model from dir
  feature_encoder, relation_network = load_model_from_file(run_dir, episode)
  _, task_param, input_param, model_param, training_param = load_logging_and_params_from_file(run_dir)

  # initi empty conf_matrix
  conf_matrix = np.zeros(shape = (len(test_classes),len(test_classes)), dtype = int)

  # loop over num_testruns
  for testrun in range(num_testruns):
    # generate a task with query and support sets
    query_x, query_y, support_x, support_y, tested_classes = gen_task(n_way = task_param['num_classes'], n_support = task_param['support_num_per_class'], 
                                                                      n_query = samples_per_run, data_x = X, data_y = y, split = split)
    query_x, query_y, support_x, support_y = query_x.to(device), query_y.to(device), support_x.to(device), support_y.to(device)

    # perform prediction on query and support set
    relations, query_y_one_hot = predict(feature_encoder, relation_network, support_x, query_x, query_y, 
                                        task_param['num_classes'], task_param['support_num_per_class'], 
                                        samples_per_run, input_param['sequence_length'], model_param['num_units_lstm_encoder'])
    _,predict_labels = torch.max(relations.data,1)

    # analyse prediction and adjust conf matrix
    for i in range(len(query_y)):
      cm_index_true = test_classes.index(tested_classes[predict_labels[i].item()])
      cm_index_pred = test_classes.index(tested_classes[query_y[i].item()])

      conf_matrix[cm_index_true][cm_index_pred] += 1

  # Calculate recall, precison and f_score based on conf matrix
  recalls = []
  precisions = []
  f_scores = []

  for i in range(len(test_classes)):
    recalls.append(conf_matrix[i][i] / conf_matrix[:,i].sum())
    precisions.append(conf_matrix[i][i] / conf_matrix[i,:].sum())
    f_scores.append(2 * (precisions[i] * recalls[i]) / (precisions[i] + recalls[i]))

  # Calculate accuracy based on conf matrix
  accuracy = conf_matrix.diagonal().sum() / conf_matrix.sum()

  # save and return metrics
  classification_report = pd.DataFrame((precisions, recalls, f_scores)).transpose()
  classification_report.index = [f'{str(x)} ({str(y_og[x][0])} & {str(y_og[x][1])})' for x in test_classes]
  classification_report.index.names = ['Class']
  classification_report.rename(columns = {0: 'Precision', 1: 'Recall', 2: 'FScore'}, inplace = True)
  
  return conf_matrix, classification_report, accuracy

# %% [markdown]
# #### Confusion matrix visualization

# %%
def plot_conf_matrix (conf_matrix, test_classes, y_og):
  """
  Visualizes a given confusion matrix as a heatmap
  Args:
    conf_matrix (np.array): confustion matrix to be visualized
    test_classes (list): list of classes the model was tested on
    y_og (list): list of original classes (before the combination) matching the test_classes
  """

  true_labels = [f'{str(x)} ({str(y_og[x][0])} & {str(y_og[x][1])})' for x in test_classes]
  pred_labels = [f'{str(x)} ({str(y_og[x][0])} & {str(y_og[x][1])})' for x in test_classes]

  fig, ax = plt.subplots(figsize = (15,15))
  im = ax.imshow(conf_matrix, cmap = 'coolwarm') 

  # Show all ticks and label them with the respective list entries
  ax.set_xticks(np.arange(len(pred_labels)))
  ax.set_yticks(np.arange(len(true_labels)))

  ax.set_xticklabels(pred_labels)
  ax.set_yticklabels(true_labels)

  ax.xaxis.tick_top()
  ax.xaxis.set_label_position('top')

  # Rotate the tick labels and set their alignment
  plt.setp(ax.get_xticklabels(), rotation=45, ha="left",
          rotation_mode="anchor")

  plt.setp(ax.get_yticklabels(), rotation=0, ha="right")

  # Loop over data dimensions and create text annotations
  for i in range(len(true_labels)):
      for j in range(len(pred_labels)):
          text = ax.text(j, i, conf_matrix[i, j],
                        ha="center", va="center", color="w")

  ax.set_title("Confusion matrix", fontsize = 18)
  fig.tight_layout()
  plt.show()

# %% [markdown]
# # Load and split data

# %% [markdown]
# Load X (extraced and combined sequences of hand-keypoints), y (combined classes from 0 to 676) and y_og (original classes from 0 to 25) from Google Drive.

# %%
# Load X, y and y_og from Google Drive.
X = np.load(gdrive + '/data/JESTER/final/X.npy')
y = np.load(gdrive + '/data/JESTER/final/y.npy')
y_og = np.load(gdrive + '/data/JESTER/final/y_og.npy')

# Check shapes 
print(f'Labels shape {y.shape}')
print(f'Data shape {X.shape}')
unique, counts = np.unique(y, return_counts=True)
print(f'\nNumber of unique classes {len(unique)}')
# Out:
# Labels shape (169000,)
# Data shape (169000, 72, 63)
#
# Number of unique classes 676

# %% [markdown]
# ## Configurate Test-strategy

# %% [markdown]
# In contrast to common machine learning approaches, the train-, test-, evaluation-split in Few-Shot Learning use cases splits the data by classes instead of drawing random samples of observations.
#
# Classes are split by their original class labels (not by combined class labels) to prevent the model from seeing bits of the data in more than one of the splits.

# %%
label_map = {'No gesture': 0, #base class, mostly zeros
            'Drumming Fingers': 1, #static
            'Pulling Hand In': 2, #dynamic
            'Pulling Two Fingers In': 3, #dynamic
            'Pushing Hand Away': 4, #dynamic
            'Pushing Two Fingers Away': 5, #dynamic
            'Rolling Hand Backward': 6, #dynamic
            'Rolling Hand Forward': 7, #dynamic
            'Shaking Hand': 8, #static
            'Sliding Two Fingers Down': 9, #dynamic
            'Sliding Two Fingers Left': 10, #dynamic
            'Sliding Two Fingers Right': 11, #dynamic
            'Sliding Two Fingers Up': 12, #dynamic
            'Stop Sign': 13, #static
            'Swiping Down': 14, #dynamic
            'Swiping Left': 15, #dynamic
            'Swiping Right': 16, #dynamic
            'Swiping Up': 17, #dynamic
            'Thumb Down': 18, #static
            'Thumb Up': 19, #static
            'Turning Hand Clockwise': 20, #dynamic
            'Turning Hand Counterclockwise': 21, #dynamic
            'Zooming In With Full Hand': 22, #dynamic
            'Zooming In With Two Fingers': 23, #dynamic
            'Zooming Out With Full Hand': 24, #dynamic
            'Zooming Out With Two Fingers': 25} #dynamic

# %% [markdown]
# Choose original class labels (pre-combination) for training, evaluation and test splits.

# %%
train_y_origin = [0, 1, 4, 5, 6, 7, 9, 10, 16, 17, 22, 25]
eval_y_origin = [0, 2, 8, 11, 14, 18, 20, 23]
test_y_origin = [0, 3, 12, 13, 15, 19, 21, 24]
jester_comp_y = [0, 2, 8, 11, 14, 18, 20, 23, 3, 12, 13, 15, 19, 21, 24]

# %% [markdown]
# Turn splits with original class labels (pre-combination) into training-, evaluation- and test- classes with combined classes.

# %%
training_classes, eval_classes, test_classes, jester_comp_classes  = [], [], [], []

for i in range(len(y_og)):
  if ((y_og[i][0] == 0) and (y_og[i][1] in eval_y_origin)) or (y_og[i][0] in eval_y_origin or y_og[i][1] in eval_y_origin) and not (y_og[i][0] in train_y_origin or y_og[i][1] in train_y_origin) and not (y_og[i][0] in test_y_origin or y_og[i][1] in test_y_origin):
    eval_classes.append(i)
  if ((y_og[i][0] == 0) and (y_og[i][1] in train_y_origin)) or (y_og[i][0] in train_y_origin or y_og[i][1] in train_y_origin) and not (y_og[i][0] in eval_y_origin or y_og[i][1] in eval_y_origin) and not (y_og[i][0] in test_y_origin or y_og[i][1] in test_y_origin):
    training_classes.append(i)
  if ((y_og[i][0] == 0) and (y_og[i][1] in test_y_origin)) or (y_og[i][0] in test_y_origin or y_og[i][1] in test_y_origin) and not (y_og[i][0] in eval_y_origin or y_og[i][1] in eval_y_origin) and not (y_og[i][0] in train_y_origin or y_og[i][1] in train_y_origin):
    test_classes.append(i)
  if ((y_og[i][0] == 0) and (y_og[i][1] in jester_comp_y)):
    jester_comp_classes.append(i)

# %% [markdown]
# Examination of resulting training-, evaluation- and test-split.

# %%
print(f'Number of classes in train-split: {len(training_classes)}')
print(f'Number of classes in eval-split: {len(eval_classes)}')
print(f'Number of classes in test-split: {len(test_classes)}')
print(f'Number of classes in JESTER-evaluation-dataset: {len(jester_comp_classes)}')
# Out:
# Number of classes in train-split: 133
# Number of classes in eval-split: 57
# Number of classes in test-split: 57

# %%
#print(f'Potential number of unique tasks for training: {len(get_classcombinations(training_classes, N_WAY))}')
#print(f'Potential number of unique tasks for evaluation: {len(get_classcombinations(eval_classes, N_WAY))}')
#print(f'Potential number of unique tasks for testing: {len(get_classcombinations(test_classes, N_WAY))}')

# %% [markdown]
# # Model tuning and training

# %% [markdown]
# In this section the model is trained. Initially, this is performed once with parameters defined by the user. Next, the model's hyperparameters are optimized by a tuning process.

# %% [markdown]
# ## Perform a training run

# %% [markdown]
# To ensure that the training function operates flawlessly (& to have a baseline model), training of the model is performed once initially with low parameter complexity.

# %%
task_param = {'support_num_per_class': K_SHOT,
              'query_num_per_class': 16,
              'num_classes': N_WAY}

input_param = {'sequence_length': 72,
               'feature_length': 63}

model_param = {'num_lstm_layer_encoder': 1,
               'num_units_lstm_encoder': 64,
               'num_lstm_layer_relationnet': 1,
               'num_units_lstm_relationnet': 64,
               'num_units_fc_relu': [32]}

training_param = {'learning_rate': 0.001,
                  'learning_rate_schedule_rate': 2000,
                  'num_train_episodes': 25000,
                  'update_and_eval_rate': 200,
                  'num_eval_episodes': 200,
                  'save_path': 'training',
                  'save_logging': True,
                  'save_all': True,
                  'save_best': True,
                  'tuning_run': False,
                  'trial': None}
            
logs = run_training(task_param, input_param, model_param, training_param)
# Out:
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: training/run_0
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.2s (27.90/s)
#     Loss: 0.16279
#     Accuracy: 0.24469
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.33813, Loss: 0.15094
#
# Episode: 200/25000 to 400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.1s (28.17/s)
#     Loss: 0.14926
#     Accuracy: 0.32125
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.35081, Loss: 0.14294
#
# Episode: 400/25000 to 600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.63/s)
#     Loss: 0.15037
#     Accuracy: 0.31538
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.34063, Loss: 0.14535
#
# Episode: 600/25000 to 800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.32/s)
#     Loss: 0.14900
#     Accuracy: 0.31625
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.34862, Loss: 0.14467
#
# Episode: 800/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.63/s)
#     Loss: 0.14803
#     Accuracy: 0.32737
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.36131, Loss: 0.14225
#
# Episode: 1000/25000 to 1200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.80/s)
#     Loss: 0.14966
#     Accuracy: 0.33800
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.36675, Loss: 0.14447
#
# Episode: 1200/25000 to 1400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.4s (26.89/s)
#     Loss: 0.14613
#     Accuracy: 0.37294
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.29856, Loss: 0.14828
#
# Episode: 1400/25000 to 1600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.42/s)
#     Loss: 0.13562
#     Accuracy: 0.48919
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.43369, Loss: 0.13858
#
# Episode: 1600/25000 to 1800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.52/s)
#     Loss: 0.11319
#     Accuracy: 0.63975
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.50938, Loss: 0.15349
#
# Episode: 1800/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.62/s)
#     Loss: 0.09545
#     Accuracy: 0.74513
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.56606, Loss: 0.13693
#
# Episode: 2000/25000 to 2200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.37/s)
#     Loss: 0.08851
#     Accuracy: 0.77275
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60462, Loss: 0.12432
#
# Episode: 2200/25000 to 2400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.48/s)
#     Loss: 0.08118
#     Accuracy: 0.79787
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60575, Loss: 0.12954
#
# Episode: 2400/25000 to 2600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.31/s)
#     Loss: 0.08174
#     Accuracy: 0.80412
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.61950, Loss: 0.14243
#
# Episode: 2600/25000 to 2800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (28.96/s)
#     Loss: 0.07493
#     Accuracy: 0.81969
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64844, Loss: 0.11671
#
# Episode: 2800/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.45/s)
#     Loss: 0.07151
#     Accuracy: 0.83406
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65387, Loss: 0.13411
#
# Episode: 3000/25000 to 3200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.9s (29.08/s)
#     Loss: 0.07002
#     Accuracy: 0.83931
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69106, Loss: 0.11688
#
# Episode: 3200/25000 to 3400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.26/s)
#     Loss: 0.06756
#     Accuracy: 0.84938
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66444, Loss: 0.11995
#
# Episode: 3400/25000 to 3600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.20/s)
#     Loss: 0.06202
#     Accuracy: 0.86731
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65200, Loss: 0.11652
#
# Episode: 3600/25000 to 3800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.86/s)
#     Loss: 0.06349
#     Accuracy: 0.86269
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.73125, Loss: 0.10289
#
# Episode: 3800/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.66/s)
#     Loss: 0.05540
#     Accuracy: 0.88681
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75800, Loss: 0.09374
#
# Episode: 4000/25000 to 4200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.44/s)
#     Loss: 0.05650
#     Accuracy: 0.88563
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77263, Loss: 0.09136
#
# Episode: 4200/25000 to 4400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.54/s)
#     Loss: 0.05168
#     Accuracy: 0.89631
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78444, Loss: 0.09394
#
# Episode: 4400/25000 to 4600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.32/s)
#     Loss: 0.04921
#     Accuracy: 0.90638
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78013, Loss: 0.08819
#
# Episode: 4600/25000 to 4800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.70/s)
#     Loss: 0.04642
#     Accuracy: 0.91025
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78850, Loss: 0.10343
#
# Episode: 4800/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.72/s)
#     Loss: 0.04124
#     Accuracy: 0.92531
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77225, Loss: 0.09440
#
# Episode: 5000/25000 to 5200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.49/s)
#     Loss: 0.04661
#     Accuracy: 0.91181
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78150, Loss: 0.10338
#
# Episode: 5200/25000 to 5400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (30.05/s)
#     Loss: 0.04291
#     Accuracy: 0.92081
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79894, Loss: 0.08801
#
# Episode: 5400/25000 to 5600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.80/s)
#     Loss: 0.04141
#     Accuracy: 0.92669
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79688, Loss: 0.08691
#
# Episode: 5600/25000 to 5800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.73/s)
#     Loss: 0.03682
#     Accuracy: 0.93319
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78838, Loss: 0.10764
#
# Episode: 5800/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.30/s)
#     Loss: 0.03506
#     Accuracy: 0.94300
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80963, Loss: 0.08447
#
# Episode: 6000/25000 to 6200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.46/s)
#     Loss: 0.03515
#     Accuracy: 0.94237
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80144, Loss: 0.08956
#
# Episode: 6200/25000 to 6400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.90/s)
#     Loss: 0.03693
#     Accuracy: 0.93512
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81956, Loss: 0.08280
#
# Episode: 6400/25000 to 6600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.32/s)
#     Loss: 0.03369
#     Accuracy: 0.94563
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81525, Loss: 0.08393
#
# Episode: 6600/25000 to 6800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.62/s)
#     Loss: 0.03381
#     Accuracy: 0.94181
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82006, Loss: 0.08305
#
# Episode: 6800/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.87/s)
#     Loss: 0.03120
#     Accuracy: 0.95300
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82181, Loss: 0.08373
#
# Episode: 7000/25000 to 7200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.58/s)
#     Loss: 0.02948
#     Accuracy: 0.95231
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81294, Loss: 0.08759
#
# Episode: 7200/25000 to 7400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.81/s)
#     Loss: 0.03085
#     Accuracy: 0.94869
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82812, Loss: 0.08058
#
# Episode: 7400/25000 to 7600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.6s (26.36/s)
#     Loss: 0.03020
#     Accuracy: 0.95075
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.83737, Loss: 0.07581
#
# Episode: 7600/25000 to 7800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.38/s)
#     Loss: 0.02772
#     Accuracy: 0.95619
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81906, Loss: 0.08719
#
# Episode: 7800/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.59/s)
#     Loss: 0.02706
#     Accuracy: 0.95975
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.83519, Loss: 0.08148
#
# Episode: 8000/25000 to 8200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.20/s)
#     Loss: 0.02692
#     Accuracy: 0.95562
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82825, Loss: 0.08583
#
# Episode: 8200/25000 to 8400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.37/s)
#     Loss: 0.02886
#     Accuracy: 0.95513
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.83825, Loss: 0.09018
#
# Episode: 8400/25000 to 8600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.70/s)
#     Loss: 0.02464
#     Accuracy: 0.96050
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.84550, Loss: 0.07679
#
# Episode: 8600/25000 to 8800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.77/s)
#     Loss: 0.02101
#     Accuracy: 0.96900
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.84937, Loss: 0.07611
#
# Episode: 8800/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.27/s)
#     Loss: 0.02329
#     Accuracy: 0.96425
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.84175, Loss: 0.08892
#
# Episode: 9000/25000 to 9200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.4s (31.02/s)
#     Loss: 0.02128
#     Accuracy: 0.97006
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85850, Loss: 0.07204
#
# Episode: 9200/25000 to 9400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.62/s)
#     Loss: 0.02483
#     Accuracy: 0.96219
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85800, Loss: 0.07086
#
# Episode: 9400/25000 to 9600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.73/s)
#     Loss: 0.02155
#     Accuracy: 0.96588
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86431, Loss: 0.07232
#
# Episode: 9600/25000 to 9800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.36/s)
#     Loss: 0.02012
#     Accuracy: 0.97188
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85231, Loss: 0.07104
#
# Episode: 9800/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.73/s)
#     Loss: 0.02119
#     Accuracy: 0.96738
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86262, Loss: 0.07764
#
# Episode: 10000/25000 to 10200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.68/s)
#     Loss: 0.02233
#     Accuracy: 0.96256
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87375, Loss: 0.08090
#
# Episode: 10200/25000 to 10400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.51/s)
#     Loss: 0.01909
#     Accuracy: 0.97181
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85000, Loss: 0.08398
#
# Episode: 10400/25000 to 10600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.72/s)
#     Loss: 0.02155
#     Accuracy: 0.96456
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85300, Loss: 0.07361
#
# Episode: 10600/25000 to 10800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.73/s)
#     Loss: 0.02116
#     Accuracy: 0.96675
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.84862, Loss: 0.07138
#
# Episode: 10800/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.55/s)
#     Loss: 0.01939
#     Accuracy: 0.97206
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87325, Loss: 0.07556
#
# Episode: 11000/25000 to 11200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.67/s)
#     Loss: 0.01939
#     Accuracy: 0.97156
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87731, Loss: 0.07410
#
# Episode: 11200/25000 to 11400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.81/s)
#     Loss: 0.01762
#     Accuracy: 0.97463
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88013, Loss: 0.06873
#
# Episode: 11400/25000 to 11600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.52/s)
#     Loss: 0.01978
#     Accuracy: 0.97206
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82638, Loss: 0.08194
#
# Episode: 11600/25000 to 11800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.74/s)
#     Loss: 0.01877
#     Accuracy: 0.97269
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87588, Loss: 0.06413
#
# Episode: 11800/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.32/s)
#     Loss: 0.01806
#     Accuracy: 0.97119
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86638, Loss: 0.06896
#
# Episode: 12000/25000 to 12200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.82/s)
#     Loss: 0.01555
#     Accuracy: 0.97669
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86306, Loss: 0.08308
#
# Episode: 12200/25000 to 12400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.69/s)
#     Loss: 0.01839
#     Accuracy: 0.97494
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87725, Loss: 0.06224
#
# Episode: 12400/25000 to 12600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.91/s)
#     Loss: 0.01802
#     Accuracy: 0.97150
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87406, Loss: 0.06497
#
# Episode: 12600/25000 to 12800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.78/s)
#     Loss: 0.01830
#     Accuracy: 0.97325
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85700, Loss: 0.07264
#
# Episode: 12800/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.18/s)
#     Loss: 0.01657
#     Accuracy: 0.97488
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88206, Loss: 0.06154
#
# Episode: 13000/25000 to 13200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.75/s)
#     Loss: 0.01813
#     Accuracy: 0.97369
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87513, Loss: 0.06396
#
# Episode: 13200/25000 to 13400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.62/s)
#     Loss: 0.01869
#     Accuracy: 0.97156
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86856, Loss: 0.07034
#
# Episode: 13400/25000 to 13600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.63/s)
#     Loss: 0.01771
#     Accuracy: 0.97488
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87987, Loss: 0.06485
#
# Episode: 13600/25000 to 13800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.86/s)
#     Loss: 0.01712
#     Accuracy: 0.97463
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85900, Loss: 0.06864
#
# Episode: 13800/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.2s (27.67/s)
#     Loss: 0.01423
#     Accuracy: 0.97925
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87819, Loss: 0.06642
#
# Episode: 14000/25000 to 14200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.36/s)
#     Loss: 0.01350
#     Accuracy: 0.98125
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88062, Loss: 0.06337
#
# Episode: 14200/25000 to 14400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.4s (31.06/s)
#     Loss: 0.01762
#     Accuracy: 0.97319
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86844, Loss: 0.08183
#
# Episode: 14400/25000 to 14600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.78/s)
#     Loss: 0.01482
#     Accuracy: 0.97612
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87925, Loss: 0.06931
#
# Episode: 14600/25000 to 14800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.52/s)
#     Loss: 0.01613
#     Accuracy: 0.97594
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87612, Loss: 0.06710
#
# Episode: 14800/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.64/s)
#     Loss: 0.01759
#     Accuracy: 0.97138
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88831, Loss: 0.06955
#
# Episode: 15000/25000 to 15200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.92/s)
#     Loss: 0.01820
#     Accuracy: 0.97212
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87719, Loss: 0.06253
#
# Episode: 15200/25000 to 15400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.84/s)
#     Loss: 0.01510
#     Accuracy: 0.97763
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88006, Loss: 0.06340
#
# Episode: 15400/25000 to 15600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.69/s)
#     Loss: 0.01917
#     Accuracy: 0.96850
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86831, Loss: 0.06773
#
# Episode: 15600/25000 to 15800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.92/s)
#     Loss: 0.01290
#     Accuracy: 0.98094
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87544, Loss: 0.06750
#
# Episode: 15800/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.4s (31.04/s)
#     Loss: 0.01540
#     Accuracy: 0.97931
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87706, Loss: 0.06485
#
# Episode: 16000/25000 to 16200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.66/s)
#     Loss: 0.01500
#     Accuracy: 0.98025
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.89138, Loss: 0.06039
#
# Episode: 16200/25000 to 16400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.18/s)
#     Loss: 0.01697
#     Accuracy: 0.97238
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87781, Loss: 0.06530
#
# Episode: 16400/25000 to 16600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.64/s)
#     Loss: 0.01725
#     Accuracy: 0.97469
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88487, Loss: 0.06482
#
# Episode: 16600/25000 to 16800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.85/s)
#     Loss: 0.01288
#     Accuracy: 0.97938
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.89363, Loss: 0.06129
#
# Episode: 16800/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.58/s)
#     Loss: 0.01540
#     Accuracy: 0.97675
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88019, Loss: 0.06457
#
# Episode: 17000/25000 to 17200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.83/s)
#     Loss: 0.01266
#     Accuracy: 0.98000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87888, Loss: 0.06300
#
# Episode: 17200/25000 to 17400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.49/s)
#     Loss: 0.01338
#     Accuracy: 0.97831
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87544, Loss: 0.07529
#
# Episode: 17400/25000 to 17600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.67/s)
#     Loss: 0.01289
#     Accuracy: 0.98113
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88456, Loss: 0.06907
#
# Episode: 17600/25000 to 17800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.27/s)
#     Loss: 0.01501
#     Accuracy: 0.97631
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87075, Loss: 0.06911
#
# Episode: 17800/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.68/s)
#     Loss: 0.01452
#     Accuracy: 0.97700
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88619, Loss: 0.06524
#
# Episode: 18000/25000 to 18200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.53/s)
#     Loss: 0.01307
#     Accuracy: 0.98031
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.89075, Loss: 0.06088
#
# Episode: 18200/25000 to 18400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.63/s)
#     Loss: 0.01405
#     Accuracy: 0.97919
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88338, Loss: 0.06292
#
# Episode: 18400/25000 to 18600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.70/s)
#     Loss: 0.01289
#     Accuracy: 0.98188
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88225, Loss: 0.06655
#
# Episode: 18600/25000 to 18800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.67/s)
#     Loss: 0.01407
#     Accuracy: 0.98044
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87331, Loss: 0.06635
#
# Episode: 18800/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.57/s)
#     Loss: 0.01414
#     Accuracy: 0.97969
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86256, Loss: 0.07803
#
# Episode: 19000/25000 to 19200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.47/s)
#     Loss: 0.01527
#     Accuracy: 0.97738
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86869, Loss: 0.07954
#
# Episode: 19200/25000 to 19400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.65/s)
#     Loss: 0.01340
#     Accuracy: 0.98013
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88531, Loss: 0.06148
#
# Episode: 19400/25000 to 19600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.65/s)
#     Loss: 0.01355
#     Accuracy: 0.97825
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88881, Loss: 0.06115
#
# Episode: 19600/25000 to 19800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.57/s)
#     Loss: 0.01293
#     Accuracy: 0.97919
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88944, Loss: 0.06676
#
# Episode: 19800/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.61/s)
#     Loss: 0.01297
#     Accuracy: 0.98150
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88675, Loss: 0.06206
#
# Episode: 20000/25000 to 20200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.86/s)
#     Loss: 0.01211
#     Accuracy: 0.98206
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88769, Loss: 0.06413
#
# Episode: 20200/25000 to 20400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.68/s)
#     Loss: 0.01375
#     Accuracy: 0.98125
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87481, Loss: 0.06591
#
# Episode: 20400/25000 to 20600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.61/s)
#     Loss: 0.01212
#     Accuracy: 0.98163
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.90425, Loss: 0.05339
#
# Episode: 20600/25000 to 20800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.84/s)
#     Loss: 0.01335
#     Accuracy: 0.97813
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88713, Loss: 0.06107
#
# Episode: 20800/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.67/s)
#     Loss: 0.01206
#     Accuracy: 0.98338
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87963, Loss: 0.06294
#
# Episode: 21000/25000 to 21200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.42/s)
#     Loss: 0.01235
#     Accuracy: 0.98138
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.89138, Loss: 0.05994
#
# Episode: 21200/25000 to 21400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.17/s)
#     Loss: 0.01288
#     Accuracy: 0.98219
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87581, Loss: 0.06699
#
# Episode: 21400/25000 to 21600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.53/s)
#     Loss: 0.01147
#     Accuracy: 0.98463
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.89263, Loss: 0.05686
#
# Episode: 21600/25000 to 21800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.12/s)
#     Loss: 0.01239
#     Accuracy: 0.98250
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88438, Loss: 0.06401
#
# Episode: 21800/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.5s (30.66/s)
#     Loss: 0.01224
#     Accuracy: 0.98013
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87681, Loss: 0.06481
#
# Episode: 22000/25000 to 22200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.15/s)
#     Loss: 0.01209
#     Accuracy: 0.98044
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88438, Loss: 0.06192
#
# Episode: 22200/25000 to 22400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.6s (30.20/s)
#     Loss: 0.01085
#     Accuracy: 0.98600
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87944, Loss: 0.06344
#
# Episode: 22400/25000 to 22600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.87/s)
#     Loss: 0.00925
#     Accuracy: 0.98806
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.89112, Loss: 0.06100
#
# Episode: 22600/25000 to 22800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.7s (29.85/s)
#     Loss: 0.01298
#     Accuracy: 0.98075
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.89213, Loss: 0.05604
#
# Episode: 22800/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 6.8s (29.39/s)
#     Loss: 0.01215
#     Accuracy: 0.98256
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88900, Loss: 0.06626
#
# Episode: 23000/25000 to 23200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.2s (27.86/s)
#     Loss: 0.01262
#     Accuracy: 0.98075
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88306, Loss: 0.06807
#
# Episode: 23200/25000 to 23400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.3s (27.39/s)
#     Loss: 0.01359
#     Accuracy: 0.97819
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86813, Loss: 0.06903
#
# Episode: 23400/25000 to 23600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.3s (27.27/s)
#     Loss: 0.01232
#     Accuracy: 0.98344
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86431, Loss: 0.07329
#
# Episode: 23600/25000 to 23800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.4s (27.20/s)
#     Loss: 0.01142
#     Accuracy: 0.98438
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87850, Loss: 0.06895
#
# Episode: 23800/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.4s (26.89/s)
#     Loss: 0.01026
#     Accuracy: 0.98675
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86825, Loss: 0.06962
#
# Episode: 24000/25000 to 24200/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.3s (27.49/s)
#     Loss: 0.01180
#     Accuracy: 0.98294
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87362, Loss: 0.07141
#
# Episode: 24200/25000 to 24400/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.2s (27.66/s)
#     Loss: 0.01039
#     Accuracy: 0.98563
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88075, Loss: 0.06371
#
# Episode: 24400/25000 to 24600/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.3s (27.37/s)
#     Loss: 0.01114
#     Accuracy: 0.98313
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88919, Loss: 0.06060
#
# Episode: 24600/25000 to 24800/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.3s (27.33/s)
#     Loss: 0.00989
#     Accuracy: 0.98356
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87994, Loss: 0.06575
#
# Episode: 24800/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 200/200 [100%] in 7.4s (26.85/s)
#     Loss: 0.01346
#     Accuracy: 0.97731
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86694, Loss: 0.07153

# %% [markdown]
# Success of the training is examined by analyzing the training curve.

# %%
plot_traincurve('training/run_0', ['train_accuracy', 'eval_accuracy'], 'Accuracy')

# %% [markdown]
# ## Perform a tuning run

# %% [markdown]
# The most decisive hyperparameters present in the model are determined by a tuning process, which runs the model training several times and tries to boost the models performance by minimizing the evaluation-loss with adaptations to the hyperparameters.

# %%
tuning = optuna.create_study(direction="minimize", 
                             sampler = optuna.samplers.TPESampler(),
                             pruner = optuna.pruners.MedianPruner(n_startup_trials=5))

tuning.optimize(run_tuning, n_trials=25)

pruned_trials = tuning.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = tuning.get_trials(deepcopy=False, states=[TrialState.COMPLETE])
importances = optuna.importance.get_param_importances(tuning)

print('\n')
print('#######################################################################')
print('########################### FINISHED TUNING ###########################')
print('#######################################################################')
print('\n \n')

print('Tuning statistics: ')
print('  Number of trials: ', len(tuning.trials))
print('  Number of pruned trials: ', len(pruned_trials))
print('  Number of complete trials: ', len(complete_trials), '\n')

print('Best trial:')
trial = tuning.best_trial

print(f'  Run {str(trial.number)} with Loss {min(trial.intermediate_values.values())} at Episode {min(trial.intermediate_values, key=trial.intermediate_values.get)}')

print('  Params: ')
for key, value in trial.params.items():
  print('    {}: {}'.format(key, value))
# Out:
# [I 2022-06-02 11:52:51,393] A new study created in memory with name: no-name-faca5f97-776b-4601-9b05-411f5b09c700
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_0
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.1s (18.48/s)
#     Loss: 0.16124
#     Accuracy: 0.20010
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.0s (18.51/s)
#     Loss: 0.16000
#     Accuracy: 0.20018
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.8s (18.00/s)
#     Loss: 0.16000
#     Accuracy: 0.19978
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.0s (18.55/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.1s (18.47/s)
#     Loss: 0.16000
#     Accuracy: 0.19990
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.0s (18.53/s)
#     Loss: 0.16000
#     Accuracy: 0.20003
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.0s (18.51/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.0s (18.54/s)
#     Loss: 0.16000
#     Accuracy: 0.19998
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.9s (18.55/s)
#     Loss: 0.16000
#     Accuracy: 0.19998
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.2s (18.41/s)
#     Loss: 0.16000
#     Accuracy: 0.19990
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.1s (18.44/s)
#     Loss: 0.16000
#     Accuracy: 0.20005
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.0s (18.51/s)
#     Loss: 0.16000
#     Accuracy: 0.19980
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.5s (18.16/s)
#     Loss: 0.16000
#     Accuracy: 0.20008
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.9s (18.56/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.1s (18.48/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.1s (18.48/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.1s (18.42/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.1s (18.42/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.2s (18.39/s)
#     Loss: 0.16000
#     Accuracy: 0.19998
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.1s (18.44/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.0s (18.51/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.1s (18.42/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.1s (18.43/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.0s (17.88/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.2s (18.36/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.0s (18.50/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.3s (18.34/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.2s (18.41/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.2s (18.37/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.1s (18.47/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.2s (18.39/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.2s (18.40/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.2s (18.41/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.1s (17.80/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.1s (18.48/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.7s (18.08/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.5s (18.19/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.6s (18.13/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.5s (18.18/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.5s (18.20/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.5s (18.17/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.4s (18.23/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.7s (18.07/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.6s (18.10/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.5s (18.21/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.6s (18.14/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.5s (18.17/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.2s (17.71/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 28.0s (17.89/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.6s (18.11/s)
#     Loss: 0.16000
#     Accuracy: 0.20000
# [I 2022-06-02 12:21:05,425] Trial 0 finished with value: 0.15999998152256012 and parameters: {'num_fc_layers': 2, 'num_units_fc_layer0': 16, 'num_units_fc_layer1': 16, 'num_lstm_layer_encoder': 3, 'num_units_lstm_encoder': 64, 'num_lstm_layer_relationnet': 3, 'num_units_lstm_relationnet': 128, 'learning_rate': 0.008700789847278846, 'learning_rate_schedule_rate': 3500}. Best is trial 0 with value: 0.15999998152256012.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20000, Loss: 0.16000
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_1
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.9s (20.91/s)
#     Loss: 0.20564
#     Accuracy: 0.21043
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20337, Loss: 0.17202
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.1s (20.77/s)
#     Loss: 0.15804
#     Accuracy: 0.24418
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.33125, Loss: 0.15240
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.4s (19.65/s)
#     Loss: 0.15392
#     Accuracy: 0.31230
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.33744, Loss: 0.15150
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.6s (19.52/s)
#     Loss: 0.15331
#     Accuracy: 0.30190
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.30981, Loss: 0.14932
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.2s (19.10/s)
#     Loss: 0.15023
#     Accuracy: 0.31985
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.34756, Loss: 0.14575
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.8s (19.37/s)
#     Loss: 0.14911
#     Accuracy: 0.32985
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.34744, Loss: 0.14580
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.6s (19.51/s)
#     Loss: 0.14790
#     Accuracy: 0.33123
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.33769, Loss: 0.14551
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.9s (19.27/s)
#     Loss: 0.14649
#     Accuracy: 0.34318
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.35519, Loss: 0.14314
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.0s (19.24/s)
#     Loss: 0.14754
#     Accuracy: 0.34420
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.44181, Loss: 0.13645
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.0s (19.26/s)
#     Loss: 0.13826
#     Accuracy: 0.46823
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.56256, Loss: 0.12382
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.1s (19.13/s)
#     Loss: 0.11221
#     Accuracy: 0.65107
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60425, Loss: 0.12040
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.9s (19.30/s)
#     Loss: 0.10231
#     Accuracy: 0.70103
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60775, Loss: 0.11842
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.9s (19.28/s)
#     Loss: 0.09814
#     Accuracy: 0.72433
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60831, Loss: 0.12378
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.9s (19.32/s)
#     Loss: 0.09503
#     Accuracy: 0.74177
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.61169, Loss: 0.11732
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.8s (19.36/s)
#     Loss: 0.08837
#     Accuracy: 0.76623
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64031, Loss: 0.11635
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.4s (18.95/s)
#     Loss: 0.08146
#     Accuracy: 0.79510
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.68338, Loss: 0.11312
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.7s (19.48/s)
#     Loss: 0.07572
#     Accuracy: 0.81848
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71469, Loss: 0.10350
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.6s (19.57/s)
#     Loss: 0.06777
#     Accuracy: 0.84067
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.72463, Loss: 0.10656
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.7s (19.48/s)
#     Loss: 0.07010
#     Accuracy: 0.83945
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75612, Loss: 0.09283
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.0s (19.24/s)
#     Loss: 0.06359
#     Accuracy: 0.85825
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75469, Loss: 0.09501
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.8s (19.39/s)
#     Loss: 0.06270
#     Accuracy: 0.86148
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.74781, Loss: 0.10210
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.7s (19.45/s)
#     Loss: 0.06052
#     Accuracy: 0.87047
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77706, Loss: 0.08965
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.8s (19.39/s)
#     Loss: 0.05865
#     Accuracy: 0.87370
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.76144, Loss: 0.08693
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.6s (19.50/s)
#     Loss: 0.05460
#     Accuracy: 0.88325
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77150, Loss: 0.09694
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.8s (19.38/s)
#     Loss: 0.05690
#     Accuracy: 0.87840
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77281, Loss: 0.09903
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.7s (19.45/s)
#     Loss: 0.05442
#     Accuracy: 0.88380
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77963, Loss: 0.09171
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.4s (18.97/s)
#     Loss: 0.05263
#     Accuracy: 0.88820
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77650, Loss: 0.09557
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.6s (19.50/s)
#     Loss: 0.04882
#     Accuracy: 0.89920
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78662, Loss: 0.09891
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.6s (19.50/s)
#     Loss: 0.05117
#     Accuracy: 0.89245
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78812, Loss: 0.08883
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.8s (19.41/s)
#     Loss: 0.04908
#     Accuracy: 0.89953
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78263, Loss: 0.08733
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.6s (19.52/s)
#     Loss: 0.04756
#     Accuracy: 0.90205
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78125, Loss: 0.09853
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.5s (19.58/s)
#     Loss: 0.04592
#     Accuracy: 0.90718
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80181, Loss: 0.08444
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.8s (19.41/s)
#     Loss: 0.04567
#     Accuracy: 0.90517
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77794, Loss: 0.10693
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.6s (19.53/s)
#     Loss: 0.04650
#     Accuracy: 0.90867
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78175, Loss: 0.10036
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.7s (19.45/s)
#     Loss: 0.04469
#     Accuracy: 0.91018
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78263, Loss: 0.09041
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.7s (19.43/s)
#     Loss: 0.04367
#     Accuracy: 0.91265
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79588, Loss: 0.09090
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.8s (19.39/s)
#     Loss: 0.04116
#     Accuracy: 0.91685
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.77563, Loss: 0.09651
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.5s (18.88/s)
#     Loss: 0.03847
#     Accuracy: 0.92335
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78719, Loss: 0.11308
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.9s (19.33/s)
#     Loss: 0.04019
#     Accuracy: 0.91888
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80025, Loss: 0.08311
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.9s (19.32/s)
#     Loss: 0.03774
#     Accuracy: 0.92353
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78625, Loss: 0.09610
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.9s (19.32/s)
#     Loss: 0.03691
#     Accuracy: 0.92818
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80287, Loss: 0.08559
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.8s (19.39/s)
#     Loss: 0.03666
#     Accuracy: 0.92490
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80888, Loss: 0.09060
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.9s (19.27/s)
#     Loss: 0.03571
#     Accuracy: 0.92650
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.79300, Loss: 0.10870
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.0s (19.26/s)
#     Loss: 0.03582
#     Accuracy: 0.92897
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80600, Loss: 0.08607
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.9s (19.27/s)
#     Loss: 0.03255
#     Accuracy: 0.93270
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80263, Loss: 0.08823
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.9s (19.30/s)
#     Loss: 0.03353
#     Accuracy: 0.93178
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81700, Loss: 0.08582
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.9s (19.31/s)
#     Loss: 0.03179
#     Accuracy: 0.93685
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82006, Loss: 0.08047
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.9s (19.30/s)
#     Loss: 0.03325
#     Accuracy: 0.93220
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81931, Loss: 0.07786
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.6s (18.83/s)
#     Loss: 0.03138
#     Accuracy: 0.93633
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.80056, Loss: 0.08451
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.0s (19.26/s)
#     Loss: 0.03253
#     Accuracy: 0.93460
# [I 2022-06-02 12:48:07,880] Trial 1 finished with value: 0.07786182073876262 and parameters: {'num_fc_layers': 1, 'num_units_fc_layer0': 16, 'num_lstm_layer_encoder': 2, 'num_units_lstm_encoder': 256, 'num_lstm_layer_relationnet': 3, 'num_units_lstm_relationnet': 16, 'learning_rate': 5.016015040811998e-05, 'learning_rate_schedule_rate': 3500}. Best is trial 1 with value: 0.07786182073876262.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81481, Loss: 0.08735
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_2
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.4s (22.31/s)
#     Loss: 0.15603
#     Accuracy: 0.23590
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.29481, Loss: 0.14734
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.6s (22.14/s)
#     Loss: 0.14807
#     Accuracy: 0.27430
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.29262, Loss: 0.14844
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.6s (22.10/s)
#     Loss: 0.14910
#     Accuracy: 0.28833
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.34600, Loss: 0.14269
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.6s (22.12/s)
#     Loss: 0.14801
#     Accuracy: 0.32865
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.34350, Loss: 0.14490
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.6s (22.13/s)
#     Loss: 0.14692
#     Accuracy: 0.33645
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.37556, Loss: 0.14238
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.6s (22.13/s)
#     Loss: 0.14372
#     Accuracy: 0.36493
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.38725, Loss: 0.14265
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.4s (22.28/s)
#     Loss: 0.13899
#     Accuracy: 0.39913
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.45150, Loss: 0.13768
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.7s (22.06/s)
#     Loss: 0.13322
#     Accuracy: 0.45840
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.48862, Loss: 0.12798
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.7s (22.05/s)
#     Loss: 0.12495
#     Accuracy: 0.53238
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.53869, Loss: 0.13159
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.4s (22.34/s)
#     Loss: 0.11350
#     Accuracy: 0.60955
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60888, Loss: 0.11656
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.5s (21.28/s)
#     Loss: 0.09638
#     Accuracy: 0.71832
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.57006, Loss: 0.12467
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.5s (22.22/s)
#     Loss: 0.08494
#     Accuracy: 0.77457
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.63525, Loss: 0.11987
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.6s (22.14/s)
#     Loss: 0.07600
#     Accuracy: 0.81737
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.65475, Loss: 0.11486
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.6s (22.09/s)
#     Loss: 0.06938
#     Accuracy: 0.84190
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.62631, Loss: 0.13952
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.8s (21.95/s)
#     Loss: 0.05946
#     Accuracy: 0.87135
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.67713, Loss: 0.12260
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.4s (22.30/s)
#     Loss: 0.05262
#     Accuracy: 0.89380
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70681, Loss: 0.10623
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.6s (22.10/s)
#     Loss: 0.04869
#     Accuracy: 0.90375
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.69750, Loss: 0.12488
#
# Episode: 8500/25000 to 9000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.5s (22.26/s)
#     Loss: 0.04444
#     Accuracy: 0.91587
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.71469, Loss: 0.12667
#
# Episode: 9000/25000 to 9500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.5s (22.27/s)
#     Loss: 0.03981
#     Accuracy: 0.92783
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.75044, Loss: 0.09888
#
# Episode: 9500/25000 to 10000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.4s (22.29/s)
#     Loss: 0.03776
#     Accuracy: 0.93438
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.78744, Loss: 0.08743
#
# Episode: 10000/25000 to 10500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.4s (22.33/s)
#     Loss: 0.03676
#     Accuracy: 0.93683
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81556, Loss: 0.08496
#
# Episode: 10500/25000 to 11000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.6s (22.17/s)
#     Loss: 0.03433
#     Accuracy: 0.94110
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.81494, Loss: 0.08241
#
# Episode: 11000/25000 to 11500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.4s (22.31/s)
#     Loss: 0.03120
#     Accuracy: 0.94668
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.83219, Loss: 0.07606
#
# Episode: 11500/25000 to 12000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.2s (21.53/s)
#     Loss: 0.02902
#     Accuracy: 0.95353
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82925, Loss: 0.07861
#
# Episode: 12000/25000 to 12500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.4s (22.31/s)
#     Loss: 0.02870
#     Accuracy: 0.95313
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.84500, Loss: 0.08151
#
# Episode: 12500/25000 to 13000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.7s (22.06/s)
#     Loss: 0.02870
#     Accuracy: 0.95363
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85100, Loss: 0.07389
#
# Episode: 13000/25000 to 13500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.3s (22.39/s)
#     Loss: 0.02540
#     Accuracy: 0.95823
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85250, Loss: 0.07222
#
# Episode: 13500/25000 to 14000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.6s (22.17/s)
#     Loss: 0.02569
#     Accuracy: 0.95805
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82037, Loss: 0.09417
#
# Episode: 14000/25000 to 14500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.6s (22.09/s)
#     Loss: 0.02628
#     Accuracy: 0.95630
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.82700, Loss: 0.09265
#
# Episode: 14500/25000 to 15000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.5s (22.25/s)
#     Loss: 0.02664
#     Accuracy: 0.95463
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85037, Loss: 0.07131
#
# Episode: 15000/25000 to 15500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.4s (22.30/s)
#     Loss: 0.02408
#     Accuracy: 0.96133
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86181, Loss: 0.07015
#
# Episode: 15500/25000 to 16000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.6s (22.16/s)
#     Loss: 0.02261
#     Accuracy: 0.96380
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.84613, Loss: 0.07728
#
# Episode: 16000/25000 to 16500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.4s (22.28/s)
#     Loss: 0.02294
#     Accuracy: 0.96280
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85900, Loss: 0.08118
#
# Episode: 16500/25000 to 17000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.7s (22.07/s)
#     Loss: 0.02072
#     Accuracy: 0.96848
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85287, Loss: 0.07775
#
# Episode: 17000/25000 to 17500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.5s (22.22/s)
#     Loss: 0.01959
#     Accuracy: 0.97153
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85531, Loss: 0.07741
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.5s (22.21/s)
#     Loss: 0.02020
#     Accuracy: 0.96728
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.84981, Loss: 0.07718
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.4s (21.35/s)
#     Loss: 0.02097
#     Accuracy: 0.96463
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85600, Loss: 0.07406
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.4s (22.36/s)
#     Loss: 0.01937
#     Accuracy: 0.96770
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.84969, Loss: 0.08234
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.5s (22.21/s)
#     Loss: 0.01919
#     Accuracy: 0.96865
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85281, Loss: 0.07896
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.8s (21.93/s)
#     Loss: 0.02104
#     Accuracy: 0.96568
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85875, Loss: 0.07871
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.6s (22.17/s)
#     Loss: 0.01799
#     Accuracy: 0.97135
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86975, Loss: 0.06470
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.6s (22.12/s)
#     Loss: 0.01922
#     Accuracy: 0.96935
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85600, Loss: 0.07163
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.6s (22.17/s)
#     Loss: 0.01692
#     Accuracy: 0.97350
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86556, Loss: 0.07682
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.5s (22.21/s)
#     Loss: 0.01687
#     Accuracy: 0.97315
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86394, Loss: 0.07156
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.6s (22.17/s)
#     Loss: 0.01717
#     Accuracy: 0.97333
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86700, Loss: 0.07238
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.5s (22.24/s)
#     Loss: 0.01552
#     Accuracy: 0.97533
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85925, Loss: 0.06923
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.4s (22.31/s)
#     Loss: 0.01524
#     Accuracy: 0.97895
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.84794, Loss: 0.07511
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.5s (22.19/s)
#     Loss: 0.01525
#     Accuracy: 0.97625
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87638, Loss: 0.06807
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.7s (22.06/s)
#     Loss: 0.01481
#     Accuracy: 0.97620
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.85463, Loss: 0.08313
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.1s (21.62/s)
#     Loss: 0.01493
#     Accuracy: 0.97715
# [I 2022-06-02 13:11:30,672] Trial 2 finished with value: 0.06469874958507717 and parameters: {'num_fc_layers': 1, 'num_units_fc_layer0': 256, 'num_lstm_layer_encoder': 3, 'num_units_lstm_encoder': 16, 'num_lstm_layer_relationnet': 1, 'num_units_lstm_relationnet': 32, 'learning_rate': 0.002046660648263382, 'learning_rate_schedule_rate': 3000}. Best is trial 2 with value: 0.06469874958507717.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.84531, Loss: 0.07078
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_3
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.0s (19.25/s)
#     Loss: 0.16403
#     Accuracy: 0.20590
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.21738, Loss: 0.15607
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.9s (19.34/s)
#     Loss: 0.15203
#     Accuracy: 0.29835
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.35744, Loss: 0.14168
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.7s (19.45/s)
#     Loss: 0.14750
#     Accuracy: 0.32825
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.34769, Loss: 0.14275
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.8s (19.39/s)
#     Loss: 0.14596
#     Accuracy: 0.35895
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.38587, Loss: 0.14186
#
# Episode: 2000/25000 to 2500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.8s (19.37/s)
#     Loss: 0.14265
#     Accuracy: 0.38137
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.44775, Loss: 0.13405
#
# Episode: 2500/25000 to 3000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.7s (19.42/s)
#     Loss: 0.13360
#     Accuracy: 0.45133
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.47763, Loss: 0.13152
#
# Episode: 3000/25000 to 3500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.0s (19.22/s)
#     Loss: 0.13011
#     Accuracy: 0.48610
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.50594, Loss: 0.12564
#
# Episode: 3500/25000 to 4000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.8s (19.37/s)
#     Loss: 0.11586
#     Accuracy: 0.58403
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.49112, Loss: 0.13383
#
# Episode: 4000/25000 to 4500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.0s (19.25/s)
#     Loss: 0.10764
#     Accuracy: 0.63382
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.51413, Loss: 0.13047
#
# Episode: 4500/25000 to 5000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.1s (19.17/s)
#     Loss: 0.10091
#     Accuracy: 0.68210
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.52138, Loss: 0.13586
#
# Episode: 5000/25000 to 5500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.7s (19.46/s)
#     Loss: 0.09034
#     Accuracy: 0.74272
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.54619, Loss: 0.14079
#
# Episode: 5500/25000 to 6000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.9s (18.57/s)
#     Loss: 0.07640
#     Accuracy: 0.80995
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60131, Loss: 0.13814
#
# Episode: 6000/25000 to 6500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 26.0s (19.26/s)
#     Loss: 0.06828
#     Accuracy: 0.83890
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.61238, Loss: 0.12405
#
# Episode: 6500/25000 to 7000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.9s (19.33/s)
#     Loss: 0.06164
#     Accuracy: 0.85907
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64769, Loss: 0.12057
#
# Episode: 7000/25000 to 7500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.4s (19.69/s)
#     Loss: 0.05583
#     Accuracy: 0.88085
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.64787, Loss: 0.11938
#
# Episode: 7500/25000 to 8000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.4s (19.66/s)
#     Loss: 0.05375
#     Accuracy: 0.88195
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.70437, Loss: 0.10424
#
# Episode: 8000/25000 to 8500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.6s (19.51/s)
#     Loss: 0.04449
# ...
#     Loss: 0.00982
#     Accuracy: 0.98493
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87056, Loss: 0.07063
#
# Episode: 17500/25000 to 18000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.2s (21.52/s)
#     Loss: 0.00918
#     Accuracy: 0.98655
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86750, Loss: 0.06722
#
# Episode: 18000/25000 to 18500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.3s (21.50/s)
#     Loss: 0.00878
#     Accuracy: 0.98660
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.89444, Loss: 0.06652
#
# Episode: 18500/25000 to 19000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.3s (21.43/s)
#     Loss: 0.00988
#     Accuracy: 0.98583
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87794, Loss: 0.06583
#
# Episode: 19000/25000 to 19500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.2s (21.53/s)
#     Loss: 0.00924
#     Accuracy: 0.98575
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.89363, Loss: 0.05933
#
# Episode: 19500/25000 to 20000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.5s (21.28/s)
#     Loss: 0.00813
#     Accuracy: 0.98770
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86781, Loss: 0.06948
#
# Episode: 20000/25000 to 20500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.5s (21.26/s)
#     Loss: 0.00854
#     Accuracy: 0.98685
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88062, Loss: 0.06980
#
# Episode: 20500/25000 to 21000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.7s (21.10/s)
#     Loss: 0.00790
#     Accuracy: 0.98823
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88481, Loss: 0.06590
#
# Episode: 21000/25000 to 21500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.4s (21.32/s)
#     Loss: 0.00750
#     Accuracy: 0.98910
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87375, Loss: 0.07290
#
# Episode: 21500/25000 to 22000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.3s (21.48/s)
#     Loss: 0.00661
#     Accuracy: 0.99118
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88025, Loss: 0.06985
#
# Episode: 22000/25000 to 22500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.4s (21.38/s)
#     Loss: 0.00849
#     Accuracy: 0.98583
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87463, Loss: 0.06593
#
# Episode: 22500/25000 to 23000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.7s (21.10/s)
#     Loss: 0.00717
#     Accuracy: 0.99050
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.88919, Loss: 0.06301
#
# Episode: 23000/25000 to 23500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.5s (21.29/s)
#     Loss: 0.00809
#     Accuracy: 0.98888
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86719, Loss: 0.06909
#
# Episode: 23500/25000 to 24000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.3s (21.44/s)
#     Loss: 0.00655
#     Accuracy: 0.99018
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86894, Loss: 0.07900
#
# Episode: 24000/25000 to 24500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.6s (20.36/s)
#     Loss: 0.00746
#     Accuracy: 0.98890
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.86450, Loss: 0.07679
#
# Episode: 24500/25000 to 25000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.5s (21.29/s)
#     Loss: 0.00670
#     Accuracy: 0.99015
# [I 2022-06-02 16:01:18,787] Trial 12 finished with value: 0.05811352807097137 and parameters: {'num_fc_layers': 3, 'num_units_fc_layer0': 256, 'num_units_fc_layer1': 256, 'num_units_fc_layer2': 32, 'num_lstm_layer_encoder': 2, 'num_units_lstm_encoder': 64, 'num_lstm_layer_relationnet': 2, 'num_units_lstm_relationnet': 128, 'learning_rate': 0.001014590458396494, 'learning_rate_schedule_rate': 8000}. Best is trial 8 with value: 0.05473549677990377.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.87581, Loss: 0.06733
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_13
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.4s (23.32/s)
#     Loss: 0.15047
#     Accuracy: 0.35555
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.41594, Loss: 0.14253
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.6s (23.10/s)
#     Loss: 0.12205
#     Accuracy: 0.59260
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.53181, Loss: 0.13897
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.7s (23.08/s)
#     Loss: 0.09110
#     Accuracy: 0.75745
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.58719, Loss: 0.13108
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.8s (22.95/s)
#     Loss: 0.07551
#     Accuracy: 0.81770
# [I 2022-06-02 16:03:08,855] Trial 13 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.66544, Loss: 0.13686
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_14
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 21.0s (23.82/s)
#     Loss: 0.17018
#     Accuracy: 0.20158
# [I 2022-06-02 16:03:35,137] Trial 14 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.27619, Loss: 0.15765
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_15
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.1s (18.45/s)
#     Loss: 0.16050
#     Accuracy: 0.20178
# [I 2022-06-02 16:04:09,660] Trial 15 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.20119, Loss: 0.16000
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_16
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 18.9s (26.46/s)
#     Loss: 0.15309
#     Accuracy: 0.34472
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.45825, Loss: 0.14530
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 18.9s (26.46/s)
#     Loss: 0.11283
#     Accuracy: 0.65427
# [I 2022-06-02 16:04:57,441] Trial 16 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.58200, Loss: 0.14910
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_17
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.4s (21.37/s)
#     Loss: 0.15607
#     Accuracy: 0.30875
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.40744, Loss: 0.14371
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.4s (21.36/s)
#     Loss: 0.11675
#     Accuracy: 0.62277
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.54194, Loss: 0.13133
#
# Episode: 1000/25000 to 1500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.5s (21.27/s)
#     Loss: 0.09346
#     Accuracy: 0.74303
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.57331, Loss: 0.12845
#
# Episode: 1500/25000 to 2000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 24.3s (20.57/s)
#     Loss: 0.08209
#     Accuracy: 0.79030
# [I 2022-06-02 16:06:56,205] Trial 17 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.60987, Loss: 0.12578
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_18
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.9s (17.90/s)
#     Loss: 0.16109
#     Accuracy: 0.20135
# [I 2022-06-02 16:07:31,495] Trial 18 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19894, Loss: 0.16000
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_19
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.2s (26.06/s)
#     Loss: 0.15275
#     Accuracy: 0.28885
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.34781, Loss: 0.14544
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 19.1s (26.11/s)
#     Loss: 0.14330
#     Accuracy: 0.40990
# [I 2022-06-02 16:08:20,125] Trial 19 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.45837, Loss: 0.14397
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_20
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 27.1s (18.44/s)
#     Loss: 0.15965
#     Accuracy: 0.21695
# [I 2022-06-02 16:08:54,527] Trial 20 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.19987, Loss: 0.16000
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_21
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.9s (20.96/s)
#     Loss: 0.15586
#     Accuracy: 0.25025
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.33856, Loss: 0.14536
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.9s (20.95/s)
#     Loss: 0.14889
#     Accuracy: 0.31720
# [I 2022-06-02 16:09:54,360] Trial 21 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.32650, Loss: 0.14367
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_22
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.8s (21.02/s)
#     Loss: 0.16073
#     Accuracy: 0.25308
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.37094, Loss: 0.14273
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.9s (20.91/s)
#     Loss: 0.14305
#     Accuracy: 0.41305
# [I 2022-06-02 16:10:54,033] Trial 22 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.48281, Loss: 0.14955
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_23
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.9s (19.30/s)
#     Loss: 0.15993
#     Accuracy: 0.24445
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.34450, Loss: 0.14482
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 25.8s (19.38/s)
#     Loss: 0.14775
#     Accuracy: 0.32867
# [I 2022-06-02 16:11:58,635] Trial 23 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.33156, Loss: 0.14699
#
# Initializing training...
#
#   Parameters accepted and set.
#   Feature encoder intialized, initial weights set.
#   Relation network intialized, initial weights set.
#   Optimizer & Learning Rate Scheduler initalized.
#   Created logging folder: tuning/run_24
#
# Training initalized.
#
#
# Start training...
#
# Episode: 0/25000 to 500/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 22.7s (21.98/s)
#     Loss: 0.15380
#     Accuracy: 0.29240
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.33019, Loss: 0.14788
#
# Episode: 500/25000 to 1000/25000
#   Training... |████████████████████████████████████████| 500/500 [100%] in 23.6s (21.16/s)
#     Loss: 0.15080
#     Accuracy: 0.29940
# [I 2022-06-02 16:12:56,112] Trial 24 pruned.
#   Validation with 200 Evaluation-Episodes. Accuracy: 0.34937, Loss: 0.14591
#
#
#
# #######################################################################
# ########################### FINISHED TUNING ###########################
# #######################################################################
#
#
#
# Tuning statistics:
#   Number of trials:  25
#   Number of pruned trials:  15
#   Number of complete trials:  10
#
# Best trial:
#   Run 8 with Loss 0.05473549677990377 at Episode 24500
#   Params:
#     num_fc_layers: 3
#     num_units_fc_layer0: 256
#     num_units_fc_layer1: 128
#     num_units_fc_layer2: 128
#     num_lstm_layer_encoder: 2
#     num_units_lstm_encoder: 16
#     num_lstm_layer_relationnet: 1
#     num_units_lstm_relationnet: 128
#     learning_rate: 0.0007093703723978738
#     learning_rate_schedule_rate: 8000

# %% [markdown]
# Zip and push tuning results to Google Drive.

# %%
push_zip('/content/tuning', gdrive + f'/results/tuning/{N_WAY}way-{K_SHOT}shot.zip')

with open(gdrive + f'/results/tuning/importances_{N_WAY}way-{K_SHOT}shot.pkl', 'wb') as handle:
    pickle.dump(importances, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Analyze the tuning run

# %% [markdown]
# Load and unpack tuning results from Google Drive.

# %%
os.system(f'cp -R /content/drive/MyDrive/ml_projects/STRHANGE/results/tuning/{N_WAY}way-{K_SHOT}shot.zip /content')
shutil.unpack_archive(f'{N_WAY}way-{K_SHOT}shot.zip', '/content')

with open(gdrive + f'/results/tuning/importances_{N_WAY}way-{K_SHOT}shot.pkl', 'rb') as handle:
  importances = pickle.load(handle)

# %% [markdown]
# Success of the tuning process is examined by analyzing the best values in each run and the training curves.

# %%
plot_tuning_history('tuning', 'eval_accuracy', 'Validations Accuracy', 'maximize')

# %%
plot_tuning_traincurves('tuning', 'eval_accuracy', 'Validations Accuracy', 'maximize', 15)

# %%
best_trials = tuning.trials_dataframe().nsmallest(5, 'value').transpose().drop(['number', 'datetime_start', 'datetime_complete'])

print(tabulate(best_trials, tablefmt = 'latex', headers=best_trials.columns, numalign="right", floatfmt=".2f"))
# Out:
# \begin{tabular}{llllll}
# \hline
#                                     & 8                      & 12                     & 9                      & 10                     & 4                      \\
# \hline
#  value                              & 0.05473549677990377    & 0.05811352807097137    & 0.059687086073681714   & 0.060377183398231865   & 0.06071784568950534    \\
#  duration                           & 0 days 00:21:23.320918 & 0 days 00:24:27.961999 & 0 days 00:24:29.727659 & 0 days 00:23:18.175133 & 0 days 00:26:07.984579 \\
#  params\_learning\_rate               & 0.0007093703723978738  & 0.001014590458396494   & 0.0005247570935712067  & 0.0033522050879260935  & 0.00038256351859052316 \\
#  params\_learning\_rate\_schedule\_rate & 8000                   & 8000                   & 7000                   & 10000                  & 3000                   \\
#  params\_num\_fc\_layers               & 3                      & 3                      & 3                      & 2                      & 3                      \\
#  params\_num\_lstm\_layer\_encoder      & 2                      & 2                      & 2                      & 1                      & 2                      \\
#  params\_num\_lstm\_layer\_relationnet  & 1                      & 2                      & 2                      & 1                      & 3                      \\
#  params\_num\_units\_fc\_layer0         & 256                    & 256                    & 256                    & 128                    & 16                     \\
#  params\_num\_units\_fc\_layer1         & 128.0                  & 256.0                  & 256.0                  & 128.0                  & 128.0                  \\
#  params\_num\_units\_fc\_layer2         & 128.0                  & 32.0                   & 32.0                   & nan                    & 256.0                  \\
#  params\_num\_units\_lstm\_encoder      & 16                     & 64                     & 64                     & 128                    & 16                     \\
#  params\_num\_units\_lstm\_relationnet  & 128                    & 128                    & 128                    & 256                    & 128                    \\
#  state                              & COMPLETE               & COMPLETE               & COMPLETE               & COMPLETE               & COMPLETE               \\
# \hline
# \end{tabular}

# %%
plot_traincurve('tuning/run_10', ['train_accuracy', 'eval_accuracy'], 'Accuracy')

# %%
plot_tuning_parameter_importance(importances)

# %% [markdown]
# ## Model selection

# %% [markdown]
# Select the final model (run an episode to stop) on the basis of the tuning analyses.

# %%
selected_run = 'run_10'
selected_episode = '13500'

# %% [markdown]
# # Model evaluation

# %% [markdown]
# Evaluate the model on unseen data.

# %%
conf_matrix, classification_report, accuracy = run_testing(num_testruns = 1000, samples_per_run = 32, run_dir = f'tuning/{selected_run}', episode = f'e{selected_episode}', test_classes = test_classes)

# %%
model_name = f'{N_WAY}-way_{K_SHOT}-sup'
path = os.path.join(gdrive, 'results', 'tests')

np.save(os.path.join(path, f'{model_name}_CM.npy'), conf_matrix)
classification_report.to_pickle(os.path.join(path, f'{model_name}_CR.pkl'))
np.save(os.path.join(path, f'{model_name}_ACC.npy'), accuracy)

# %% [markdown]
# Visualize Confusion Matrix

# %%
plot_conf_matrix (conf_matrix, test_classes, y_og)

# %% [markdown]
# Analyse Accuracy, Precision, Recall and F-Score.

# %%
print(f'Average Accuracy of the model on testdata {accuracy}\n')
print(f'Average Precision of the model on testdata {round(classification_report.Precision.mean(),3)}\n')
print(f'Average Recall of the model on testdata {round(classification_report.Recall.mean(),3)}\n')
print(f'Average F-Score of the model on testdata {round(classification_report.FScore.mean(),3)}\n')

print(tabulate(classification_report, tablefmt = 'latex', headers=classification_report.columns, numalign="right", floatfmt=".2f"))
# Out:
# Average Accuracy of the model on testdata 0.8881937499999999
#
# Average Precision of the model on testdata 0.888
#
# Average Recall of the model on testdata 0.878
#
# Average F-Score of the model on testdata 0.881
#
# \begin{tabular}{lrrr}
# \hline
#                &   Precision &   Recall &   FScore \\
# \hline
#  0 (0 \& 0)     &        0.94 &     0.99 &     0.97 \\
#  3 (0 \& 3)     &        0.91 &     0.94 &     0.95 \\
#  12 (0 \& 12)   &        0.94 &     0.97 &     0.96 \\
#  13 (0 \& 13)   &        0.98 &     0.97 &     0.94 \\
#  15 (0 \& 15)   &        0.95 &     0.90 &     0.93 \\
#  19 (0 \& 19)   &        0.91 &     0.93 &     0.92 \\
#  21 (0 \& 21)   &        0.96 &     0.89 &     0.92 \\
#  24 (0 \& 24)   &        0.97 &     0.96 &     0.97 \\
#  81 (3 \& 3)    &        0.75 &     0.78 &     0.77 \\
#  90 (3 \& 12)   &        0.94 &     0.97 &     0.96 \\
#  91 (3 \& 13)   &        0.89 &     0.90 &     0.89 \\
#  93 (3 \& 15)   &        0.79 &     0.71 &     0.75 \\
#  97 (3 \& 19)   &        0.78 &     0.78 &     0.78 \\
#  99 (3 \& 21)   &        0.83 &     0.74 &     0.78 \\
#  102 (3 \& 24)  &        0.85 &     0.79 &     0.82 \\
#  315 (12 \& 3)  &        0.91 &     0.93 &     0.92 \\
#  324 (12 \& 12) &        0.99 &     0.96 &     0.95 \\
#  325 (12 \& 13) &        0.98 &     0.97 &     0.94 \\
#  327 (12 \& 15) &        0.96 &     0.95 &     0.95 \\
#  331 (12 \& 19) &        0.94 &     0.98 &     0.96 \\
#  333 (12 \& 21) &        0.93 &     0.92 &     0.92 \\
#  336 (12 \& 24) &        0.95 &     0.94 &     0.94 \\
#  341 (13 \& 3)  &        0.89 &     0.91 &     0.90 \\
#  350 (13 \& 12) &        0.97 &     0.94 &     0.98 \\
#  351 (13 \& 13) &        0.96 &     0.97 &     0.93 \\
#  353 (13 \& 15) &        0.91 &     0.92 &     0.91 \\
#  357 (13 \& 19) &        0.90 &     0.98 &     0.94 \\
#  359 (13 \& 21) &        0.95 &     0.88 &     0.92 \\
#  362 (13 \& 24) &        0.95 &     0.91 &     0.93 \\
#  393 (15 \& 3)  &        0.80 &     0.82 &     0.81 \\
#  402 (15 \& 12) &        0.95 &     0.95 &     0.95 \\
#  403 (15 \& 13) &        0.87 &     0.92 &     0.89 \\
#  405 (15 \& 15) &        0.80 &     0.72 &     0.76 \\
#  409 (15 \& 19) &        0.75 &     0.78 &     0.76 \\
#  411 (15 \& 21) &        0.82 &     0.72 &     0.76 \\
#  414 (15 \& 24) &        0.87 &     0.81 &     0.84 \\
#  497 (19 \& 3)  &        0.73 &     0.85 &     0.78 \\
#  506 (19 \& 12) &        0.90 &     0.94 &     0.92 \\
#  507 (19 \& 13) &        0.85 &     0.97 &     0.91 \\
#  509 (19 \& 15) &        0.82 &     0.81 &     0.82 \\
#  513 (19 \& 19) &        0.72 &     0.86 &     0.78 \\
#  515 (19 \& 21) &        0.83 &     0.78 &     0.80 \\
#  518 (19 \& 24) &        0.83 &     0.80 &     0.82 \\
#  549 (21 \& 3)  &        0.86 &     0.77 &     0.81 \\
#  558 (21 \& 12) &        0.95 &     0.94 &     0.95 \\
#  559 (21 \& 13) &        0.95 &     0.88 &     0.91 \\
#  561 (21 \& 15) &        0.90 &     0.76 &     0.82 \\
#  565 (21 \& 19) &        0.85 &     0.78 &     0.81 \\
#  567 (21 \& 21) &        0.91 &     0.73 &     0.81 \\
#  570 (21 \& 24) &        0.90 &     0.80 &     0.85 \\
#  627 (24 \& 3)  &        0.82 &     0.87 &     0.85 \\
#  636 (24 \& 12) &        0.96 &     0.94 &     0.98 \\
#  637 (24 \& 13) &        0.91 &     0.94 &     0.95 \\
#  639 (24 \& 15) &        0.85 &     0.87 &     0.86 \\
#  643 (24 \& 19) &        0.82 &     0.92 &     0.87 \\
#  645 (24 \& 21) &        0.87 &     0.83 &     0.85 \\
#  648 (24 \& 24) &        0.92 &     0.92 &     0.92 \\
# \hline
# \end{tabular}

# %% [markdown]
# Test the model on origial Jester-Data.

# %%
conf_matrix, classification_report, accuracy = run_testing(num_testruns = 500, samples_per_run = 32, run_dir = f'tuning/{selected_run}', episode = f'e{selected_episode}', test_classes = jester_comp_classes, split = 'jester')

# %%
print(f'Average Accuracy of the model on Jester: {accuracy}\n')
# Out:
# Average Accuracy of the model on Jester: 0.9147921

# %% [markdown]
# # Model saving

# %% [markdown]
# Save the best model to the Google Drive.

# %%
push_model_to_gdrive(f'tuning/{selected_run}', f'e{selected_episode}',f'{N_WAY}way-{K_SHOT}shot')
